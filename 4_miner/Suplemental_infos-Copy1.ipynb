# %%
sys.executable
# Out:
# '/usr/bin/python'

# %%
import os
import json
import pymongo
import musicbrainzngs
import arrow
from datetime import datetime
from pymongo import MongoClient
from collections import defaultdict
from dateutil import parser

# %%
# setup mongo
client = MongoClient()
db = client["bandstour"]
bandsintown =  db["bandsintown"]

# source data
DATA_FOLDER = "data/labels"
countMBID = 0
countNAME = 0
count = 0
# date parsing
DATETIME_FORMAT = '%Y-%m-%dT%H:%M:%S'
DATETIME_FORMAT_FOR_MSBNZ ='%Y-%m-%d'
# init label_db_retrieval
labels_aliases ={}
#retrieve label for each artist before a tour starts
#i.e what is the album previously to the first year
for artist in db.minedArtists.find("Deerhoof") :
                    print artist["name"]
    
                    #print db.minedArtists[artist]
                    #print artist
                    labels_dict= defaultdict(list)
                    labels_dict["id"]=[]

                    if  artist["mbid"] is ( None ) :
                        print ("NOMBID for",artist["name"])

                    else:
                     if  bool(artist["mbid"]) is ( False ) :
                      print ("NOMBID2 for",artist["name"])

                     else:
                      print "aartist_mbid", artist["mbid"]
                      try:
                        artist["releases"]=(musicbrainzngs.browse_releases( artist["mbid"], release_type=["album"], includes=["labels"] ))
                            
                                  
                        #print "...."
                        #print artist["release_groups"]
                        key= 0
                        for release in  artist["releases"]["release-list"]:
                            #print release
                            if  release.has_key("release-event-list"):
                                #print "artist_name:",artist["name"]
                                #print "albumtitle:",release["title"]
                                #print "albumid:",release["id"]
                                #print "label-list",release["label-info-list"]
                                #print "releaseLBL",release["label-info-list"]
                                if not release["label-info-list"]:
                                    print "pppppppppppppp"
                                
                                else:
                                 if release["label-info-list"][0].has_key('label'):
                                  for label in release["label-info-list"]:
                                    #WE NEED TO TEST HERE
                                    #print "label:",label["label"]["sort-name"]
                                    #print "labelid:",label
                                    
#WE CREATE A DICTIONNARY WITH OUR FIELDS, WITH FORMAT
                                    if label.has_key('label'):
                                     if label["label"]["id"] not in labels_dict["labids"]:
                                        labels_dict["labids"].append(label["label"]["id"])
                                        labels_dict[label["label"]["id"]]={}

                                        labels_dict[label["label"]["id"]]["label_name"]=label["label"]["sort-name"]
                                        labels_dict[label["label"]["id"]]["label_id" ]=label["label"]["id"]
#WE Build the label aliases tables here so that all labels have their relationships##
                                        if label["label"]["id"] not in labels_aliases:
                                            labels_aliases[label["label"]["id"]] = musicbrainzngs.get_label_by_id(label["label"]["id"], includes=["aliases", "annotation", "area-rels", "label-rels", "place-rels"])
                                        #print "labels_aliases",labels_aliases
                                     labels_dict[label["label"]["id"]][str(key)]={}
                                    #print key
                                     labels_dict[label["label"]["id"]][str(key)]["album_id"]=release["id"]
                                     labels_dict[label["label"]["id"]][str(key)]["album_title"]=release["title"]
                                     releDate=release["release-event-list"][0]
                                #print "releDate", release["release-event-list"][0]
                                     if  releDate.has_key("date"):
                                        dateRel=arrow.get(releDate["date"])
                                        #print "date:", dateRel.strftime('%Y-%m-%d')
                                        labels_dict[label["label"]["id"]][str(key)]["album_date"]=dateRel.strftime('%Y-%m-%d')
                                     key = key +1
                                 else:
                                    print "NORELEASEDATE2"
                                    #key = key +1
                            #else:
                                #key = key +1
                                #print "NORELEASEDATE"
#NOW we make a nice lightweight object to push to mongo
                        labels_dict["name"]=artist["name"]
                        print labels_dict["name"],'\r\n'
                        db.labels_dict_per_artist.update({'myid': artist["name"] } ,labels_dict, upsert=True, multi=False)
                      except  musicbrainzngs.ResponseError:
                        print "oups",artist["name"]

                #with open(os.path.join(DATA_FOLDER,artist["name"],".json"), 'w') as outfile:
                             #   json.dump(labels_dict, outfile)
                            #db.minedArtists.artist.insert_one(labels_dict)
#with open(os.path.join(DATA_FOLDER,"label_equiv_table.json"), 'w') as outfile:
 #                               json.dump(labels_aliases, outfile)
print labels_aliases,'\r\n\r\n\r\n'
# Out:
# Николай Луганский
# aartist_mbid cd909fcb-7c80-4988-9b91-930c06d18d27
# pppppppppppppp
# Николай Луганский
#
# serafine
# ('NOMBID for', u'serafine')
# ÖRFAZ
# ('NOMBID for', u'\xd6RFAZ')
# zilselance
# ('NOMBID for', u'zilselance')
# twenty one pilots
# ('NOMBID for', u'twenty one pilots')
# tigran
# ('NOMBID for', u'tigran')
# the Shrine
# ('NOMBID for', u'the Shrine')
# the Bottlemen
# ('NOMBID for', u'the Bottlemen')
# rødhåd
# ('NOMBID for', u'r\xf8dh\xe5d')
# pastor
# ('NOMBID for', u'pastor')
# openightmare
# ('NOMBID for', u'openightmare')
# noJazz
# aartist_mbid 710e4f10-55ee-4328-8270-672ab64031f8
# pppppppppppppp
# pppppppppppppp
# noJazz
#
# maracujah
# ('NOMBID for', u'maracujah')
# krAzy spAce
# ('NOMBID for', u'krAzy spAce')
# jeanette berger
# ('NOMBID for', u'jeanette berger')
# hiks
# ('NOMBID for', u'hiks')
# dj yannick robyns
# ('NOMBID for', u'dj yannick robyns')
# dean
# aartist_mbid 9255340c-8a9d-4822-8f4a-941ecdd20b83
# pppppppppppppp
# dean
#
# belin
# ('NOMBID for', u'belin')
# anka
# ('NOMBID for', u'anka')
# alan
# aartist_mbid dded0177-e235-474e-8529-a812b89f806c
# pppppppppppppp
# alan
#
# a Tribute To ABBA
# ('NOMBID for', u'a Tribute To ABBA')
# Zachary Richard
# aartist_mbid 2b1999ba-5256-4e9b-84be-4a23b9283e84
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Zachary Richard
#
# ZUDAKABASS
# ('NOMBID for', u'ZUDAKABASS')
# ZAM'S
# aartist_mbid 15b30991-0bbd-430e-9ebb-134b141e61e4
# pppppppppppppp
# ZAM'S
#
# Yutaka Shiina
# ('NOMBID for', u'Yutaka Shiina')
# Yoann Kempst
# ('NOMBID for', u'Yoann Kempst')
# bomba estereo
# ('NOMBID for', u'bomba estereo')
# Zoufris Maracas
# ('NOMBID for', u'Zoufris Maracas')
# Zimmer
# aartist_mbid e6de1f3b-6484-491c-88dd-6d619f142abc
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Zimmer
#
# Zebrahead
# aartist_mbid 4df5d35b-a9d4-4d4f-91f6-bae55693de31
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Zebrahead
#
# Youthman
# ('NOMBID for', u'Youthman')
# Youssef
# aartist_mbid dd02e5d3-8022-4cc7-a10d-7ada9031b545
# Youssef
#
# Young Marble Giants
# aartist_mbid 3d113367-769f-4200-9ff8-e19d47def451
# pppppppppppppp
# Young Marble Giants
#
# You said strange
# ('NOMBID for', u'You said strange')
# Year of No Light
# aartist_mbid 2a1a36b0-d465-4941-9658-2c67cdfb9bba
# pppppppppppppp
# Year of No Light
#
# Yaron Herman
# aartist_mbid fe018ccc-1943-4287-ac8b-2681e259e0f5
# pppppppppppppp
# Yaron Herman
#
# Yannick Robert
# ('NOMBID for', u'Yannick Robert')
# Yaniss Odua
# aartist_mbid c332d8d7-9f93-40eb-891b-05d060850d65
# pppppppppppppp
# pppppppppppppp
# Yaniss Odua
#
# Ya-Ourt
# ('NOMBID for', u'Ya-Ourt')
# YELLI YELLI
# ('NOMBID for', u'YELLI YELLI')
# Xavier Rudd
# aartist_mbid 6689a626-4de7-41d5-9ec3-5a289472a9e2
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Xavier Rudd
#
# XY
# ('NOMBID for', u'XY')
# X-TV
# ('NOMBID for', u'X-TV')
# Worms Eat Her
# ('NOMBID for', u'Worms Eat Her')
# Woodini
# ('NOMBID for', u'Woodini')
# Wombo Orchestra
# ('NOMBID for', u'Wombo Orchestra')
# Witches
# aartist_mbid f586a74f-55b4-48f6-93fa-220319c7d80f
# Witches
#
# Wine
# aartist_mbid 3631115d-a560-421a-b2be-5c41ed72024d
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Wine
#
# Will Buck
# ('NOMBID for', u'Will Buck')
# Who's Panda
# ('NOMBID for', u"Who's Panda")
# Where is Stanley
# ('NOMBID for', u'Where is Stanley')
# Wedge
# aartist_mbid a5b93913-10ae-4ff6-83d1-839031dd0a77
# Wedge
#
# We Project
# ('NOMBID for', u'We Project')
# Way Of Changes
# ('NOMBID for', u'Way Of Changes')
# Water Mane
# ('NOMBID for', u'Water Mane')
# Wapalek
# ('NOMBID for', u'Wapalek')
# Walk Off the Earth
# ('NOMBID for', u'Walk Off the Earth')
# WEEKEND AFFAIR
# ('NOMBID for', u'WEEKEND AFFAIR')
# WALKO (Afrobeat)
# ('NOMBID for', u'WALKO (Afrobeat)')
# Vulvectomy
# aartist_mbid bbe5bd6d-0971-4fc8-a76c-9acc2ceee3e9
# Vulvectomy
#
# Volin
# ('NOMBID for', u'Volin')
# Vital Remains
# aartist_mbid 39977a2d-659a-43e6-b2ad-0c33687624f7
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Vital Remains
#
# Virgin Snatch
# aartist_mbid 81a4f87a-cb82-45fc-a21a-dbce8a421dc6
# pppppppppppppp
# Virgin Snatch
#
# Vinicio Capossela
# aartist_mbid 5115929f-f133-47b4-bf1c-8a0df582ce23
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Vinicio Capossela
#
# Vincent
# aartist_mbid b828f310-037b-442e-94aa-6bd2bd8ff047
# Vincent
#
# Viken Arman
# ('NOMBID for', u'Viken Arman')
# Vidal Benjamin
# ('NOMBID for', u'Vidal Benjamin')
# Vianney
# ('NOMBID for', u'Vianney')
# Verveine
# ('NOMBID for', u'Verveine')
# Veronica & The Red Wine Serenaders
# ('NOMBID for', u'Veronica & The Red Wine Serenaders')
# Velasquez
# ('NOMBID for', u'Velasquez')
# Varekai
# ('NOMBID for', u'Varekai')
# Valley of the Sun
# ('NOMBID for', u'Valley of the Sun')
# Valdes
# aartist_mbid 4aa7c152-8c2b-4879-b0c7-817456423f22
# Valdes
#
# VS Music-com
# ('NOMBID for', u'VS Music-com')
# VINTAGE TROUBLE
# ('NOMBID for', u'VINTAGE TROUBLE')
# VADEL
# ('NOMBID for', u'VADEL')
# Upon A Burning Body
# ('NOMBID for', u'Upon A Burning Body')
# United Music Records
# ('NOMBID for', u'United Music Records')
# Uncle Joe
# aartist_mbid f94d6b64-f5bb-4636-952b-0b931c24ca2c
# pppppppppppppp
# Uncle Joe
#
# Ulster Page
# ('NOMBID for', u'Ulster Page')
# UNSU
# ('NOMBID for', u'UNSU')
# U Stone
# ('NOMBID for', u'U Stone')
# TwoSixOnes
# ('NOMBID for', u'TwoSixOnes')
# Tube
# aartist_mbid 9b1da1cf-e620-4de2-a54d-356541a6a2d7
# Tube
#
# Try $ Again
# ('NOMBID for', u'Try $ Again')
# Überkeine
# ('NOMBID for', u'\xdcberkeine')
# Turzi
# aartist_mbid 869ecd86-35e7-409c-9813-28efb8638904
# Turzi
#
# Trivium
# aartist_mbid 1f5ff245-2837-4d4a-a609-e93e544478c3
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Trivium
#
# Trio BASSMA
# ('NOMBID for', u'Trio BASSMA')
# Travis Scott
# ('NOMBID for', u'Travis Scott')
# Toxic Waste
# aartist_mbid ae753640-8cef-44a2-bccb-98ad2d24267b
# Toxic Waste
#
# Totó La Momposina
# aartist_mbid 6904c849-97ab-4bf2-af51-467e8dd98ec9
# Totó La Momposina
#
# Tony Melvil
# ('NOMBID for', u'Tony Melvil')
# Tony Allen
# aartist_mbid 7d4a5895-e40e-47ed-b1f3-74224fe667d4
# Tony Allen
#
# Tonga
# ('NOMBID for', u'Tonga')
# Tommy Jacob
# ('NOMBID for', u'Tommy Jacob')
# Tom McRae
# aartist_mbid 9f5a87ec-0201-45ba-8b03-3b9e0b50a112
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Tom McRae
#
# Tom Demac
# aartist_mbid c63ab5df-3be5-42c1-b7f0-6d090c7408c9
# Tom Demac
#
# Todd Terje
# aartist_mbid a0cded3a-4ca3-4ddb-8e46-ed9037f30aea
# NORELEASEDATE2
# Todd Terje
#
# To be confirmed
# ('NOMBID for', u'To be confirmed')
# Titi Robin
# aartist_mbid b8872c45-bbb5-448d-a438-8e3956258715
# pppppppppppppp
# pppppppppppppp
# Titi Robin
#
# Time for T.
# ('NOMBID for', u'Time for T.')
# Thurisaz
# aartist_mbid 54e8d246-554a-41ff-9b83-ad4a48377f9c
# Thurisaz
#
# Thorsten Havener
# ('NOMBID for', u'Thorsten Havener')
# Thomas Ngijol
# ('NOMBID for', u'Thomas Ngijol')
# Thomas Enhco
# aartist_mbid e5cd692d-e3ea-4f89-8635-abf577f45f53
# pppppppppppppp
# Thomas Enhco
#
# Things Of Life
# ('NOMBID for', u'Things Of Life')
# 恩田晃
# aartist_mbid 68987424-7c3e-458e-a79a-736a4883c9d5
# 恩田晃
#
# Արամ Խաչատրյան
# aartist_mbid fa25cd1f-beeb-4718-b4bb-d3da4f53539f
# Արամ Խաչատրյան
#
# Στέλιος Πετράκης
# aartist_mbid fdd6d721-1748-4b0d-941e-bc7c6e3f29f0
# Στέλιος Πετράκης
#
# Élodie Frégé
# aartist_mbid 8cda32b5-1447-4ded-8a0e-f1cf8e6b3480
# Élodie Frégé
#
# xdb
# ('NOMBID for', u'xdb')
# vendome
# ('NOMBID for', u'vendome')
# tlr
# ('NOMBID for', u'tlr')
# the autumn art festival
# ('NOMBID for', u'the autumn art festival')
# the Innocent Criminals
# ('NOMBID for', u'the Innocent Criminals')
# steve gunn
# ('NOMBID for', u'steve gunn')
# sean360x
# ('NOMBID for', u'sean360x')
# pianiste
# ('NOMBID for', u'pianiste')
# ordoeuvre
# ('NOMBID for', u'ordoeuvre')
# ochoa
# ('NOMBID for', u'ochoa')
# muramasa
# ('NOMBID for', u'muramasa')
# midnight sorrow
# ('NOMBID for', u'midnight sorrow')
# la dame blanche
# aartist_mbid d3a4de9a-5931-46de-9aca-56aed2a3ef48
# pppppppppppppp
# la dame blanche
#
# julien D aka Smither
# ('NOMBID for', u'julien D aka Smither')
# hollander
# aartist_mbid e057bfca-c278-4337-abd5-b7648d015d98
# pppppppppppppp
# hollander
#
# gabo lora
# ('NOMBID for', u'gabo lora')
# dypingoos
# ('NOMBID for', u'dypingoos')
# dj emerson
# ('NOMBID for', u'dj emerson')
# dKmiKe
# ('NOMBID for', u'dKmiKe')
# bird
# aartist_mbid 7dafc8b7-8d46-49b7-bc48-558b1fd181e9
# NORELEASEDATE2
# NORELEASEDATE2
# NORELEASEDATE2
# NORELEASEDATE2
# NORELEASEDATE2
# NORELEASEDATE2
# pppppppppppppp
# NORELEASEDATE2
# pppppppppppppp
# pppppppppppppp
# bird
#
# antropofago
# ('NOMBID for', u'antropofago')
# alto clark
# ('NOMBID for', u'alto clark')
# [yet]
# ('NOMBID for', u'[yet]')
# Zenker Brothers
# ('NOMBID for', u'Zenker Brothers')
# Zargenbruch
# ('NOMBID for', u'Zargenbruch')
# Zahra
# ('NOMBID for', u'Zahra')
# Za:im
# ('NOMBID for', u'Za:im')
# ZEBRA KATZ
# ('NOMBID for', u'ZEBRA KATZ')
# Yves Duteil
# aartist_mbid b8fb054b-86c9-4c6b-8bb1-d1b088c46e2c
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# NORELEASEDATE2
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Yves Duteil
#
# Yuksek
# aartist_mbid d6285d95-8ee1-4de2-8ceb-ff90098ab1d1
# Yuksek
#
# Young Thug
# ('NOMBID for', u'Young Thug')
# Youcef
# aartist_mbid b4c931b8-0577-4e66-94f8-76b988e5ead3
# Youcef
#
# Yonathan AVISHAI
# ('NOMBID for', u'Yonathan AVISHAI')
# Yilian Canizares
# ('NOMBID for', u'Yilian Canizares')
# Years & Years
# ('NOMBID for', u'Years & Years')
# Yasmin Shah
# ('NOMBID for', u'Yasmin Shah')
# Yannick
# aartist_mbid 0f51b7d8-50d8-4703-918b-37e91bb53297
# Yannick
#
# Yael Naim
# aartist_mbid def226b0-7990-4b38-ab1a-7740461844dc
# pppppppppppppp
# Yael Naim
#
# YOUR OWN FILM
# ('NOMBID for', u'YOUR OWN FILM')
# Xanthoula Dakovanou et l'Ensemble Anassa
# ('NOMBID for', u"Xanthoula Dakovanou et l'Ensemble Anassa")
# XAVIER RUDD & THE UNITED NATIONS
# ('NOMBID for', u'XAVIER RUDD & THE UNITED NATIONS')
# Wyld
# aartist_mbid dc94e943-0aec-410a-b4e9-c882d7b6fc59
# Wyld
#
# Worakls
# ('NOMBID for', u'Worakls')
# Wood
# aartist_mbid f48cde2f-e9a5-4ae3-8a2b-b9adaed2296e
# pppppppppppppp
# Wood
#
# Wo Fat
# aartist_mbid 78998e4b-fc1d-4f87-bf4b-c6f3ca82a77a
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Wo Fat
#
# Winston
# aartist_mbid f91adf16-cc9e-4b0e-8f16-d59a788a74c9
# Winston
#
# Willi Williams
# aartist_mbid 14f03e90-a90c-4579-8faf-5296d716c3a7
# pppppppppppppp
# Willi Williams
#
# Why (FR)
# ('NOMBID for', u'Why (FR)')
# White Crocodile
# ('NOMBID for', u'White Crocodile')
# Weval
# ('NOMBID for', u'Weval')
# Wehrmacht
# aartist_mbid ee1eb273-e040-42ca-a076-c02faedb378b
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Wehrmacht
#
# We Will Meet Again
# ('NOMBID for', u'We Will Meet Again')
# We Have Band
# aartist_mbid b83b1cc7-38ea-4a6c-bd87-9853f0034fab
# We Have Band
#
# Wayne McGregor
# ('NOMBID for', u'Wayne McGregor')
# Wavesonik
# ('NOMBID for', u'Wavesonik')
# Washington Dead Cats
# aartist_mbid f246422f-1ed4-4621-9955-5ae91efae895
# pppppppppppppp
# pppppppppppppp
# Washington Dead Cats
#
# Wad Ad
# ('NOMBID for', u'Wad Ad')
# WBA Entertainment
# ('NOMBID for', u'WBA Entertainment')
# Véronique Sanson
# aartist_mbid f1dc86d6-9f45-4736-8884-7fcafbccd876
# Véronique Sanson
#
# Volumes
# aartist_mbid 9d397404-907d-4355-b5d6-299bae93f6d9
# Volumes
#
# Visionist
# ('NOMBID for', u'Visionist')
# Violetta Live
# ('NOMBID for', u'Violetta Live')
# Vincent Peirani
# ('NOMBID for', u'Vincent Peirani')
# Villanova
# aartist_mbid 0b276f0a-a318-4cdf-9654-e7dd42045e5c
# Villanova
#
# Viet Cong
# ('NOMBID for', u'Viet Cong')
# Vestiges
# ('NOMBID for', u'Vestiges')
# Vertical
# aartist_mbid eeb9d0c0-6794-4284-b8ed-9117f8e3288c
# Vertical
#
# Venice Beach
# ('NOMBID for', u'Venice Beach')
# Valeriane
# ('NOMBID for', u'Valeriane')
# zuuma
# ('NOMBID for', u'zuuma')
# Vibronics
# aartist_mbid 0f43b78a-575b-4bd1-b538-840c474800aa
# Vibronics
#
# Varoslav
# ('NOMBID for', u'Varoslav')
# Vandal
# aartist_mbid f4bd6762-58c4-4db9-b053-c4fecccb383a
# Vandal
#
# Vaguement la Jungle
# aartist_mbid 9092b520-1fa0-458d-accf-0aa810af526b
# pppppppppppppp
# pppppppppppppp
# Vaguement la Jungle
#
# VIP
# aartist_mbid b3bc83ce-9520-4884-85c7-8c4222d5ae40
# VIP
#
# VANUPIE
# ('NOMBID for', u'VANUPIE')
# Unknown Mortal Orchestra
# ('NOMBID for', u'Unknown Mortal Orchestra')
# Unibox
# ('NOMBID for', u'Unibox')
# Uncle Acid
# ('NOMBID for', u'Uncle Acid ')
# Ubikar Musique
# ('NOMBID for', u'Ubikar Musique')
# U2 France Info
# ('NOMBID for', u'U2 France Info')
# Tyler, The Creator
# ('NOMBID for', u'Tyler, The Creator')
# Tutti
# ('NOMBID for', u'Tutti')
# Turbo Turbo
# ('NOMBID for', u'Turbo Turbo')
# Trypod
# ('NOMBID for', u'Trypod')
# Tropkillaz
# ('NOMBID for', u'Tropkillaz')
# Triptykon
# ('NOMBID for', u'Triptykon')
# Trio JMK Officiel
# ('NOMBID for', u'Trio JMK Officiel')
# Tremonti
# ('NOMBID for', u'Tremonti')
# Trama
# aartist_mbid a9336489-09b2-4188-8c66-aa1a4a26a761
# Trama
#
# Torb
# ('NOMBID for', u'Torb')
# Tony Bennett & Lady Gaga
# ('NOMBID for', u'Tony Bennett & Lady Gaga')
# TonTon
# ('NOMBID for', u'TonTon')
# Tom Wardle
# ('NOMBID for', u'Tom Wardle')
# Tom Frager
# aartist_mbid 74a48e30-37f9-40fb-a30f-116c83f1e773
# pppppppppppppp
# Tom Frager
#
# Tom Arthurs
# aartist_mbid ac585659-54d1-47f3-9c87-1cdf8bb50712
# Tom Arthurs
#
# Toi et  Moi
# ('NOMBID for', u'Toi et  Moi')
# Toby Rost
# ('NOMBID for', u'Toby Rost')
# Titus Andronicus
# aartist_mbid d38c47f6-d9bb-4a77-aaea-df53a6616a68
# Titus Andronicus
#
# Tina May
# aartist_mbid cebc70a9-512b-4922-8481-c977b1d7c854
# pppppppppppppp
# Tina May
#
# Tildon Krautz
# ('NOMBID for', u'Tildon Krautz')
# Thylacine
# ('NOMBID for', u'Thylacine')
# Thousand
# aartist_mbid fcb651e5-78ff-4b44-8e07-5a1aa1be1ba4
# Thousand
#
# Thomas Schoeffler Jr.
# ('NOMBID for', u'Thomas Schoeffler Jr.')
# Thomas Fersen
# aartist_mbid 083a443a-dcba-4d48-aa62-fda1f130002f
# Thomas Fersen
#
# Thomas BRAMERIE
# ('NOMBID for', u'Thomas BRAMERIE')
# Theorist OFC
# ('NOMBID for', u'Theorist OFC')
# The Wombats
# aartist_mbid e105c272-b5d7-4135-82ef-d60bded54345
# The Wombats
#
# The Wildabouts
# ('NOMBID for', u'The Wildabouts')
# The Wedding Present
# aartist_mbid 707622da-475f-48e1-905d-248718df6521
# pppppppppppppp
# pppppppppppppp
# NORELEASEDATE2
# pppppppppppppp
# pppppppppppppp
# The Wedding Present
#
# The Wanton Bishops
# ('NOMBID for', u'The Wanton Bishops')
# The Vintage Caravan
# ('NOMBID for', u'The Vintage Caravan')
# The Toure Raichel Collective
# ('NOMBID for', u'The Toure Raichel Collective')
# The Tallest Man on Earth
# aartist_mbid 7e35659f-f3bb-4c28-bcf5-47bd5cfa2bca
# pppppppppppppp
# The Tallest Man on Earth
#
# The Sunvizors
# ('NOMBID for', u'The Sunvizors')
# The Steam Dream
# ('NOMBID for', u'The Steam Dream')
# The Souljazz Orchestra
# aartist_mbid 453dab0c-aa5f-4091-bf58-64dead0d06b8
# The Souljazz Orchestra
#
# ★ DJ MISS ROXX ★
# ('NOMBID for', u'\u2605 DJ MISS ROXX \u2605')
# Фаррелл Уильямс
# ('NOMBID for', u'\u0424\u0430\u0440\u0440\u0435\u043b\u043b \u0423\u0438\u043b\u044c\u044f\u043c\u0441')
# Μαρία Φαραντούρη
# aartist_mbid 9e585bf7-feb0-4960-9b6a-eefe3ae6a61e
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Μαρία Φαραντούρη
#
# Ø L T E N
# ('NOMBID for', u'\xd8 L T E N')
# xa
# ('NOMBID for', u'xa')
# undobar
# ('NOMBID for', u'undobar')
# tite
# ('NOMBID for', u'tite')
# the Tips
# ('NOMBID for', u'the Tips')
# the Family Stone
# ('NOMBID for', u'the Family Stone')
# sayCeT
# aartist_mbid 1a7bd36d-0547-409d-83f2-2a815d55ddcd
# sayCeT
#
# photograph
# ('NOMBID for', u'photograph')
# ophélie mercury
# ('NOMBID for', u'oph\xe9lie mercury')
# noZen
# ('NOMBID for', u'noZen')
# mr statik
# ('NOMBID for', u'mr statik')
# michael valeanu
# ('NOMBID for', u'michael valeanu')
# mademoiselle Théodore
# ('NOMBID for', u'mademoiselle Th\xe9odore')
# kravitz
# ('NOMBID for', u'kravitz')
# john osborn
# ('NOMBID for', u'john osborn')
# hindi
# ('NOMBID2 for', u'hindi')
# fatras
# ('NOMBID for', u'fatras')
# djruffneck
# ('NOMBID for', u'djruffneck')
# dj PM
# ('NOMBID for', u'dj PM')
# dDamage
# aartist_mbid a2d15e23-1bcb-45b5-8d3b-893f75274ab4
# pppppppppppppp
# dDamage
#
# biga ranx
# ('NOMBID for', u'biga ranx')
# antiloops
# ('NOMBID for', u'antiloops')
# alexandre astier
# ('NOMBID for', u'alexandre astier')
# a-ha
# aartist_mbid 7364dea6-ca9a-48e3-be01-b44ad0d19897
# pppppppppppppp
# pppppppppppppp
# a-ha
#
# Zu
# aartist_mbid 46541c29-e1d4-4015-91e8-6ca7b5e6fb9b
# pppppppppppppp
# Zu
#
# Zizor
# ('NOMBID for', u'Zizor')
# Zef
# ('NOMBID for', u'Zef')
# Zappa Plays Zappa
# aartist_mbid fcebdabe-319f-4690-8827-c8fac63b1b80
# Zappa Plays Zappa
#
# Zachary Richard- Official
# ('NOMBID for', u'Zachary Richard- Official')
# ZZ Top
# aartist_mbid a81259a0-a2f5-464b-866e-71220f2739f1
# pppppppppppppp
# ZZ Top
#
# ZAZ
# ('NOMBID for', u'ZAZ')
# Yseult
# ('NOMBID for', u'Yseult')
# Youssef Dhafer
# ('NOMBID for', u'Youssef Dhafer')
# Young Rebel Set
# aartist_mbid 7b2aeb3f-c51f-4b35-8f38-54bdbab7a8a9
# Young Rebel Set
#
# You're Next Records
# ('NOMBID for', u"You're Next Records")
# Yom
# aartist_mbid 423ab89d-fec4-4d10-a5d0-606d83258ab2
# pppppppppppppp
# Yom
#
# Yes
# ('NOMBID for', u'Yes ')
# Years
# aartist_mbid ba535289-8407-4642-9b00-e7973458cbcb
# Years
#
# Yasiin Bey
# ('NOMBID for', u'Yasiin Bey')
# Yannick Robyns
# ('NOMBID for', u'Yannick Robyns')
# Yann
# ('NOMBID for', u'Yann')
# Yael
# ('NOMBID for', u'Yael')
# YEMAYA LA BANDA
# ('NOMBID for', u'YEMAYA LA BANDA')
# Xtreme Fest
# ('NOMBID for', u'Xtreme Fest')
# Xandria
# aartist_mbid 656a0800-3a2b-47ed-a3ff-1e2908fdd2ff
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Xandria
#
# X-Y
# ('NOMBID for', u'X-Y')
# WonderSoul
# ('NOMBID for', u'WonderSoul')
# Witchsmeller Pursuivant
# aartist_mbid 0e721e45-cb62-4631-b9ef-94b76c768d7c
# Witchsmeller Pursuivant
#
# Winnipeg
# ('NOMBID for', u'Winnipeg')
# Vérane
# ('NOMBID for', u'V\xe9rane')
# Vitrolles Sun Festival
# ('NOMBID for', u'Vitrolles Sun Festival')
# Wu-Tang Clan
# aartist_mbid 0febdcf7-4e1f-4661-9493-b40427de2c13
# pppppppppppppp
# Wu-Tang Clan
#
# Woods
# aartist_mbid 42a1253e-0efc-45e8-b627-ff802fb9e9ee
# Woods
#
# Williams
# aartist_mbid 5b95b2d4-67fd-4158-ada9-fc70e1a493db
# Williams
#
# Will Saul
# aartist_mbid be7eebdd-a63b-462b-9f38-96bd6502d14b
# Will Saul
#
# WhoMadeWho
# aartist_mbid e731ab08-45c4-4e98-a1e4-7a16462c9cfb
# pppppppppppppp
# WhoMadeWho
#
# Whisper of Death
# ('NOMBID for', u'Whisper of Death')
# Weltend
# ('NOMBID for', u'Weltend')
# Wehbba
# aartist_mbid e04887f6-78ce-4164-859b-7de28ae6f7c0
# Wehbba
#
# We Were Promised Jetpacks
# aartist_mbid 8f0e0596-5a39-4bd5-9dfa-f2b12030ffdc
# We Were Promised Jetpacks
#
# We Are the City
# ('NOMBID for', u'We Are the City')
# Wayne Escoffery
# ('NOMBID for', u'Wayne Escoffery')
# Wati B
# ('NOMBID for', u'Wati B')
# Wardruna
# aartist_mbid 91136bf7-3b12-4ae5-b93b-eddb9e561dfb
# Wardruna
#
# Walk The Moon
# ('NOMBID for', u'Walk The Moon')
# WINSTON McANUFF & FIXI
# ('NOMBID for', u'WINSTON McANUFF & FIXI')
# WANG RAMIREZ
# ('NOMBID for', u'WANG RAMIREZ')
# Våld
# ('NOMBID for', u'V\xe5ld')
# Volk
# ('NOMBID for', u'Volk')
# Virginie Teychené
# ('NOMBID for', u'Virginie Teychen\xe9')
# Violetta
# ('NOMBID for', u'Violetta')
# Vincent Jourde
# ('NOMBID for', u'Vincent Jourde')
# Viktorija Gečytė
# ('NOMBID for', u'Viktorija Ge\u010dyt\u0117')
# Vide Grenier Brass Band
# ('NOMBID for', u'Vide Grenier Brass Band')
# Victor Kiswell
# ('NOMBID for', u'Victor Kiswell')
# Vibration Visuelle
# ('NOMBID for', u'Vibration Visuelle')
# Versus the World
# aartist_mbid 0171fb12-5302-4b70-9bf3-c1030ec122b3
# Versus the World
#
# Vendège
# ('NOMBID for', u'Vend\xe8ge')
# Varez
# ('NOMBID for', u'Varez')
# Valentin Huedo
# ('NOMBID for', u'Valentin Huedo')
# Vadim Svoboda
# ('NOMBID for', u'Vadim Svoboda')
# VADER
# aartist_mbid 702c7d71-7559-4850-b6dc-1de54ada4abc
# VADER
#
# Uppermost
# aartist_mbid 166fd628-f034-434d-bcd8-37618db2bbf0
# pppppppppppppp
# Uppermost
#
# Unearth
# aartist_mbid 9f336c50-ae4c-4440-bda7-958aa12bc15a
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Unearth
#
# Un Nerf De Swing
# ('NOMBID for', u'Un Nerf De Swing')
# UVB
# ('NOMBID for', u'UVB')
# U2
# aartist_mbid a3cb23fc-acd3-4ce0-8f36-1e5aa6a18432
# U2
#
# Tygers of Pan Tang
# aartist_mbid fe179f28-3cab-4337-9575-c13f8d077b13
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Tygers of Pan Tang
#
# Tuscaloosa
# ('NOMBID for', u'Tuscaloosa')
# 郎朗
# aartist_mbid 43e1570a-1a0d-479f-9c95-fba971aec91a
# 郎朗
#
# فيروز
# aartist_mbid 338bbb53-5b96-447a-9444-8906844a0790
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# فيروز
#
# ДахаБраха
# aartist_mbid 208334a1-abf0-4791-9705-b45838244b29
# pppppppppppppp
# pppppppppppppp
# ДахаБраха
#
# Željko Joksimović
# aartist_mbid 380b799f-4aca-44e9-aade-5b0714cadb6c
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Željko Joksimović
#
# zid
# ('NOMBID for', u'zid')
# wimp
# ('NOMBID for', u'wimp')
# toybloid
# ('NOMBID for', u'toybloid')
# the police contact
# ('NOMBID for', u'the police contact')
# the Rooms
# ('NOMBID for', u'the Rooms')
# the Bad
# ('NOMBID for', u'the Bad')
# segur
# ('NOMBID for', u'segur')
# pasi
# ('NOMBID for', u'pasi')
# oh happy day
# ('NOMBID for', u'oh happy day')
# nickelback
# aartist_mbid bc710bcf-8815-42cf-bad2-3f1d12246aeb
# NORELEASEDATE2
# pppppppppppppp
# nickelback
#
# moms
# aartist_mbid f80fa0d7-d913-4bec-96db-e4efa31e4238
# pppppppppppppp
# moms
#
# meggy
# ('NOMBID for', u'meggy')
# manu svensson
# ('NOMBID for', u'manu svensson')
# lauri soini
# ('NOMBID for', u'lauri soini')
# keen V
# ('NOMBID for', u'keen V')
# iZA
# ('NOMBID for', u'iZA')
# getdown
# ('NOMBID for', u'getdown')
# eli verveine
# ('NOMBID for', u'eli verveine')
# dj oil
# ('NOMBID for', u'dj oil')
# ddd
# aartist_mbid b9d2fcb1-95e1-4498-877f-3770e46de2ca
# ddd
#
# buena vista social club
# aartist_mbid 2a85ecff-41e9-4be1-aca6-c87054a4c334
# buena vista social club
#
# andreas gabalier
# ('NOMBID for', u'andreas gabalier')
# al'tarba
# ('NOMBID for', u"al'tarba")
# a Midsummer Night's Dream
# ('NOMBID for', u"a Midsummer Night's Dream")
# Zomething
# ('NOMBID for', u'Zomething')
# Zi Elektrik Beez
# ('NOMBID for', u'Zi Elektrik Beez')
# Zebda Officiel
# ('NOMBID for', u'Zebda Officiel')
# Zanmari Bare
# ('NOMBID for', u'Zanmari Bare')
# Zacharie Abraham
# ('NOMBID for', u'Zacharie Abraham')
# ZOB'
# ('NOMBID for', u"ZOB'")
# Z-ID
# ('NOMBID for', u'Z-ID')
# Yuri Buenaventura
# aartist_mbid 4b33cf77-1ced-42e2-955c-ace858710b69
# pppppppppppppp
# Yuri Buenaventura
#
# Youssoupha
# aartist_mbid 6fabf3aa-1822-49f2-b6c7-57560464696f
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Youssoupha
#
# Your Old Droog
# ('NOMBID for', u'Your Old Droog')
# Young Fathers
# aartist_mbid 24aa5c20-a275-468a-93a9-b3d96b344b6c
# Young Fathers
#
# You Man
# ('NOMBID for', u'You Man')
# Yo La Tengo
# aartist_mbid 3f542031-b054-454d-b57b-812fa2a81b11
# pppppppppppppp
# Yo La Tengo
#
# Yellow
# aartist_mbid c616aef1-e21f-46f8-864f-b7bad96f41b2
# Yellow
#
# Ycare
# aartist_mbid b4225d57-ea6a-4260-993b-cae49c638dae
# pppppppppppppp
# Ycare
#
# Yaron
# ('NOMBID for', u'Yaron')
# Yannick Noah Officiel
# ('NOMBID for', u'Yannick Noah Officiel')
# Yan
# aartist_mbid e65948ec-284c-4360-bb11-eb3d45263ee6
# Yan
#
# YVAN LE BOLLOC'H
# ('NOMBID for', u"YVAN LE BOLLOC'H")
# YEALLOW
# ('NOMBID for', u'YEALLOW')
# XPLCT
# ('NOMBID for', u'XPLCT')
# X Syndicate
# aartist_mbid 5ad1044b-b737-4a86-b575-0a06995b8947
# pppppppppppppp
# pppppppppppppp
# X Syndicate
#
# World People Prod Label
# ('NOMBID for', u'World People Prod Label')
# Wooden Shields
# ('NOMBID for', u'Wooden Shields')
# Winter
# aartist_mbid 57e5fa50-48fd-4920-a5bf-0e6d7950a2ba
# pppppppppppppp
# Winter
#
# Wim Vandekeybus
# ('NOMBID for', u'Wim Vandekeybus')
# William Forsythe
# ('NOMBID for', u'William Forsythe')
# Wild Side
# ('NOMBID for', u'Wild Side')
# Whitney Weiss
# ('NOMBID for', u'Whitney Weiss')
# When Reasons Collapse
# ('NOMBID for', u'When Reasons Collapse')
# Weldis&Ros
# ('NOMBID for', u'Weldis&Ros')
# Weazley
# ('NOMBID for', u'Weazley')
# We Insist!
# ('NOMBID for', u'We Insist!')
# Wbeeza
# aartist_mbid dc258e6e-8924-4867-8a8d-6b3efbb4b83a
# Wbeeza
#
# Waxist
# ('NOMBID for', u'Waxist')
# Water Babies - Band
# ('NOMBID for', u'Water Babies - Band')
# Walter
# aartist_mbid 9f5a9ada-3ce6-4af7-8b90-527cb6dfc5ac
# Walter
#
# Waiting For Breakfast
# ('NOMBID for', u'Waiting For Breakfast')
# WE ARE MATCH
# ('NOMBID for', u'WE ARE MATCH')
# W.A.S.P.
# aartist_mbid 171cbc8f-8ab3-4aec-9916-f0bdbe26bb79
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# W.A.S.P.
#
# Vso
# ('NOMBID for', u'Vso')
# Volcan
# ('NOMBID for', u'Volcan')
# Vitaa
# aartist_mbid aad54e51-0619-4b21-a69b-d0901d2ef7e0
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Vitaa
#
# Virgil
# aartist_mbid 6fb20917-f0a6-474e-aa12-f92ad85250cc
# pppppppppppppp
# pppppppppppppp
# Virgil
#
# Vincent Vega
# aartist_mbid 5078622f-a360-428e-b276-bf6117b64a1d
# Vincent Vega
#
# Vince Staples
# ('NOMBID for', u'Vince Staples')
# Vieux Farka Touré
# aartist_mbid 7682d624-9e0b-45b2-b7d0-d1b18b3ebd05
# Vieux Farka Touré
#
# Vidal
# aartist_mbid 2a9a6fb3-6e64-4596-b37b-2c2f67dd7724
# Vidal
#
# Victor Deweerdt
# ('NOMBID for', u'Victor Deweerdt')
# Vertikal
# ('NOMBID for', u'Vertikal')
# Veil of Maya
# aartist_mbid 32e740e5-95ea-42e3-b5e2-29f6630488e4
# Veil of Maya
#
# Vanupié Officiel
# ('NOMBID for', u'Vanupi\xe9 Officiel')
# Valgeir Sigurðsson
# aartist_mbid b47171a4-1bfc-4d80-a91e-33c368fa6a5a
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Valgeir Sigurðsson
#
# Vakula
# ('NOMBID for', u'Vakula')
# VOICE OF RUIN
# ('NOMBID for', u'VOICE OF RUIN')
# VINCENT GIUMELLI
# ('NOMBID for', u'VINCENT GIUMELLI')
# V.I.A.
# ('NOMBID for', u'V.I.A.')
# Until Rain
# ('NOMBID for', u'Until Rain')
# Unit
# aartist_mbid 410e6545-3952-4402-9281-b4c1308cc296
# Unit
#
# Uncle Acid and the deadbeats
# ('NOMBID for', u'Uncle Acid and the deadbeats')
# Uli Jon Roth
# aartist_mbid cc533920-6a69-4b14-96ff-27a4cac89365
# Uli Jon Roth
#
# UKANDANZ
# ('NOMBID for', u'UKANDANZ')
# Typoboy
# ('NOMBID for', u'Typoboy')
# Twin Atlantic
# aartist_mbid 98a819b7-2634-4987-815b-bc66182dc97f
# Twin Atlantic
#
# Turnsteak
# ('NOMBID for', u'Turnsteak')
# Tub' à l'image
# ('NOMBID for', u"Tub' \xe0 l'image")
# Troubles Fete
# ('NOMBID for', u'Troubles Fete')
# Tristan
# aartist_mbid 8e3fbfcf-e072-47d0-80cb-a01700ea90c9
# NORELEASEDATE2
# Tristan
#
# Trio Nelson Schmidt
# ('NOMBID for', u'Trio Nelson Schmidt')
# Trilok Gurtu
# aartist_mbid 5af7a83c-88ba-493f-8bec-5c9e3b895e3e
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Trilok Gurtu
#
# TraumeR
# ('NOMBID for', u'TraumeR')
# Toxic Holocaust
# aartist_mbid b1c00b61-2673-458f-bba3-7470712a3b94
# pppppppppppppp
# Toxic Holocaust
#
# Toto
# aartist_mbid aab5c954-cabe-432e-899e-1c4f99757327
# Toto
#
# Tony Match
# ('NOMBID for', u'Tony Match')
# Toneshifterz
# ('NOMBID for', u'Toneshifterz')
# Tom Joyce
# ('NOMBID for', u'Tom Joyce')
# Tom Browne
# aartist_mbid 2b2596a1-089b-47ee-9aad-0587da08383a
# pppppppppppppp
# Tom Browne
#
# Tokyo Taboo
# ('NOMBID for', u'Tokyo Taboo')
# Tocotronic
# aartist_mbid 7717539b-33aa-45d5-b88d-9e627172db19
# pppppppppppppp
# Tocotronic
#
# 沖野修也
# aartist_mbid e903ba3c-8d06-4256-9c80-f264ae3431a7
# 沖野修也
#
# Виктория Муллова
# aartist_mbid 02bd2dff-f337-4788-9e75-0eb6beb932ac
# Виктория Муллова
#
# ÿordan
# ('NOMBID for', u'\xffordan')
# youn caro
# ('NOMBID for', u'youn caro')
# waze
# ('NOMBID for', u'waze')
# top 50
# ('NOMBID for', u'top 50')
# the Krooks
# ('NOMBID for', u'the Krooks')
# aoki
# ('NOMBID for', u'aoki')
# Tiëstolive
# ('NOMBID for', u'Ti\xebstolive')
# עידן רייכל
# aartist_mbid 48b69932-5352-4b2e-9847-b15ec8736d1e
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# עידן רייכל
#
# Ólafur Arnalds
# ('NOMBID for', u'\xd3lafur Arnalds')
# the magician
# ('NOMBID for', u'the magician')
# svadba
# ('NOMBID for', u'svadba')
# secret room
# ('NOMBID for', u'secret room')
# pHEN
# ('NOMBID for', u'pHEN')
# of Montreal
# aartist_mbid 8475297d-fb78-4630-8d74-9b87b6bb7cc8
# of Montreal
#
# nFiX & Candice
# ('NOMBID for', u'nFiX & Candice')
# module virus
# ('NOMBID for', u'module virus')
# mathieu salama
# ('NOMBID for', u'mathieu salama')
# manu lanvin
# ('NOMBID for', u'manu lanvin')
# la smala
# ('NOMBID for', u'la smala')
# jun
# aartist_mbid 767c86d6-cdcc-4d08-a104-318a06e05e03
# jun
#
# iAROSS
# ('NOMBID for', u'iAROSS')
# gainsbourg
# ('NOMBID for', u'gainsbourg')
# electrophazz
# ('NOMBID for', u'electrophazz')
# dj mat denum
# ('NOMBID for', u'dj mat denum')
# davoodi
# ('NOMBID for', u'davoodi')
# amine edge
# ('NOMBID for', u'amine edge')
# al mckay
# ('NOMBID for', u'al mckay')
# ___________
# ('NOMBID for', u'___________')
# Zombie-Zombie
# aartist_mbid 6d78ed61-5275-4af4-bcec-b609d2ade96c
# pppppppppppppp
# pppppppppppppp
# Zombie-Zombie
#
# Zenzile
# aartist_mbid 813d273f-a945-4c09-8318-49dba4fd13a4
# pppppppppppppp
# Zenzile
#
# Zebda
# aartist_mbid 8eebc0a9-653e-4b12-bfb6-471a95f8cf73
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Zebda
#
# Zaltan
# ('NOMBID for', u'Zaltan')
# Zach & Cedre
# ('NOMBID for', u'Zach & Cedre')
# ZIMA
# ('NOMBID for', u'ZIMA')
# Yves Torchinsky
# ('NOMBID for', u'Yves Torchinsky')
# Yul
# aartist_mbid a4685130-60aa-443c-ab35-f9f6ffa08a2a
# Yul
#
# Youssou N'Dour
# aartist_mbid af081ea2-7a2c-4fbd-8200-92d62056b5f5
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Youssou N'Dour
#
# Youngstown country band
# ('NOMBID for', u'Youngstown country band')
# Young Blood Brass Band
# ('NOMBID for', u'Young Blood Brass Band')
# Yoni Zelnik
# ('NOMBID for', u'Yoni Zelnik')
# Yngve and his Boogie Legs
# ('NOMBID for', u'Yngve and his Boogie Legs')
# Yelle
# aartist_mbid f43d43c8-eedf-4628-99b0-04120e7124c8
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Yelle
#
# Yasmine KYD
# ('NOMBID for', u'Yasmine KYD')
# Yarol Poupaud
# ('NOMBID for', u'Yarol Poupaud')
# Yannick Noah
# aartist_mbid fe87035a-eef5-4cde-9961-747f0492c5d7
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Yannick Noah
#
# YOUSK
# ('NOMBID for', u'YOUSK')
# YAN WAGNER
# ('NOMBID for', u'YAN WAGNER')
# XOMA SILENT LISTENER
# ('NOMBID for', u'XOMA SILENT LISTENER')
# Wynton Marsalis
# aartist_mbid 0d74dcc7-5684-4695-830f-a9846aad8ba9
# pppppppppppppp
# Wynton Marsalis
#
# Working Class Zero
# ('NOMBID for', u'Working Class Zero')
# Wooden Beaver
# ('NOMBID for', u'Wooden Beaver')
# Wolf Alice
# ('NOMBID for', u'Wolf Alice')
# Winston McAnuff
# aartist_mbid 46685feb-c574-4777-b5ff-3a60c232b955
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Winston McAnuff
#
# Willy Monfret
# ('NOMBID for', u'Willy Monfret')
# William Brunard
# ('NOMBID for', u'William Brunard')
# Whyskins
# ('NOMBID for', u'Whyskins')
# White Hills
# aartist_mbid 524718e3-ff02-489a-a131-753dc2f9cb9d
# pppppppppppppp
# White Hills
#
# What So Not
# ('NOMBID for', u'What So Not')
# Weiland
# ('NOMBID for', u'Weiland')
# We are LUX
# ('NOMBID for', u'We are LUX')
# We Insist !
# ('NOMBID for', u'We Insist !')
# Waysons
# ('NOMBID for', u'Waysons')
# Waxhead
# ('NOMBID for', u'Waxhead')
# Water Babies
# ('NOMBID for', u'Water Babies')
# Wally Stryk
# ('NOMBID for', u'Wally Stryk')
# Wailing Trees
# ('NOMBID for', u'Wailing Trees')
# WDB Management
# ('NOMBID for', u'WDB Management')
# W.A.S.A.B.I.
# ('NOMBID for', u'W.A.S.A.B.I.')
# Voodoo Vegas
# aartist_mbid 075bfeef-296d-4c01-b115-523545a08e11
# Voodoo Vegas
#
# Volutes
# ('NOMBID for', u'Volutes')
# Visualize
# ('NOMBID for', u'Visualize')
# Virage
# ('NOMBID for', u'Virage')
# Vincent Segal
# ('NOMBID for', u'Vincent Segal')
# Vince
# aartist_mbid e28d09d2-3aab-40fa-b604-7b9c1fa2489f
# Vince
#
# Victor
# aartist_mbid 12368b95-69ae-42bd-bf7b-85b54bd28938
# Victor
#
# Vetiver
# aartist_mbid 328068c9-ee60-408e-8c24-b1dc1ae08b94
# pppppppppppppp
# pppppppppppppp
# Vetiver
#
# Vertigo (Official)
# ('NOMBID for', u'Vertigo (Official)')
# Venom
# aartist_mbid 7ac77718-541a-4ca2-98de-004bff2420e8
# Venom
#
# Vaudou Game
# ('NOMBID for', u'Vaudou Game')
# Vanderstar
# ('NOMBID for', u'Vanderstar')
# Valerie Ghent
# ('NOMBID for', u'Valerie Ghent')
# VIVa Music
# ('NOMBID for', u'VIVa Music')
# VINCENT BLACK
# ('NOMBID for', u'VINCENT BLACK')
# Urban Trad
# aartist_mbid 175c2096-38c4-45ee-b034-5a2f51095a26
# pppppppppppppp
# Urban Trad
#
# Uniform Motion
# ('NOMBID for', u'Uniform Motion')
# Uncle Acid & The Deadbeats
# ('NOMBID for', u'Uncle Acid & The Deadbeats')
# Ugonna Okegwo
# ('NOMBID for', u'Ugonna Okegwo')
# UB40
# aartist_mbid 7113aab7-628f-4050-ae49-dbecac110ca8
# UB40
#
# Typh Barrow
# ('NOMBID for', u'Typh Barrow')
# Twin Arrows
# ('NOMBID for', u'Twin Arrows')
# Turn Off Your Brain
# ('NOMBID for', u'Turn Off Your Brain')
# Tsjuder
# aartist_mbid dbf23164-c702-46b9-a7e1-32acaabca310
# Tsjuder
#
# Troublemakers
# aartist_mbid adae038f-f39b-4ed3-bca8-dd1044a60f7c
# Troublemakers
#
# Triptykon (Official)
# ('NOMBID for', u'Triptykon (Official)')
# Trio Journal Intime
# ('NOMBID for', u'Trio Journal Intime')
# Trilok
# aartist_mbid 23a32579-b07c-4053-8407-75c82e2c51ef
# Trilok
#
# Tri Yann
# aartist_mbid 8bd21b26-f513-4d79-8fe4-a386289a1e65
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# NORELEASEDATE2
# Tri Yann
#
# Touzdec
# ('NOMBID for', u'Touzdec')
# Torsten Kanzler
# aartist_mbid 7c4401d9-3b47-4b5a-b8c7-d8229d03d6b3
# pppppppppppppp
# Torsten Kanzler
#
# Tony MacAlpine
# aartist_mbid 1245270a-3548-43a1-9b88-3fbf625148fa
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Tony MacAlpine
#
# Toni Varga
# ('NOMBID for', u'Toni Varga')
# Tonbandgerät
# ('NOMBID for', u'Tonbandger\xe4t')
# Tom Zé
# aartist_mbid 9f284484-c949-4199-8741-aba416a497a8
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Tom Zé
#
# Tom Hagen Official
# ('NOMBID for', u'Tom Hagen Official')
# Tom Baxter
# aartist_mbid e2547cbc-742d-4eb5-89c4-3b4daea476f1
# pppppppppppppp
# Tom Baxter
#
# Tokyo
# aartist_mbid ecd9bffa-26ff-42b1-aed9-c94e38962814
# Tokyo
#
# Tocadisco
# aartist_mbid 43d30d64-e433-4314-86e4-16288d3378a6
# Tocadisco
#
# Tiziano Ferro
# aartist_mbid d12b05b0-a0af-4c2c-8c8c-ab8bcf49439e
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Tiziano Ferro
#
# Tiphaine Wary
# ('NOMBID for', u'Tiphaine Wary')
# Tim Fromont Placenti
# ('NOMBID for', u'Tim Fromont Placenti')
# Tigers Can Swim
# ('NOMBID for', u'Tigers Can Swim')
# Thundamentals
# ('NOMBID for', u'Thundamentals')
# Thomy
# ('NOMBID for', u'Thomy')
# Thomas De Pourquery
# ('NOMBID for', u'Thomas De Pourquery')
# Thibbv
# ('NOMBID for', u'Thibbv')
# Theo
# aartist_mbid c8c47b92-0ac1-4c2a-8833-5e91b99126f9
# Theo
#
# The Wonder
# ('NOMBID for', u'The Wonder')
# The Wipes
# ('NOMBID for', u'The Wipes')
# The Welderz
# ('NOMBID for', u'The Welderz')
# Theodore, Paul & Gabriel
# ('NOMBID for', u'Theodore, Paul & Gabriel')
# The Works
# aartist_mbid c8c1fde2-76db-4071-abf9-659c822f0f85
# The Works
#
# The Wolf
# aartist_mbid e9fe8491-ef9d-4090-97e9-c4374de2cac5
# oups The Wolf
# The Who
# aartist_mbid 9fdaa16b-a6c4-4831-b87c-bc9ca8ce7eaa
# pppppppppppppp
# pppppppppppppp
# The Who
#
# The Watch
# aartist_mbid 843d0b5a-e146-4c95-963e-6d831fa12242
# pppppppppppppp
# NORELEASEDATE2
# The Watch
#
# The Wailers
# aartist_mbid a3bd2e9e-3839-48bc-abfa-6b6ad2bdcb8e
# The Wailers
#
# The Unlikely Boy
# ('NOMBID for', u'The Unlikely Boy')
# The Thurston Moore Band
# ('NOMBID for', u'The Thurston Moore Band')
# The Taikonauts
# ('NOMBID for', u'The Taikonauts')
# The Subs
# aartist_mbid 40463321-46e0-4994-bc37-97c0b5fc1f25
# The Subs
#
# The Stalls
# ('NOMBID for', u'The Stalls')
# The Soul Papaz
# ('NOMBID for', u'The Soul Papaz')
# The Sixxis
# ('NOMBID for', u'The Sixxis')
# The Shoes
# aartist_mbid f527fc42-5905-4f48-976f-717080455ff9
# The Shoes
#
# The Roughneck riot
# ('NOMBID for', u'The Roughneck riot')
# The Roadies of the D
# ('NOMBID for', u'The Roadies of the D')
# The Red Paintings
# aartist_mbid 6f3a2d19-0952-49fe-bbdf-50f842358155
# pppppppppppppp
# The Red Paintings
#
# The RH Factor
# aartist_mbid 27decac7-06de-4a04-ab45-d214dfae5d19
# The RH Factor
#
# The Prophets
# aartist_mbid 49781338-10aa-4bd7-86a7-b69f71d3037f
# The Prophets
#
# The Polyphonic Spree
# aartist_mbid 6758601f-6d57-491e-a125-037f382a5ddd
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# The Polyphonic Spree
#
# The Ones - Groupe
# ('NOMBID for', u'The Ones - Groupe')
# The Notwist
# aartist_mbid f180cec2-9421-4417-a841-c7372090d13d
# pppppppppppppp
# The Notwist
#
# The Monkberry Moon Orchestra
# ('NOMBID for', u'The Monkberry Moon Orchestra')
# The Mighty Mocambos
# ('NOMBID for', u'The Mighty Mocambos')
# The Martinez Brothers
# aartist_mbid c9c65c94-27b4-4eca-82f0-80055ac4f8a7
# The Martinez Brothers
#
# The Libertines
# aartist_mbid e6e64ac4-9233-4bb6-92f3-1392f8b018f3
# The Libertines
#
# The Konbinis
# ('NOMBID for', u'The Konbinis')
# The Keith Richardson Syndrome
# ('NOMBID for', u'The Keith Richardson Syndrome')
# The Janoskians
# ('NOMBID for', u'The Janoskians')
# The Herbaliser
# aartist_mbid bf48d271-9595-4043-9064-52f43707d4ab
# pppppppppppppp
# The Herbaliser
#
# The Hacker
# aartist_mbid e044fb9c-7c2e-48f7-81f6-ea2ae99d2ef0
# pppppppppppppp
# The Hacker
#
# The Golden Gate Quartet
# aartist_mbid 3ac646f6-2057-485c-bf7e-205887c81426
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# The Golden Gate Quartet
#
# The Gladiators
# aartist_mbid 0a08dd31-cf1f-44f6-bc19-0b7d483f6389
# The Gladiators
#
# The Gaslight Anthem
# aartist_mbid f208f09e-b5b3-4b06-87cd-f7230fae17e3
# The Gaslight Anthem
#
# The Four Horsemen
# aartist_mbid be0e6dd6-929b-451c-8fa7-f098f716f19e
# pppppppppppppp
# pppppppppppppp
# The Four Horsemen
#
# The FAT BASTARD Gang Band
# ('NOMBID for', u'The FAT BASTARD Gang Band')
# The Early Grave
# ('NOMBID for', u'The Early Grave')
# The Driver
# ('NOMBID for', u'The Driver')
# The Districts
# aartist_mbid d4cb6c89-d615-40e4-b78d-ae5ab1565462
# pppppppppppppp
# pppppppppppppp
# The Districts
#
# The Deans
# aartist_mbid 43dfed8f-9054-46d1-82a3-50a15c1ff995
# pppppppppppppp
# The Deans
#
# The Damnettes
# ('NOMBID for', u'The Damnettes')
# The Chemical Brothers
# aartist_mbid 1946a82a-f927-40c2-8235-38d64f50d043
# pppppppppppppp
# pppppppppppppp
# The Chemical Brothers
#
# The Butcher's Rodeo
# ('NOMBID for', u"The Butcher's Rodeo")
# The Broken Bones
# ('NOMBID for', u'The Broken Bones')
# The Black Leaders
# ('NOMBID for', u'The Black Leaders')
# The BellRays
# aartist_mbid c754774d-d3ea-4216-9486-368c04b1bbe7
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# NORELEASEDATE2
# pppppppppppppp
# pppppppppppppp
# The BellRays
#
# The Australian Pink Floyd Show
# ('NOMBID for', u'The Australian Pink Floyd Show')
# The Argument
# aartist_mbid ccb42994-72ea-475f-bb04-20a4888fe10e
# The Argument
#
# The Angry Cats
# ('NOMBID for', u'The Angry Cats')
# The Advent
# aartist_mbid b3a35974-4703-4423-92bf-a1b5ac6cac3b
# pppppppppppppp
# pppppppppppppp
# The Advent
#
# Thalamos
# ('NOMBID for', u'Thalamos')
# Terry Riley
# aartist_mbid 7bf257bf-19a8-4205-8ae8-98511e50b719
# Terry Riley
#
# Tender Games
# ('NOMBID for', u'Tender Games')
# TelDem Com'unity
# ('NOMBID for', u"TelDem Com'unity")
# Teenage Mutants
# ('NOMBID for', u'Teenage Mutants')
# Techno Parade
# ('NOMBID for', u'Techno Parade')
# Teacup Monster
# ('NOMBID for', u'Teacup Monster')
# Taxis For Galaxies
# ('NOMBID for', u'Taxis For Galaxies')
# Tara McDonald
# aartist_mbid 147c4fa2-45a2-4f35-b75f-4124a33db1d9
# Tara McDonald
#
# Tanguy Blum
# ('NOMBID for', u'Tanguy Blum')
# Tamboral
# ('NOMBID for', u'Tamboral')
# Tal
# aartist_mbid f2787157-3ba4-4bdc-9024-e23949312012
# Tal
#
# Taipan
# ('NOMBID for', u'Taipan')
# TURTLE
# ('NOMBID for', u'TURTLE')
# TOO MANY ZOOZ
# ('NOMBID for', u'TOO MANY ZOOZ')
# TIM VANTOL
# ('NOMBID for', u'TIM VANTOL')
# THE WACKIDS
# ('NOMBID for', u'THE WACKIDS')
# THE REBELS OF TIJUANA
# ('NOMBID for', u'THE REBELS OF TIJUANA')
# THE MOORINGS
# ('NOMBID for', u'THE MOORINGS')
# THE ELECTRIC EPIC
# ('NOMBID for', u'THE ELECTRIC EPIC')
# TARAN CELT
# ('NOMBID for', u'TARAN CELT')
# T-Pain
# aartist_mbid ce55e49a-32f4-4757-9849-bf04d06d5fcc
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# T-Pain
#
# Séverine de Close
# ('NOMBID for', u'S\xe9verine de Close')
# Syndrôm
# ('NOMBID for', u'Syndr\xf4m')
# Sylvain Ransy
# ('NOMBID for', u'Sylvain Ransy')
# Syl Johnson
# aartist_mbid 2e8cbd3d-44c0-4725-89e0-7db8010aa832
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Syl Johnson
#
# Swift Guad
# aartist_mbid 607a36bb-e965-486d-b9ae-f635ba53c1b4
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Swift Guad
#
# Swans
# aartist_mbid 3285dc48-9505-469d-ad8a-bdf2d3dba632
# NORELEASEDATE2
# Swans
#
# Suzanna Choffel
# aartist_mbid 0b5a0001-6fe4-43e5-8d5d-e47870d3137c
# pppppppppppppp
# pppppppppppppp
# Suzanna Choffel
#
# Surgeon
# aartist_mbid dcc5653c-3e3f-4666-a520-45fb032694a7
# Surgeon
#
# Supersonic
# aartist_mbid 9c1f731f-9501-42c7-ad65-047636955e6f
# Supersonic
#
# Super Etoile De Dakar
# ('NOMBID for', u'Super Etoile De Dakar')
# Sunshadows
# ('NOMBID for', u'Sunshadows')
# Sun Kil Moon
# aartist_mbid ef2c6449-d02b-415b-ad8c-c14c08266552
# Sun Kil Moon
#
# The Sobers
# ('NOMBID for', u'The Sobers')
# The Shutters
# ('NOMBID for', u'The Shutters')
# The Sensational Space Shifters
# ('NOMBID for', u'The Sensational Space Shifters')
# The Rileys
# aartist_mbid 9cb6d2f3-9409-4e02-b494-9eddcaff1f2b
# The Rileys
#
# The Razorblades
# ('NOMBID for', u'The Razorblades')
# The Qemists
# aartist_mbid eae38719-96b6-4aa5-8303-5bb08f953c86
# The Qemists
#
# The Pop Group
# aartist_mbid 4c9f194e-6235-475a-bf7b-2fd54a0879ec
# The Pop Group
#
# The Palata Singers
# ('NOMBID for', u'The Palata Singers')
# The Octopus Project
# aartist_mbid aaf92b5a-199c-4b1b-969d-7a915ffb6f0f
# pppppppppppppp
# The Octopus Project
#
# The New Divide
# ('NOMBID for', u'The New Divide')
# The Morganatics
# ('NOMBID for', u'The Morganatics')
# The Mirrors
# aartist_mbid 6db26fe7-a0e8-4733-9807-cd8959873b57
# The Mirrors
#
# The Mekanism
# ('NOMBID for', u'The Mekanism')
# The London Souls
# aartist_mbid 301bf336-0cce-4f35-8bc3-23267033bf6c
# pppppppppppppp
# The London Souls
#
# The Kreeks
# ('NOMBID for', u'The Kreeks')
# The Kids
# aartist_mbid 398e1c8f-6706-4b84-a1fe-92d58549eeec
# The Kids
#
# The John Butler Trio
# aartist_mbid 7952b266-9fd4-4a09-a324-7dc84f11b5fc
# pppppppppppppp
# NORELEASEDATE2
# NORELEASEDATE2
# The John Butler Trio
#
# The Hooters
# aartist_mbid fc20ca3a-5fb5-475c-b151-516829c14d9b
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# The Hooters
#
# The Harts Industry
# ('NOMBID for', u'The Harts Industry')
# The Graduates
# aartist_mbid c6747f43-e942-4d64-aad0-9051d6b9a503
# The Graduates
#
# The Goddamn Gallows
# ('NOMBID for', u'The Goddamn Gallows')
# The Geek x Vrv
# ('NOMBID for', u'The Geek x Vrv ')
# The Fratellis
# aartist_mbid f4ad883e-9a92-45ed-a540-a49c2d1c36dd
# pppppppppppppp
# The Fratellis
#
# The Fat Badgers
# ('NOMBID for', u'The Fat Badgers')
# The Emma Project
# ('NOMBID for', u'The Emma Project')
# The Drops
# ('NOMBID for', u'The Drops')
# The Dodoz
# aartist_mbid e006e9f5-906a-4eb7-8d81-24e7c838d3e2
# pppppppppppppp
# The Dodoz
#
# The Delta Saints
# ('NOMBID for', u'The Delta Saints')
# The Day Before
# ('NOMBID for', u'The Day Before')
# The Crimes
# aartist_mbid 2bf627cb-3083-45b4-a917-69abeadbd9b9
# The Crimes
#
# The Chillers
# ('NOMBID for', u'The Chillers')
# The Casualties
# aartist_mbid d2bf45ea-1d83-4fa7-9613-459071a08cf1
# The Casualties
#
# The Broken Circle Breakdown Bluegrass Band
# ('NOMBID for', u'The Broken Circle Breakdown Bluegrass Band')
# The Bloody Beetroots
# aartist_mbid 30d639db-5c8f-494e-a937-460a4b67f3b4
# pppppppppppppp
# The Bloody Beetroots
#
# The Ben Miller Band
# ('NOMBID for', u'The Ben Miller Band')
# The Bart Walker Band
# ('NOMBID for', u'The Bart Walker Band')
# The Arrs
# aartist_mbid 86130770-ff37-4925-81cf-8110b3adf2b6
# The Arrs
#
# The Answer
# aartist_mbid 4fef3623-cedb-4cc5-a94d-a8f075168821
# The Answer
#
# The 2 Bears
# ('NOMBID for', u'The 2 Bears')
# Tess Parks
# ('NOMBID for', u'Tess Parks')
# Terakaft
# ('NOMBID2 for', u'Terakaft')
# Temple of Baal
# aartist_mbid a8245362-fcec-459d-b9d6-d270ca9c0c9a
# Temple of Baal
#
# Teki Latex
# aartist_mbid 14b05d93-86a1-471d-b7d8-8090dbe50b82
# Teki Latex
#
# Tedmo Festival
# ('NOMBID for', u'Tedmo Festival')
# Team William
# aartist_mbid 8c5fa7e5-434a-4ae5-83a1-cdc103260f5e
# Team William
#
# Taîeb Chékir
# ('NOMBID for', u'Ta\xeeeb Ch\xe9kir')
# Tasseomancy
# ('NOMBID for', u'Tasseomancy')
# Tarek Abdallah   طارق عبدالله
# ('NOMBID for', u'Tarek Abdallah   \u0637\u0627\u0631\u0642 \u0639\u0628\u062f\u0627\u0644\u0644\u0647')
# Tankrust
# ('NOMBID for', u'Tankrust')
# Tample
# ('NOMBID2 for', u'Tample')
# Tale Of Us
# ('NOMBID for', u'Tale Of Us')
# Takeshi Asai, pianist & composer
# ('NOMBID for', u'Takeshi Asai, pianist & composer')
# TWINSMATIC
# ('NOMBID for', u'TWINSMATIC')
# TOURNEE GENERALE
# ('NOMBID for', u'TOURNEE GENERALE')
# TNT
# aartist_mbid 458f0043-e94f-43e3-bb73-38bcb1ce7e0a
# TNT
#
# THOS HENLEY
# ('NOMBID for', u'THOS HENLEY')
# THE SUMMER REBELLION
# ('NOMBID for', u'THE SUMMER REBELLION')
# THE PEACOCK SOCIETY
# ('NOMBID for', u'THE PEACOCK SOCIETY')
# THA TRICKAZ
# ('NOMBID for', u'THA TRICKAZ')
# TAÏRO
# ('NOMBID for', u'TA\xcfRO')
# T.A.N.K (Think of A New Kind)
# ('NOMBID for', u'T.A.N.K (Think of A New Kind)')
# Söndörgő
# ('NOMBID for', u'S\xf6nd\xf6rg\u0151')
# Sylvie Guillem
# ('NOMBID for', u'Sylvie Guillem')
# Sylvain Crouneur Ultimate Intergalactic Karaoké
# ('NOMBID for', u'Sylvain Crouneur Ultimate Intergalactic Karaok\xe9')
# Swiss Powerbrass
# ('NOMBID for', u'Swiss Powerbrass')
# Sweat Lodge Agency
# ('NOMBID for', u'Sweat Lodge Agency')
# Sven Sossong (Official)
# ('NOMBID for', u'Sven Sossong (Official)')
# Surnatural Orchestra
# ('NOMBID for', u'Surnatural Orchestra')
# Support
# aartist_mbid 95489210-4be5-4054-baf5-cae3371df3e0
# Support
#
# Superets
# ('NOMBID for', u'Superets')
# SupaZero
# ('NOMBID for', u'SupaZero')
# Sunflower Dead
# ('NOMBID for', u'Sunflower Dead')
# Summer Sessions
# aartist_mbid 1cf1cd03-fa07-4938-a15c-907fd4af43c5
# Summer Sessions
#
# Tube & Berger
# aartist_mbid bfbaa549-1504-417c-a045-16d984f3d586
# Tube & Berger
#
# Tryde
# ('NOMBID for', u'Tryde')
# Trombone Shorty & Orleans Avenue
# aartist_mbid cae4fd51-4d58-4d48-92c1-6198cc2e45ed
# Trombone Shorty & Orleans Avenue
#
# Trio Wanderer
# aartist_mbid 296a518e-85b6-42ee-8a57-7d75a4dbf486
# Trio Wanderer
#
# Trio Chemirani
# aartist_mbid 98e858c0-66b8-47c6-ba51-13002adab4c9
# pppppppppppppp
# pppppppppppppp
# Trio Chemirani
#
# Trigones+
# ('NOMBID for', u'Trigones+')
# Traits d'Unions
# ('NOMBID for', u"Traits d'Unions")
# Touche Amore
# ('NOMBID for', u'Touche Amore')
# Topp Dogg
# ('NOMBID for', u'Topp Dogg')
# Tony Bennett
# aartist_mbid 7268ff55-3ac2-4546-a0cf-d7273840472f
# Tony Bennett
#
# Toni
# aartist_mbid 2610aa95-b563-4c4b-9d46-af03229ad6ed
# Toni
#
# Tomorrow - TMRW
# ('NOMBID for', u'Tomorrow - TMRW')
# Tom Pooks
# aartist_mbid 680b7e8b-d8dd-4f30-b42a-b4d5a5a34916
# Tom Pooks
#
# Tom Fire
# ('NOMBID for', u'Tom Fire')
# Tom Akman
# ('NOMBID for', u'Tom Akman')
# Toi Toi Musik
# ('NOMBID for', u'Toi Toi Musik')
# Titus
# aartist_mbid c2c513e1-2564-46fa-8c23-63c7a183f044
# Titus
#
# Tina
# aartist_mbid e60228b6-8c61-405e-947b-5c5cd6111891
# Tina
#
# Tiken Jah Fakoly
# aartist_mbid edef3cfa-4e5e-4d64-8bd8-20f9dc1d8cad
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Tiken Jah Fakoly
#
# Thurston Moore
# aartist_mbid 8ba48525-d922-42ee-9775-97b7b8f9712e
# pppppppppppppp
# pppppppppppppp
# Thurston Moore
#
# Thomas Pitiot
# ('NOMBID for', u'Thomas Pitiot')
# Thomas Evans
# ('NOMBID for', u'Thomas Evans')
# Thomas
# aartist_mbid c08cef97-eda3-4121-adb1-c9e79aeb98dc
# Thomas
#
# Theorama
# ('NOMBID for', u'Theorama')
# The Young Folk
# ('NOMBID for', u'The Young Folk')
# The Wolf Under The Moon
# ('NOMBID for', u'The Wolf Under The Moon')
# The Wild Sons
# ('NOMBID for', u'The Wild Sons')
# The Weather Station
# ('NOMBID for', u'The Weather Station')
# The Walk
# aartist_mbid f06ce4ea-4db6-4985-b96c-7c89f760404b
# pppppppppppppp
# The Walk
#
# The Vaccines
# ('NOMBID for', u'The Vaccines')
# The Ting Tings
# aartist_mbid e618770f-e994-41c3-856f-1eedf56b6d74
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# The Ting Tings
#
# The Talks
# ('NOMBID for', u'The Talks')
# The Subways
# aartist_mbid 20e264d7-b4d5-4e49-8931-a9c67ff07f04
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# The Subways
#
# The Steady Rollin' Men
# ('NOMBID for', u"The Steady Rollin' Men")
# The Soul Rebels
# aartist_mbid 9fb89a6d-1883-4735-a94e-2fe8e0f1d59f
# pppppppppppppp
# pppppppppppppp
# The Soul Rebels
#
# The Skints
# aartist_mbid 7a279145-e778-4099-8f73-ea917a1956c9
# The Skints
#
# The Shougashack
# ('NOMBID for', u'The Shougashack')
# The Script
# aartist_mbid 4c98aa1b-34eb-4336-987f-5e50aa059c00
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# The Script
#
# The Robert Cray Band
# aartist_mbid 9adffe09-8bea-4f08-a409-923ecb3d029d
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# The Robert Cray Band
#
# The Rhythm Junks
# aartist_mbid ea07d294-8bb9-4320-a8eb-c4b95838cd99
# pppppppppppppp
# The Rhythm Junks
#
# The Raven Age
# ('NOMBID for', u'The Raven Age')
# The Puppini Sisters
# aartist_mbid c17d3b64-57f1-4e28-8a85-2c02bfc0bc05
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# The Puppini Sisters
#
# The Poodles
# aartist_mbid 4c446c3c-d340-4fc5-8c25-2fb060eb5ce8
# pppppppppppppp
# pppppppppppppp
# The Poodles
#
# The Original Wailers
# ('NOMBID for', u'The Original Wailers')
# The Ocean
# aartist_mbid 8d0acf0e-c099-49ac-b4b3-d57ca9eb2561
# The Ocean
#
# The Neighborhood
# aartist_mbid cf437be2-408d-48ae-9fc9-d5045c139ff6
# pppppppppppppp
# The Neighborhood
#
# The Moon and the Nightspirit
# aartist_mbid 32590def-5684-4649-89cd-48addfafff4f
# The Moon and the Nightspirit
#
# The Miracles
# aartist_mbid 6a4c2d34-7f7f-4f87-b17f-b5540aa840db
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# The Miracles
#
# The Mavorix
# ('NOMBID for', u'The Mavorix')
# The Littles
# ('NOMBID for', u'The Littles')
# The Kooks
# aartist_mbid c41c6a32-cd7e-4cce-8859-559efdd457b3
# pppppppppppppp
# pppppppppppppp
# The Kooks
#
# The Kid
# aartist_mbid 892e1d4d-d507-4528-b48f-283fdd79bcfc
# The Kid
#
# The Jerry Khan Bangers
# ('NOMBID for', u'The Jerry Khan Bangers')
# The Heron Theme
# ('NOMBID for', u'The Heron Theme')
# The Goo Goo Goes
# ('NOMBID for', u'The Goo Goo Goes')
# The Go! Team
# aartist_mbid 8a396a9c-2e4f-47e2-a587-c26e93a0953f
# pppppppppppppp
# pppppppppppppp
# The Go! Team
#
# The Geek
# ('NOMBID for', u'The Geek')
# The Francis Inferno Orchestra
# ('NOMBID for', u'The Francis Inferno Orchestra')
# The Fantastic Laura B
# ...
# Al' Tarba
# ('NOMBID for', u"Al' Tarba")
# Akua Naru
# ('NOMBID for', u'Akua Naru')
# Akalé Wubé
# ('NOMBID for', u'Akal\xe9 Wub\xe9')
# Airelle Besson
# ('NOMBID for', u'Airelle Besson')
# Ahmed Sylla Officiel
# ('NOMBID for', u'Ahmed Sylla Officiel')
# Agnostic Front
# aartist_mbid 40b8a690-94e4-4c82-ad0f-73f4b841e46a
# pppppppppppppp
# Agnostic Front
#
# Aftermoon
# ('NOMBID for', u'Aftermoon')
# Affkt
# aartist_mbid 06d5afd8-f3bd-4f89-8f6a-7a1dfd6e3a75
# Affkt
#
# Aerisian
# ('NOMBID for', u'Aerisian')
# Babylon Circus
# aartist_mbid 84788caa-d859-4814-bf18-cbfbe277ce73
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Babylon Circus
#
# Babel
# aartist_mbid b8a210b7-a8be-4255-a2b4-5a14219d2800
# Babel
#
# BUKOWSKI
# ('NOMBID for', u'BUKOWSKI')
# BRICE
# ('NOMBID for', u'BRICE')
# BOXON RECORDS
# ('NOMBID for', u'BOXON RECORDS')
# BLACK LILYS
# ('NOMBID for', u'BLACK LILYS')
# BEST OF FLOYD
# ('NOMBID for', u'BEST OF FLOYD')
# BEHEMOTH
# aartist_mbid 69632f9c-31eb-43d5-a864-e73ac72efc66
# BEHEMOTH
#
# BAD MULES
# ('NOMBID for', u'BAD MULES')
# Azar Lawrence
# aartist_mbid 8935ef74-e1ac-4683-858f-64ebc7808fad
# Azar Lawrence
#
# Aymeric Lompret
# ('NOMBID for', u'Aymeric Lompret')
# Axis
# aartist_mbid 6f69f35b-586a-4096-85ed-a9058eb81b24
# Axis
#
# Avrosse
# ('NOMBID for', u'Avrosse')
# Ave Maria à la Sainte Chapelle
# ('NOMBID for', u'Ave Maria \xe0 la Sainte Chapelle')
# Aurelien Bouly
# ('NOMBID for', u'Aurelien Bouly')
# Aveyroad
# ('NOMBID for', u'Aveyroad')
# Atili Bandalero
# ('NOMBID for', u'Atili Bandalero')
# Astrix
# aartist_mbid 13875f81-5bfc-4939-a6cc-296c3f8d0fa5
# Astrix
#
# Assassin
# aartist_mbid 20cf9a2a-7418-42e1-9b36-312cd9c2088f
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Assassin
#
# Asian Dub Foundation
# aartist_mbid db612997-f11e-424d-8b41-cf410a433656
# pppppppppppppp
# pppppppppppppp
# Asian Dub Foundation
#
# Artikal Band
# ('NOMBID for', u'Artikal Band')
# Art Garfunkel
# aartist_mbid fc0a5289-4b77-4246-9c8d-857c8b617f5d
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Art Garfunkel
#
# Aron'C
# ('NOMBID for', u"Aron'C")
# Armin van Buuren
# aartist_mbid 477b8c0c-c5fc-4ad2-b5b2-191f0bf2a9df
# Armin van Buuren
#
# Arkona
# aartist_mbid 9be897fc-6267-45ef-a745-22414d2fad3b
# Arkona
#
# Ariel Tessier
# ('NOMBID for', u'Ariel Tessier')
# Archipel
# ('NOMBID for', u'Archipel')
# Archer
# aartist_mbid b6de21b3-e1af-4a18-ac96-e45994446e5d
# Archer
#
# Ara Gevorgyan
# ('NOMBID for', u'Ara Gevorgyan')
# Aprile
# ('NOMBID for', u'Aprile')
# Appalache
# ('NOMBID for', u'Appalache')
# Apassionata
# ('NOMBID for', u'Apassionata')
# Antonio Sanchez
# aartist_mbid 3bb7845a-bc8a-4ac6-bc31-32046b604e47
# pppppppppppppp
# Antonio Sanchez
#
# Antoine Delprat
# ('NOMBID for', u'Antoine Delprat')
# Antislash
# aartist_mbid ba59f845-ca47-4cd0-ac72-6ae6e9fec1d5
# Antislash
#
# Anthony Joseph
# aartist_mbid 8ccaf73c-3ff0-4b66-8217-5670305c7b0e
# pppppppppppppp
# Anthony Joseph
#
# Anthony
# aartist_mbid 63edf8cd-ec84-470c-9d4a-1f897de8f317
# pppppppppppppp
# Anthony
#
# Another Ox
# ('NOMBID for', u'Another Ox')
# AnnenMayKantereit
# ('NOMBID for', u'AnnenMayKantereit')
# Anne Queffélec
# aartist_mbid b49797fb-7cc9-4eae-ad94-3872818ed281
# Anne Queffélec
#
# Annalise Emerick
# ('NOMBID for', u'Annalise Emerick')
# Anissa Bensalah
# ('NOMBID for', u'Anissa Bensalah')
# Angus and Julia Stone
# aartist_mbid 69837400-8e31-4949-aac2-00b46b4df126
# pppppppppppppp
# pppppppppppppp
# Angus and Julia Stone
#
# Angerfist
# aartist_mbid 91d8e441-73a6-48a6-aed1-2bef4da87799
# Angerfist
#
# Angel Mosteiro
# ('NOMBID for', u'Angel Mosteiro')
# Ane Brun
# aartist_mbid d735497b-25f9-4503-8fb5-f50150730c18
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Ane Brun
#
# André Ceccarelli
# aartist_mbid 68a155b4-0345-44be-ab3f-dc88f68960ec
# pppppppppppppp
# André Ceccarelli
#
# Andrew
# aartist_mbid b94c80c9-e2c4-4338-9e8c-5db937e220e5
# Andrew
#
# Andrea Motis
# ('NOMBID for', u'Andrea Motis')
# Anaïs
# aartist_mbid dfd0087e-64e2-4677-9d31-23f25974c138
# pppppppppppppp
# Anaïs
#
# AnGy KoRe
# ('NOMBID for', u'AnGy KoRe')
# Amenra
# aartist_mbid e7af1101-e51a-4eaf-ae2e-b4de760bd428
# Amenra
#
# Amante
# ('NOMBID for', u'Amante')
# Alwaid
# ('NOMBID for', u'Alwaid')
# Altair
# ('NOMBID for', u'Altair')
# Alpha Steppa
# ('NOMBID for', u'Alpha Steppa')
# Alonzo
# aartist_mbid 9ff87295-bdfc-46fc-b605-456cc39d84ca
# pppppppppppppp
# pppppppppppppp
# Alonzo
#
# Allnighters
# aartist_mbid f2a671c8-eb11-4ef5-83e9-2c19d39fb725
# Allnighters
#
# Allan Ros
# ('NOMBID for', u'Allan Ros')
# All Atlas Drowning
# ('NOMBID for', u'All Atlas Drowning')
# Alice on the roof
# aartist_mbid e32f2cd6-8695-4914-9c24-72e02ebd09ee
# pppppppppppppp
# pppppppppppppp
# Alice on the roof
#
# AlgoRythmiK
# ('NOMBID for', u'AlgoRythmiK')
# Alfio
# ('NOMBID for', u'Alfio')
# Alexis HK
# aartist_mbid eab89147-d970-49c4-82a3-eff4440a81e9
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Alexis HK
#
# Alexandre SAADA
# ('NOMBID for', u'Alexandre SAADA')
# Alex Tassel
# ('NOMBID for', u'Alex Tassel')
# Alex
# aartist_mbid 5039b07c-ab13-46be-a7bf-0eaf2079ba97
# pppppppppppppp
# Alex
#
# Alec K. Redfearn
# ('NOMBID for', u'Alec K. Redfearn')
# Aldebert
# aartist_mbid 21f0c4f0-e8b6-4748-8df8-9789ea5e3acc
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Aldebert
#
# Alan Stivell
# aartist_mbid abc61045-7ae3-48d9-91f2-d44689d53c9a
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Alan Stivell
#
# Alain SOUCHON et Laurent VOULZY
# ('NOMBID for', u'Alain SOUCHON et Laurent VOULZY')
# Alain Chamfort
# aartist_mbid 5d908002-b164-4dce-9930-f740b165b7fe
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Alain Chamfort
#
# Al Jarreau
# aartist_mbid 3e54ba8b-f4cc-4192-9813-890d570e2b7a
# pppppppppppppp
# Al Jarreau
#
# Aktarüs
# ('NOMBID for', u'Aktar\xfcs')
# Aka Moon
# aartist_mbid 3ae1ea83-e585-4318-8f67-2412276b5c7d
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Aka Moon
#
# Airelle
# ('NOMBID for', u'Airelle')
# Agents Of Time
# ('NOMBID for', u'Agents Of Time')
# After the Flood
# aartist_mbid 2a010d6b-5c4d-4097-bf2a-97a8e9293190
# pppppppppppppp
# After the Flood
#
# Aetherlone
# ('NOMBID for', u'Aetherlone')
# Adèle Belmont
# ('NOMBID for', u'Ad\xe8le Belmont')
# Admiral Fallow
# ('NOMBID for', u'Admiral Fallow')
# Added
# ('NOMBID for', u'Added')
# Adam Stromstedt
# ('NOMBID for', u'Adam Stromstedt')
# Adam B
# ('NOMBID for', u'Adam B')
# Acid Mothers Temple & The Melting Paraiso U.F.O.
# aartist_mbid 41984dda-1f0e-436d-88d1-decb8d787122
# Acid Mothers Temple & The Melting Paraiso U.F.O.
#
# Abyale
# aartist_mbid 8ab0d851-917d-468b-b943-14a1aa81018a
# Abyale
#
# Aborted
# aartist_mbid 15b16969-3d22-4435-9534-c9a074e7e005
# Aborted
#
# Aaron Diehl Trio
# ('NOMBID for', u'Aaron Diehl Trio')
# AUTOUR DE LA GUITARE
# ('NOMBID for', u'AUTOUR DE LA GUITARE')
# ASHES WARRIORS
# ('NOMBID for', u'ASHES WARRIORS')
# AXEL TONY
# ('NOMBID for', u'AXEL TONY')
# ANTICEPTIK
# ('NOMBID for', u'ANTICEPTIK')
# ANATHEMA - official band page
# aartist_mbid 3d21b44c-8ddf-4513-b130-f5c019382680
# ANATHEMA - official band page
#
# ALLEN
# ('NOMBID for', u'ALLEN')
# ALCINA
# ('NOMBID for', u'ALCINA')
# AKASAVA
# ('NOMBID for', u'AKASAVA')
# AGATHE IRACEMA
# ('NOMBID for', u'AGATHE IRACEMA')
# ADRIEN MOIGNARD
# ('NOMBID for', u'ADRIEN MOIGNARD')
# A2H
# ('NOMBID for', u'A2H')
# 999
# aartist_mbid 90967f7a-dccf-43f8-a212-e84b34e24a7d
# pppppppppppppp
# 999
#
# 49 Swimming Pools
# ('NOMBID for', u'49 Swimming Pools')
# 89 Proposal
# ('NOMBID for', u'89 Proposal')
# 3D
# aartist_mbid bb0bafca-82df-46d7-ae80-8ea89943b1af
# 3D
#
# 2 Funky
# ('NOMBID for', u'2 Funky')
# 2Vilas
# ('NOMBID for', u'2Vilas')
# Ambrose Akinmusire
# ('NOMBID for', u'Ambrose Akinmusire')
# Amadou Bagayoko
# ('NOMBID for', u'Amadou Bagayoko')
# Alvin Ailey
# aartist_mbid a7eb7bcd-090f-4ae0-8547-dab1e0318e1b
# Alvin Ailey
#
# Alt
# aartist_mbid b500fb6b-3209-4689-9ef9-02eaaa489843
# pppppppppppppp
# Alt
#
# Alpha
# aartist_mbid 473ad870-79c2-456b-9680-4a73162b59c0
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Alpha
#
# Allen Toussaint
# aartist_mbid ec21cced-2d22-4883-9ee3-f642e6e52f58
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Allen Toussaint
#
# Allan
# ('NOMBID for', u'Allan')
# Alisa Weilerstein
# ('NOMBID for', u'Alisa Weilerstein')
# Alfredo Rodríguez
# aartist_mbid 8d7fb4b0-dcc7-471d-80df-f769d79a89ae
# pppppppppppppp
# Alfredo Rodríguez
#
# Alexkid
# ('NOMBID for', u'Alexkid')
# Alexi Delano
# aartist_mbid 864a0bdc-cb4c-4953-97c7-e96407c73042
# Alexi Delano
#
# Alexander Nut
# aartist_mbid 8f193440-687c-4636-a2ba-9dff18254557
# Alexander Nut
#
# Alex Finkin
# ('NOMBID for', u'Alex Finkin')
# Alcest -official-
# aartist_mbid dd77b8da-cdc7-46b8-8a7f-10894ca0490e
# Alcest -official-
#
# Alaine
# aartist_mbid e64ced44-2dc9-4f57-9017-b8fd028e4041
# Alaine
#
# Alain Morisod & Sweet People
# aartist_mbid 14ed2314-24e2-4a9a-a20e-4700137b4b29
# pppppppppppppp
# Alain Morisod & Sweet People
#
# Alabama Shakes
# ('NOMBID for', u'Alabama Shakes')
# Al Core
# aartist_mbid 7464f3d3-45f8-45a7-b872-354d32cc04a2
# Al Core
#
# Akram Khan
# ('NOMBID for', u'Akram Khan')
# Ajja
# aartist_mbid 6e6e3359-1291-4a71-83d2-181c5ece4acd
# Ajja
#
# Aim
# aartist_mbid 8e678953-c97b-435b-af18-2425b6db71d0
# pppppppppppppp
# Aim
#
# Agua Roja
# ('NOMBID for', u'Agua Roja')
# Against The Current
# ('NOMBID for', u'Against The Current')
# Afro Social Club
# ('NOMBID for', u'Afro Social Club')
# Aert Prog
# ('NOMBID for', u'Aert Prog')
# Adina Paun
# ('NOMBID for', u'Adina Paun')
# Adana Twins
# ('NOMBID for', u'Adana Twins')
# Absded
# ('NOMBID for', u'Absded')
# Abi
# aartist_mbid a340dfa2-3e6c-42da-b0d1-7beeedf231b6
# Abi
#
# AZIZ SAHMAOUI
# ('NOMBID for', u'AZIZ SAHMAOUI')
# ASTROCLUB
# ('NOMBID for', u'ASTROCLUB')
# ASAP Rocky
# ('NOMBID for', u'ASAP Rocky')
# ASAF
# ('NOMBID for', u'ASAF')
# ANDY Foursix
# ('NOMBID for', u'ANDY Foursix')
# ALPAGE RECORDS
# ('NOMBID for', u'ALPAGE RECORDS')
# ALL ACCESS ENTERTAINMENT GmbH
# ('NOMBID for', u'ALL ACCESS ENTERTAINMENT GmbH')
# ALAIN JEAN MARIE
# ('NOMBID for', u'ALAIN JEAN MARIE')
# AK47
# aartist_mbid 23302c59-dcd9-4a70-902f-88ff62b9f13e
# AK47
#
# ABRAMOVIČ
# ('NOMBID for', u'ABRAMOVI\u010c')
# A.Paul
# ('NOMBID for', u'A.Paul')
# A State of Mind
# aartist_mbid d2d9fc16-27ba-4399-888d-cabd65cb5fac
# A State of Mind
#
# 7 Seconds
# aartist_mbid 3594dd1c-1267-471f-a6e2-78978bb3e024
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# 7 Seconds
#
# A Call at Nausicaa
# ('NOMBID for', u'A Call at Nausicaa')
# 2b2
# ('NOMBID for', u'2b2')
# 16 THE DAY
# ('NOMBID for', u'16 THE DAY')
# 1200 Micrograms
# aartist_mbid bf346e67-b4b1-41c0-bcc7-a8f4df4fbbbb
# pppppppppppppp
# 1200 Micrograms
#
# ALEX GRENIER
# ('NOMBID for', u'ALEX GRENIER')
# AIRNADETTE
# ('NOMBID for', u'AIRNADETTE')
# ADX
# aartist_mbid 46c470bf-575f-4821-928b-91c2cd663e95
# pppppppppppppp
# pppppppppppppp
# ADX
#
# ABOVE THE NORTH
# ('NOMBID for', u'ABOVE THE NORTH')
# A-Vox
# ('NOMBID for', u'A-Vox')
# A Filetta
# aartist_mbid 501c34d0-8376-4ae7-af01-0c4f77ee1ade
# pppppppppppppp
# A Filetta
#
# 58 Shots
# ('NOMBID for', u'58 Shots')
# 9 o'Clock
# ('NOMBID for', u"9 o'Clock")
# 42195
# ('NOMBID for', u'42195')
# 2Y'S
# ('NOMBID for', u"2Y'S")
# 'Anastasia
# ('NOMBID for', u"'Anastasia")
# Addison Groove
# ('NOMBID for', u'Addison Groove')
# Adam Wood
# ('NOMBID for', u'Adam Wood')
# Adam Ben Ezra
# ('NOMBID for', u'Adam Ben Ezra')
# Acorps de Rue
# ('NOMBID for', u'Acorps de Rue')
# Accept
# aartist_mbid 41f4d85a-0bd7-4602-a3e3-8c47f36efb0a
# pppppppppppppp
# Accept
#
# Abou Diarra
# ('NOMBID for', u'Abou Diarra')
# Abd al Malik
# aartist_mbid 4c7a7959-7cf8-4de8-b7b7-6fe83122926b
# Abd al Malik
#
# Aazar
# ('NOMBID for', u'Aazar')
# AYMERIC
# ('NOMBID for', u'AYMERIC')
# ASK AFTER B
# ('NOMBID for', u'ASK AFTER B')
# ANGELIQUE IONATOS
# ('NOMBID for', u'ANGELIQUE IONATOS')
# ANDRE GALLUZZI
# ('NOMBID for', u'ANDRE GALLUZZI')
# ALMOND
# ('NOMBID for', u'ALMOND')
# ALEM
# ('NOMBID for', u'ALEM')
# AKO
# aartist_mbid de0a8c33-ae0f-4d7c-9962-36042418e135
# AKO
#
# AGATHE JAZZ QUARTET
# ('NOMBID for', u'AGATHE JAZZ QUARTET')
# ADSR
# ('NOMBID for', u'ADSR')
# A state of mind (ASM)
# ('NOMBID for', u'A state of mind (ASM)')
# A Failing Devotion
# ('NOMBID for', u'A Failing Devotion')
# 4korners
# ('NOMBID for', u'4korners')
# 9 Fake Reasons
# ('NOMBID for', u'9 Fake Reasons')
# 3sOmEsiStERs
# ('NOMBID for', u'3sOmEsiStERs')
# 2 Many DJ's
# aartist_mbid 82dc508a-dbda-4954-aedc-28895edfa42e
# pppppppppppppp
# pppppppppppppp
# NORELEASEDATE2
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# 2 Many DJ's
#
# {'22c1ac7e-ebee-4749-9a28-0d27ea35d3f1': {'label': {'name': u'\u30c7\u30a3\u30b9\u30af\u30e6\u30cb\u30aa\u30f3', 'area': {'sort-name': 'Japan', 'iso-3166-1-code-list': ['JP'], 'id': '2db42837-c832-3c27-b4a3-08198f75693c', 'name': 'Japan'}, 'country': 'JP', 'alias-count': 2, 'sort-name': u'\u30c7\u30a3\u30b9\u30af\u30e6\u30cb\u30aa\u30f3', 'alias-list': [{'sort-name': 'disc union', 'alias': 'disc union'}, {'sort-name': u'\u30c7\u30a3\u30b9\u30af\u30fb\u30e6\u30cb\u30aa\u30f3', 'type': 'Search hint', 'alias': u'\u30c7\u30a3\u30b9\u30af\u30fb\u30e6\u30cb\u30aa\u30f3'}], 'label-relation-list': [{'type-id': 'ab7a9be0-c060-4852-8f2e-4faf5b33231e', 'type': 'label ownership', 'target': '8ef7e9b8-4125-4c2d-8e85-e3d47139b9d4', 'label': {'sort-name': u'\u662d\u548c\u6b4c\u8b21\u30b8\u30e5\u30fc\u30af\u30dc\u30c3\u30af\u30b9', 'id': '8ef7e9b8-4125-4c2d-8e85-e3d47139b9d4', 'name': u'\u662d\u548c\u6b4c\u8b21\u30b8\u30e5\u30fc\u30af\u30dc\u30c3\u30af\u30b9'}}], 'id': '22c1ac7e-ebee-4749-9a28-0d27ea35d3f1'}}, 'e39982c8-5d30-4cc0-bd2f-a878985a0706': {'label': {'name': 'Architecture', 'area': {'sort-name': 'Australia', 'iso-3166-1-code-list': ['AU'], 'id': '106e0bec-b638-3b37-b731-f53d507dc00e', 'name': 'Australia'}, 'country': 'AU', 'disambiguation': 'Australian', 'alias-count': 1, 'sort-name': 'Architecture', 'alias-list': [{'sort-name': 'Architecture label', 'alias': 'Architecture label'}], 'type': 'Original Production', 'id': 'e39982c8-5d30-4cc0-bd2f-a878985a0706'}}, '6635675b-d3a0-4c7b-be84-ffa779fd8266': {'label': {'sort-name': 'Guerilla Asso', 'name': 'Guerilla Asso', 'area': {'sort-name': 'France', 'iso-3166-1-code-list': ['FR'], 'id': '08310658-51eb-3801-80de-5a0739207115', 'name': 'France'}, 'country': 'FR', 'type': 'Original Production', 'id': '6635675b-d3a0-4c7b-be84-ffa779fd8266'}}, '9012c9b0-e3e4-41e5-bea0-e9073195040a': {'label': {'sort-name': 'Satta', 'name': 'Satta', 'area': {'sort-name': 'Italy', 'iso-3166-1-code-list': ['IT'], 'id': 'c6500277-9a3d-349b-bf30-41afdbf42add', 'name': 'Italy'}, 'country': 'IT', 'type': 'Original Production', 'id': '9012c9b0-e3e4-41e5-bea0-e9073195040a'}}, 'c0d5f506-e3e4-47d7-8b91-4e6579f67273': {'label': {'name': 'Magic Records', 'area': {'sort-name': 'France', 'iso-3166-1-code-list': ['FR'], 'id': '08310658-51eb-3801-80de-5a0739207115', 'name': 'France'}, 'country': 'FR', 'disambiguation': 'France', 'annotation': {'text': u'MAGIC Records is a specialized label in the reissue of " variety " artists of the 50\'s, 60\u2019s, 70\u2019s and 80\u2019s. This work of reissue will permit to discover or rediscover recordings only owned by the collectors, most of the time very demanded by the general public. MAGIC chooses the recordings in the repertory of the most prestigious artists of these decades.\n\nA collector packaging, but also a selection of rare or unissued titles in CD. Systematic remastering from the original masters tapes. The CD is provided with a booklet: original sleeves copies and french historical information. Each volume gathers for each artist, all the 7\u2019\u2019 4 titles and 2 titles completed by rare or unissued titles.'}, 'sort-name': 'Magic Records', 'type': 'Reissue Production', 'id': 'c0d5f506-e3e4-47d7-8b91-4e6579f67273'}}, '7d12a153-0967-4728-b656-510917daca0d': {'label': {'sort-name': 'Scion Audio/Visual', 'alias-list': [{'sort-name': 'Scion A/V', 'alias': 'Scion A/V'}], 'name': 'Scion Audio/Visual', 'area': {'sort-name': 'United States', 'iso-3166-1-code-list': ['US'], 'id': '489ce91b-6658-3307-9877-795b68554c98', 'name': 'United States'}, 'country': 'US', 'id': '7d12a153-0967-4728-b656-510917daca0d', 'alias-count': 1}}, '6cae749e-6464-410b-89bd-465f8f19c75c': {'label': {'name': 'Z-Label', 'life-span': {'begin': '1999'}, 'area': {'sort-name': 'Japan', 'iso-3166-1-code-list': ['JP'], 'id': '2db42837-c832-3c27-b4a3-08198f75693c', 'name': 'Japan'}, 'country': 'JP', 'disambiguation': 'hard rock / heavy metal label', 'alias-count': 1, 'sort-name': 'Z-Label', 'alias-list': [{'sor ...
