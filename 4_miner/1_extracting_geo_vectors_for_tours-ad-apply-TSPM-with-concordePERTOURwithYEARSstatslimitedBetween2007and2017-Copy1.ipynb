# %%
# %matplotlib inline

##THIS IS FOR ACCESSING THE CONCORDE TSP SOLVER
from subprocess import Popen

import os
class tsp:
    def __init__(self, points=None):
        self.points = points if points else []
    def solve(self, filename='_tmp_'):
        with open('%s.dat' % filename, 'w') as fp:
            fp.write('TYPE : TSP\nDIMENSION : %d\n' % len(self.points))
            fp.write('EDGE_WEIGHT_TYPE : GEO\nNODE_COORD_SECTION\n')
            for i, (x, y) in enumerate(self.points):
                fp.write('%d %g %g\n' % (i, x, y))
            fp.write('EOF\n')
        prc = Popen('./concorde   -m %s.dat' % filename, shell=True)
        prc.wait()
        with open('%s.sol' % filename) as fp:
            ll = (''.join(fp)).split()
        self.result = [int(s) for s in ll[1:]]
        for s in ('%s.dat', '%s.sol'): os.remove(s % filename)

# %%
##THIS I FOR ACCESSING THE CONCORDE TSP SOLVER BZCKUP,SWITCHING TO GEO
#from subprocess import Popen
#import os
#class tsp:
#    def __init__(self, points=None):
#        self.points = points if points else []
#    def solve(self, filename='_tmp_'):
#        with open('%s.dat' % filename, 'w') as fp:
#            fp.write('TYPE : TSP\nDIMENSION : %d\n' % len(self.points))
#            fp.write('EDGE_WEIGHT_TYPE : EUC_2D\nNODE_COORD_SECTION\n')
#            for i, (x, y) in enumerate(self.points):
#                fp.write('%d %g %g\n' % (i, x, y))
#            fp.write('EOF\n')
#        prc = Popen('./concorde -m  %s.dat' % filename, shell=True)
#        prc.wait()
#        with open('%s.sol' % filename) as fp:
#            ll = (''.join(fp)).split()
#        self.result = [int(s) for s in ll[1:]]
#        for s in ('%s.dat', '%s.sol'): os.remove(s % filename)

# %%
import geopy
import pickle
import json
import pymongo
from geopy.distance import geodesic
#import musicbrainzngs
import arrow
from datetime import datetime
from pymongo import MongoClient
from collections import defaultdict
from dateutil import parser
from slugify import slugify
import math
from numbers import Number

# setup mongo
client = MongoClient()
db = client["bandstour"]
bandsintown =  db["bandsintown"]

# date parsing
DATETIME_FORMAT = '%Y-%m-%dT%H:%M:%S'
DATETIME_FORMAT_FOR_MSBNZ ='%Y-%m-%d'

#retrieve trip coords for each artist
dict_coords={}

import numpy as np
from matplotlib import pyplot as plt

# %%
#INITIALIZE
import operator
final={}
totalDists=0
totalOptDists=0
totalOptDistsMin=0
#for artist in db.minedArtists.find({ 'name' : 'David Guetta' }) :
#for artist in db.minedArtists.find({ 'name' : 'Vokab Kompany' }) :
#for artist in db.minedArtists.find({ 'name' : 'Ural Kosaken Chor' }) :
#for artist in db.minedArtists.find({ 'name' : 'Leo Kottke' }) :
#for artist in db.minedArtists.find({ 'name' : 'Björk' }) :
#for artist in db.minedArtists.find({ 'name' : 'Deerhoof' }) :
#for artist in db.minedArtists.find({ 'name' : 'Legends' }) :
#for artist in db.minedArtists.find({ 'name' : 'Laidback Luke' }) :
#for artist in db.minedArtists.find({ 'name' : 'Andy Moor' }) :
#for artist in db.minedArtists.find({ 'name' : 'Mia' }) :
#for artist in db.minedArtists.find({ 'name' : 'Dead Kennedys' }) :
#for artist in db.minedArtists.find({ 'name' : 'House of Pain' }) :
for artist in db.minedArtists.find(no_cursor_timeout=True) :
 print artist["name"],"/",int(round(artist["co2Spent"],-1))
# final[artist["name"]]=artist["co2Spent"]
# Out:
#  Adestria, Erra / 2080
#  Joey Cape, Jon Snodgrass & Brian Wahlstrom / 2120
#  Novustory / 790
#  Phil Campbell and the Bastard Sons / 6510
# !!! / 242810
# "Acoustic Africa" / 6420
# "Scream The Prayer" / 2930
# "Super DJ" Romeo / 0
# #1 Dads / 2520
# #PushYourDrumming / 6720
# #PushYourDrumming/RolandVDrums / 2230
# $uicideboy$ / 19350
# $wingin' Utter$ / 25020
# '77 / 4430
# 'Stache! / 10860
# 'Thee' Duke of Dark / 7180
# (IAM)WARFACE / 190
# (N)ception / 180
# (de)absolve / 1730
# (həd) p.e. / 309970
# -- The CELL ---- Southern-Fried Bohemian Blues-Rock -- / 610
# -=HAVEN=- music / 340
# ...And The Hangnails / 590
# ...And You Will Know Us by the Trail of Dead / 7640
# .357 Lover / 530
# .38 Special / 181010
# 01 / 4070
# 070 SHAKE / 10090
# 070shake / 3710
# 0hnoes / 0
# 0phe1ia / 3770
# 1 AMAZING SHOW-THINK PINK FLOYD / 1450
# 1 Girl Nation / 1200
# 1 Last Chance / 22830
# 1 in Five / 200
# 1-800 DINOSAUR / 16750
# 1-O.A.K. / 1570
# 10 / 140750
# 10 000 Russos / 1490
# 10 String Symphony / 78060
# 10 Years / 177020
# 10,000 Days (a Tribute to Tool) / 250
# 10,000 Maniacs / 47760
# 100 Fables / 600
# 100 Proof / 10770
# 100 Watt Mind / 490
# 1000 Miles of Fire / 1870
# 10000 RUSSOS / 980
# 1000Mods / 15580
# 1001 / 4680
# 101 Proof / 40
# 10cc / 72180
# 10th Letter / 1220
# 112 / 127450
# 11th Hour / 4200
# 11th Hour Gospel Group / 6160
# 12 / 78560
# 12 Gauge Awakening / 60
# 12 Stones / 79080
# 123 Schtunk / 210
# 12th Avenue Hot Club / 0
# 12th Planet / 282940
# 13 Crowes / 1470
# 13 Nails / 840
# 13 Scars / 3790
# 1349 / 20390
# 138 / 15920
# 14 / 26870
# 143 / 0
# 15 / 45130
# 16 / 6900
# 16 THE DAY / 50
# 1605 / 8680
# 16BIT / 52090
# 17 / 14730
# 17 Hippies / 42280
# 1776 / 3900
# 182 - UK Tribute Act To Blink 182 / 2510
# 187 Strassenbande / 2240
# 18th & Addison / 6150
# 1910 Fruitgum Company / 3520
# 1939 Ensemble / 2670
# 1977 / 31310
# 1988 / 14200
# 19th Street Band / 2610
# 1Lady / 13000
# 1accord / 0
# 2 Bad Mice / 7670
# 2 Blyga Läppar / 1250
# 2 CELLOS / 20450
# 2 Chainz / 229900
# 2 Dudes with Acoustic Guitars / 90
# 2 Elements / 7380
# 2 IN THE CHEST / 2230
# 2 Many DJ's / 231770
# 2 Men will move you / 0
# 2 Mile Final / 6800
# 2 Rude / 160
# 2 Sick Monkeys / 1040
# 2 Tone Lizard Kings / 1390
# 20 Reasons Taken / 330
# 20 Syl / 1140
# 20 Watt Tombstone / 14150
# 2011 / 37420
# 2017 / 59930
# 21 / 73690
# 21 Savage / 44880
# 219 Boys / 6880
# 22 / 53750
# 22 Top / 700
# 222 / 7520
# 23 / 34100
# 23 Deluxe / 470
# 24 HORAS / 2150
# 24HRS / 8220
# 257ers / 9240
# 25th anniversary tour / 4240
# 27 Club / 3860
# 28 Degrees Taurus / 2270
# 28 Double / 80
# 28DAYS / 35950
# 29TH STREET SWINGTET / 0
# 2BAL / 2620
# 2Bangers / 70
# 2Cellos / 133360
# 2Elements / 10730
# 2Elements Fanpage / 50450
# 2Empress / 63300
# 2FingerJester Band / 60
# 2Hot2Handle All-Female UFO Tribute / 130
# 2MX2 / 1350
# 2Steel Girls / 3290
# 2Tone / 8650
# 2X4 / 3570
# 2b2 / 5550
# 2far2jump / 90
# 2fer1 / 0
# 2nd II None / 1360
# 2nd Room / 14930
# 2nd Wind Band / 590
# 2raumwohnung / 6820
# 3 / 1800
# 3 Daft Monkeys / 11060
# 3 Dayz Whizkey / 680
# 3 Deep / 5280
# 3 Doors Down / 182240
# 3 Doors Down Acoustic / 1120
# 3 Finger Betty / 70
# 3 Inches of Blood / 14160
# 3 Legged Willie / 180
# 3 Minute Hero / 870
# 3 Parts Dead / 1770
# 3 Penny Acre / 810
# 3 Pill Morning / 27310
# 3 West / 19080
# 3 Years Hollow / 21300
# 3 for 3 / 3160
# 30 / 250320
# 300 Days / 60
# 30footFALL / 210
# 31 / 15480
# 311 / 166390
# 32 Below / 44920
# 32 Pints / 1340
# 32headshots / 1050
# 33 AD / 1730
# 33 Years / 13450
# 33Miles / 1850
# 34 / 0
# 36 Crazyfists / 20690
# 36 Crazyfists, Skinlab & All Hail the Yeti / 2880
# 3AM / 16160
# 3D / 360
# 3Eighty3 / 4750
# 3Hattrio / 4010
# 3LAU / 238300
# 3OH!3 / 15420
# 3PEACE / 190
# 3PM / 540
# 3RDegree / 13840
# 3TEETH / 22970
# 3rd / 10010
# 3rd Degree - band / 50
# 3rd Dimension / 130
# 3rd Sunday / 1360
# 3sOmEsiStERs / 2740
# 4 Aspirin Morning / 210
# 4 Daze Dead / 4120
# 4 Door Theatre / 1320
# 4 Minute Warning / 3360
# 4 One Quartet / 3510
# 4 Past Midnight / 15590
# 4 Promille / 1560
# 40 Akerz / 24660
# 40 Below Summer / 9970
# 40 oz. To Freedom / 111820
# 40oz Burrito: A Tribute to Sublime / 2110
# 42Radar / 130
# 42nd Street / 57530
# 45 Adapters / 2060
# 45 RPM / 1860
# 45 rpm NY / 2790
# 45RPM / 70
# 45rpmny / 430
# 47SOUL / 12170
# 4Dudes / 20
# 4PZ / 240
# 4ey the Future / 5390
# 4onthefloor / 62030
# 4th / 18540
# 4th Curtis / 10
# 4th Dimension / 87060
# 4th Labyrinth / 1050
# 4th Street / 16930
# 5 Billion and Counting / 380
# 5 Seconds of Summer / 148420
# 5 Stories / 2850
# 50 / 6850
# 50 Caliber Crisis / 210
# 50 Cent / 139830
# 500 Miles to Memphis / 24670
# 5150 / 1120
# 52nd Street - Playing the Music of Billy Joel / 70
# 56DAZE / 180
# 57 State / 430
# 58 Shots / 2320
# 5ha5h / 100
# 5ive / 52940
# 5j Barrow / 2850
# 5prite / 530
# 5th Avenue Hamburg / 630
# 5th Element Band / 10
# 6 Million Dollar Band / 730
# 6 String Drag / 3950
# 6'10 / 190
# 60 / 8860
# 609 / 1510
# 64 To Grayson / 19590
# 65 Shapeshifters / 10
# 65daysofstatic / 137100
# 68 / 111030
# 69db / 11060
# 6LACK / 11990
# 7 Come 11 / 6570
# 7 Dials Mystery / 560
# 7 Horns 7 Eyes / 3850
# 7 Minutes in Heaven / 7370
# 7 Seconds / 80110
# 7 Stone Riot / 1980
# 7 WEEKS / 19120
# 70's / 20490
# 74th Street Band / 6490
# 75 Dollar Bill / 6810
# 7EVENTH TIME DOWN / 88410
# 7Horse / 21420
# 7he 7ouch / 10
# 7th Circle / 4390
# 7th Heaven / 4880
# 8 Ball Aitken / 158380
# 8 SECOND RIDE / 1490
# 8 Track Massacre / 470
# 8-bit creeps / 90
# 80 / 9010
# 80 Proof / 930
# 80's Proof / 1590
# 80's and 90's Throwback Party / 0
# 800 lb Gorilla / 2400
# 808 State / 28010
# 8123 tour / 630
# 82fifty / 40
# 88 Fingers Louie / 21590
# 88 Fingers' Shows / 3220
# 888 / 18520
# 88er / 220
# 8Ball Booking / 1230
# 8Lb Pressure / 2480
# 8bitsf / 0
# 8erl in Ehr'n / 1820
# 8kids / 3140
# 9 1 1 / 26310
# 9 Mile Roots / 4870
# 90 Proof Therapist / 330
# 90 Proof Twang / 12120
# 90's / 57920
# 908 / 1200
# 90s Television / 20
# 91 All Stars / 40
# 97 Nine / 45020
# 98 Degrees / 6410
# 99 Crimes / 220
# 99 Luftballons / 0
# 99.9 KISW PAIN IN THE GRASS / 120
# 999 / 17140
# 999999999 / 3460
# 9Bach / 1190
# 9ELECTRIC / 5410
# ::: Su Ta Gar ::: / 3850
# :::KILLCODE::: / 5290
# :lovesongs / 0
# ?uestlove / 7200
# A BOOGIE WIT DA HOODIE / 21040
# A Band Called E / 13720
# A Band of Bitches / 3530
# A Band of Orcs / 9240
# A Bleeding Sky / 40
# A Breakthrough In Field Studies / 10
# A Brilliant Lie / 3310
# A Bronx Tale / 12230
# A Brother's Fountain / 260
# A Burden to Bear / 120
# A Certain Ratio / 5220
# A Charlie Brown Christmas / 15510
# A Chorus Line / 67780
# A Christmas Carol / 73300
# A Christmas Story / 17970
# A Club Called Rhonda / 1470
# A Cold Trip Nowhere / 580
# A Collective Subconscious / 120
# A Crowd Like You / 1670
# A D A I R / 3280
# A DECADE OF SOUL / 270
# A Dangerous Affair / 3450
# A Dark Orbit / 20
# A Day At The Races / 2130
# A Day To Remember / 420970
# A Day Without Love / 4690
# A Dead Forest Index / 10870
# A Deathbed Promise / 380
# A Deer A Horse / 4580
# A Devil's Daydream / 40
# A Drug Called Tradition / 620
# A Dying Ultimatum / 420
# A F K / 54070
# A FRIEND / 2580
# A FUNNY THING HAPPENED ON THE WAY TO THE FORUM / 8870
# A Fall From Break / 1150
# A Fall To Break / 2780
# A Faylene Sky / 1980
# A Ferocious Jungle Cat / 820
# A Fistful of Soul / 10
# A Flock of Seagulls / 5020
# A Flourishing Scourge / 2080
# A Friend A Foe / 280
# A Gentleman's Guide to Love and Murder / 22560
# A Global Threat / 5920
# A Good Rogering / 870
# A Great Big Pile of Leaves / 6770
# A Great Big World / 9220
# A Guy Called Gerald / 124880
# A Hanging / 180
# A Hard Knock Life / 230
# A Horse A Spoon A Bucket / 890
# A John Waters Christmas / 24420
# A Killer's Confession / 5430
# A Killers Confession / 2430
# A LIGHT WITHIN / 140
# A Lapse of Ethos / 50
# A Legacy Unwritten / 1280
# A Life Divided / 830
# A Life Once Lost / 5660
# A Life Set Apart / 1760
# A Light Among Many / 400
# A Light Divided / 7510
# A Little Less Human / 10
# A Live One / 820
# A Loss for Words / 28420
# A Lot Like Birds / 15920
# A Love From Outer Space / 4240
# A Means To An End / 380
# A Metal Christmas & A Heavy New Year Tour / 970
# A Midnight Tragedy / 470
# A Midnight Tragedy (Official) / 1730
# A Million Dead Birds Laughing / 1410
# A Minor Revolution / 1320
# A Mirrors Embrace / 390
# A Mission / 33050
# A New Hope / 2570
# A New Tomorrow / 9570
# A New World / 21750
# A Night / 466130
# A Night of Worship / 12080
# A PALE HORSE NAMED DEATH / 2710
# A PLACE IN TIME / 890
# A Perfect Circle / 7820
# A Place to Bury Strangers / 14940
# A Plea For Purging Official / 3620
# A Poison Alibi / 1240
# A Pony Named Olga / 18140
# A Primitive Evolution / 930
# A Quatre Épingles / 2360
# A R I Z O N A / 50410
# A Ritual Spirit / 200
# A Rumor Of War / 10
# A SILENT TRUTH / 110
# A Scent Like Wolves / 16420
# A Sense of Purpose / 490
# A Shadow of Jaguar / 9980
# A Skylit Drive / 34720
# A Sounding Sea / 1250
# A State of Grace - Tribute to Tim and Jeff Buckley / 1360
# A State of Mind / 12540
# A Story Inspired / 1640
# A Story Told / 4340
# A Story Unwritten / 500
# A Strength Within / 420
# A Summer Better Than Yours / 9400
# A Sundae Drive / 270
# A TIGER LILY / 1050
# A Tale of Two Cities / 6810
# A Taste of Daylight / 90
# A Thousand Enemies / 100
# A Thousand Horses / 101870
# A Tower Of Crows / 100
# A Traitor Like Judas / 2560
# A Tribe Called Quest / 40860
# A Tribe Called Red / 75400
# A VOID / 130
# A Very Merry Christmas Acoustic Tour / 800
# A Vibrant Lye / 0
# A Wake In Providence / 18240
# A War Within / 26510
# A Wasted Effort / 3400
# A Wilhelm Scream / 257670
# A Will Away / 30150
# A Wolf in the City / 100
# A Work Of Fiction / 1770
# A World Extinct / 50
# A hero build / 1420
# A la Mode / 21730
# A$AP Ferg / 137050
# A-1 / 2410
# A-F-R-O / 25410
# A-GAME / 12160
# A-Mac & The Height / 9370
# A-Rock / 24290
# A-Trak / 612520
# A-Vox / 2160
# A-WA / 46570
# A. G. Cook / 18220
# A. J. LeGrand / 2110
# A. R. Rahman / 46280
# A. Sinclair / 9100
# A.A. Bondy / 2520
# A.C. Myles / 250
# A.D.D. / 9260
# A.D.H.S. / 10
# A.D.M. / 400
# A.J. Croce / 82290
# A.J. Fullerton  / 2480
# A.M. Mills / 0
# A.N.A.L. Alles Nur Aus Liebe / 14600
# A.N.S. / 5180
# A.P. Appleberry / 4370
# A.Professor / 450
# A.Skillz / 96360
# A.V.N. / 910
# A.Z.  / 68090
# A1 / 49020
# AADEN / 1270
# ABBA Gold The Concert Show / 10050
# ABBA Mania / 241890
# ABBA the Music / 24710
# ABBI PRESS / 10
# ABC / 82670
# ABDULLA RASHIM / 91620
# ABK / 85520
# ABSENCE OF DESPAIR / 23340
# AC Slater / 366370
# AC/DC / 19630
# ACH / 610
# ACI Entertainment / 120
# ACKER / 9000
# ACLU Benefit / 3050
# ACODA / 190
# ACOUSTIC / 174030
# ACOUSTICALLY SPEAKING / 870
# ACxDC / 5690
# ADD / 7650
# ADHD / 37140
# ADHD Entertainment / 1260
# ADRIEN MOIGNARD / 1620
# ADULT. / 7420
# ADULT. (Official)  / 35810
# ADX / 4920
# AFFIANCE / 100200
# AFI / 130500
# AFK / 36200
# AFTON SHOWCASE / 83870
# AG / 66280
# AGAPE* (Dave Scherer) / 18460
# AGE TENDRE / 10270
# AH-Effects / 10
# AHNEST! / 270
# AHoriBuzz / 620
# AIR / 117170
# AIR RAID / 9690
# AIRNADETTE / 4380
# AJ Castillo / 6350
# AJ Croce / 24020
# AJ Davila & Terror Amor / 980
# AJ Froman / 4040
# AJ Ghent Band / 26730
# AJ Hobbs / 12490
# AJ Lehrman / 11740
# AJ McQueen / 220
# AJ Pero / 1940
# AJ Rafael / 14480
# AJ Smith / 3020
# AJ Tracey / 24560
# AJJ / 7210
# AJR / 42010
# AK1200 / 61530
# AKA AKA / 23610
# AKA Faceless / 3690
# AKANI / 470
# AKIR / 1260
# AKLI D. / 0
# AL / 128120
# ALA.NI / 26860
# ALADDIN / 314290
# ALADIN 135 / 1460
# ALAN CORBEL / 6950
# ALAN JONES / 4560
# ALASKALASKA / 10
# ALAZKA / 15070
# ALB / 5790
# ALBARE / 52510
# ALBERT MESLAY / 820
# ALBUCREEPY Downtown Ghost Walk / 90
# ALE CASTRO / 9100
# ALEM / 5230
# ALEQS NOTAL / 26060
# ALEX BREITLING / 380
# ALEX CARO / 14360
# ALEX GRENIER / 8910
# ALEX MOFA GANG / 6950
# ALEX PASTERNAK / 1380
# ALEX STREET / 3610
# ALGEBRA BLESSETT / 7660
# ALIA (US) / 6450
# ALICE IM WUNDERLAND / 2460
# ALKI Jones / 2010
# ALL ACCESS ENTERTAINMENT GmbH / 5410
# ALL WILL KNOW / 470
# ALL4DORAS / 20
# ALLAOUA / 510
# ALLFACESDOWN / 11340
# ALLHAZERED / 140
# ALLISON POLANS / 490
# ALO / 91670
# ALXXA / 11200
# AM / 49140
# AM & Shawn Lee / 1260
# AM Exchange / 3370
# AM Taxi / 470
# AME / 419980
# AMP Trio / 3010
# AMS / 11570
# AMTRAC / 89920
# AMY BLACK / 29820
# AN21 / 13140
# ANAKRONIC / 2250
# ANCIIENTS / 32990
# ANDRE GALLUZZI / 92180
# ANDRE MANOUKIAN / 7570
# ANDRE MINVIELLE / 5080
# ANDREAS RAUSCHER / 840
# ANDREAS TOME / 940
# ANGEL DU$T / 40200
# ANGELIQUE IONATOS / 4020
# ANGER MANAGEMENT / 6350
# ANIMA (Official) / 2280
# ANIMI VOX / 1030
# ANNA RF / 2000
# ANNE ROUMANOFF / 11610
# ANNIX / 56350
# ANONYMOUS / 5390
# ANORAAK / 85490
# ANT ANTIC / 430
# ANTA / 2040
# ANTHONY JAMBON GROUP / 0
# ANTISERUM / 133720
# ANTISTAR / 4550
# ANTiSEEN / 32020
# ANiMAL / 84660
# AOA / 12710
# AOE / 0
# AOK Music / 990
# APATT / 1090
# APOCALYPTICA PLAYS METALLICA BY FOUR CELLOS / 5240
# ARAABMUZIK / 4590
# ARAT KILO / 2110
# ARCHITECTS (UK) / 4060
# ARISA / 6600
# ARIUS / 33450
# ARMNHMR / 13390
# ARMS / 80310
# ARNAUD DOLMEN / 6150
# AROUND THE WORLD / 31420
# ARPANET / 1610
# ART GRAY NOIZZ QUINTET / 90
# ART OF SHOCK / 7320
# ARTIK / 70
# ARW / 17850
# ARY ABITTAN / 3040
# AS YOU LIKE IT / 18730
# ASA 808 / 3150
# ASAP Ferg / 121560
# ASAP Rocky / 18750
# ASG / 16440
# ASHTON BROTHERS / 240
# ASIO / 990
# ASK AFTER B / 270
# ASSASSINS / 5000
# ASTR / 3420
# ATB / 358130
# ATB - The best DJ in the World / 27360
# ATEQ / 48380
# ATFC / 26070
# ATLiens / 24730
# ATN Stadwijk-keys / 1610
# ATOMIC LOVE / 780
# ATOMO / 0
# ATTARI / 58070
# ATTEMPT / 5410
# AUDAZ / 2460
# AUNTY DONNA / 15250
# AURA NOIR [official] / 25090
# AURE / 3360
# AURELIE CABREL / 900
# AUTOBAHN / 44150
# AUTORYNO / 310
# AVADOX / 46910
# AVALANCHE PARTY / 2510
# AVALON CELTIC DANCES / 4290
# AVANTIST / 460
# AVI BORTNICK Guitarist / 9090
# AVN / 1920
# AVOID / 42960
# AWAY Soundsystem / 10
# AWOL / 85830
# AWOLNATION / 218090
# AWOOGA / 830
# AY-MusiK / 5700
# AYO Breeze / 0
# AZALEA / 10600
# AZP / 1570
# AZTEC SUN / 960
# Aalma Dili / 1780
# Aananda / 120
# Aardvark / 9000
# Aaron Beaumont / 13300
# Aaron Berg / 400
# Aaron Bordas / 160
# Aaron Buchanan & The Cult Classics / 1140
# Aaron Buckley Band / 1000
# Aaron Burdett / 8440
# Aaron Carter / 83990
# Aaron Cole / 10330
# Aaron Copeland / 26870
# Aaron Crawford / 8050
# Aaron Daniel / 1660
# Aaron Einhouse / 56870
# Aaron English / 17720
# Aaron Gibson / 1840
# Aaron Goldberg / 99380
# Aaron Guest / 780
# Aaron Heick / 10
# Aaron Heick - sax / 4910
# Aaron Kamm & The One Drops / 740
# Aaron Kamm and the One Drops / 24330
# Aaron Keylock / 4260
# Aaron Knight / 10
# Aaron LaCombe / 1510
# Aaron Lee Tasjan / 90010
# Aaron Lefebvre Music / 210
# Aaron Lewis / 217290
# Aaron Liberator / 11790
# Aaron Lopez-Barrantes / 900
# Aaron Manzo / 30
# Aaron McDonnell / 1580
# Aaron Neville / 140920
# Aaron Parks / 42290
# Aaron Parnell Brown / 400
# Aaron Rizzo / 160
# Aaron Roche / 2790
# Aaron Shust / 120750
# Aaron Stephens / 14770
# Aaron Tippin / 3700
# Aaron Watson / 212690
# Aaron West & The Roaring Twenties / 2010
# Aaron West and The Roaring Twenties / 32670
# Aaron Wilburn / 18850
# Aaron Woodall Comedy / 18510
# Aaron Woods Band / 18250
# Aazar / 27610
# Ab In Den Süden / 940
# Ab-Soul / 61240
# Aba Shanti-I / 11790
# Abacabb / 54490
# Abacinate / 3890
# Abacus / 15480
# Abajour / 1400
# Abandoman / 12060
# Abandon / 4900
# Abandon All Ships! / 11260
# Abandon The Midwest / 6120
# Abandoned By Bears / 30880
# Abass Abass / 400
# Abba Gold / 18420
# Abba the Concert / 61300
# AbbaFab / 80750
# Abbacadabra - The Ultimate ABBA Tribute / 13800
# Abbamania / 66890
# Abbath / 42240
# Abbath -Official- / 36840
# Abbey Lane Band / 30
# Abbey Road / 7220
# Abbey Road - A Tribute to the Beatles / 7450
# Abbey Road Tribute / 20690
# Abbot Kinney / 5310
# Abby Diamond / 1250
# Abby Jeanne / 10
# Abby Owens / 1080
# Abd al Malik / 20960
# Abdominal / 8070
# Abdoulaye Diabate / 3990
# Abdullah Ibrahim / 32150
# Abe / 14960
# Abe Parker / 850
# Abe Parker Music / 2840
# Abel Raise The Cain / 3280
# Abel the Kid / 3220
# Aberdeen Band / 1220
# Abhorrent Decimation / 3450
# Abi / 17220
# Abi Ann / 2550
# Abi Reimold / 3650
# Abigail / 42850
# Abigail Stauffer / 13130
# Abigail Washburn / 133250
# Abigail Williams / 9280
# Abigail's Party / 2690
# Abiosis / 230
# Abiotic / 18520
# Abisha Uhl / 3150
# Abjure / 0
# Ablaze My Sorrow / 1200
# Ablebody / 16290
# Abnormality / 10860
# Abode / 3290
# Abolishment of Flesh / 29270
# Aborted / 172120
# Aborted, Origin, Miasmal / 2750
# Abortion Twins / 20
# Abou Diarra / 8340
# About A Mile / 15640
# About Béliveau / 1080
# Above & Beyond / 691270
# Above It All / 5680
# Above The Moon / 410
# Above Them / 970
# Above This Fire / 380
# Above the Mendoza / 1620
# Abra / 44810
# Abra Cadabra / 700
# Abraham Inc. / 7490
# Abraham King / 90
# Abram Shook / 2740
# Abramowicz / 7110
# Abrams / 2230
# Abrasive Wheels / 23560
# Absinthe / 147620
# Absinthe Rose / 5510
# Absolut Deafers / 6910
# Absolute Blondie / 260
# Absolute Bowie Band / 13900
# Absolute Hero / 120
# Absolute Journey Tribute / 5280
# Absolute Kinks / 950
# Absolute Suffering / 10740
# Absolutely Free / 3500
# Absolutely Not / 6620
# Absolva / 3790
# Abstract & Logic / 290
# Abstract Artimus / 26940
# Abstraxion / 43460
# Abstürzende Brieftauben / 2970
# Absu / 81980
# Absurd / 5730
# Absynthe Minded / 18840
# Abysmal Dawn / 16720
# Abysmal Lord / 3150
# Academy Of St Martin In The Fields Chamber Ensemble / 3370
# Academy of St. Martin in the Fields / 55370
# Acadians / 290
# Acapulco Lips / 250
# Accelerator / 3410
# Accentus / 790
# Accept / 129160
# Acceptance / 8470
# Accessory / 16050
# Accident Prone / 3690
# Accidental Seabirds / 230
# Accidentally Murdered / 530
# Accordi Disaccordi / 21510
# Accordo / 20
# Accro d'Jazz / 0
# Ace / 97820
# Ace Alvarez / 6060
# Ace Enders / 3570
# Ace Fontana / 810
# Ace Frehley / 89440
# Ace One / 2590
# Ace Ventura / 102460
# Ace Wilder / 1670
# Acedia / 8070
# Aceldama / 100
# Acemo / 30
# Acera / 140
# Aces of Comedy / 0
# Aceyalone / 26870
# Ache / 2910
# Acherontas / 1030
# Achtung Baby / 18810
# Acid Arab / 52730
# Acid Baby Jesus / 30440
# Acid Carousel / 40
# Acid Dad / 7940
# Acid King / 55820
# Acid Mother Temple / 3400
# Acid Mothers Temple & The Melting Paraiso U.F.O. / 112610
# Acid Muffin / 1830
# Acid Pauli / 130100
# Acid Reign / 6190
# Acid Sisters / 270
# Acid Tongue / 24150
# Acid Witch / 8560
# AcidPoint / 730
# Acidez / 31990
# Acidic / 6830
# Ackboo / 9050
# Ackee Jam / 140
# Ackerman Music / 1010
# Acme Jazz Company / 0
# Acorn Bcorn / 960
# Acorps de Rue / 3020
# AcoustiCafe / 0
# AcoustiCafe Band / 30
# Acoustic Alchemy / 72640
# Acoustic Christmas Tour / 2340
# Acoustic Duo / 3060
# Acoustic Eidolon / 12360
# Acoustic Fantasy / 190
# Acoustic Hash / 500
# Acoustic Hot Tuna / 9940
# Acoustic Jam / 860
# Acoustic Jams / 1160
# Acoustic Mafia / 310
# Acoustic Open MIc / 3130
# Acoustic Rooster / 740
# Acoustic Show / 1030
# Acoustic Syndicate / 11360
# Acoustic Vibes / 0
# Acracy / 20
# Acrania / 16060
# Acranius / 3740
# Acropolis / 1930
# Across The Atlantic / 8590
# Across The Wide / 630
# Across the Border / 50
# Across the white water tower / 290
# Act of Defiance / 4770
# Act of Impalement / 320
# Action Bronson / 197820
# Action Camp / 7330
# Action Item / 10980
# Action Jackson / 13210
# Actionesse / 370
# Activation Trio / 0
# Active Bird Community / 5680
# Active Child / 2750
# Actress / 141780
# Actual Wolf / 9150
# Acyl / 3140
# Ad Patres / 3740
# Ada / 48700
# Ada Kaleh / 11730
# Ada Rovatti / 6710
# Adairs Run / 13400
# Adakain / 25430
# Adal Ramones / 12940
# Adaliah / 12470
# Adam / 155700
# Adam & Kizzie / 7560
# Adam Aguilar / 2440
# Adam Aguilar Band / 40
# Adam Ahuja / 110
# Adam Auburn / 20
# Adam Baker and The Heartache / 170
# Adam Barnes / 9320
# Adam Beattie / 2340
# Adam Beattie and the Consultants / 4890
# Adam Beyer / 304380
# Adam Birnbaum / 11720
# Adam Bodine Trio / 40
# Adam Bricks / 2250
# Adam Burrows / 31300
# Adam Buxton / 580
# Adam Cappa / 69470
# Adam Carolla / 32490
# Adam Carpet / 190
# Adam Carroll / 15960
# Adam Chaffins / 4630
# Adam Chance / 8510
# Adam Cloud / 860
# Adam Craig / 27300
# Adam Day / 3290
# Adam Deitch / 27100
# Adam Eckersley Band / 20390
# Adam Ezra Group / 105070
# Adam F / 31870
# Adam Faucett / 40800
# Adam Fears / 29120
# Adam Ferrara / 4680
# Adam Foster / 16820
# Adam Friedman / 4200
# Adam Giles Levy / 10530
# Adam Gontier / 17150
# Adam Hambrick / 690
# Adam Henry / 950
# Adam Holloway Drums / 680
# Adam Holzman / 4680
# Adam Hood / 70300
# Adam Joseph / 16610
# Adam Keith / 5570
# Adam Klipple -keys / 220
# Adam Lambert / 173760
# Adam Lee / 15010
# Adam Levy / 42840
# Adam London / 6980
# Adam Lopez / 3300
# Adam Mamawala Comedy / 14460
# Adam Melchor / 970
# Adam Miller / 14100
# Adam Murray / 3210
# Adam Naas / 1710
# Adam Najemian - Musician / 90
# Adam Newman / 24990
# Adam Nitti / 2180
# Adam Pieronczyk / 2820
# Adam Port / 115310
# Adam Rafferty / 87300
# Adam Ray / 14860
# Adam Remnant / 850
# Adam Rupp / 21790
# Adam Sanders / 23370
# Adam Sandler / 16350
# Adam Savage / 8090
# Adam Scott / 18070
# Adam Searan / 940
# Adam Shelton / 119460
# Adam Smith / 11540
# Adam Stafford / 5880
# Adam Stasica Music / 1100
# Adam Sweet / 5460
# Adam Topol / 6360
# Adam Torres / 28610
# Adam Travis & The Soul / 860
# Adam Trent / 2780
# Adam Wade / 0
# Adam Wakefield / 5500
# Adam X / 68180
# Adam Yarger / 9090
# Adamon / 290
# Adams Call / 12470
# Adana Twins / 175940
# Addal / 17580
# Addicted / 26420
# Addictive TV / 12040
# Addie / 7710
# Addison Groove / 111470
# Addison Johnson / 7220
# Adel Tawil / 7550
# Adelaide / 142990
# Adelaide Music / 3630
# Adele / 108410
# Adeline / 23020
# Adelitas Way / 147160
# Adella / 800
# Adept / 1160
# Adesse Versions / 26090
# Adesta / 460
# AdestriA / 19430
# Adhesive / 6820
# Adia Victoria / 37390
# Adian Coker / 410
# Adil Hiani / 7040
# Adimiron / 6890
# Adir L.C. / 1640
# Adira Amram / 8140
# Adjiri Odametey Afrikanische Weltmusik / 1040
# Adjy / 13520
# Adley Stump / 7420
# Adlib / 32740
# Admiral Contempt / 20
# Admiral Fallow / 17930
# Admiral Freebee - Official Fanpage / 1870
# Admiral T. / 4610
# Adna / 3340
# Adnan Joubran / 1390
# Adolescents / 123570
# Adonis Wolf / 370
# Adore Delano / 24220
# Adoro / 14330
# Adrenaline / 28040
# Adrenaline Mob / 41820
# Adrian / 88980
# Adrian Daniel / 6900
# Adrian Duke / 1200
# Adrian Fix / 5830
# Adrian Jarvis / 10140
# Adrian Johnston / 4960
# Adrian Lux / 16830
# Adrian Raso / 1180
# Adrian Sherwood / 28120
# Adrian Uribe / 12900
# Adrian Xavier / 3750
# Adrian+Meredith / 65050
# Adriana López / 64090
# Adrianna Marie / 560
# Adriano / 41470
# Adriano Adewale / 1080
# Adriano Tenorio DD / 2280
# Adrianos Papadeas / 900
# Adriatique / 212250
# Adriel Favela / 2920
# Adrien Fontaine / 10
# Adrien Losco / 0
# Adrien Reju / 2180
# Adrien Soleiman / 2050
# Adrien Toma / 4880
# Adrienne & the Merrylanders / 170
# Adrienne Haan / 2340
# AdrienneO / 310
# Adrián Terrazas-González / 32490
# Adron / 9920
# Adult Beverage / 1050
# Adult Books / 13690
# Adult Mom / 8100
# Advance Base / 34720
# Adventure Club / 19550
# Adventure Of The Sea / 0
# Adventurer / 5050
# Adventures Of Rodeo And Juliet / 1160
# Adwela & The Uprising / 14350
# Ady Suleiman / 1150
# AeB / 20
# Aegaeon / 12080
# Aeges / 22160
# Aegeus / 810
# Aegis / 12050
# Aegror / 190
# Aela / 360
# Aeneas / 12160
# Aenimus / 21270
# Aeon / 18450
# Aeonic Impulse / 180
# Aeons of Corruption / 750
# Aer / 25570
# Aeraco / 20
# Aerial Ruin / 9840
# Aero Flynn / 26350
# Aeroplane / 6020
# Aerosmith / 136390
# Aesop Rock / 5150
# Aesthetic Perfection / 138730
# Aether Realm / 9830
# Aethere / 17360
# Aevum / 3480
# Afel Bocoum / 6830
# Affair / 9380
# Affairs / 21840
# Affect / 52530
# Affkt / 66060
# Afflictive Nature / 1060
# Aficionado / 1220
# Africa / 9210
# Africa Entsha / 6560
# Africa Unite / 7540
# Afrikan Boy / 5950
# Afriqua / 13350
# Afriquoi / 2750
# Afro / 45740
# Afro Celt Sound System / 15350
# Afro Cluster / 1360
# Afro Social Club / 1450
# Afro-Cuban All Stars / 14110
# Afrobeta / 16810
# Afroholix / 160
# Afrojack / 477450
# Afrolicious / 23240
# Afroman / 101060
# Afropunk / 6030
# Afshin / 15910
# After 7 / 37870
# After All / 22000
# After Arizona / 0
# After Dark / 68000
# After Funk / 30640
# After Hours / 109820
# After Marianne / 2670
# After Me The Flood / 6570
# After Midnight / 31490
# After Ours / 3520
# After Party / 155990
# After Shock / 4690
# After The Calm / 30
# After The Departure / 140
# After The Fallout / 2010
# After The Minor / 240
# After The Smoke / 14440
# After the Burial / 248910
# After the Fall / 88810
# After the Flood / 4740
# AfterFab / 620
# AfterShow / 13610
# Afterhours / 90730
# Afterimage / 710
# Aftermath / 34100
# Afternoon Delight / 14110
# Afternoon Tea / 45440
# Afterparty / 130670
# Aftershock / 24000
# Afu-Ra / 6380
# Again / 8770
# Against All Odds / 10500
# Against Himself / 2890
# Against Me! / 388390
# Against The Current / 94340
# Against The Grain  / 9590
# Against the Plagues / 2200
# AgapéSoul / 110
# Agar Agar / 4740
# Agathe Ze Bouse / 360
# Age of Days / 2160
# Age of Embers / 380
# Age of Woe / 10590
# Agent / 73770
# Agent 13 / 340
# Agent Fresco / 30180
# Agent Moosehead / 10
# Agent Orange / 260120
# Agents Of Time / 94360
# Agents of Change / 110
# Ages And Ages / 44930
# Ages Apart / 4850
# Aggravator / 1120
# Aggressive / 550
# Aggressive (GER) / 710
# Aggressive Betty / 70
# Aggressive Vibe / 90
# Aghast / 1220
# Agnelli & Nelson / 1220
# Agnes Milewski / 5100
# Agnes Obel / 91860
# Agnieszka Chylińska / 2560
# Agnostic Front / 272770
# Agony / 2870
# Agoraphobic Nosebleed / 6160
# Agori Tribe / 3440
# Agoria / 12530
# Agression / 580
# Agrypnie / 1230
# Ags Connolly / 10630
# Ah / 7920
# Ahab / 31840
# Ahleuchatistas / 11240
# Ahmad Jamal / 139000
# Ahmed Ahmed / 12330
# Ahmed Sylla / 2020
# Ahmet Gülbay / 670
# Ahn Trio / 21280
# Ahoi / 690
# Ahora / 0
# AiNA ROXX / 5220
# Aida / 51160
# Aida Rodriguez  / 8240
# Aidan Connell / 21650
# Aidan Doherty / 15250
# Aiden / 1360
# Aiden Jude / 22500
# Aileeah Colgan / 340
# Aileen Quinn And The Leapin' Lizards / 180
# Ailie Robertson / 4730
# Aim / 42610
# Aimee Allen / 10
# Aimee Mann / 116520
# Aiming For Average / 4530
# Aiming for Enrike / 14950
# Ain't Misbehavin' / 7280
# Aine Duffy / 320
# Aine O'Doherty / 4310
# Air Credits / 7120
# Air Drawn Dagger / 11850
# Air Dubai / 10180
# Air For Ants / 4080
# Air Supply / 379590
# Air Traffic / 15590
# Air Traffic Controller / 36010
# Air Waves / 30930
# Air Zaïre / 2170
# Airbourne / 244560
# Aircraft / 3930
# Airdice / 6670
# Aireene Espiritu / 39370
# Airelle Besson / 7180
# Airi / 11070
# Airlift NYC / 110
# Airling / 2580
# Airlooms / 470
# Airpark / 6960
# Airplane Mode / 15300
# Airport Novels / 1440
# Airrace / 1630
# Airside / 8320
# Airwave / 43220
# Airways / 8520
# Aisha Burns / 4400
# Aisha Devi / 11420
# Aisles / 10070
# Aisling Iris / 5370
# Aitas / 8650
# Aj Fullerton / 220
# Aja / 10820
# Aja Gample / 8110
# Ajhenda / 970
# Ajoyo / 6350
# Ajëvā / 1500
# Ak'chamel / 500
# Aka Aka feat. Thalstroem / 540
# Aka Moon / 5230
# Akadia / 580
# Akae Beka / 12900
# Akala / 22590
# Akalé Wubé / 2970
# Akan Khelen / 7290
# Akenya / 30
# Akercocke / 5850
# Aki Kumar / 540
# Aki Kumar Blues Band / 50
# Akiko Tsuruga  敦賀明子 / 12280
# Akilavue / 360
# Akina Adderley / 10
# Akira / 120740
# Akira Tana / 3130
# Akjela / 370
# Akos Veecs / 580
# Akris / 1360
# Akrobatik / 37810
# Akrom / 10
# Akron/Family / 2460
# Akua Allrich / 8660
# Akua Naru / 22670
# Akwid / 9320
# Al Andalus Flamenco Nuevo / 470
# Al B. Sure! / 35070
# Al Bano & Romina Power / 12750
# Al Bano Carrisi / 42160
# Al Di Meola / 140410
# Al Di Meola World Sinfonia / 19490
# Al Doyle / 5090
# Al Foster / 19860
# Al Holliday and The East Side Rhythm Band / 4060
# Al Jawala / 42750
# Al Kapone / 1110
# Al Lover / 24790
# Al Murray / 11790
# Al Pitcher / 5550
# Al Ross / 4630
# Al Scorch / 42610
# Al Smith / 1500
# Al Staehely / 2720
# Al Stewart / 157000
# Al Wallis / 50
# Al Zanders / 1240
# Alabama / 56410
# Alabama Avenue / 230
# Alabama Mike / 2780
# Alabama Shakes / 154360
# Alaclair Ensemble / 6200
# Aladin / 3720
# Alain Asplanato / 630
# Alain Jean-Marie / 6640
# Alain Morisod & Sweet People / 18490
# Alain Platel / 2680
# Alain Ruart / 80
# Alain Souchon / 12310
# Alaina Blair / 5160
# Alaina Blair Music / 3510
# Alamo Race Track / 380
# Alan Barnes / 5310
# Alan Bennett Music / 1130
# Alan Bibey & Grasstowne / 4700
# Alan Bonner / 8410
# Alan Castro / 12350
# Alan Doyle / 48680
# Alan Doyle & The Beautiful Gypsies / 860
# Alan Fitzpatrick / 219490
# Alan Glen / 940
# Alan Hall / 30
# Alan Hall - drum set / 50
# Alan Hall - drums / 6930
# Alan Haynes / 15700
# Alan Jackson / 168630
# Alan Jardine / 42190
# Alan Kendall Music / 2650
# Alan Licht / 4980
# Alan Manzi / 10
# Alan Nieves / 10
# Alan Reed / 1230
# Alan Smithee / 2120
# Alan Stivell / 7150
# Alan Turner / 19440
# Alan Walker / 80880
# Alan Winkle / 4610
# Alan.D / 190
# Alana Amram / 13730
# Alanis Morissette / 61310
# Alanna Royale / 21890
# Alanna Story / 13870
# Alarm Drum / 500
# Alarm Will Sound / 14880
# Alasdair Roberts / 35410
# Alash / 11040
# Alaska / 141490
# Alaska Thunderfuck / 17470
# Alaska and Madi / 1230
# Alaskan Tin Soldiers / 660
# Alastair / 9310
# Alastair Greene / 14320
# Alastair Moock / 1100
# Alaya / 3820
# Alayna / 680
# Alba / 4500
# Alban Ivanov / 3020
# Albannach / 5280
# Albany / 5690
# Albany Street / 190
# Albeez 4 Sheez / 30
# Albert / 32630
# Albert Castiglia / 44740
# Albert Cummings / 67640
# Albert Hammond / 37970
# Albert Lee / 140130
# Albert Marzinotto / 9570
# Albert The Cannibal / 1020
# Alberta / 1780
# Alberto / 3470
# Alberto Alaska / 960
# Alberto Antonucci music / 620
# Albin de la Simone / 20830
# Albo's Music Room / 100
# Alborosie / 104110
# Albrecht Schrader / 640
# Albuquerque Isotopes / 10390
# Alcazar / 11870
# Alcest -official- / 140130
# Alchemist / 44300
# Alchemy / 64360
# Alcordo / 3900
# Aldebert / 16840
# Alden / 12340
# Alder Street / 0
# Aldo Romano / 5890
# Aldous Collins Band / 940
# Aldous Harding / 73150
# Ale / 9580
# Alea Jacta Est / 5050
# Alec Benjamin / 2680
# Alec Lytle / 14100
# Alec MacGillivray / 100
# Alec Ryan / 570
# Alee / 730
# Alejandra Guzmán / 80870
# Alejandra Ribera / 35780
# Alejandro Escovedo / 189750
# Alejandro Fernández / 87170
# Alejandro Sanz / 95680
# Alejandro Vivanco / 44870
# Alek Lee / 3340
# Aleks / 38620
# Aleks Jackman / 17130
# Aleks Syntek / 21320
# Aleksandra Kurzak / 1180
# Aleksey (Dj and producer) / 1620
# Alert The Medic / 23220
# Alerta Zero / 2300
# Alesana / 25150
# Alesia / 6880
# Alessandra Machella / 190
# Alessandro Adriani / 3100
# Alessandro Castelli / 170
# Alessandro Ciminata / 160
# Alessandro Mannarino / 3440
# Alessia Cara / 49280
# Alesso / 371790
# Alestorm / 172550
# Alethia / 2560
# Alex / 379540
# Alex & Sierra / 10510
# Alex & The Soul Bakers / 880
# Alex Acosta / 175080
# Alex Acuña / 18940
# Alex Aiono / 27560
# Alex Angelo / 14650
# Alex Anwandter / 4680
# Alex Battles / 10
# Alex Bayly / 440
# Alex Beaupain / 9400
# Alex Bianchi / 4470
# Alex Bosworth / 10
# Alex Britti / 5470
# Alex Brown / 37370
# Alex Bugnon / 54320
# Alex Burkat / 2640
# Alex Calder / 2750
# Alex Cameron / 51490
# Alex Campos / 57740
# Alex Cantié / 720
# Alex Claffy / 350
# Alex Clare / 58520
# Alex Cornish http://www.alexcornish.com/ / 770
# Alex Cruz / 26850
# Alex Cuba / 84050
# Alex Dallas / 7720
# Alex Dezen / 2450
# Alex Di Leo Music / 3590
# Alex Di Stefano / 111770
# Alex Diaz / 6110
# Alex Diehl / 1740
# Alex English / 210
# Alex Faith / 1970
# Alex Flatner / 47940
# Alex Francis / 160
# Alex G / 90540
# Alex Gauthier / 40
# Alex Grey / 4080
# Alex Guthrie / 10940
# Alex Hargreaves / 15910
# Alex Hendrix / 310
# Alex Hilton Band / 3550
# Alex Hunnicutt / 5460
# Alex Kates & Late Night Elixir / 230
# Alex Kidd / 160980
# Alex Lahey / 38130
# Alex Ligertwood / 18130
# Alex Lore / 10
# Alex M.O.R.P.H. / 230330
# Alex MASSMEDIA / 1720
# Alex Machacek / 5950
# Alex Maxwell / 1470
# Alex McAleer / 17220
# Alex McMurray / 4450
# Alex Mckown / 860
# Alex Mechew / 3770
# Alex Mendenall / 10660
# Alex Mendham & His Orchestra / 110
# Alex Mery and The Townsmen / 1500
# Alex Metric / 6380
# Alex Milsted / 3650
# Alex Napping / 7360
# Alex Neri / 14330
# Alex Newell / 2770
# Alex Niggemann / 135280
# Alex Ohm / 220
# Alex Pall / 0
# Alex Parker / 90
# Alex Pintaa / 0
# Alex Powers / 150
# Alex Preston / 2470
# Alex Prospect / 17420
# Alex Rath / 200
# Alex Reymundo / 2760
# Alex Riddle / 260
# Alex Ruiz / 330
# Alex Seeley / 2980
# Alex Sensation / 16700
# Alex Skolnick / 16410
# Alex Skolnick Trio / 33460
# Alex Stein / 19390
# Alex Stone / 46340
# Alex Taylor / 203120
# Alex Tomb / 8300
# Alex Tronique aka S P R R V R (Official) / 2750
# Alex Troubetzkoy / 20
# Alex Van Diel / 390
# Alex Varell / 220
# Alex Vargas / 47520
# Alex Way / 0
# Alex Williams / 16080
# Alex Winters / 770
# Alex Wong / 38620
# Alex de Grassi / 7490
# Alex de Vree / 1840
# Alex de Vree & Erwan Le Fichant / 1070
# Alex's Bar Karaoke / 0
# Alex.Do / 35140
# Alex2e / 5420
# Alexa Green / 520
# Alexa Kishner / 820
# Alexa Kriss / 5350
# Alexa Rose / 3400
# Alexa Tarantino / 800
# Alexa de Strange / 760
# Alexandar Kyosev / 2420
# Alexander Barck / 40330
# Alexander Cherry / 11780
# Alexander Goebel / 170
# Alexander Lewis / 11700
# Alexander Lynch / 380
# Alexander Madness  / 800
# Alexander Marcus / 6680
# Alexander O'Neal / 59740
# Alexander Popov / 8290
# Alexander Rocciasana / 150
# Alexander Stewart / 5280
# Alexander V / 150
# Alexander Wren / 1380
# Alexander and The Big Sleep / 10
# Alexander f / 580
# Alexandra Arrieche / 20
# Alexandra Scott / 1470
# Alexandre Désilets / 8130
# Alexandre SAADA / 22780
# Alexandre Tharaud / 21580
# Alexis / 107990
# Alexis & Fido / 17560
# Alexis Babini / 11950
# Alexis Cabrera / 73460
# Alexis EVANS / 1540
# Alexis Gomez / 2230
# Alexis HK / 19950
# Alexis Keegan / 3980
# Alexis Kings / 50
# Alexis Lombre / 770
# Alexis Tantau / 10
# Alexis Taylor / 43700
# Alexisonfire / 7550
# Alexius Harris / 20
# Alexkid / 139590
# Alexz Johnson / 9540
# Alfa / 61610
# Alfa Rococo / 7730
# Alfie Boe / 42640
# Alfred Banks / 7940
# Alfred Heinrichs / 7160
# Alfredo / 31290
# Alfredo De La Fe / 1560
# Alfredo Olivas / 5610
# Alfredo Rodríguez / 64810
# Alfret / 10
# Algernon Cadwallader / 1040
# Algiers / 37260
# Ali As / 1000
# Ali Campbell / 72740
# Ali Holder / 3700
# Ali Jackson / 9440
# Ali Köse - Kozy / 0
# Ali Laz / 5830
# Ali McGuirk / 410
# Ali Rose / 2580
# Ali Shaheed Muhammad / 30920
# Ali Wilson / 1550
# Ali Wong / 27010
# Ali Zafar / 2970
# Alia Tempora / 1410
# Alibi / 1910
# Alibutton / 700
# Alican / 4860
# Alice & The Wonders / 1670
# Alice Bag / 9520
# Alice Cooper / 292020
# Alice D / 5270
# Alice Dimicele / 7270
# Alice Drinks the Kool Aid / 11040
# Alice Phoebe Lou / 28140
# Alice Pisano / 20
# Alice Russell / 73110
# Alice Smith / 57060
# Alice Un Chained / 6860
# Alice Underground / 1400
# Alice Wallace / 44910
# Alice and the Underground / 10
# Alice in Chains / 20840
# Alice in Chains UK / 10
# Alice in Chains, Jane's Addiction, Circa Survive / 2650
# Alice in Wonderland / 27330
# Alicia Blue / 30
# Alicia Olatuja / 22590
# Alicia Witt / 51410
# Alicia en el Pais de las Mil Maravillas / 0
# Alien Ant Farm / 31080
# Alien Knife Fight / 11690
# Alien Rain / 5740
# Alific / 590
# Aliji / 17390
# Alika & Nueva Alianza / 21380
# Alil Vardar / 1480
# Alin Coen Band / 5160
# Alina Baraz / 18940
# Alina Bea / 2290
# Alina Hardin / 1140
# Aline Frazão / 13140
# Aline Vida / 20
# Aliocha / 17740
# Aliose / 570
# Alisa Weilerstein / 85600
# Alisa Weilerstein, cello / 31120
# Alisha Pattillo / 0
# Alison Brown / 34830
# Alison Burns / 3250
# Alison Clancy / 4110
# Alison James / 0
# Alison Krauss / 2780
# Alison Moyet / 59380
# Alison Wonderland / 145100
# Alisonn / 7990
# Alissa White-Gluz - Official Page / 1350
# Alithia / 10590
# Alive & Well / 2510
# Alive By Sunrise / 4160
# Alive In Barcelona / 16210
# Alive In Standby / 1600
# Alive In The Dark / 1080
# Alive Like Me / 12940
# Alix Perez / 159780
# Alkaline Trio / 40740
# Alkalino / 19910
# Alkbottle / 1340
# Alkeline Trio, New Found Glory / 2960
# Alki / 1400
# Alkinoos Ioannidis / 5170
# Alkpote / 4100
# All Aboard! / 9900
# All About A Bubble / 6720
# All At Sea / 240
# All Black Everything Tour / 6620
# All Changes Apply / 1190
# All Chiefs / 160
# All Cows Eat Grass / 820
# All Day I Dream / 48140
# All Dogs / 2180
# All Ears Avow / 4840
# All Folk'd Up / 9700
# All Get Out / 78930
# All God's Children / 0
# All Hail The Yeti / 61160
# All Hell / 7350
# All I Lost / 1090
# All Inclusive Beer or Wine Tour / 0
# All Kanye Everything / 7790
# All Misery / 18320
# All Night Workers / 590
# All Out War / 23080
# All Poets & Heroes / 350
# All Saints / 9500
# All Shall Perish / 35670
# All Shook Up / 21560
# All Star Trio / 10
# All Talk / 1040
# All That / 3930
# All That Glitters / 5110
# All That Remains / 287320
# All The Above / 8550
# All Them Witches / 66980
# All Things New / 13460
# All Time Low / 491890
# All Torn Up / 4670
# All Types Of Kinds / 250
# All Waffle Trick / 180
# All We Are / 17120
# All Young Girls Are Machine Guns / 1240
# All Your Sisters / 7190
# All Your Sorrows / 1980
# All for Nothing / 6900
# All or Nothing / 27660
# All the Little Pieces / 2780
# All the Locals / 5740
# All the People / 70
# All the Rage / 6110
# All the Saints / 8080
# All you need is love! / 9930
# All-4-One / 85330
# All-Star Jam / 1730
# AllBe / 200
# Allah-Las / 152840
# Allan Harris / 191610
# Allan Holdsworth Band / 19490
# Allan Jones / 0
# Allan Kingdom / 5950
# Allan Mednard / 4480
# Allan Olsen / 1540
# Allan Rayman / 23040
# Allan Ros / 2000
# Allan Scott / 9150
# Allan Taylor / 8150
# Allan Tincrès / 30270
# Alle Farben / 69400
# Allegaeon / 22070
# Allegeaon / 3130
# Allegiance Music Ministries / 19820
# Allegra Lusini / 11100
# Allen  Thompson / 31270
# Allen Biffle Band / 2000
# Allen Hebert / 0
# Allen Karl / 30
# Allen Morris Music / 1870
# Allen Stone / 191640
# Allen, Mack, Myers, Moore / 3890
# Allensworth / 52100
# Alleys / 4990
# Alli and I / 6330
# Allie Kral / 2780
# Allie Moss / 31840
# Allies Always Lie / 80
# Alligatoah / 13460
# Allison Adams Tucker / 14530
# Allison Iraheta / 10990
# Allison Miller / 66780
# Allison Pierce / 18880
# Allison Weiss / 13400
# Allison de Groot / 4560
# Allman Brown / 1100
# Allout Helter / 1960
# Allred / 9480
# Allstar Weekend / 7120
# Alltheniko / 860
# AllttA / 3000
# Allura / 2290
# Allusondrugs / 7390
# Alluvial / 4670
# Alluvion / 570
# Alluvion - MN / 3640
# Ally Venable's Music Page / 5130
# Allysa Grace  / 5760
# Alma / 36200
# Alma Afrobeat Ensemble / 1860
# Alma Andina / 380
# Alma Libre / 2650
# Alma Mahler / 4010
# Alma Mia / 0
# Alma Quartet / 11220
# Almeida / 70
# Almighty / 4900
# Almighty American / 420
# Almighty, le groupe / 330
# Almo M. Viana / 8830
# Almost Aimless / 250
# Almost Angels / 6070
# Almost Awake / 1200
# Almost Easy / 3660
# Almost Famous / 110
# Almost Heroes Music / 700
# Almost Kings / 65260
# Almost Normal / 660
# Almost People / 1530
# Almost Queen / 25360
# Almost Wrong / 2180
# Almost, Maine / 6090
# Aloe Blacc / 151270
# Aloha Radio / 2930
# Alone / 53730
# Alone at 3am / 4150
# Alonzo / 14860
# Alonzo Bodden / 21370
# Aloud / 24380
# Alouette / 390
# Alper Tuzcu / 310
# Alpha & Omega / 63340
# Alpha 9 / 9130
# Alpha Blondy / 124720
# Alpha Rev / 56810
# Alpha Steppa / 43960
# Alpha Tiger / 4420
# Alpha Union / 6190
# Alpha Wolf / 1440
# Alphaduka / 10
# Alphatronic / 2420
# Alphaville / 9680
# Alpheus / 1750
# Already Dead / 790
# Already Gone / 4510
# Alright Junior / 2730
# Alsarah / 30740
# Alt Road / 10
# Alt-J / 269930
# Alta Consigna / 3020
# Altan / 81210
# Altar Blood / 0
# Altar Of I / 80
# Altars / 2310
# Altars, Mouth of the South / 1370
# Alte Bekannte / 2470
# Alter Bridge / 188110
# Alter Eagles / 6880
# Alter Eden / 4750
# Alter The Design / 130
# Alter Within / 120
# Alteras / 11720
# Alterbeast / 7970
# Altered Images / 9060
# Altered Sky / 7220
# Alternate Routes / 88890
# Alternative Champs / 70
# Alternative TV / 8790
# Althea Rene / 9240
# Altocamet / 15960
# Alton Brown / 32840
# Altruism / 17460
# Alukah / 820
# AlunaGeorge / 124240
# Alune Wade / 2160
# Alustrium / 2190
# Alva / 3410
# Alvarez Kings / 59430
# Alvaro / 100330
# Alvaro Medina / 980
# Alvaro Soler / 6310
# Alvaro Suarez / 600
# Alvie & The Breakfast Pigs / 2180
# Alvin Ailey American Dance Theater / 14880
# Alvin Crow / 640
# Alvin Queen / 0
# Alvin Risk / 9830
# Alvin Youngblood Hart / 60310
# Alvin és a Mókusok / 2270
# Alvon / 0
# Alvon Johnson / 700
# Alvvays / 74390
# Always The Alibi / 60
# Always Wanted War / 810
# Aly / 51760
# Aly & Fila / 597340
# Aly'an / 19890
# Alycia Lang / 40
# Alyeska / 6890
# Alyosha Barreiro / 3040
# Alyotis / 180
# Alyse Black / 58030
# Alyson's Anthem / 90
# Alyssa Barron / 10
# Alyssa Edwards / 9270
# Alyssa Joseph / 270
# Alyssa Micaela / 10650
# Alyssa Trahan / 13240
# Alyssa Walker / 140
# AmStan Street Team / 3810
# Ama / 31930
# Amable / 0
# Amadeus / 46130
# Amadou / 30130
# Amadou & Mariam / 57620
# Amael Piano Trio / 2210
# Amalgam / 10
# Amalgam Effect / 510
# Amalia Watty / 3730
# Amanda Anne Platt and The Honeycutters / 52620
# Amanda Cevallos / 12000
# Amanda Colleen Williams / 380
# Amanda Daughtry / 12860
# Amanda Ducorbier / 0
# Amanda Fields / 2080
# Amanda Fish Band / 3890
# Amanda Gray / 3260
# Amanda Holley / 150
# Amanda Hughey Music / 330
# Amanda June / 650
# Amanda Lepore / 68100
# Amanda Lynne / 890
# Amanda McBroom / 10080
# Amanda Miguel / 35300
# Amanda Palmer / 226200
# Amanda Pearcy / 11770
# Amanda Perez / 6860
# Amanda Rheaume / 30380
# Amanda Richards & The Good Long Whiles / 790
# Amanda Shaw / 32870
# Amanda Shires / 83770
# Amanda Sprecher, Vocalist / 8390
# Amanda St John Music / 1140
# Amanda Taylor / 960
# Amanda Vernon / 26820
# Amanda Walker / 30
# Amanda X / 10950
# Amane / 3440
# Amanova / 710
# Amara / 8410
# Amaral / 52360
# Amaranthe / 119750
# Amaraterra / 40
# Amari / 7210
# Amarillo Junction / 1400
# Amarionette / 5350
# Amaris / 70
# Amasa Hines / 3240
# Amateur Eyes / 3240
# Amateur Night At The Apollo / 20
# Amaury Altmayer / 2540
# Amaury Faye / 910
# Amaury Filliard / 0
# Amaury Gutiérrez / 3100
# Amaury Vassili / 3180
# Ambassador / 11300
# Ambassador21 / 8580
# Ambe / 220
# Amber / 25450
# Amber Arcades / 33460
# Amber Cox / 1560
# Amber Digby / 8460
# Amber Digby & Midnight Flyer / 23710
# Amber Hayes / 11940
# Amber Nelson / 640
# Amber Rubarth / 162200
# Amber Run / 6570
# Amber Sweeney / 4570
# Amberstein / 2260
# Ambeyance / 410
# Ambiance Evolution / 40
# Ambrose Akinmusire / 95040
# Ambrosia / 104380
# Amee Chapman / 90
# Amee Chapman Music / 660
# Amel Brahim-Djelloul / 690
# Amel Larrieux / 57870
# Amelia Brightman / 650
# Amelia Curran / 88670
# Amelia White / 69050
# Amelie Lens / 8260
# Amelie McCandless / 1000
# Ameling & Glauß / 8700
# Amena Brown / 15230
# Amenaza / 2220
# Amendola vs. Blades / 5790
# Amenra / 33840
# Amenta Abioto / 10
# Amenthes / 770
# Amentia / 2540
# Amer / 2920
# America / 323610
# American Anymen / 170
# American Aquarium / 183120
# American Arson / 10450
# American Authors / 130940
# American Babies / 67980
# American Ballet Theatre / 9140
# American Bandit / 59450
# American Beauty / 6970
# American Bombshell / 2880
# American Burn / 4740
# American Dinosaur / 190
# American Dischord / 1080
# American Dreamer / 950
# American English Beatles Tribute / 3110
# American Evil / 11530
# American Express® Presale / 29480
# American Fangs / 1430
# American Football / 49320
# American Goon / 10
# American Grim / 9350
# American Grizzly / 990
# American Gypsy Band / 540
# American Head Charge / 17640
# American Headcharge / 2480
# American Hi-Fi / 4360
# American Hitmen / 68980
# American Island / 30
# American Lions / 290
# American Lions (AR) / 3410
# American Longspurs / 320
# American Me / 11210
# American Opera / 39880
# American Party Machine / 90
# American Pinup / 28170
# American Psychos / 1710
# American Road / 260
# American Scarecrows / 340
# American Sharks / 26550
# American Sin / 2310
# American Speedway / 9650
# American Spiritual Ensemble / 1230
# American Standards / 8410
# American String Quartet / 7460
# American Television / 230
# American Trappist / 630
# American Voodoo / 0
# American Watermelon / 590
# American Werewolf Academy / 3440
# American Wrecking Company / 1230
# American Young / 59440
# American Youth Symphony / 20
# American Zer0s / 480
# Americana-Na / 2290
# Americano Social Club / 0
# Americas / 3190
# Americo / 7600
# Amerikan Bear / 150
# Amerikan Primitive / 10
# Amewu / 1930
# Amigo / 11160
# Amigo the Devil / 31900
# Amigos Nobles / 440
# Amilia K Spicer Music / 6530
# Amine / 23920
# Amine Edge & DANCE / 168940
# Amine K / 27810
# Amini / 1930
# Amir / 57210
# Amir Blumenfeld / 17270
# Amir ElSaffar / 13440
# Amir Obè / 10720
# Amira B / 2680
# Amistat / 22710
# Amity Flow / 10
# Amjad Ali Khan / 21810
# Amnaye / 30
# Amnesty International / 500
# Amnesty Please / 2040
# Amon Amarth / 256840
# Among Criminals / 3400
# Among The Echoes / 110
# Among The Thirsty / 9150
# Amor / 56430
# Amor Blitz / 1270
# Amora / 380
# Amoral / 4970
# Amoramora / 2160
# Amorphis / 176750
# Amos Hoffman / 3110
# Amos Lee / 133430
# Amos Lora / 120
# Amourette / 10
# Amp Fiddler / 36900
# Amp Live / 5370
# Ampallang Infection / 100
# Ampersand / 7930
# Amplexus / 740
# Amplified Heat / 19090
# Amplified. / 11150
# Amplifier / 600
# Amplifive / 130
# Amrita / 3240
# Amsterdam / 99860
# Amsterdam Sinfonietta / 1560
# Amuse / 4710
# Amusement Parks on Fire / 4110
# Amy Andrews / 33350
# Amy Becker / 11570
# Amy Benton / 5510
# Amy Cook / 2000
# Amy Estrada / 4130
# Amy Fairchild / 7720
# Amy Fairchild Musician / 540
# Amy Gerhartz / 2810
# Amy Goloby Music / 1260
# Amy Grant / 76890
# Amy Helm / 80920
# Amy Jay / 1390
# Amy LaVere / 145090
# Amy LaVere & Will Sexton / 1110
# Amy Leon / 1940
# Amy Lynn / 2170
# Amy Lynn & The Honey Men / 5010
# Amy Lynn Music / 690
# Amy Macdonald / 77340
# Amy McCarley / 870
# Amy Miller / 10360
# Amy Obenski / 4810
# Amy Odell / 10
# Amy Petty / 2370
# Amy Ray / 21760
# Amy Sailor Band / 1790
# Amy Schumer / 76890
# Amy Shark / 20830
# Amy Speace / 141860
# Amy Stroup / 48510
# Amy Unland / 3150
# Amy Vachal / 14820
# Amy Westney / 560
# Amy and the Peace Pipes / 200
# Amy-Jo Clough / 290
# Amygdala / 4060
# Amyst / 2820
# Amythyst Kiah / 15960
# An Albatross / 36600
# An American In Paris / 192280
# An Appalachian Christmas / 1710
# An Cat Dubh / 150
# An Eagle In Your Mind / 3100
# An Early Cascade / 5880
# An Eaters Curse / 0
# An English Place / 1300
# An Evening / 564650
# An Evening With / 2720
# An Evening with Bruce Hornsby (solo) / 5800
# An Everyday Tradition / 110
# An Honest Year / 2010
# An Irish Christmas / 94470
# An Oath Of Misdirection / 540
# An Ocean of Void / 450
# An Pierlé / 7250
# An-ten-nae / 40410
# AnGy KoRe / 59580
# Ana Carla Maza / 1040
# Ana Cristina / 8010
# Ana Lola Roman / 20
# Ana Moura / 97720
# Ana Popovic / 267280
# Ana Torroja / 23310
# Anaal Nathrakh / 34610
# Anabelle Kay / 1840
# Anahata / 4560
# Anais Mitchell / 196540
# Anais St. john / 10
# Anaka / 1010
# Analog Bandits / 250
# Analog Son / 4530
# Anamorph / 330
# Anana Kaye / 20
# Anane Vega / 34780
# Anarbor / 133150
# Anastacia / 58950
# Anastasia / 21470
# Anastasia McQueen / 750
# Anastasia Mcqueen Saxophonist / 750
# Anat Cohen / 165540
# Anat Cohen Quartet / 13670
# Anat Fort / 4530
# Anatevka / 3040
# Anathema  / 165270
# Anathemic / 230
# Anatomy / 12030
# Anatomy Of An Outcast / 600
# Anaïs / 35200
# Anaïs Delva / 2870
# Anberlin / 28560
# Anchor / 420
# Anchor Detail / 470
# Anchor North / 260
# Anchored / 39970
# Anchorlot / 230
# Anchors / 16820
# Anchors & Hearts / 1300
# Anchors Affliction / 20
# Anchors For Airplanes / 100
# Anchorsong / 45520
# Ancient Ascendant / 490
# Ancient Astronauts / 16270
# Ancient Cities / 5780
# Ancient Methods / 41070
# Ancient Ocean / 5990
# Ancient Spell / 440
# Ancient Sun / 4380
# Ancient Vvisdom / 6400
# Ancient Whales / 60
# Ancients / 3550
# And Finally, Phil Collins / 290
# And One / 12150
# And So I Watch You From Afar / 97590
# And The Black Feathers / 10
# And The Kids / 34380
# And The Traveler / 90
# And.ID / 42320
# Andalyn / 2360
# Andead / 3010
# Anders / 29440
# Anders F Rönnblom / 420
# Anders F Rönnblom band / 320
# Anders Osborne / 146830
# Anders Parker / 2590
# Anderson / 61050
# Anderson .Paak / 84850
# Anderson Cooper / 6110
# Anderson East / 103160
# Anderson Noise / 115560
# AndersonPonty Band / 4330
# Andi & Alex / 740
# Andlee / 2920
# Andorra / 190
# Andra Day / 59040
# Andras / 58370
# Andras Schiff / 52190
# Andre / 2290
# Andre Bohren / 10
# Andre Buljat / 84730
# Andre Byrd / 2420
# Andre Costello / 10
# Andre Hommen / 60360
# Andre Kronert / 3620
# Andre Nickatina / 72650
# Andre Power / 53260
# Andre Ward / 13900
# Andre Watts / 37200
# Andrea / 2680
# Andrea Bazzicalupo / 20
# Andrea Bignasca / 560
# Andrea Bocelli / 230900
# Andrea Celeste / 12850
# Andrea Crestani / 10
# Andrea Dawson / 160
# Andrea Gibson / 2290
# Andrea Goodman / 1520
# Andrea Manzoni / 910
# Andrea Marcori / 1780
# Andrea McArdle / 5200
# Andrea Menabò - chitarra / 680
# Andrea Motis / 5620
# Andrea Nardello / 9840
# Andrea Oliva / 167180
# Andrea Paone / 0
# Andrea Silva / 520
# Andrea Valeri / 58300
# Andrea von Kampen / 1750
# Andreas (Risk) / 720
# Andreas Arnold / 8770
# Andreas Bourani / 7880
# Andreas Henneberg / 39210
# Andreas Johnson / 3360
# Andreas Kümmert / 5920
# Andreas Martin Hofmeir / 910
# Andreas Ottensamer / 21090
# Andreas Pasternack / 30
# Andreas S. Jensen Music / 5540
# Andreas Schaerer / 770
# Andreas Scholl / 14980
# Andreilien / 45730
# Andres / 136050
# Andres Laprida / 20
# Andres Rotmistrovsky / 29700
# Andrew Adkins / 4300
# Andrew Allen / 2700
# Andrew BG / 1200
# Andrew Bayer / 116040
# Andrew Belle / 4820
# Andrew Bird / 238920
# Andrew Blair / 60
# Andrew Calhoun / 220
# Andrew Castro / 870
# Andrew Combs / 78380
# Andrew Cosentino / 110
# Andrew Cyrille / 3680
# Andrew Dice Clay / 50410
# Andrew Duhon / 62080
# Andrew E. Ullman / 310
# Andrew Greer / 7940
# Andrew Hall / 1030
# Andrew Hammond / 380
# Andrew James / 43200
# Andrew James Music / 5100
# Andrew Joltik / 20
# Andrew Kennedy / 1070
# Andrew Keoghan / 4970
# Andrew Leahey & the Homestead / 18630
# Andrew London / 9470
# Andrew Mark Schaffer / 2860
# Andrew Marshall / 49020
# Andrew McMahon in the Wilderness / 126220
# Andrew Mccormack / 22870
# Andrew Norelli / 4320
# Andrew O'Keeffe / 50
# Andrew Peterson / 83600
# Andrew Rayel / 411900
# Andrew Ripp / 11850
# Andrew Roachford / 7420
# Andrew Rohlk / 70
# Andrew Saint Andrew / 10
# Andrew Santino / 3080
# Andrew Sapin / 10040
# Andrew Schulz / 6660
# Andrew Scotchie & The River Rats / 260
# Andrew St. James / 20740
# Andrew Sturtz Music / 1190
# Andrew The Bullet Lauer / 4700
# Andrew Tufano / 17780
# Andrew W.K. / 200020
# Andrew Wade Band / 3090
# Andrew Walesch / 0
# Andrew Waltrip  / 20
# Andrew Watt / 1950
# Andrew Weatherall / 95600
# Andrew Willard / 12410
# Andrew Wiscombe / 5800
# Andrew Wynne / 460
# Andrey PUSHKAREV / 85300
# Andreya Triana / 43350
# Andrez / 3540
# Androbeat / 20
# Androith / 90
# Androma / 2060
# Andromeda / 1830
# Andromeda Theory / 5650
# Andrzej Piaseczny / 1840
# Andrè the GAWS / 280
# André Ceccarelli / 8530
# André Costello and the Cool Minors / 840
# André Lodemann / 145260
# André Rieu / 239200
# Andrés Campo / 10310
# Andy / 255110
# Andy Ard / 70
# Andy Babb / 3690
# Andy Black / 39900
# Andy Blake / 16570
# Andy Bruh / 600
# Andy Buckner Music / 2250
# Andy C / 368620
# Andy Cairns / 3380
# Andy Catana / 1380
# Andy Cherry / 810
# Andy Cohen / 6200
# Andy Cowan / 4290
# Andy Cutting / 2020
# Andy D / 25820
# Andy Davis / 2390
# Andy Diagram Trumpet / 11690
# Andy Fairweather Low / 5780
# Andy Fairweather Low & The Low Riders / 2010
# Andy Fairweather Low and the Low Riders / 54220
# Andy Farley / 38390
# Andy Frasco / 178360
# ...
# electrophazz / 1630
# elska / 4170
# elvi / 1140
# emalkay / 121220
# emily bell / 6960
# eminem / 50900
# encono / 650
# end.user / 16260
# endless sacrifice / 2350
# entheos / 4640
# erromeria.eus / 270
# escandalos / 1220
# esclé / 590
# escuela / 8190
# eskimeaux / 2840
# esterina / 510
# esthen dehut / 430
# everett / 1710
# ex Licks / 0
# ex hex / 44220
# eyeQ / 2340
# eyedress / 8460
# eyenine / 3530
# faire / 2660
# falling cows live / 350
# falling stars / 340
# famous last words / 13440
# fatras / 7600
# feat. David Readman on vocals / 520
# femina / 7710
# finishticket / 1570
# flipturn / 100
# flor / 47540
# for / 11670
# for KING & COUNTRY / 208880
# for all the emptiness / 1660
# for the Foxes / 7850
# forecast / 30190
# fortunate son / 310
# fox and the acres / 390
# fractured transmission / 930
# fraidycat / 520
# fred d'oelsnitz / 270
# free cake for every creature / 10160
# friday nights / 20510
# frnkiero andthe cellabration / 3520
# fuel fandango / 19660
# funk master flex / 70
# furys tornados / 640
# gardens & villa / 9920
# garry todd / 50390
# gaslight anthem, bouncing souls / 870
# gaël duro / 2510
# get closer / 4790
# ghostbusters / 19060
# ginla / 1610
# giorgio gigli / 23360
# girless / 910
# girling / 50
# give / 25930
# glenn yoder / 340
# godblesscomputers / 1740
# gogolab / 0
# goldbones / 70
# gonesthedj / 15710
# graff / 8780
# grand tapestry / 1770
# grey sweater audio / 0
# gäster / 1550
# göteborg / 910
# hallower / 720
# hammada / 190
# hamster / 3120
# hannes smith / 590
# harbour / 34720
# heap / 25500
# hear kitty kitty / 21010
# heather trost / 5300
# hello dollface / 3250
# hellogoodbye / 12080
# herbert prohaska / 30
# herbivore / 290
# here i come / 1130
# hi-ker / 260
# hide / 45110
# high.co.coon / 6700
# hold youth / 18880
# honey mustard / 10
# honeychain / 350
# host Brendan Getzell / 0
# houndmouth / 98870
# http / 28430
# https / 59180
# https://goo.gl/CMW5il / 0
# hurts / 42520
# i am a dragon / 2820
# i, the Ghost / 40
# iAROSS / 20910
# iHeartRadio Music Festival / 260
# iO / 61710
# iVardensphere / 33960
# iZem / 14470
# iamchelseaiam / 4220
# iamsu! / 49020
# ici et lui / 440
# idoljob / 390
# ilia / 13560
# ill River / 550
# ill.gates / 113750
# ilyAIMY / 5330
# in evil hour / 1290
# in the heights / 31230
# indi and The Vegas / 8760
# inna vision / 49840
# inthebackground / 100
# isolation berlin / 10240
# it's always sunny in tijuana / 230
# itch / 9170
# itchy-O / 1890
# iwrestledabearonce / 37900
# iwrestledabearonce, Oceano, For All Those Sleeping / 2180
# jUsTiNa / 6990
# jackLNDN / 50840
# jake paleschic / 510
# jamaican queens / 2650
# jamie drake / 4640
# jason philips / 3690
# jeezy / 49140
# jeremy underground / 91740
# jesus christ pose / 70
# jesus ojeda / 1570
# jimm / 8300
# joe fox / 6000
# joe mullins / 4920
# joe nice / 63710
# john early / 16520
# john loring band / 3800
# joren / 110
# joris mallia / 30
# josh garrels / 31240
# junge junge / 3030
# k.flay / 157500
# k.s. Rhoads / 1940
# k:sun / 610
# kPek / 0
# kachupa / 3230
# kal-el / 1540
# kinfolk / 10490
# kirk baxley / 4080
# klanglos / 1620
# klub Stodoła / 10380
# kofelgschroa / 1990
# kojey radical / 12350
# kompost 3 / 530
# kublai kahn / 3160
# kurt baker combo / 5180
# la Bestia / 9950
# la Rappresentante di Lista / 3200
# la dame blanche / 10200
# la smala / 3770
# laCasta / 550
# lake of fire / 980
# laura whidden / 70
# lee benoit / 0
# legally blonde / 24000
# lenguas largas / 15130
# les Garçons / 5840
# les ballets C de la B / 2500
# lilabungalow / 5230
# lili poe / 440
# linnie & amy joy / 860
# little Barefoot / 470
# litz  / 5870
# local opener / 4340
# local support / 224090
# long shot / 2440
# loopers / 6620
# los kung fu monkeys / 37990
# lost beach / 90
# louis berry / 4300
# lowercase gods / 190
# luca ciarla / 23200
# lucent dossier / 4270
# lust for glory / 640
# machineheart / 3620
# maeva carter / 850
# mafia rusa / 480
# magic buck / 990
# makeup and vanity set / 2580
# manu lanvin / 7190
# many / 107370
# maracujah / 1270
# marco shuttle / 56240
# masaé gimbayashi-barbotte / 420
# matatu / 600
# matt simons / 89110
# maybecyborgs / 800
# mc chris / 7230
# mcfabulous / 780
# md / 40710
# me / 114420
# measures / 1350
# medlz / 3960
# meggy / 31200
# megitza / 13140
# members of Great American Taxi / 580
# merchandice / 11550
# merdan taplak / 570
# mewithoutYou / 139860
# mic boogie / 1370
# mickael berthelemy / 20
# microClocks / 650
# microsurco / 580
# miguel flaco / 10
# mike perry / 19260
# mike watt + the missingmen / 4150
# milkers / 400
# mimi love / 15070
# minimums / 10
# minor wits / 20
# minorcan / 3770
# miri / 30
# modern lives / 190
# modoc / 740
# moe. / 147490
# mohna / 2830
# molly burch / 22110
# moms / 34190
# mononome / 2620
# monsalve / 690
# moodie black / 32720
# morgxn / 10740
# motives / 31320
# mowri / 10
# muramasa / 45660
# musiques / 1510
# mustrd. / 530
# my favorite band / 14470
# m² / 5380
# nFiX & Candice / 11220
# naked sunday / 15990
# nathan carter / 44510
# native tongues / 650
# naza / 5270
# neckbreaker / 40
# ned roberts / 520
# nelo / 2910
# nenemusik.com / 3440
# neverise / 150
# nina papa / 60
# no eXscape / 60
# no gods / 1040
# noJazz / 13490
# noNCompliant / 400
# noZen / 13220
# noaria / 7130
# noe talbot / 1310
# nokx / 0
# noodles / 51150
# norm / 2750
# northless / 1550
# nthng / 7000
# nuit blanche / 4060
# nullingroots / 10
# nunofyrbeeswax / 2990
# oberst / 1430
# oceanstone / 2170
# of Mice / 41980
# of Montreal / 213270
# of limbo / 310
# off bloom / 6020
# ohGr / 15920
# old coast / 90
# olinclusive / 0
# one for sorrow / 250
# oneirogen / 17330
# onesie / 10
# onewayness / 2830
# opiuo / 17140
# option4 / 26760
# orKa odyssey / 1420
# ordoeuvre / 9000
# orgel / 11300
# osba / 180
# ourfathers / 80
# ourselves / 4360
# over the threshold / 640
# overclocked / 90
# oxygen destroyer / 90
# p0gman / 44800
# pagan poetry / 390
# pallbearer / 120880
# panoptica orchestra / 440
# pants party / 700
# paper arms / 2010
# paris_monster / 920
# peaer / 3700
# pecas / 1080
# pete sabo / 14330
# petra marklund / 2990
# pg.99 / 320
# phil crow / 250
# pkew pkew pkew / 13780
# polemica / 1520
# portrayal of guilt / 3780
# power serge / 2790
# prettygirlhatemachine / 4270
# production / 7420
# project .44 / 290
# prom date / 2330
# proud parents / 2560
# psytrance / 10610
# punkt3 / 4650
# purification by fire / 470
# pushing buttons / 0
# que lastima / 1060
# queer / 6660
# quieter / 510
# raener / 10
# rainMKERS / 430
# rainertrueby / 27400
# raison d'être / 7200
# re:search / 490
# re:set / 120
# reNounced / 5010
# reba and brooks and dunn / 0
# rebelHot / 1060
# recycled percussion / 27940
# redray frazier / 400
# redsean / 0
# reinventing jude / 1680
# repose / 2740
# rich the kid / 36520
# ricky hana / 7670
# riotmaker / 220
# rips / 20020
# riya / 3780
# rnb / 58960
# rob benedict / 3050
# rockaway bitch / 130
# rod tuffcurls and the bench press / 1000
# roi / 2970
# rsk / 9850
# rtb2 / 1460
# rødhåd / 211530
# s.o. / 35930
# sHEPARD / 36630
# sab / 9580
# sabb / 30350
# salsa / 79500
# salvation AMP / 1270
# sandy Campbell, Robby Campbell, steve Volk, Steven Gore , Mario Bozza / 2690
# sandy Campbell, Robby Campbell, steve Volk, Steven Gore , Mario Bozza,anthony albanese / 5110
# sasasas / 13340
# schlachthofbronx / 40300
# schoolboy / 2970
# scott elkins / 40
# scrooge / 10240
# sean nicholas savage / 47110
# season of strangers / 300
# seedless / 12480
# selina albright / 26270
# sergio flores / 320
# serial butcher / 420
# serpentwithfeet / 9640
# set and setting / 1980
# settler / 10630
# shEver / 5530
# shakespeare / 15390
# shoot the girl first / 3500
# shoto / 13880
# sicktanick / 4910
# silent / 12370
# singer China Forbes / 119090
# singer China Forbes and special guests The von Trapps / 570
# singer Storm Large / 53190
# singers China Forbes and Storm Large / 810
# singers China Forbes and The von Trapps / 4580
# sir Was / 1580
# sistergold / 570
# sit / 26360
# skull drug / 660
# sleepmakeswaves / 110210
# sleepy kitty / 1160
# smiiffy / 150
# soldiers / 4800
# somos / 7940
# sonic hippies / 0
# soulfiya / 1440
# sound nomaden / 12870
# soundcloud.com / 48160
# spaceinvasion / 760
# speaknspell / 4160
# special guest Ari Shapiro / 1430
# special guest Brothers McCann / 3110
# special guest Josh Morningstar / 690
# special guest The Accidentals / 2850
# stampy / 230
# stargazing / 90
# statiqbloom / 7400
# steep leans / 10840
# sterac aka steve rachmad / 14340
# steve gunn / 99410
# steve martin DJ / 10100
# stilbruch / 460
# stills / 74500
# stimulus / 31180
# stonic / 1490
# subPrime / 3680
# suena hermosa / 10
# sugar moon rabbit / 10
# sugarstone / 110
# sunnata / 9800
# sykoya / 160
# t0yGuitar / 4880
# tUnE-YaRdS / 174200
# taMe / 15240
# take today / 7030
# tashaki miyaki / 21460
# teen suicide / 5260
# tenThing / 6050
# teorem / 1240
# that dog. / 4820
# thayer sarrano / 15260
# the 78s / 40780
# the Academic / 19470
# the Afrofunk Experience / 7450
# the Alibi / 9630
# the Amazons / 17260
# the Analogues / 1850
# the Apocalypse / 4270
# the BBQ Swingers / 3140
# the Bad / 206240
# the Bad Husbands Club / 1730
# the Bad Ideas / 5140
# the Bama Lamas / 20
# the Barbecue Swingers / 5330
# the Barn Door Slammers / 160
# the Beaches / 18590
# the Bear / 69460
# the Beaver Brown Band / 3420
# the Best of the Wor / 3450
# the Big Lonesome / 4340
# the Bigger Empty / 3080
# the Bigness / 110
# the Black Mantis project / 360
# the Black Roses / 3030
# the Black Tape / 880
# the Blacks Unlimited / 7740
# the Blues / 30810
# the Blues Ambassadors / 50
# the Blues Power Band / 2390
# the Bluff / 5840
# the Boozers / 5290
# the Bottlemen / 66840
# the Branches / 12900
# the Brokedowns / 1620
# the Buzz / 1690
# the Candles / 41090
# the Central Plains / 180
# the Classic Rock Show / 51280
# the Closers / 1800
# the Coldies / 0
# the Collingwood / 160
# the Colorines / 780
# the Colourist / 3490
# the Commonwealth / 18560
# the Coral Reefer Band / 36910
# the Cordovas / 43700
# the Courtesans / 10350
# the Cryptics / 17060
# the Cured / 1960
# the Deadlies / 730
# the Deadmen / 13130
# the Deer / 24560
# the Deloreans / 7020
# the Dewars / 1340
# the Dirty Diamond / 23880
# the Dirty South / 2420
# the Dirty Streets / 4590
# the Divide / 10970
# the Drug Budget / 0
# the Dustbowl Revival / 93940
# the Dyes / 1060
# the End of America / 6840
# the Escape Artists / 120
# the Family Stone / 96180
# the Flats / 8400
# the Fractals / 80
# the Function / 4380
# the G / 5100
# the Garifuna Collective / 15200
# the Georgetown Orbits / 860
# the Gills / 3930
# the Gloaming / 61140
# the Go Ahead / 4310
# the Go Rounds / 10970
# the Goat / 11050
# the Goddamn Band / 42280
# the Golden Cadillacs / 6080
# the Good Rats / 1550
# the Gotobeds / 9550
# the Greenery / 9290
# the Grownup Noise / 18060
# the Guests / 5700
# the Hands of Glory / 5150
# the Hang / 4750
# the Haunted Windchimes / 9260
# the Heat / 9260
# the Heroine / 36970
# the Hillbenders / 60600
# the Hollows / 24690
# the Hooliganz / 2550
# the Houserockers / 12340
# the Humble / 11870
# the Humbuckers / 680
# the Ibervillianaires / 500
# the Illusionists / 51240
# the Infamous Swanks / 1000
# the Innocent Criminals / 77630
# the Ivory / 2140
# the Jacobins / 2500
# the Jerry Douglas Band / 4660
# the Juggernauts / 12880
# the Kids Table / 9660
# the Krank Daddies / 20690
# the Kruger Brothers / 1110
# the Late Bloomers / 4720
# the Lawrence Peters Outfit / 50
# the Lemon Twigs / 69840
# the Liza Colby Sound / 4310
# the Lollygags / 200
# the Lost Minds / 70
# the Louisville Orchestra / 10
# the Maension / 61520
# the Maxies / 4600
# the Menders / 1620
# the Moonshine Band / 17020
# the Musical / 48010
# the Mystery Jets / 2930
# the National Reserve / 7480
# the Neon Shadows / 0
# the Nightcats / 118140
# the Nite Trippers / 12150
# the Noisemakers / 30220
# the Non-Believers / 3800
# the Orphan, the Poet / 36580
# the Pandemics / 950
# the Party Line / 3610
# the Patients / 7660
# the Pauses / 6560
# the Philosophers / 2900
# the Pocket Band / 230
# the Porchistas / 600
# the Powers / 4220
# the Procrastinistas / 0
# the Public / 270
# the Rant Band / 32950
# the Reason Why / 3070
# the Redemptions / 420
# the Restless / 10400
# the Reverend Payton's Big Damn Band / 3000
# the Reverends / 480
# the Revolution / 13050
# the Riveters / 5560
# the Roach / 670
# the Rocket 88s / 470
# the Roe Family Singers / 10
# the Roof / 11930
# the Rough / 2410
# the Ruination / 10
# the Run Around / 2070
# the SPiKEDRiVERs / 38570
# the Schooley Mountain Band / 1570
# the Scotch Bonnets / 5850
# the Shady Horns / 10940
# the Shag Rats / 190
# the Shills / 9780
# the Ship / 24420
# the Shrine / 26780
# the Silver Bullet Band / 8470
# the Skeleton Crew / 2370
# the Skyline / 0
# the Sleeper / 6270
# the Small Glories / 24400
# the Snips / 6150
# the Soft White Sixties / 47770
# the Soul Rebels Brass Band / 4550
# the Sour Notes / 11240
# the South Austin Moonlighters / 22200
# the Stampede / 9520
# the Still Tide / 16260
# the Stuntmen / 11440
# the Successful Failures / 1210
# the Suicide Girls / 21330
# the Sussex Wit / 18510
# the Sweet Remains / 21690
# the T-Stones / 8290
# the Tangiers Combo / 10
# the Tantrums / 102350
# the Tea Club / 2990
# the Tenderloins / 29390
# the ThoughtCriminals / 1100
# the Tips / 14600
# the Tiptons / 10980
# the Trigger Code / 10
# the Van Burens / 33880
# the Vandellas / 34420
# the Watkins Family / 22370
# the Way Up / 450
# the Whooligan / 76400
# the Willis Clan / 1050
# the Workshy / 4530
# the World's Hottest '80s / 0
# the Wrongs / 8860
# the albatross / 8340
# the black sound / 0
# the central / 670
# the come up / 15660
# the dose / 4680
# the dove & the wolf / 12240
# the hoyle brothers / 30
# the kats / 4160
# the last five years / 20020
# the legend of zelda / 91110
# the magician / 232410
# the mexicats / 3010
# the one and only PPL MVR / 1080
# the peptides / 13650
# the rifle / 5020
# the substance / 1300
# the the Band Band / 6470
# the touchies / 40
# the vaughns / 1130
# the86 / 110
# theGathering / 57250
# thePhantom* / 380
# theSHIFT / 32030
# theSTART / 24950
# theSurrendering / 11120
# thee nosebleeds / 10
# thelastplaceyoulook / 1110
# theo kottis / 6060
# this broken beat / 140
# tim gearan / 30
# timbo / 1900
# tobyMac / 215090
# together PANGEA / 127380
# tori kelly / 7440
# transient / 19680
# trp / 10390
# truett / 13030
# tubafresh / 630
# twen / 5260
# twenty one pilots / 232270
# twin peetz / 0
# twoloud / 56440
# tyDi / 409460
# tyler boone / 20870
# u z z v / 3640
# ukulele / 6570
# unbeing / 740
# uvm. / 1730
# vSQUARED / 0
# valafar / 290
# vashawn mitchell / 19390
# vendi / 12100
# victor provost / 0
# viech / 1510
# vikkei / 920
# vinyltheatre / 1570
# vito fattore / 1690
# von Brücken / 3680
# vverevvolf / 20
# vōx / 35690
# w Freddi Gowdy / 2700
# w/ For Today, The Word Alive, Memphis May Fire, and Upon A Burning Body   / 1740
# w/ Impending Doom, Erra, and To Each His Own / 1630
# w/ Lee Bains III & The Glory Fires / 850
# w/ The Devil Makes Three / 2180
# w/ This Or The Apocalypse, Ice Nine Kills / 610
# w/Billy Masters on guitar / 3370
# waFF / 171470
# waldden / 4190
# wankelmut / 126260
# wavelengths / 3410
# wax wings / 7050
# waxworks / 2580
# wayne's world / 9420
# we dream dawn / 4070
# weRcalled / 2480
# weiherer / 18210
# wellRED Comedy Tour / 26220
# wellman / 6130
# wellwell / 50
# wes finch music / 1570
# whetherman / 73160
# white ghost / 30
# wild Up / 4720
# william becket / 2020
# wilton / 3690
# wincent weiss / 2580
# winnie / 5250
# with Aaron Lee Tasjan / 2010
# with Adel Shams El-Din / 11980
# wonder woman / 4660
# wooden indian burial ground / 27960
# wooly mamas / 670
# wovoka / 9530
# wrtch / 4360
# www.kierangoss.com / 1200
# xxanaxx / 4720
# xxxy / 89510
# xxyyxx / 5730
# yMusic / 38750
# yaeji / 2640
# yellowtieguy / 2060
# yotto / 80110
# youANDme / 39210
# youn caro / 190
# your last chance / 980
# yours are the only ears / 230
# ysl / 58670
# zac rome / 140
# zachary cale / 18350
# zachary garren / 3500
# zahni / 1150
# zakázanÝ ovoce / 620
# zalem / 7930
# zenitram / 2110
# zeroh / 9210
# zuuma / 40
# ~SOULBOUND~ / 6000
# ¡Cubanismo! / 12090
# ¡Esso Afrojam Funkbeat / 3930
# ¡Mayday! / 33130
# Áine Cahill / 1120
# Ásgeir / 113560
# Åge Aleksandersen / 2750
# Åse Kleveland / 90
# Équipe de Foot / 2910
# Òai Star / 8420
# Ólafur Arnalds / 118580
# Özz Nûjen / 3910
# ØIVIND BLUNCK / 0
# Økapi / 5710
# Øresund Space Collective / 9830
# Ørkenkjøtt / 2500
# Ørsted / 330
# Øyvind Morken / 1690
# ÜBERMENSCH (Rammstein Tribute Band) / 470
# ÿordan / 1880
# Łona / 6360
# Łona i Webber / 2080
# ŚexPistols Eẋperience / 14080
# Ūnderestimate / 20
# Αντώνης Ρέμος / 23000
# Μαρία Φαραντούρη / 5320
# Μαρινέλλα / 6860
# Μελίνα Ασλανίδου / 3480
# Πυξ Λαξ / 3440
# Азиза / 13950
# Анна Юрьевна Нетребко / 25660
# Ані Лорак / 5760
# Би-2 / 13170
# Валерия / 16750
# Владимир Фельцман / 9860
# ДахаБраха / 68960
# Дмитрий Дмитриевич Шостакович / 58290
# Добраночь / 12770
# Евгений Игоревич Кисин / 23720
# Калевала / 5230
# Конец Лета / 0
# Кристина Орбакайте / 8250
# Ленинград / 29720
# Лили Иванова / 2160
# Пётр Ильич Чайковский / 121180
# Софийска филхармония / 0
# Сплин / 9310
# أم كلثوم / 1660
# श्रेया घोषाल / 59000
# सोनू निगम / 47090
# ᵀᴴᴱ ᴼᴿᴵᴳᴵᴻᴬᴸ Funky Monkey / 12490
# デザート / 3220
# 久石譲 / 3990
# 任賢齊 / 8490
# 王羽佳 / 69600
# 郎朗 / 40380
# 陳光榮 / 78380
# 鼓童 / 35750
# 비 / 14300
# 조수미 / 13170
# Nick Cave / 360540

# %%
print final
# Out:
# {u'The Pigs': 76746.0711071374, u'Artur Menezes Oficial': 894.4280668973093, u'Negative sky': 242.96764827199527, u'chthonic': 4083.644651157822, u'Poetry': 53474.86986537042, u'MARTIN 2 SMOOVE': 1421.1320969765293, u'Steve Connolly': 1285.0120535601131, u'UWE STEIMLE': 2530.708232557808, u'Marion Poncet': 702.8310193592348, u'All Night Workers': 593.6655903725126, u'LASS': 7276.334770408842, u'Wheelchair Sportscamp': 4682.507341739373, u'Johnny Beauford': 414.2747074385591, u'Blind Tiger': 5342.000824177097, u'The Bitter Diamonds': 58.1916799502275, u'Brooke Nicholls': 7127.939146781077, u"No Man's Valley": 1334.5297016990226, u'EMBRACE THE DIRT': 0.0, u'The Legendary': 3339.435999457386, u'Lavatch': 2599.3231682424152, u'Ania Wyszkoni': 5336.330190470686, u'SIRES': 6144.4183066816795, u'The Six Shooters': 228.53036243870204, u'Rayna Gellert': 28052.9070551311, u'Joey Cape, Jon Snodgrass and Brian Wahlstrom': 2589.42722496778, u'Lucha Libre': 30696.37200645132, u'The Super Saturated Sugar Strings': 3790.613552541181, u'Disco Ball': 7803.423642471192, u'Phantoms (Official)': 18975.15292445537, u'Davey Lane': 1959.166765154262, u"The 94's": 10.072182857357, u'Ginny Mules': 182.943228216111, u'Bobby Whitlock & CoCo Carmel': 1864.8871924800821, u'Weatherstate': 1395.37654507108, u'Morten': 136368.76657943043, u'Megan Barker': 1069.2202062843078, u'Wes Starr': 535.0654548833496, u'Umberto Echo': 573.7552571012206, u'M Pokora': 12649.218936039448, u'the Humbuckers': 675.1193489993567, u'AnnenMayKantereit': 13219.288073814272, u'Bazar et B\xe9mols ': 1689.4073490211404, u'DELTAnine': 597.5417874347966, u'Teeth of the Sea': 319.868665917377, u'Joseph Veazie': 662.1938581203749, u'NORA HAMZAWI': 1808.8391278404563, u'The Dawn Chose Orion': 3523.5633435479854, u'Elijah Blake': 6435.603433915411, u'Twisted Sister': 15029.91397780738, u'Busta Rhymes': 147229.885442265, u'Jake Clayton': 13659.511912866496, u'Bj\xf8rn Eidsv\xe5g': 17817.353672818685, u'Chris Packer': 12329.68621738213, u'La Compagnie Cr\xe9ole': 5172.236443655146, u'(IAM)WARFACE': 188.67534354642567, u'Musician Jesse Cook': 116729.23220577126, u'Pampa': 13762.030650523515, u'Moonshine Prophets': 134.45655521455356, u'Shwayze': 220386.89434766502, u'Ross Arthur': 1073.18050912177, u'que lastima': 1061.9713994071305, u'maeva carter': 845.7534842332152, u'The Homing': 19.809008225519477, u'Lunatic Fringe': 9889.84622972453, u'Jan Garbarek': 20932.49712853591, u'Heavytones': 3321.44718419576, u'Tigers of Youth': 2835.4541801021846, u'Andy Jones': 963.9794151578145, u'HAVASI': 859.3668312929884, u'The Pretty Things': 35753.04502441735, u'athas': 4437.986631661336, u'Pleasure Island': 23923.39676706925, u'Stanton Warriors': 463978.822142666, u'Amuse': 4708.425143390908, u'Emile Parisien': 5766.881929864226, u'Patrick Murphy': 1879.2532106246226, u'Skee Mask': 10976.56790800761, u'The Priests': 17493.220567936394, u'LAST GOOD TOOTH': 802.7970939490589, u'Shantel': 82506.35724146978, u'Avenoir': 4.067362659054891, u'The Outer Vibe': 26962.907701691245, u'Soulparlor': 7061.643985339392, u'Wucan': 8730.037006672717, u'Ruleta Rusa': 5093.098112701547, u'China Gate': 797.1926863456605, u'Jan Bylund': 1776.1791186819385, u'KarlDensonTinyUniverse': 2039.9536270276765, u'Prison City Brigade': 249.2983533616807, u'Tablao After Dark': 0.0, u'Downfall': 49484.98539762393, u'HARMONIC BRASS': 513.7498903879493, u'Section Hate': 80.79855937855875, u'Jewels': 6294.970631932498, u'J.Lately': 24138.05137780965, u'Ray Fulcher': 4401.757031399268, u'G-Mo Skee': 14408.664748299561, u'Wheatus': 76206.81516696989, u'Good Morning Bedlam': 7939.595033358757, u'Driss El Maloumi': 10586.171603816363, u'Kabayun': 2850.9871252151747, u'Murs': 169050.39886125407, u'JD Shelburne': 20460.825989424015, u'April & Amy': 53.0326239721588, u'A Day At The Races': 2125.82094296106, u'Dexter': 120935.69973940558, u'DJ Sash': 73283.30055750736, u'Colt Landon Baker': 369.30035316352615, u'The Wednesday People': 3.250723 ...

# %%
#CALCULATE GLOBAL  RAW YEAR STATS
import os

#totalDistsPERYEAR={}
#totalOptDistsPERYEAR={}
#totalOptDistsMinPERYEAR={}
Artists_that_tour_Years_in_a_row=[]
resultsGlobalYears={}
resultsGlobalYearsAddedResultsCount={}
for filename in os.listdir('./tour_miner'):
    with open("./tour_miner/"+filename, 'rb') as handle:
#with open("./tour_miner/young-mc693097c4-17ec-4bb8-9b7c-74a5a2a85723"+".obj", 'rb') as handle:    
     temp= pickle.load( handle)
     resultsYears=temp["resultsYears"]
     nameOfBand=filename[:-4]
     if nameOfBand[-4:] == "none":
                nameOfBand=nameOfBand[:-4]
     else: 
                nameOfBand=nameOfBand[:-36]
    
     #print nameOfBand
    
     
        #print "------------"
        #print resultsYears  
        #print "------------"
     for Year in resultsYears:
        
            #print Year
            #print resultsYears[Year]
            
            #print "****"
      if isinstance(Year, Number):
        if Year>=2007 and Year<=2017:
         if resultsYears[Year]["toursLength"] > 365:
            Artists_that_tour_Years_in_a_row.append([nameOfBand,Year,resultsYears[Year]["toursLength"]])
         else:
          if resultsYears[Year]["toursDist"] > 0 :
            if Year not in resultsGlobalYears:
                resultsGlobalYears[Year]={"stattoursGlobalLength": 0,"toursGlobalLength": 0,"toursGlobalDistOpt": 0,"stattoursGlobalDist": 0,\
"toursGlobalDist": 0,"stattoursGlobalDistOpt": 0,"toursGlobalCount": 0,"stattoursGlobalCount": 0,\
"stattoursGlobalLengthMEAN": 0,"toursGlobalLengthMEAN": 0,"toursGlobalDistOptMEAN": 0,"stattoursGlobalDistMEAN": 0,\
"toursGlobalDistMEAN": 0,"stattoursGlobalDistOptMEAN": 0,"toursGlobalCountMEAN": 0,"stattoursGlobalCountMEAN": 0,\
"stattoursGlobalLengthMEAN": 0,"toursGlobalLengthMEAN": 0,"toursGlobalDistOptMEAN": 0,"stattoursGlobalDistMEAN": 0,\
"toursGlobalDistMEAN": 0,"stattoursGlobalDistOptMEAN": 0,"toursGlobalCountMEAN": 0,"stattoursGlobalCountMEAN": 0,\
"stattoursGlobalLengthMAX": 0,"tour sGlobalLengthMAX": 0,"toursGlobalDistOptMAX": 0,"stattoursGlobalDistMAX": 0,\
"toursGlobalDistMAX": 0,"stattoursGlobalDistOptMAX": 0,"toursGlobalCountMAX": 0,"stattoursGlobalCountMAX": 0,\
"stattoursGlobalLengthMAX": 0,"toursGlobalLengthMAX": 0,"toursGlobalDistOptMAX": 0,"stattoursGlobalDistMAX": 0,\
"toursGlobalDistMAX": 0,"stattoursGlobalDistOptMAX": 0,"toursGlobalCountMAX": 0,"stattoursGlobalCountMAX": 0,\
"stattoursGlobalLengthMAXartist": [],"tour sGlobalLengthMAXartist": [],"toursGlobalDistOptMAXartist": [],"stattoursGlobalDistMAXartist": [],\
"toursGlobalDistMAXartist": [],"stattoursGlobalDistOptMAXartist": [],"toursGlobalCountMAXartist": [],"stattoursGlobalCountMAXartist": [],\
"stattoursGlobalLengthMAXartist": [],"toursGlobalLengthMAXartist": [],"toursGlobalDistOptMAXartist": [],"stattoursGlobalDistMAXartist": [],\
"toursGlobalDistMAXartist": [],"stattoursGlobalDistOptMAXartist": [],"toursGlobalCountMAXartist": [],"stattoursGlobalCountMAXartist": [],\
                                         }
                resultsGlobalYearsAddedResultsCount[Year]=0
            resultsGlobalYearsAddedResultsCount[Year]+=1
            resultsGlobalYears[Year]["stattoursGlobalLength"]=float(resultsYears[Year]["stattoursLength"])+float(resultsGlobalYears[Year]["stattoursGlobalLength"])
            resultsGlobalYears[Year]["toursGlobalLength"]=float(resultsYears[Year]["toursLength"])+float(resultsGlobalYears[Year]["toursGlobalLength"])
            resultsGlobalYears[Year]["toursGlobalDistOpt"]=float(resultsYears[Year]["toursDistOpt"])+float(resultsGlobalYears[Year]["toursGlobalDistOpt"])
            resultsGlobalYears[Year]["stattoursGlobalDist"]=float(resultsYears[Year]["stattoursDist"])+float(resultsGlobalYears[Year]["stattoursGlobalDist"])
            resultsGlobalYears[Year]["toursGlobalDist"]=float(resultsYears[Year]["toursDist"])+float(resultsGlobalYears[Year]["toursGlobalDist"])
            resultsGlobalYears[Year]["stattoursGlobalDistOpt"]=float(resultsYears[Year]["stattoursDistOpt"])+float(resultsGlobalYears[Year]["stattoursGlobalDistOpt"])
            resultsGlobalYears[Year]["toursGlobalCount"]=float(resultsYears[Year]["toursCount"])+float(resultsGlobalYears[Year]["toursGlobalCount"])
            resultsGlobalYears[Year]["stattoursGlobalCount"]=float(resultsYears[Year]["stattoursCount"])+float(resultsGlobalYears[Year]["stattoursGlobalCount"])

##ADDING MAX AND MAX ARTISTS FILTERING
            #HERE
            if round(resultsYears[Year]["stattoursLength"],-1) > round(resultsGlobalYears[Year]["stattoursGlobalLengthMAX"],-1):
                resultsGlobalYears[Year]["stattoursGlobalLengthMAXartist"]=[nameOfBand]
                resultsGlobalYears[Year]["stattoursGlobalLengthMAX"]=float(resultsGlobalYears[Year]["stattoursGlobalLength"])
                #print resultsGlobalYears[Year]["stattoursGlobalLengthMAXartist"]
                #print resultsGlobalYears[Year]["stattoursGlobalLengthMAX"]
            elif round(resultsYears[Year]["stattoursLength"],-1) == round(resultsGlobalYears[Year]["stattoursGlobalLengthMAX"],-1):
                resultsGlobalYears[Year]["stattoursGlobalLengthMAXartist"].append(nameOfBand)
                #print resultsGlobalYears[Year]["stattoursGlobalLengthMAXartist"]
            
            if round(resultsYears[Year]["toursLength"],-1) > round(resultsGlobalYears[Year]["toursGlobalLengthMAX"],-1):
                if resultsYears[Year]["toursLength"] < 365:
                    resultsGlobalYears[Year]["toursGlobalLengthMAXartist"]=[nameOfBand]
                    resultsGlobalYears[Year]["toursGlobalLengthMAX"]=float(resultsGlobalYears[Year]["toursGlobalLength"])
                ####SOME BANDS ARE TOURING NON STOP FOR YEARS,NEED TO CHECK THAT OUT:
                ####WHY DO WE COUNT IT EVERY YEAR, THERE MUST BE A MISHAP
                else:
                    print resultsGlobalYears[Year]["toursGlobalLengthMAXartist"]
                    print resultsGlobalYears[Year]["toursGlobalLengthMAX"]
            elif round(resultsYears[Year]["toursLength"],-1) == round(resultsGlobalYears[Year]["toursGlobalLengthMAX"],-1):
                resultsGlobalYears[Year]["toursGlobalLengthMAXartist"].append(nameOfBand)
                #print resultsGlobalYears[Year]["toursGlobalLengthMAXartist"]

            if round(resultsYears[Year]["toursDistOpt"],-3) > round(resultsGlobalYears[Year]["toursGlobalDistOptMAX"],-3):
                resultsGlobalYears[Year]["toursGlobalDistOptMAXartist"]=[nameOfBand]
                resultsGlobalYears[Year]["toursGlobalDistOptMAX"]=float(resultsGlobalYears[Year]["toursGlobalDistOpt"])
                #print resultsGlobalYears[Year]["toursGlobalDistOptMAXartist"]
                #print resultsGlobalYears[Year]["toursGlobalDistOptMAX"]
            elif round(resultsYears[Year]["toursDistOpt"],-3) == round(resultsGlobalYears[Year]["toursGlobalDistOptMAX"],-3):
                resultsGlobalYears[Year]["toursGlobalDistOptMAXartist"].append(nameOfBand)
                #print resultsGlobalYears[Year]["toursGlobalDistOptMAXartist"]

            if round(resultsYears[Year]["stattoursDist"],-1) > round(resultsGlobalYears[Year]["stattoursGlobalDistMAX"],-1):
                resultsGlobalYears[Year]["stattoursGlobalDistMAXartist"]=[nameOfBand]
                resultsGlobalYears[Year]["stattoursGlobalDistMAX"]=float(resultsYears[Year]["stattoursDist"])
                #print resultsGlobalYears[Year]["stattoursGlobalDistMAXartist"]
                #print resultsGlobalYears[Year]["stattoursGlobalDistMAX"]
            elif round(resultsYears[Year]["stattoursDist"],-1) == round(resultsGlobalYears[Year]["stattoursGlobalDistMAX"],-1):
                resultsGlobalYears[Year]["stattoursGlobalDistMAXartist"].append(nameOfBand)
                #print resultsGlobalYears[Year]["stattoursGlobalDistMAXartist"]

            if round(resultsYears[Year]["toursDist"],-3) > round(resultsGlobalYears[Year]["toursGlobalDistMAX"],-3):
                resultsGlobalYears[Year]["toursGlobalDistMAXartist"]=[nameOfBand]
                resultsGlobalYears[Year]["toursGlobalDistMAX"]=float(resultsYears[Year]["toursDist"])
                #print resultsGlobalYears[Year]["toursGlobalDistMAX"]
                #print resultsGlobalYears[Year]["toursGlobalDistMAX"]
            elif round(resultsYears[Year]["toursDist"],-3) == round(resultsGlobalYears[Year]["toursGlobalDistMAX"],-3):
                resultsGlobalYears[Year]["toursGlobalDistMAXartist"].append(nameOfBand)
                #print resultsGlobalYears[Year]["toursGlobalDistMAX"]

            if round(resultsYears[Year]["stattoursDistOpt"],-1) > round(resultsGlobalYears[Year]["stattoursGlobalDistOptMAX"],-1):
                resultsGlobalYears[Year]["stattoursGlobalDistOptMAXartist"]=[nameOfBand]
                resultsGlobalYears[Year]["stattoursGlobalDistOptMAX"]=float(resultsYears[Year]["stattoursDistOpt"])
                #print resultsGlobalYears[Year]["stattoursGlobalDistOptMAX"]
                #print resultsGlobalYears[Year]["stattoursGlobalDistOptMAX"]
            elif round(resultsYears[Year]["stattoursDistOpt"],-1) == round(resultsGlobalYears[Year]["stattoursGlobalDistOptMAX"],-1):
                resultsGlobalYears[Year]["stattoursGlobalDistOptMAXartist"].append(nameOfBand)
                #print resultsGlobalYears[Year]["stattoursGlobalDistOptMAX"]
            #print "MX",resultsGlobalYears[Year]["toursGlobalCountMAX"]
            #print resultsYears[Year]["toursCount"]
            if round(resultsYears[Year]["toursCount"],-1) > round(resultsGlobalYears[Year]["toursGlobalCountMAX"],-1) and round(resultsYears[Year]["toursCount"],-1) > 5:
                resultsGlobalYears[Year]["toursGlobalCountMAXartist"]=[nameOfBand]
                resultsGlobalYears[Year]["toursGlobalCountMAX"]=float(resultsYears[Year]["toursCount"])
                #print resultsGlobalYears[Year]["toursGlobalCountMAX"]
                #print resultsGlobalYears[Year]["toursGlobalCountMAX"]
            #elif round(resultsYears[Year]["toursCount"],-1) == round(resultsGlobalYears[Year]["toursGlobalCountMAX"],-1)and round(resultsYears[Year]["toursCount"],-1) > 5:
             #   resultsGlobalYears[Year]["toursGlobalCountMAXartist"].append(nameOfBand)
                #print resultsGlobalYears[Year]["toursGlobalCountMAX"]

            if round(resultsYears[Year]["stattoursCount"],-1) > round(resultsGlobalYears[Year]["stattoursGlobalCountMAX"],-1):
                resultsGlobalYears[Year]["stattoursGlobalCountMAXartist"]=[nameOfBand]
                resultsGlobalYears[Year]["stattoursGlobalCountMAX"]=float(resultsYears[Year]["stattoursDistOpt"])
                #print resultsGlobalYears[Year]["stattoursGlobalCountMAX"]
                #print resultsGlobalYears[Year]["stattoursGlobalCountMAX"]
            elif round(resultsYears[Year]["stattoursCount"],-1) == round(resultsGlobalYears[Year]["stattoursGlobalCountMAX"],-1):
                resultsGlobalYears[Year]["stattoursGlobalCountMAXartist"].append(nameOfBand)
                #print resultsGlobalYears[Year]["stattoursGlobalCountMAX"]
            
                #print "statLE",resultsYears[Year]["stattoursLength"]
            #TRY IS NOT REPORTING ANY RESULTS,HANDLED BY tourDIst test

#(WE REALISE THAT TO GET ACCURATE STATS, WE SHOULD FILTER BY YEARS WITH ENOUGH DATAS, AND BANDS WITH ENOUGH SHOWS) 
##CORRECTED HERE SINCE WE ONLY FILTER BETWEEN 2007 AND 2017

# %% [markdown]
# WE NEED TO TURN resultsglobalyears into an array of arrays instead of a dict for easier plotting and computation

# %%
print Artists_that_tour_Years_in_a_row
# Out:
# [['cabaret', 2016, 441], ['penn', 2010, 416], ['stoney-larue', 2014, 402], ['the-djembabe', 2014, 470], ['the-mentalist', 2017, 457], ['dear-evan-hansen', 2017, 414], ['recycled-percussion', 2016, 700], ['recycled-percussion', 2014, 626], ['vegas-the-show', 2016, 1646], ['vegas-the-show', 2010, 370], ['raphael-bas', 2016, 423], ['beautiful', 2017, 554], ['raiding-the-rock-vault', 2015, 860], ['frank-caliendo', 2010, 376], ['rumpke-mountain-boys', 2012, 1040], ['stomp', 2017, 664], ['stomp', 2010, 773], ['stomp', 2014, 1156], ['blaggards', 2011, 571], ['the-marvelettes', 2009, 563], ['frank-marino-s-divas', 2015, 1864], ['harlem-gospel-choir', 2015, 416], ['aaron-lopez-barrantes', 2016, 448], ['just-joe', 2014, 1509], ['an-american-in-paris', 2017, 525], ['rick-krasowski-music', 2015, 602], ['3-west', 2015, 552], ['reed-lightfoot', 2016, 371], ['avi-sic', 2015, 708], ['fantasy', 2017, 537], ['zombie-burlesque', 2017, 471], ['zombie-burlesque', 2014, 472], ['the-australian-bee-gees', 2015, 1971], ['mac-king', 2017, 382], ['human-nature', 2010, 400], ['mike-archer', 2016, 379], ['baz-star-crossed-love', 2017, 585], ['v-the-ultimate-variety-show', 2010, 542], ['the-australian-bee-gees-show', 2015, 1048], ['', 2015, 648], ['mike-and-the-moonpies', 2013, 838], ['titanic', 2017, 397], ['thunder-from-down-under', 2017, 532], ['dean-johanesen', 2014, 473], ['matilda-the-musical', 2017, 432], ['ka-nection-band', 2016, 464], ['dj-jonesy', 2015, 934], ['stripper-101', 2017, 639], ['donny-marie-osmond', 2010, 372], ['dj-peeti-v', 2012, 383], ['xavier-mortimer', 2017, 444], ['private-event', 2015, 434], ['bodies', 2017, 396], ['disco-inferno', 2013, 421], ['the-town-drunks', 2016, 378], ['the-town-drunks', 2013, 686], ['blues-masters', 2016, 461], ['nathan-burton-comedy-magic', 2017, 410], ['jason-masi', 2016, 417], ['jason-masi', 2013, 623], ['larry-griffith-band', 2016, 571], ['frank-marinos-divas', 2016, 900], ['frank-marinos-divas', 2014, 395], ['laugh-factory', 2017, 524], ['carrot-top', 2010, 490], ['rj-howson', 2013, 899], ['david-puentez', 2014, 510], ['frederic-da-silva', 2017, 440], ['jabbawockeez', 2015, 1273], ['the-book-of-mormon', 2017, 571], ['the-book-of-mormon', 2015, 372], ['adam-london', 2017, 528], ['jay-frog', 2014, 646], ['christian-ryan-music', 2015, 630], ['marty-nightengale', 2015, 716], ['amanda-walker', 2016, 388], ['footloose-80-s-night-every-friday-at-midnight', 2017, 697], ['aaron-watson', 2014, 484], ['absinthe', 2017, 388], ['dj-sol', 2016, 482], ['bodyguard', 2016, 442], ['rock', 2010, 584], ['dj-eu', 2016, 514], ['aron-kent-kent-stop-won-t-stop', 2015, 450], ['micky-the-motorcars', 2014, 532], ['on-your-feet-', 2017, 480], ['marriage-can-be-murder', 2017, 536], ['the-slipper-room-show', 2015, 925], ['purple-reign', 2016, 413], ['mat-franco', 2017, 394], ['steamboat-willie-jazz-band', 2016, 634], ['best-303-sounds', 2016, 419], ['in-the-den', 2014, 855], ['duke-city-tours-wine', 2016, 367], ['the-rat-pack-is-back', 2017, 456], ['the-rat-pack-is-back', 2014, 703], ['claude-michel-schonberg', 2017, 376], ['aladdin', 2017, 683], ['david-copperfield', 2017, 425], ['frank', 2010, 387], ['the-hangovers', 2016, 463], ['dj-rock-city', 2015, 559], ['karaoke', 2016, 1022], ['the-exhibition', 2017, 396], ['barelyon', 2016, 466], ['zach-deputy', 2010, 477], ['jeremy-davenport', 2016, 371], ['obsolete-august', 2015, 982], ['something-rotten-', 2017, 418], ['baz', 2017, 376], ['cody-jinks', 2012, 471], ['brek-one', 2015, 640], ['mel-debarge', 2014, 692], ['gas-station-disco', 2013, 525], ['trentino', 2011, 466], ['blue-man-group-las-vegas', 2017, 605], ['all-shook-up', 2017, 535], ['kyle-park', 2012, 391], ['le-jazzophone', 2016, 772], ['real-bodies', 2017, 517], ['teller', 2010, 417], ['defending-the-caveman', 2017, 527], ['dj-ruckus', 2015, 375], ['menopause-the-musical', 2017, 473], ['chippendales', 2017, 524], ['hitzville', 2010, 455], ['hitzville', 2015, 1853], ['david-joel', 2016, 513], ['amanda-daughtry', 2016, 415 ...

# %%
print resultsGlobalYears
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
listP=["","MOY","MAX","MIN","VAR","ECTP"]
for YearG in sorted(resultsGlobalYears,key=int):
 if YearG >=2007 and YearG <= 2017:
    #CALCULATE MEAN VALUES
    resultsGlobalYears[YearG]["stattoursGlobalLengthMEAN"]=float(resultsGlobalYears[YearG]["stattoursGlobalLength"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["toursGlobalLengthMEAN"]=float(resultsGlobalYears[YearG]["toursGlobalLength"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["toursGlobalDistOptMEAN"]=float(resultsGlobalYears[YearG]["toursGlobalDistOpt"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["stattoursGlobalDistMEAN"]=float(resultsGlobalYears[YearG]["stattoursGlobalDist"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["toursGlobalDistMEAN"]=float(resultsGlobalYears[YearG]["toursGlobalDist"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["stattoursGlobalDistOptMEAN"]=float(resultsGlobalYears[YearG]["stattoursGlobalDistOpt"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["toursGlobalCountMEAN"]=float(resultsGlobalYears[YearG]["toursGlobalCount"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["stattoursGlobalCountMEAN"]=float(resultsGlobalYears[YearG]["stattoursGlobalCount"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    #ADD MAX AND MIN VALUES
    
    #CALCULATE TOT VALUES
    resultsGlobalYears[YearG]["stattoursGlobalLength"]=float(resultsGlobalYears[YearG]["stattoursGlobalLength"])
    resultsGlobalYears[YearG]["toursGlobalLength"]=float(resultsGlobalYears[YearG]["toursGlobalLength"])
    resultsGlobalYears[YearG]["toursGlobalDistOpt"]=float(resultsGlobalYears[YearG]["toursGlobalDistOpt"])
    resultsGlobalYears[YearG]["stattoursGlobalDist"]=float(resultsGlobalYears[YearG]["stattoursGlobalDist"])
    resultsGlobalYears[YearG]["toursGlobalDist"]=float(resultsGlobalYears[YearG]["toursGlobalDist"])
    resultsGlobalYears[YearG]["stattoursGlobalDistOpt"]=float(resultsGlobalYears[YearG]["stattoursGlobalDistOpt"])
    resultsGlobalYears[YearG]["toursGlobalCount"]=float(resultsGlobalYears[YearG]["toursGlobalCount"])
    resultsGlobalYears[YearG]["stattoursGlobalCount"]=float(resultsGlobalYears[YearG]["stattoursGlobalCount"])
    
    

    
    
    print "*----------"
    print YearG,"/ Nb de groupes comptabilisés cette année /",resultsGlobalYearsAddedResultsCount[YearG]
    print "-----------"
    
    
    print "=>stat longueur tournées moy",100*resultsGlobalYears[YearG]["stattoursGlobalLengthMEAN"], "%" 
    print "=>longueur tournées ",resultsGlobalYears[YearG]["toursGlobalLength"]," dates" 
    print "=>longueur tournées moy",resultsGlobalYears[YearG]["toursGlobalLengthMEAN"]," dates" 
    print "=>distances tournées ",resultsGlobalYears[YearG]["toursGlobalDist"]," km" 
    print "=>distances tournées moy",resultsGlobalYears[YearG]["toursGlobalDistMEAN"]," km" 
    print "=>distances tournées optimisés  ",resultsGlobalYears[YearG]["toursGlobalDistOpt"]," km" 
    print "=>distances tournées optimisés moy ",resultsGlobalYears[YearG]["toursGlobalDistOptMEAN"]," km" 
    
    print "=>Stat distances tournées moy",100*resultsGlobalYears[YearG]["stattoursGlobalDistMEAN"]," %" 
    
    print "=>Stat distances tournées optimisés moy",100*resultsGlobalYears[YearG]["stattoursGlobalDistOptMEAN"]," %" 
    print "=>nombre de tournées  ",resultsGlobalYears[YearG]["toursGlobalCount"] 
    print "=>nombre de tournées moy ",resultsGlobalYears[YearG]["toursGlobalCountMEAN"] 
    
    print "=>Stat nombre de tournées moy",100*resultsGlobalYears[YearG]["stattoursGlobalCountMEAN"]," %" 
    
    ######MAX#######
    print "=> nb de dates max",resultsGlobalYears[YearG]["toursGlobalCountMAX"]
    print "=> artiste(s) de la tournée au plus grand nombre de dates",resultsGlobalYears[YearG]["toursGlobalCountMAXartist"]
    #print "=>stat longueur tournées max",100*resultsGlobalYears[YearG]["stattoursGlobalLengthMAX"],"%"
    print "=> longueur tournée max",resultsGlobalYears[YearG]["toursGlobalLengthMAX"],"dates"
    print "=> artiste(s) de la tournée la(les) plus longue(s) -en dates",resultsGlobalYears[YearG]["toursGlobalLengthMAXartist"]
    print "=> distance tournée max",resultsGlobalYears[YearG]["toursGlobalDistMAX"],"km"
    print "=> artiste(s) de la tournée la(les) plus longue(s) -en km",resultsGlobalYears[YearG]["toursGlobalDistMAXartist"]
    print "=> distance tournée optimisée max",resultsGlobalYears[YearG]["toursGlobalDistOptMAX"],"km"
    print "=> artiste(s) de la tournée optimisée la(les) plus longue(s) -en km",resultsGlobalYears[YearG]["toursGlobalDistOptMAXartist"]
    
   # print resultsGlobalYears[YearG]["stattoursGlobalDistMAX"]
    
   # print resultsGlobalYears[YearG]["stattoursGlobalDistOptMAX"]
  
    #print resultsGlobalYears[YearG]["stattoursGlobalCountMAX"]
    
    #print resultsGlobalYears[YearG]["stattoursGlobalLengthMAXartist"]
    #print resultsGlobalYears[YearG]["toursGlobalLengthMAXartist"]
    #print resultsGlobalYears[YearG]["toursGlobalDistOptMAXartist"]
    #print resultsGlobalYears[YearG]["stattoursGlobalDistMAXartist"]
    #print resultsGlobalYears[YearG]["toursGlobalDistMAXartist"]
    #print resultsGlobalYears[YearG]["stattoursGlobalDistOptMAXartist"]
    #print resultsGlobalYears[YearG]["toursGlobalCountMAXartist"]
    #print resultsGlobalYears[YearG]["stattoursGlobalCountMAXartist"]
    
    
    
    
    print "----------*"
# Out:
# *----------
# 2007 / Nb de groupes comptabilisés cette année / 2592
# -----------
# =>stat longueur tournées moy -19.4496127324 %
# =>longueur tournées  61150.0  dates
# =>longueur tournées moy 23.5918209877  dates
# =>distances tournées  43627989.1682  km
# =>distances tournées moy 16831.7859445  km
# =>distances tournées optimisés   33633194.2428  km
# =>distances tournées optimisés moy  12975.7693838  km
# =>Stat distances tournées moy -23.071154216  %
# =>Stat distances tournées optimisés moy -23.930321729  %
# =>nombre de tournées   4988.0
# =>nombre de tournées moy  1.92438271605
# =>Stat nombre de tournées moy -2.99189814815  %
# => nb de dates max 6.0
# => artiste(s) de la tournée au plus grand nombre de dates ['bouncing-souls']
# => longueur tournée max 3282.0 dates
# => artiste(s) de la tournée la(les) plus longue(s) -en dates ['louie-anderson']
# => distance tournée max 317773.925512 km
# => artiste(s) de la tournée la(les) plus longue(s) -en km ['an-evening']
# => distance tournée optimisée max 95798.4348689 km
# => artiste(s) de la tournée optimisée la(les) plus longue(s) -en km ['pink-martini']
# ----------*
# *----------
# 2008 / Nb de groupes comptabilisés cette année / 3926
# -----------
# =>stat longueur tournées moy 2.99976313669 %
# =>longueur tournées  114118.0  dates
# =>longueur tournées moy 29.0672440143  dates
# =>distances tournées  93070085.2979  km
# =>distances tournées moy 23706.0838762  km
# =>distances tournées optimisés   69380293.6063  km
# =>distances tournées optimisés moy  17672.0055034  km
# =>Stat distances tournées moy 8.47514134864  %
# =>Stat distances tournées optimisés moy 5.09057351029  %
# =>nombre de tournées   8989.0
# =>nombre de tournées moy  2.28960774325
# =>Stat nombre de tournées moy 17.3790117168  %
# => nb de dates max 5.0
# => artiste(s) de la tournée au plus grand nombre de dates ['caroline-herring']
# => longueur tournée max 4524.0 dates
# => artiste(s) de la tournée la(les) plus longue(s) -en dates ['mayday-parade']
# => distance tournée max 384232.341643 km
# => artiste(s) de la tournée la(les) plus longue(s) -en km ['an-evening']
# => distance tournée optimisée max 3948087.89821 km
# => artiste(s) de la tournée optimisée la(les) plus longue(s) -en km ['coheed-and-cambria']
# ----------*
# *----------
# 2009 / Nb de groupes comptabilisés cette année / 5136
# -----------
# =>stat longueur tournées moy 10.2310758561 %
# =>longueur tournées  159263.0  dates
# =>longueur tournées moy 31.0091510903  dates
# =>distances tournées  136097156.438  km
# =>distances tournées moy 26498.6675308  km
# =>distances tournées optimisés   95386248.337  km
# =>distances tournées optimisés moy  18572.0888507  km
# =>Stat distances tournées moy 13.5445736802  %
# =>Stat distances tournées optimisés moy 9.64135889293  %
# =>nombre de tournées   12133.0
# =>nombre de tournées moy  2.36234423676
# =>Stat nombre de tournées moy 24.9331516096  %
# => nb de dates max 5.0
# => artiste(s) de la tournée au plus grand nombre de dates ['pink-martini']
# => longueur tournée max 521.0 dates
# => artiste(s) de la tournée la(les) plus longue(s) -en dates ['our-last-night']
# => distance tournée max 925631.713422 km
# => artiste(s) de la tournée la(les) plus longue(s) -en km ['steve-aoki']
# => distance tournée optimisée max 266751.387825 km
# => artiste(s) de la tournée optimisée la(les) plus longue(s) -en km ['our-last-night']
# ----------*
# *----------
# 2010 / Nb de groupes comptabilisés cette année / 6664
# -----------
# =>stat longueur tournées moy 12.4418939484 %
# =>longueur tournées  193736.0  dates
# =>longueur tournées moy 29.0720288115  dates
# =>distances tournées  154663275.331  km
# =>distances tournées moy 23208.7748095  km
# =>distances tournées optimisés   112268833.928  km
# =>distances tournées optimisés moy  16847.0639148  km
# =>Stat distances tournées moy 11.5998754665  %
# =>Stat distances tournées optimisés moy 9.54371589565  %
# =>nombre de tournées   16198.0
# =>nombre de tournées moy  2.43067226891
# =>Stat nombre de tournées moy 32.1768707483  %
# => nb de dates max 5.0
# => artiste(s) de la tournée au plus grand nombre de dates ['pink-martini']
# => longueur tournée max 1467.0 dates
# => artiste(s) de la tournée la(les) plus longue(s) -en dates ['chris-young']
# => distance tournée max 1357098.53278 km
# => artiste(s) de la tournée la(les) plus longue(s) -en km ['dj-dan']
# => distance tournée optimisée max 743475.046096 km
# => artiste(s) de la tournée optimisée la(les) plus longue(s) -en km ['the-expendables']
# ----------*
# *----------
# 2011 / Nb de groupes comptabilisés cette année / 6636
# -----------
# =>stat longueur tournées moy -9.75063073031 %
# =>longueur tournées  160244.0  dates
# =>longueur tournées moy 24.1476793249  dates
# =>distances tournées  118731774.219  km
# =>distances tournées moy 17892.0696532  km
# =>distances tournées optimisés   91380027.5415  km
# =>distances tournées optimisés moy  13770.3477308  km
# =>Stat distances tournées moy -14.7733440501  %
# =>Stat distances tournées optimisés moy -12.9591859838  %
# =>nombre de tournées   14674.0
# =>nombre de tournées moy  2.21127185051
# =>Stat nombre de tournées moy 17.0403857746  %
# => nb de dates max 5.0
# => artiste(s) de la tournée au plus grand nombre de dates ['pink-martini']
# => longueur tournée max 18153.0 dates
# => artiste(s) de la tournée la(les) plus longue(s) -en dates ['the-marvelettes']
# => distance tournée max 766182.477824 km
# => artiste(s) de la tournée la(les) plus longue(s) -en km ['chuckie']
# => distance tournée optimisée max 281495.713288 km
# => artiste(s) de la tournée optimisée la(les) plus longue(s) -en km ['lupe-fiasco']
# ----------*
# *----------
# 2012 / Nb de groupes comptabilisés cette année / 10570
# -----------
# =>stat longueur tournées moy -2.90442185858 %
# =>longueur tournées  247753.0  dates
# =>longueur tournées moy 23.4392620624  dates
# =>distances tournées  192568654.223  km
# =>distances tournées moy 18218.4157259  km
# =>distances tournées optimisés   140670402.881  km
# =>distances tournées optimisés moy  13308.4581723  km
# =>Stat distances tournées moy -6.68731201739  %
# =>Stat distances tournées optimisés moy -5.99519207745  %
# =>nombre de tournées   23146.0
# =>nombre de tournées moy  2.18978240303
# =>Stat nombre de tournées moy 20.7579627878  %
# => nb de dates max 6.0
# => artiste(s) de la tournée au plus grand nombre de dates ['the-mountain-goats']
# => longueur tournée max 437.0 dates
# => artiste(s) de la tournée la(les) plus longue(s) -en dates ['the-ghost-inside']
# => distance tournée max 914263.774657 km
# => artiste(s) de la tournée la(les) plus longue(s) -en km ['steve-aoki']
# => distance tournée optimisée max 2705281.24769 km
# => artiste(s) de la tournée optimisée la(les) plus longue(s) -en km ['paul-van-dyk']
# ----------*
# *----------
# 2013 / Nb de groupes comptabilisés cette année / 12985
# -----------
# =>stat longueur tournées moy 0.530915565245 %
# =>longueur tournées  305466.0  dates
# =>longueur tournées moy 23.5245283019  dates
# =>distances tournées  242700410.012  km
# =>distances tournées moy 18690.8286494  km
# =>distances tournées optimisés   176480700.633  km
# =>distances tournées optimisés moy  13591.1205724  km
# =>Stat distances tournées moy -2.42498158408  %
# =>Stat distances tournées optimisés moy -1.59946110762  %
# =>nombre de tournées   29560.0
# =>nombre de tournées moy  2.27647285329
# =>Stat nombre de tournées moy 23.9979463484  %
# => nb de dates max 5.0
# => artiste(s) de la tournée au plus grand nombre de dates ['gael-faye']
# => longueur tournée max 3115.0 dates
# => artiste(s) de la tournée la(les) plus longue(s) -en dates ['noah-peterson']
# => distance tournée max 790887.529266 km
# => artiste(s) de la tournée la(les) plus longue(s) -en km ['sunnery-james-ryan-marciano']
# => distance tournée optimisée max 3321205.66118 km
# => artiste(s) de la tournée optimisée la(les) plus longue(s) -en km ['paul-van-dyk']
# ----------*
# *----------
# 2014 / Nb de groupes comptabilisés cette année / 15811
# -----------
# =>stat longueur tournées moy 2.96436184608 %
# =>longueur tournées  373095.0  dates
# =>longueur tournées moy 23.5971791791  dates
# =>distances tournées  277469061.595  km
# =>distances tournées moy 17549.1152739  km
# =>distances tournées optimisés   199218749.531  km
# =>distances tournées optimisés moy  12600.0094574  km
# =>Stat distances tournées moy -1.16425856799  %
# =>Stat distances tournées optimisés moy -0.767303309423  %
# =>nombre de tournées   35923.0
# =>nombre de tournées moy  2.27202580482
# =>Stat nombre de tournées moy 24.1963401008  %
# => nb de dates max 5.0
# => artiste(s) de la tournée au plus grand nombre de dates ['shaggy']
# => longueur tournée max 859.0 dates
# => artiste(s) de la tournée la(les) plus longue(s) -en dates ['cabaret']
# => distance tournée max 932339.187823 km
# => artiste(s) de la tournée la(les) plus longue(s) -en km ['laidback-luke']
# => distance tournée optimisée max 2692321.32034 km
# => artiste(s) de la tournée optimisée la(les) plus longue(s) -en km ['jerome-isma-ae']
# ----------*
# *----------
# 2015 / Nb de groupes comptabilisés cette année / 20420
# -----------
# =>stat longueur tournées moy 7.84829980813 %
# =>longueur tournées  470281.0  dates
# =>longueur tournées moy 23.0304113614  dates
# =>distances tournées  336976487.904  km
# =>distances tournées moy 16502.2765869  km
# =>distances tournées optimisés   245409427.039  km
# =>distances tournées optimisés moy  12018.0914319  km
# =>Stat distances tournées moy 6.82049771452  %
# =>Stat distances tournées optimisés moy 6.92273310665  %
# =>nombre de tournées   46847.0
# =>nombre de tournées moy  2.29417238002
# =>Stat nombre de tournées moy 28.1500163239  %
# => nb de dates max 5.0
# => artiste(s) de la tournée au plus grand nombre de dates ['d-o-d']
# => longueur tournée max 1906.0 dates
# => artiste(s) de la tournée la(les) plus longue(s) -en dates ['dj-b-mills']
# => distance tournée max 651809.93259 km
# => artiste(s) de la tournée la(les) plus longue(s) -en km ['ladies-night']
# => distance tournée optimisée max 3202322.54587 km
# => artiste(s) de la tournée optimisée la(les) plus longue(s) -en km ['thomas-gold']
# ----------*
# *----------
# 2016 / Nb de groupes comptabilisés cette année / 25031
# -----------
# =>stat longueur tournées moy 14.6928996045 %
# =>longueur tournées  601058.0  dates
# =>longueur tournées moy 24.0125444449  dates
# =>distances tournées  389006272.666  km
# =>distances tournées moy 15540.9800913  km
# =>distances tournées optimisés   283661818.226  km
# =>distances tournées optimisés moy  11332.4205276  km
# =>Stat distances tournées moy 15.689947966  %
# =>Stat distances tournées optimisés moy 15.6839162049  %
# =>nombre de tournées   58234.0
# =>nombre de tournées moy  2.32647517079
# =>Stat nombre de tournées moy 32.3121995392  %
# => nb de dates max 5.0
# => artiste(s) de la tournée au plus grand nombre de dates ['young-mister']
# => longueur tournée max 521.0 dates
# => artiste(s) de la tournée la(les) plus longue(s) -en dates ['clint-holmes']
# => distance tournée max 1036471.25882 km
# => artiste(s) de la tournée la(les) plus longue(s) -en km ['dance']
# => distance tournée optimisée max 14242536.8131 km
# => artiste(s) de la tournée optimisée la(les) plus longue(s) -en km ['kura']
# ----------*
# *----------
# 2017 / Nb de groupes comptabilisés cette année / 24501
# -----------
# =>stat longueur tournées moy -3.30418176384 %
# =>longueur tournées  452105.0  dates
# =>longueur tournées moy 18.4525121424  dates
# =>distances tournées  281743755.566  km
# =>distances tournées moy 11499.2757669  km
# =>distances tournées optimisés   214431836.546  km
# =>distances tournées optimisés moy  8751.96263606  km
# =>Stat distances tournées moy -1.00892283974  %
# =>Stat distances tournées optimisés moy -0.305224787009  %
# =>nombre de tournées   45846.0
# =>nombre de tournées moy  1.87118893106
# =>Stat nombre de tournées moy 11.1811762785  %
# => nb de dates max 5.0
# => artiste(s) de la tournée au plus grand nombre de dates ['pink-martini']
# => longueur tournée max 1105.0 dates
# => artiste(s) de la tournée la(les) plus longue(s) -en dates ['thomas']
# => distance tournée max 435766.960387 km
# => artiste(s) de la tournée la(les) plus longue(s) -en km ['carmen']
# => distance tournée optimisée max 538995.869788 km
# => artiste(s) de la tournée optimisée la(les) plus longue(s) -en km ['thomas']
# ----------*

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

ax1 = fig.add_subplot(111)

ax1.set_title("Classement groupes par distances parcourues ")    
ax1.set_xlabel('rang')
ax1.set_ylabel('km')
ax1.plot(sorted(resultsGlobalYears,key=int),resultsGlobalYears[YearG]["toursGlobalLengthMAX"],'x' ,color='r', label="data['nom']")
ax1.set_autoscale_on
leg = ax1.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-dbf59ab8b5b9> in <module>()
#       8 ax1.set_xlabel('rang')
#       9 ax1.set_ylabel('km')
# ---> 10 ax1.plot(sorted(resultsGlobalYears,key=int),resultsGlobalYears[YearG]["toursGlobalLengthMAX"],'x' ,color='r', label="data['nom']")
#      11 ax1.set_autoscale_on
#      12 leg = ax1.legend()
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1526         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1527
# -> 1528         for line in self._get_lines(*args, **kwargs):
#    1529             self.add_line(line)
#    1530             lines.append(line)
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (11,) and (1,)

# %%
with open("./tour_miner/"+"young-mc693097c4-17ec-4bb8-9b7c-74a5a2a85723"+".obj", 'rb') as handle:
    temp= pickle.load(handle)
    
print temp
# Out:
# {1: {'tourLength': 3, 'tourdist': 4412.095403569076, 'tourYear': 2013, 'tourdistOpt': 4412.095403569076}, 2: {'tourLength': 3, 'tourdist': 3598.3834783813863, 'tourYear': 2016, 'tourdistOpt': 3598.3834783813863}, 3: {'tourLength': 20, 'tourdist': 27289.99921420611, 'tourYear': 2016, 'tourdistOpt': 9304.647910861806}, 4: {'tourLength': 6, 'tourdist': 4892.130973463658, 'tourYear': 2016, 'tourdistOpt': 4892.130973463658}, 'name': u'Young MC', 6: {'tourLength': 8, 'tourdist': 7787.715648749957, 'tourYear': 2017, 'tourdistOpt': 6323.238414375028}, 7: {'tourLength': 31, 'tourdist': 73680.08716318749, 'tourYear': 2017, 'tourdistOpt': 46773.53267687943}, 8: {'tourLength': 4, 'tourdist': 2438.171813830467, 'tourYear': 2017, 'tourdistOpt': 2438.171813830467}, 9: {'tourLength': 10, 'tourdist': 16354.945789979454, 'tourYear': 2017, 'tourdistOpt': 10940.483749558794}, 10: {'tourLength': 8, 'tourdist': 8978.55589883757, 'tourYear': 2017, 'tourdistOpt': 15295.868189735194}, 'totalArtistOptTourDist': 117104.55491428997, 'OptArtistPercent': 35.167405650966764, 'totalArtistTourDist': 180626.0509703576, 'resultsYears': {2016: {'stattoursLength': 0.38461538461538464, 'toursLength': 54, 'toursDistOpt': 30921.164666341967, 'stattoursDist': 0.11237242179193828, 'toursDist': 66974.4792522036, 'stattoursDistOpt': -0.2078575076185511, 'toursCount': 4, 'stattoursCount': 0.3333333333333333}, 2017: {'stattoursLength': 0.5641025641025641, 'toursLength': 61, 'toursDistOpt': 81771.2948443789, 'stattoursDist': 0.8143475272984647, 'toursDist': 109239.47631458494, 'stattoursDistOpt': 1.0948278631235522, 'toursCount': 5, 'stattoursCount': 0.6666666666666666}, 'statMeanYeartoursLength': 39, 'statMeanYeartoursCount': 3, 'statMeanYearDistOpt': 39034.851638096654, 'statNbYear': 3, 'statMeanYearDist': 60208.68365678588, 2013: {'stattoursLength': -0.9230769230769231, 'toursLength': 3, 'toursDistOpt': 4412.095403569076, 'stattoursDist': -0.9267199490904032, 'toursDist': 4412.095403569076, 'stattoursDistOpt': -0.8869703555050015, 'toursCount': 1, 'stattoursCount': -0.6666666666666666}}, 5: {'tourLength': 25, 'tourdist': 31193.96558615244, 'tourYear': 2016, 'tourdistOpt': 13126.002303635118}}

# %%
with open("./RESULTSGLOBAL.obj", 'rb') as handle:
          temp= pickle.load( handle)
print temp
# Out:
# {'manOpt': 0.23255376595961377, 'autoOpt': 0.21995298276047787, 'totalOptDistsMin': 1639279100.4292355, 'totalOptDists': 1666194602.2991636, 'totalDists': 2136018170.0272305}

# %%
***************************
TOTAL ARTISTS TOURS DISTS 2135250690.17 km
TOTAL AUTO OPTIMIZED ARTISTS TOURS DISTS 1665625398.71
TOTAL MANUALLY OPTIMIZED ARTISTS TOURS DISTS 1638787824.49
AUTO-OPTIMIZED BY  21.993918261  %
MANUALLY OPTIMIZED BY  23.2507999161  %
***************************

***************************
TOTAL ARTISTS TOURS DISTS 2136018170.03 km
TOTAL AUTO OPTIMIZED ARTISTS TOURS DISTS 1666994420.69
TOTAL MANUALLY OPTIMIZED ARTISTS TOURS DISTS 1640164490.57
AUTO-OPTIMIZED BY  21.9578539134  %
MANUALLY OPTIMIZED BY  23.2139260994  %
***************************

# %%
***************************
TOTAL ARTISTS TOURS DISTS 2297461485.47 km
TOTAL AUTO OPTIMIZED ARTISTS TOURS DISTS 1666777181.22
TOTAL MANUALLY OPTIMIZED ARTISTS TOURS DISTS 1644324623.69
AUTO-OPTIMIZED BY  27.4513548211  %
MANUALLY OPTIMIZED BY  28.4286315965  %
***************************
