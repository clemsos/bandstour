# %%
sys.executable
# Out:
# '/usr/bin/python'

# %%
import os
import json
import pymongo
import musicbrainzngs
import arrow
from datetime import datetime
from pymongo import MongoClient
from collections import defaultdict
from dateutil import parser

# %%
# setup mongo
client = MongoClient()
db = client["bandstour"]
bandsintown =  db["bandsintown"]
#setup mbrainz client
musicbrainzngs.set_useragent("Example music app", "0.1", "http://example.com/music")

# source data
DATA_FOLDER = "data/labels"
countMBID = 0
countNAME = 0
count = 0
# date parsing
DATETIME_FORMAT = '%Y-%m-%dT%H:%M:%S'
DATETIME_FORMAT_FOR_MSBNZ ='%Y-%m-%d'
# init label_db_retrieval
labels_aliases ={}
#retrieve label for each artist before a tour starts
#i.e what is the album previously to the first year
for artist in db.minedArtists.find() :
                    print artist["name"]
    
                    #print db.minedArtists[artist]
                    #print artist
                    labels_dict= defaultdict(list)
                    labels_dict["id"]=[]

                    if  artist["mbid"] is ( None ) :
                        print ("NOMBID for",artist["name"])

                    else:
                     if  bool(artist["mbid"]) is ( False ) :
                      print ("NOMBID2 for",artist["name"])

                     else:
                      print "aartist_mbid", artist["mbid"]
                      try:
                        artist["releases"]=(musicbrainzngs.browse_releases( artist["mbid"], release_type=["album"], includes=["labels"] ))
                            
                                  
                        #print "...."
                        #print artist["release_groups"]
                        key= 0
                        for release in  artist["releases"]["release-list"]:
                            #print release
                            if  release.has_key("release-event-list"):
                                #print "artist_name:",artist["name"]
                                #print "albumtitle:",release["title"]
                                #print "albumid:",release["id"]
                                #print "label-list",release["label-info-list"]
                                #print "releaseLBL",release["label-info-list"]
                                if not release["label-info-list"]:
                                    print "pppppppppppppp"
                                
                                else:
                                 if release["label-info-list"][0].has_key('label'):
                                  for label in release["label-info-list"]:
                                    #WE NEED TO TEST HERE
                                    #print "label:",label["label"]["sort-name"]
                                    #print "labelid:",label
                                    
#WE CREATE A DICTIONNARY WITH OUR FIELDS, WITH FORMAT
                                    if label.has_key('label'):
                                     if label["label"]["id"] not in labels_dict["labids"]:
                                        labels_dict["labids"].append(label["label"]["id"])
                                        labels_dict[label["label"]["id"]]={}

                                        labels_dict[label["label"]["id"]]["label_name"]=label["label"]["sort-name"]
                                        labels_dict[label["label"]["id"]]["label_id" ]=label["label"]["id"]
#WE Build the label aliases tables here so that all labels have their relationships##
                                        if label["label"]["id"] not in labels_aliases:
                                            labels_aliases[label["label"]["id"]] = musicbrainzngs.get_label_by_id(label["label"]["id"], includes=["aliases", "annotation", "area-rels", "label-rels", "place-rels"])
                                        #print "labels_aliases",labels_aliases
                                     labels_dict[label["label"]["id"]][str(key)]={}
                                    #print key
                                     labels_dict[label["label"]["id"]][str(key)]["album_id"]=release["id"]
                                     labels_dict[label["label"]["id"]][str(key)]["album_title"]=release["title"]
                                     releDate=release["release-event-list"][0]
                                #print "releDate", release["release-event-list"][0]
                                     if  releDate.has_key("date"):
                                        dateRel=arrow.get(releDate["date"])
                                        #print "date:", dateRel.strftime('%Y-%m-%d')
                                        labels_dict[label["label"]["id"]][str(key)]["album_date"]=dateRel.strftime('%Y-%m-%d')
                                     key = key +1
                                 else:
                                    print "NORELEASEDATE2"
                                    #key = key +1
                            #else:
                                #key = key +1
                                #print "NORELEASEDATE"
#NOW we make a nice lightweight object to push to mongo
                        labels_dict["name"]=artist["name"]
                        print labels_dict["name"],'\r\n'
                        db.labels_dict_per_artist.update({'myid': artist["name"] } ,labels_dict, upsert=True, multi=False)
                      except  musicbrainzngs.ResponseError:
                        print "oups",artist["name"]

                #with open(os.path.join(DATA_FOLDER,artist["name"],".json"), 'w') as outfile:
                             #   json.dump(labels_dict, outfile)
                            #db.minedArtists.artist.insert_one(labels_dict)
#with open(os.path.join(DATA_FOLDER,"label_equiv_table.json"), 'w') as outfile:
 #                               json.dump(labels_aliases, outfile)
print labels_aliases,'\r\n\r\n\r\n'
# Out:
# Николай Луганский
# aartist_mbid cd909fcb-7c80-4988-9b91-930c06d18d27
# pppppppppppppp
# Николай Луганский
#
# serafine
# ('NOMBID for', u'serafine')
# ÖRFAZ
# ('NOMBID for', u'\xd6RFAZ')
# zilselance
# ('NOMBID for', u'zilselance')
# twenty one pilots
# ('NOMBID for', u'twenty one pilots')
# tigran
# ('NOMBID for', u'tigran')
# the Shrine
# ('NOMBID for', u'the Shrine')
# the Bottlemen
# ('NOMBID for', u'the Bottlemen')
# rødhåd
# ('NOMBID for', u'r\xf8dh\xe5d')
# pastor
# ('NOMBID for', u'pastor')
# openightmare
# ('NOMBID for', u'openightmare')
# noJazz
# aartist_mbid 710e4f10-55ee-4328-8270-672ab64031f8
# pppppppppppppp
# pppppppppppppp
# noJazz
#
# maracujah
# ('NOMBID for', u'maracujah')
# krAzy spAce
# ('NOMBID for', u'krAzy spAce')
# jeanette berger
# ('NOMBID for', u'jeanette berger')
# hiks
# ('NOMBID for', u'hiks')
# dj yannick robyns
# ('NOMBID for', u'dj yannick robyns')
# dean
# aartist_mbid 9255340c-8a9d-4822-8f4a-941ecdd20b83
# pppppppppppppp
# dean
#
# belin
# ('NOMBID for', u'belin')
# anka
# ('NOMBID for', u'anka')
# alan
# aartist_mbid dded0177-e235-474e-8529-a812b89f806c
# pppppppppppppp
# alan
#
# a Tribute To ABBA
# ('NOMBID for', u'a Tribute To ABBA')
# Zachary Richard
# aartist_mbid 2b1999ba-5256-4e9b-84be-4a23b9283e84
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Zachary Richard
#
# ZUDAKABASS
# ('NOMBID for', u'ZUDAKABASS')
# ZAM'S
# aartist_mbid 15b30991-0bbd-430e-9ebb-134b141e61e4
# pppppppppppppp
# ZAM'S
#
# Yutaka Shiina
# ('NOMBID for', u'Yutaka Shiina')
# Yoann Kempst
# ('NOMBID for', u'Yoann Kempst')
# bomba estereo
# ('NOMBID for', u'bomba estereo')
# Zoufris Maracas
# ('NOMBID for', u'Zoufris Maracas')
# Zimmer
# aartist_mbid e6de1f3b-6484-491c-88dd-6d619f142abc
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Zimmer
#
# Zebrahead
# aartist_mbid 4df5d35b-a9d4-4d4f-91f6-bae55693de31
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Zebrahead
#
# Youthman
# ('NOMBID for', u'Youthman')
# Youssef
# aartist_mbid dd02e5d3-8022-4cc7-a10d-7ada9031b545
# Youssef
#
# Young Marble Giants
# aartist_mbid 3d113367-769f-4200-9ff8-e19d47def451
# pppppppppppppp
# Young Marble Giants
#
# You said strange
# ('NOMBID for', u'You said strange')
# Year of No Light
# aartist_mbid 2a1a36b0-d465-4941-9658-2c67cdfb9bba
# pppppppppppppp
# Year of No Light
#
# Yaron Herman
# aartist_mbid fe018ccc-1943-4287-ac8b-2681e259e0f5
# pppppppppppppp
# Yaron Herman
#
# Yannick Robert
# ('NOMBID for', u'Yannick Robert')
# Yaniss Odua
# aartist_mbid c332d8d7-9f93-40eb-891b-05d060850d65
# pppppppppppppp
# pppppppppppppp
# Yaniss Odua
#
# Ya-Ourt
# ('NOMBID for', u'Ya-Ourt')
# YELLI YELLI
# ('NOMBID for', u'YELLI YELLI')
# Xavier Rudd
# aartist_mbid 6689a626-4de7-41d5-9ec3-5a289472a9e2
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Xavier Rudd
#
# XY
# ('NOMBID for', u'XY')
# X-TV
# ('NOMBID for', u'X-TV')
# Worms Eat Her
# ('NOMBID for', u'Worms Eat Her')
# Woodini
# ('NOMBID for', u'Woodini')
# Wombo Orchestra
# ('NOMBID for', u'Wombo Orchestra')
# Witches
# aartist_mbid f586a74f-55b4-48f6-93fa-220319c7d80f
# Witches
#
# Wine
# aartist_mbid 3631115d-a560-421a-b2be-5c41ed72024d
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Wine
#
# Will Buck
# ('NOMBID for', u'Will Buck')
# Who's Panda
# ('NOMBID for', u"Who's Panda")
# Where is Stanley
# ('NOMBID for', u'Where is Stanley')
# Wedge
# aartist_mbid a5b93913-10ae-4ff6-83d1-839031dd0a77
# Wedge
#
# We Project
# ('NOMBID for', u'We Project')
# Way Of Changes
# ('NOMBID for', u'Way Of Changes')
# Water Mane
# ('NOMBID for', u'Water Mane')
# Wapalek
# ('NOMBID for', u'Wapalek')
# Walk Off the Earth
# ('NOMBID for', u'Walk Off the Earth')
# WEEKEND AFFAIR
# ('NOMBID for', u'WEEKEND AFFAIR')
# WALKO (Afrobeat)
# ('NOMBID for', u'WALKO (Afrobeat)')
# Vulvectomy
# aartist_mbid bbe5bd6d-0971-4fc8-a76c-9acc2ceee3e9
# Vulvectomy
#
# Volin
# ('NOMBID for', u'Volin')
# Vital Remains
# aartist_mbid 39977a2d-659a-43e6-b2ad-0c33687624f7
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Vital Remains
#
# Virgin Snatch
# aartist_mbid 81a4f87a-cb82-45fc-a21a-dbce8a421dc6
# pppppppppppppp
# Virgin Snatch
#
# Vinicio Capossela
# aartist_mbid 5115929f-f133-47b4-bf1c-8a0df582ce23
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Vinicio Capossela
#
# Vincent
# aartist_mbid b828f310-037b-442e-94aa-6bd2bd8ff047
# Vincent
#
# Viken Arman
# ('NOMBID for', u'Viken Arman')
# Vidal Benjamin
# ('NOMBID for', u'Vidal Benjamin')
# Vianney
# ('NOMBID for', u'Vianney')
# Verveine
# ('NOMBID for', u'Verveine')
# Veronica & The Red Wine Serenaders
# ('NOMBID for', u'Veronica & The Red Wine Serenaders')
# Velasquez
# ('NOMBID for', u'Velasquez')
# Varekai
# ('NOMBID for', u'Varekai')
# Valley of the Sun
# ('NOMBID for', u'Valley of the Sun')
# Valdes
# aartist_mbid 4aa7c152-8c2b-4879-b0c7-817456423f22
# Valdes
#
# VS Music-com
# ('NOMBID for', u'VS Music-com')
# VINTAGE TROUBLE
# ('NOMBID for', u'VINTAGE TROUBLE')
# VADEL
# ('NOMBID for', u'VADEL')
# Upon A Burning Body
# ('NOMBID for', u'Upon A Burning Body')
# United Music Records
# ('NOMBID for', u'United Music Records')
# Uncle Joe
# aartist_mbid f94d6b64-f5bb-4636-952b-0b931c24ca2c
# pppppppppppppp
# Uncle Joe
#
# Ulster Page
# ('NOMBID for', u'Ulster Page')
# UNSU
# ('NOMBID for', u'UNSU')
# U Stone
# ('NOMBID for', u'U Stone')
# TwoSixOnes
# ('NOMBID for', u'TwoSixOnes')
# Tube
# aartist_mbid 9b1da1cf-e620-4de2-a54d-356541a6a2d7
# Tube
#
# Try $ Again
# ('NOMBID for', u'Try $ Again')
# Überkeine
# ('NOMBID for', u'\xdcberkeine')
# Turzi
# aartist_mbid 869ecd86-35e7-409c-9813-28efb8638904
# Turzi
#
# Trivium
# aartist_mbid 1f5ff245-2837-4d4a-a609-e93e544478c3
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Trivium
#
# Trio BASSMA
# ('NOMBID for', u'Trio BASSMA')
# Travis Scott
# ('NOMBID for', u'Travis Scott')
# Toxic Waste
# aartist_mbid ae753640-8cef-44a2-bccb-98ad2d24267b
# Toxic Waste
#
# Totó La Momposina
# aartist_mbid 6904c849-97ab-4bf2-af51-467e8dd98ec9
# Totó La Momposina
#
# Tony Melvil
# ('NOMBID for', u'Tony Melvil')
# Tony Allen
# aartist_mbid 7d4a5895-e40e-47ed-b1f3-74224fe667d4
# Tony Allen
#
# Tonga
# ('NOMBID for', u'Tonga')
# Tommy Jacob
# ('NOMBID for', u'Tommy Jacob')
# Tom McRae
# aartist_mbid 9f5a87ec-0201-45ba-8b03-3b9e0b50a112
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Tom McRae
#
# Tom Demac
# aartist_mbid c63ab5df-3be5-42c1-b7f0-6d090c7408c9
# Tom Demac
#
# Todd Terje
# aartist_mbid a0cded3a-4ca3-4ddb-8e46-ed9037f30aea
# NORELEASEDATE2
# Todd Terje
#
# To be confirmed
# ('NOMBID for', u'To be confirmed')
# Titi Robin
# aartist_mbid b8872c45-bbb5-448d-a438-8e3956258715
# pppppppppppppp
# pppppppppppppp
# Titi Robin
#
# Time for T.
# ('NOMBID for', u'Time for T.')
# Thurisaz
# aartist_mbid 54e8d246-554a-41ff-9b83-ad4a48377f9c
# Thurisaz
#
# Thorsten Havener
# ('NOMBID for', u'Thorsten Havener')
# Thomas Ngijol
# ('NOMBID for', u'Thomas Ngijol')
# Thomas Enhco
# aartist_mbid e5cd692d-e3ea-4f89-8635-abf577f45f53
# pppppppppppppp
# Thomas Enhco
#
# Things Of Life
# ('NOMBID for', u'Things Of Life')
# 恩田晃
# aartist_mbid 68987424-7c3e-458e-a79a-736a4883c9d5
# 恩田晃
#
# Արամ Խաչատրյան
# aartist_mbid fa25cd1f-beeb-4718-b4bb-d3da4f53539f
# Արամ Խաչատրյան
#
# Στέλιος Πετράκης
# aartist_mbid fdd6d721-1748-4b0d-941e-bc7c6e3f29f0
# Στέλιος Πετράκης
#
# Élodie Frégé
# aartist_mbid 8cda32b5-1447-4ded-8a0e-f1cf8e6b3480
# Élodie Frégé
#
# xdb
# ('NOMBID for', u'xdb')
# vendome
# ('NOMBID for', u'vendome')
# tlr
# ('NOMBID for', u'tlr')
# the autumn art festival
# ('NOMBID for', u'the autumn art festival')
# the Innocent Criminals
# ('NOMBID for', u'the Innocent Criminals')
# steve gunn
# ('NOMBID for', u'steve gunn')
# sean360x
# ('NOMBID for', u'sean360x')
# pianiste
# ('NOMBID for', u'pianiste')
# ordoeuvre
# ('NOMBID for', u'ordoeuvre')
# ochoa
# ('NOMBID for', u'ochoa')
# muramasa
# ('NOMBID for', u'muramasa')
# midnight sorrow
# ('NOMBID for', u'midnight sorrow')
# la dame blanche
# aartist_mbid d3a4de9a-5931-46de-9aca-56aed2a3ef48
# pppppppppppppp
# la dame blanche
#
# julien D aka Smither
# ('NOMBID for', u'julien D aka Smither')
# hollander
# aartist_mbid e057bfca-c278-4337-abd5-b7648d015d98
# pppppppppppppp
# hollander
#
# gabo lora
# ('NOMBID for', u'gabo lora')
# dypingoos
# ('NOMBID for', u'dypingoos')
# dj emerson
# ('NOMBID for', u'dj emerson')
# dKmiKe
# ('NOMBID for', u'dKmiKe')
# bird
# aartist_mbid 7dafc8b7-8d46-49b7-bc48-558b1fd181e9
# NORELEASEDATE2
# NORELEASEDATE2
# NORELEASEDATE2
# NORELEASEDATE2
# NORELEASEDATE2
# NORELEASEDATE2
# pppppppppppppp
# NORELEASEDATE2
# pppppppppppppp
# pppppppppppppp
# bird
#
# antropofago
# ('NOMBID for', u'antropofago')
# alto clark
# ('NOMBID for', u'alto clark')
# [yet]
# ('NOMBID for', u'[yet]')
# Zenker Brothers
# ('NOMBID for', u'Zenker Brothers')
# Zargenbruch
# ('NOMBID for', u'Zargenbruch')
# Zahra
# ('NOMBID for', u'Zahra')
# Za:im
# ('NOMBID for', u'Za:im')
# ZEBRA KATZ
# ('NOMBID for', u'ZEBRA KATZ')
# Yves Duteil
# aartist_mbid b8fb054b-86c9-4c6b-8bb1-d1b088c46e2c
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# NORELEASEDATE2
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Yves Duteil
#
# Yuksek
# aartist_mbid d6285d95-8ee1-4de2-8ceb-ff90098ab1d1
# Yuksek
#
# Young Thug
# ('NOMBID for', u'Young Thug')
# Youcef
# aartist_mbid b4c931b8-0577-4e66-94f8-76b988e5ead3
# Youcef
#
# Yonathan AVISHAI
# ('NOMBID for', u'Yonathan AVISHAI')
# Yilian Canizares
# ('NOMBID for', u'Yilian Canizares')
# Years & Years
# ('NOMBID for', u'Years & Years')
# Yasmin Shah
# ('NOMBID for', u'Yasmin Shah')
# Yannick
# aartist_mbid 0f51b7d8-50d8-4703-918b-37e91bb53297
# Yannick
#
# Yael Naim
# aartist_mbid def226b0-7990-4b38-ab1a-7740461844dc
# pppppppppppppp
# Yael Naim
#
# YOUR OWN FILM
# ('NOMBID for', u'YOUR OWN FILM')
# Xanthoula Dakovanou et l'Ensemble Anassa
# ('NOMBID for', u"Xanthoula Dakovanou et l'Ensemble Anassa")
# XAVIER RUDD & THE UNITED NATIONS
# ('NOMBID for', u'XAVIER RUDD & THE UNITED NATIONS')
# Wyld
# aartist_mbid dc94e943-0aec-410a-b4e9-c882d7b6fc59
# Wyld
#
# Worakls
# ('NOMBID for', u'Worakls')
# Wood
# aartist_mbid f48cde2f-e9a5-4ae3-8a2b-b9adaed2296e
# pppppppppppppp
# Wood
#
# Wo Fat
# aartist_mbid 78998e4b-fc1d-4f87-bf4b-c6f3ca82a77a
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Wo Fat
#
# Winston
# aartist_mbid f91adf16-cc9e-4b0e-8f16-d59a788a74c9
# Winston
#
# Willi Williams
# aartist_mbid 14f03e90-a90c-4579-8faf-5296d716c3a7
# pppppppppppppp
# Willi Williams
#
# Why (FR)
# ('NOMBID for', u'Why (FR)')
# White Crocodile
# ('NOMBID for', u'White Crocodile')
# Weval
# ('NOMBID for', u'Weval')
# Wehrmacht
# aartist_mbid ee1eb273-e040-42ca-a076-c02faedb378b
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Wehrmacht
#
# We Will Meet Again
# ('NOMBID for', u'We Will Meet Again')
# We Have Band
# aartist_mbid b83b1cc7-38ea-4a6c-bd87-9853f0034fab
# We Have Band
#
# Wayne McGregor
# ('NOMBID for', u'Wayne McGregor')
# Wavesonik
# ('NOMBID for', u'Wavesonik')
# Washington Dead Cats
# aartist_mbid f246422f-1ed4-4621-9955-5ae91efae895
# pppppppppppppp
# pppppppppppppp
# Washington Dead Cats
#
# Wad Ad
# ('NOMBID for', u'Wad Ad')
# WBA Entertainment
# ('NOMBID for', u'WBA Entertainment')
# Véronique Sanson
# aartist_mbid f1dc86d6-9f45-4736-8884-7fcafbccd876
# Véronique Sanson
#
# Volumes
# aartist_mbid 9d397404-907d-4355-b5d6-299bae93f6d9
# Volumes
#
# Visionist
# ('NOMBID for', u'Visionist')
# Violetta Live
# ('NOMBID for', u'Violetta Live')
# Vincent Peirani
# ('NOMBID for', u'Vincent Peirani')
# Villanova
# aartist_mbid 0b276f0a-a318-4cdf-9654-e7dd42045e5c
# Villanova
#
# Viet Cong
# ('NOMBID for', u'Viet Cong')
# Vestiges
# ('NOMBID for', u'Vestiges')
# Vertical
# aartist_mbid eeb9d0c0-6794-4284-b8ed-9117f8e3288c
# Vertical
#
# Venice Beach
# ('NOMBID for', u'Venice Beach')
# Valeriane
# ('NOMBID for', u'Valeriane')
# zuuma
# ('NOMBID for', u'zuuma')
# Vibronics
# aartist_mbid 0f43b78a-575b-4bd1-b538-840c474800aa
# Vibronics
#
# Varoslav
# ('NOMBID for', u'Varoslav')
# Vandal
# aartist_mbid f4bd6762-58c4-4db9-b053-c4fecccb383a
# Vandal
#
# Vaguement la Jungle
# aartist_mbid 9092b520-1fa0-458d-accf-0aa810af526b
# pppppppppppppp
# pppppppppppppp
# Vaguement la Jungle
#
# VIP
# aartist_mbid b3bc83ce-9520-4884-85c7-8c4222d5ae40
# VIP
#
# VANUPIE
# ('NOMBID for', u'VANUPIE')
# Unknown Mortal Orchestra
# ('NOMBID for', u'Unknown Mortal Orchestra')
# Unibox
# ('NOMBID for', u'Unibox')
# Uncle Acid
# ('NOMBID for', u'Uncle Acid ')
# Ubikar Musique
# ('NOMBID for', u'Ubikar Musique')
# U2 France Info
# ('NOMBID for', u'U2 France Info')
# Tyler, The Creator
# ('NOMBID for', u'Tyler, The Creator')
# Tutti
# ('NOMBID for', u'Tutti')
# Turbo Turbo
# ('NOMBID for', u'Turbo Turbo')
# Trypod
# ('NOMBID for', u'Trypod')
# Tropkillaz
# ('NOMBID for', u'Tropkillaz')
# Triptykon
# ('NOMBID for', u'Triptykon')
# Trio JMK Officiel
# ('NOMBID for', u'Trio JMK Officiel')
# Tremonti
# ('NOMBID for', u'Tremonti')
# Trama
# aartist_mbid a9336489-09b2-4188-8c66-aa1a4a26a761
# Trama
#
# Torb
# ('NOMBID for', u'Torb')
# Tony Bennett & Lady Gaga
# ('NOMBID for', u'Tony Bennett & Lady Gaga')
# TonTon
# ('NOMBID for', u'TonTon')
# Tom Wardle
# ('NOMBID for', u'Tom Wardle')
# Tom Frager
# aartist_mbid 74a48e30-37f9-40fb-a30f-116c83f1e773
# pppppppppppppp
# Tom Frager
#
# Tom Arthurs
# aartist_mbid ac585659-54d1-47f3-9c87-1cdf8bb50712
# Tom Arthurs
#
# Toi et  Moi
# ('NOMBID for', u'Toi et  Moi')
# Toby Rost
# ('NOMBID for', u'Toby Rost')
# Titus Andronicus
# aartist_mbid d38c47f6-d9bb-4a77-aaea-df53a6616a68
# Titus Andronicus
#
# Tina May
# aartist_mbid cebc70a9-512b-4922-8481-c977b1d7c854
# pppppppppppppp
# Tina May
#
# Tildon Krautz
# ('NOMBID for', u'Tildon Krautz')
# Thylacine
# ('NOMBID for', u'Thylacine')
# Thousand
# aartist_mbid fcb651e5-78ff-4b44-8e07-5a1aa1be1ba4
# Thousand
#
# Thomas Schoeffler Jr.
# ('NOMBID for', u'Thomas Schoeffler Jr.')
# Thomas Fersen
# aartist_mbid 083a443a-dcba-4d48-aa62-fda1f130002f
# Thomas Fersen
#
# Thomas BRAMERIE
# ('NOMBID for', u'Thomas BRAMERIE')
# Theorist OFC
# ('NOMBID for', u'Theorist OFC')
# The Wombats
# aartist_mbid e105c272-b5d7-4135-82ef-d60bded54345
# The Wombats
#
# The Wildabouts
# ('NOMBID for', u'The Wildabouts')
# The Wedding Present
# aartist_mbid 707622da-475f-48e1-905d-248718df6521
# pppppppppppppp
# pppppppppppppp
# NORELEASEDATE2
# pppppppppppppp
# pppppppppppppp
# The Wedding Present
#
# The Wanton Bishops
# ('NOMBID for', u'The Wanton Bishops')
# The Vintage Caravan
# ('NOMBID for', u'The Vintage Caravan')
# The Toure Raichel Collective
# ('NOMBID for', u'The Toure Raichel Collective')
# The Tallest Man on Earth
# aartist_mbid 7e35659f-f3bb-4c28-bcf5-47bd5cfa2bca
# pppppppppppppp
# The Tallest Man on Earth
#
# The Sunvizors
# ('NOMBID for', u'The Sunvizors')
# The Steam Dream
# ('NOMBID for', u'The Steam Dream')
# The Souljazz Orchestra
# aartist_mbid 453dab0c-aa5f-4091-bf58-64dead0d06b8
# The Souljazz Orchestra
#
# ★ DJ MISS ROXX ★
# ('NOMBID for', u'\u2605 DJ MISS ROXX \u2605')
# Фаррелл Уильямс
# ('NOMBID for', u'\u0424\u0430\u0440\u0440\u0435\u043b\u043b \u0423\u0438\u043b\u044c\u044f\u043c\u0441')
# Μαρία Φαραντούρη
# aartist_mbid 9e585bf7-feb0-4960-9b6a-eefe3ae6a61e
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Μαρία Φαραντούρη
#
# Ø L T E N
# ('NOMBID for', u'\xd8 L T E N')
# xa
# ('NOMBID for', u'xa')
# undobar
# ('NOMBID for', u'undobar')
# tite
# ('NOMBID for', u'tite')
# the Tips
# ('NOMBID for', u'the Tips')
# the Family Stone
# ('NOMBID for', u'the Family Stone')
# sayCeT
# aartist_mbid 1a7bd36d-0547-409d-83f2-2a815d55ddcd
# sayCeT
#
# photograph
# ('NOMBID for', u'photograph')
# ophélie mercury
# ('NOMBID for', u'oph\xe9lie mercury')
# noZen
# ('NOMBID for', u'noZen')
# mr statik
# ('NOMBID for', u'mr statik')
# michael valeanu
# ('NOMBID for', u'michael valeanu')
# mademoiselle Théodore
# ('NOMBID for', u'mademoiselle Th\xe9odore')
# kravitz
# ('NOMBID for', u'kravitz')
# john osborn
# ('NOMBID for', u'john osborn')
# hindi
# ('NOMBID2 for', u'hindi')
# fatras
# ('NOMBID for', u'fatras')
# djruffneck
# ('NOMBID for', u'djruffneck')
# dj PM
# ('NOMBID for', u'dj PM')
# dDamage
# aartist_mbid a2d15e23-1bcb-45b5-8d3b-893f75274ab4
# pppppppppppppp
# dDamage
#
# biga ranx
# ('NOMBID for', u'biga ranx')
# antiloops
# ('NOMBID for', u'antiloops')
# alexandre astier
# ('NOMBID for', u'alexandre astier')
# a-ha
# aartist_mbid 7364dea6-ca9a-48e3-be01-b44ad0d19897
# pppppppppppppp
# pppppppppppppp
# a-ha
#
# Zu
# aartist_mbid 46541c29-e1d4-4015-91e8-6ca7b5e6fb9b
# pppppppppppppp
# Zu
#
# Zizor
# ('NOMBID for', u'Zizor')
# Zef
# ('NOMBID for', u'Zef')
# Zappa Plays Zappa
# aartist_mbid fcebdabe-319f-4690-8827-c8fac63b1b80
# Zappa Plays Zappa
#
# Zachary Richard- Official
# ('NOMBID for', u'Zachary Richard- Official')
# ZZ Top
# aartist_mbid a81259a0-a2f5-464b-866e-71220f2739f1
# pppppppppppppp
# ZZ Top
#
# ZAZ
# ('NOMBID for', u'ZAZ')
# Yseult
# ('NOMBID for', u'Yseult')
# Youssef Dhafer
# ('NOMBID for', u'Youssef Dhafer')
# Young Rebel Set
# aartist_mbid 7b2aeb3f-c51f-4b35-8f38-54bdbab7a8a9
# Young Rebel Set
#
# You're Next Records
# ('NOMBID for', u"You're Next Records")
# Yom
# aartist_mbid 423ab89d-fec4-4d10-a5d0-606d83258ab2
# pppppppppppppp
# Yom
#
# Yes
# ('NOMBID for', u'Yes ')
# Years
# aartist_mbid ba535289-8407-4642-9b00-e7973458cbcb
# Years
#
# Yasiin Bey
# ('NOMBID for', u'Yasiin Bey')
# Yannick Robyns
# ('NOMBID for', u'Yannick Robyns')
# Yann
# ('NOMBID for', u'Yann')
# Yael
# ('NOMBID for', u'Yael')
# YEMAYA LA BANDA
# ('NOMBID for', u'YEMAYA LA BANDA')
# Xtreme Fest
# ('NOMBID for', u'Xtreme Fest')
# Xandria
# aartist_mbid 656a0800-3a2b-47ed-a3ff-1e2908fdd2ff
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Xandria
#
# X-Y
# ('NOMBID for', u'X-Y')
# WonderSoul
# ('NOMBID for', u'WonderSoul')
# Witchsmeller Pursuivant
# aartist_mbid 0e721e45-cb62-4631-b9ef-94b76c768d7c
# Witchsmeller Pursuivant
#
# Winnipeg
# ('NOMBID for', u'Winnipeg')
# Vérane
# ('NOMBID for', u'V\xe9rane')
# Vitrolles Sun Festival
# ('NOMBID for', u'Vitrolles Sun Festival')
# Wu-Tang Clan
# aartist_mbid 0febdcf7-4e1f-4661-9493-b40427de2c13
# pppppppppppppp
# Wu-Tang Clan
#
# Woods
# aartist_mbid 42a1253e-0efc-45e8-b627-ff802fb9e9ee
# Woods
#
# Williams
# aartist_mbid 5b95b2d4-67fd-4158-ada9-fc70e1a493db
# Williams
#
# Will Saul
# aartist_mbid be7eebdd-a63b-462b-9f38-96bd6502d14b
# Will Saul
#
# WhoMadeWho
# aartist_mbid e731ab08-45c4-4e98-a1e4-7a16462c9cfb
# pppppppppppppp
# WhoMadeWho
#
# Whisper of Death
# ('NOMBID for', u'Whisper of Death')
# Weltend
# ('NOMBID for', u'Weltend')
# Wehbba
# aartist_mbid e04887f6-78ce-4164-859b-7de28ae6f7c0
# Wehbba
#
# We Were Promised Jetpacks
# aartist_mbid 8f0e0596-5a39-4bd5-9dfa-f2b12030ffdc
# We Were Promised Jetpacks
#
# We Are the City
# ('NOMBID for', u'We Are the City')
# Wayne Escoffery
# ('NOMBID for', u'Wayne Escoffery')
# Wati B
# ('NOMBID for', u'Wati B')
# Wardruna
# aartist_mbid 91136bf7-3b12-4ae5-b93b-eddb9e561dfb
# Wardruna
#
# Walk The Moon
# ('NOMBID for', u'Walk The Moon')
# WINSTON McANUFF & FIXI
# ('NOMBID for', u'WINSTON McANUFF & FIXI')
# WANG RAMIREZ
# ('NOMBID for', u'WANG RAMIREZ')
# Våld
# ('NOMBID for', u'V\xe5ld')
# Volk
# ('NOMBID for', u'Volk')
# Virginie Teychené
# ('NOMBID for', u'Virginie Teychen\xe9')
# Violetta
# ('NOMBID for', u'Violetta')
# Vincent Jourde
# ('NOMBID for', u'Vincent Jourde')
# Viktorija Gečytė
# ('NOMBID for', u'Viktorija Ge\u010dyt\u0117')
# Vide Grenier Brass Band
# ('NOMBID for', u'Vide Grenier Brass Band')
# Victor Kiswell
# ('NOMBID for', u'Victor Kiswell')
# Vibration Visuelle
# ('NOMBID for', u'Vibration Visuelle')
# Versus the World
# aartist_mbid 0171fb12-5302-4b70-9bf3-c1030ec122b3
# Versus the World
#
# Vendège
# ('NOMBID for', u'Vend\xe8ge')
# Varez
# ('NOMBID for', u'Varez')
# Valentin Huedo
# ('NOMBID for', u'Valentin Huedo')
# Vadim Svoboda
# ('NOMBID for', u'Vadim Svoboda')
# VADER
# aartist_mbid 702c7d71-7559-4850-b6dc-1de54ada4abc
# VADER
#
# Uppermost
# aartist_mbid 166fd628-f034-434d-bcd8-37618db2bbf0
# pppppppppppppp
# Uppermost
#
# Unearth
# aartist_mbid 9f336c50-ae4c-4440-bda7-958aa12bc15a
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Unearth
#
# Un Nerf De Swing
# ('NOMBID for', u'Un Nerf De Swing')
# UVB
# ('NOMBID for', u'UVB')
# U2
# aartist_mbid a3cb23fc-acd3-4ce0-8f36-1e5aa6a18432
# U2
#
# Tygers of Pan Tang
# aartist_mbid fe179f28-3cab-4337-9575-c13f8d077b13
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Tygers of Pan Tang
#
# Tuscaloosa
# ('NOMBID for', u'Tuscaloosa')
# 郎朗
# aartist_mbid 43e1570a-1a0d-479f-9c95-fba971aec91a
# 郎朗
#
# فيروز
# aartist_mbid 338bbb53-5b96-447a-9444-8906844a0790
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# فيروز
#
# ДахаБраха
# aartist_mbid 208334a1-abf0-4791-9705-b45838244b29
# pppppppppppppp
# pppppppppppppp
# ДахаБраха
#
# Željko Joksimović
# aartist_mbid 380b799f-4aca-44e9-aade-5b0714cadb6c
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Željko Joksimović
#
# zid
# ('NOMBID for', u'zid')
# wimp
# ('NOMBID for', u'wimp')
# toybloid
# ('NOMBID for', u'toybloid')
# the police contact
# ('NOMBID for', u'the police contact')
# the Rooms
# ('NOMBID for', u'the Rooms')
# the Bad
# ('NOMBID for', u'the Bad')
# segur
# ('NOMBID for', u'segur')
# pasi
# ('NOMBID for', u'pasi')
# oh happy day
# ('NOMBID for', u'oh happy day')
# nickelback
# aartist_mbid bc710bcf-8815-42cf-bad2-3f1d12246aeb
# NORELEASEDATE2
# pppppppppppppp
# nickelback
#
# moms
# aartist_mbid f80fa0d7-d913-4bec-96db-e4efa31e4238
# pppppppppppppp
# moms
#
# meggy
# ('NOMBID for', u'meggy')
# manu svensson
# ('NOMBID for', u'manu svensson')
# lauri soini
# ('NOMBID for', u'lauri soini')
# keen V
# ('NOMBID for', u'keen V')
# iZA
# ('NOMBID for', u'iZA')
# getdown
# ('NOMBID for', u'getdown')
# eli verveine
# ('NOMBID for', u'eli verveine')
# dj oil
# ('NOMBID for', u'dj oil')
# ddd
# aartist_mbid b9d2fcb1-95e1-4498-877f-3770e46de2ca
# ddd
#
# buena vista social club
# aartist_mbid 2a85ecff-41e9-4be1-aca6-c87054a4c334
# buena vista social club
#
# andreas gabalier
# ('NOMBID for', u'andreas gabalier')
# al'tarba
# ('NOMBID for', u"al'tarba")
# a Midsummer Night's Dream
# ('NOMBID for', u"a Midsummer Night's Dream")
# Zomething
# ('NOMBID for', u'Zomething')
# Zi Elektrik Beez
# ('NOMBID for', u'Zi Elektrik Beez')
# Zebda Officiel
# ('NOMBID for', u'Zebda Officiel')
# Zanmari Bare
# ('NOMBID for', u'Zanmari Bare')
# Zacharie Abraham
# ('NOMBID for', u'Zacharie Abraham')
# ZOB'
# ('NOMBID for', u"ZOB'")
# Z-ID
# ('NOMBID for', u'Z-ID')
# Yuri Buenaventura
# aartist_mbid 4b33cf77-1ced-42e2-955c-ace858710b69
# pppppppppppppp
# Yuri Buenaventura
#
# Youssoupha
# aartist_mbid 6fabf3aa-1822-49f2-b6c7-57560464696f
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Youssoupha
#
# Your Old Droog
# ('NOMBID for', u'Your Old Droog')
# Young Fathers
# aartist_mbid 24aa5c20-a275-468a-93a9-b3d96b344b6c
# Young Fathers
#
# You Man
# ('NOMBID for', u'You Man')
# Yo La Tengo
# aartist_mbid 3f542031-b054-454d-b57b-812fa2a81b11
# pppppppppppppp
# Yo La Tengo
#
# Yellow
# aartist_mbid c616aef1-e21f-46f8-864f-b7bad96f41b2
# Yellow
#
# Ycare
# aartist_mbid b4225d57-ea6a-4260-993b-cae49c638dae
# pppppppppppppp
# Ycare
#
# Yaron
# ('NOMBID for', u'Yaron')
# Yannick Noah Officiel
# ('NOMBID for', u'Yannick Noah Officiel')
# Yan
# aartist_mbid e65948ec-284c-4360-bb11-eb3d45263ee6
# Yan
#
# YVAN LE BOLLOC'H
# ('NOMBID for', u"YVAN LE BOLLOC'H")
# YEALLOW
# ('NOMBID for', u'YEALLOW')
# XPLCT
# ('NOMBID for', u'XPLCT')
# X Syndicate
# aartist_mbid 5ad1044b-b737-4a86-b575-0a06995b8947
# pppppppppppppp
# pppppppppppppp
# X Syndicate
#
# World People Prod Label
# ('NOMBID for', u'World People Prod Label')
# Wooden Shields
# ('NOMBID for', u'Wooden Shields')
# Winter
# aartist_mbid 57e5fa50-48fd-4920-a5bf-0e6d7950a2ba
# pppppppppppppp
# Winter
#
# Wim Vandekeybus
# ('NOMBID for', u'Wim Vandekeybus')
# William Forsythe
# ('NOMBID for', u'William Forsythe')
# Wild Side
# ('NOMBID for', u'Wild Side')
# Whitney Weiss
# ('NOMBID for', u'Whitney Weiss')
# When Reasons Collapse
# ('NOMBID for', u'When Reasons Collapse')
# Weldis&Ros
# ('NOMBID for', u'Weldis&Ros')
# Weazley
# ('NOMBID for', u'Weazley')
# We Insist!
# ('NOMBID for', u'We Insist!')
# Wbeeza
# aartist_mbid dc258e6e-8924-4867-8a8d-6b3efbb4b83a
# Wbeeza
#
# Waxist
# ('NOMBID for', u'Waxist')
# Water Babies - Band
# ('NOMBID for', u'Water Babies - Band')
# Walter
# aartist_mbid 9f5a9ada-3ce6-4af7-8b90-527cb6dfc5ac
# Walter
#
# Waiting For Breakfast
# ('NOMBID for', u'Waiting For Breakfast')
# WE ARE MATCH
# ('NOMBID for', u'WE ARE MATCH')
# W.A.S.P.
# aartist_mbid 171cbc8f-8ab3-4aec-9916-f0bdbe26bb79
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# W.A.S.P.
#
# Vso
# ('NOMBID for', u'Vso')
# Volcan
# ('NOMBID for', u'Volcan')
# Vitaa
# aartist_mbid aad54e51-0619-4b21-a69b-d0901d2ef7e0
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Vitaa
#
# Virgil
# aartist_mbid 6fb20917-f0a6-474e-aa12-f92ad85250cc
# pppppppppppppp
# pppppppppppppp
# Virgil
#
# Vincent Vega
# aartist_mbid 5078622f-a360-428e-b276-bf6117b64a1d
# Vincent Vega
#
# Vince Staples
# ('NOMBID for', u'Vince Staples')
# Vieux Farka Touré
# aartist_mbid 7682d624-9e0b-45b2-b7d0-d1b18b3ebd05
# Vieux Farka Touré
#
# Vidal
# aartist_mbid 2a9a6fb3-6e64-4596-b37b-2c2f67dd7724
# Vidal
#
# Victor Deweerdt
# ('NOMBID for', u'Victor Deweerdt')
# Vertikal
# ('NOMBID for', u'Vertikal')
# Veil of Maya
# aartist_mbid 32e740e5-95ea-42e3-b5e2-29f6630488e4
# Veil of Maya
#
# Vanupié Officiel
# ('NOMBID for', u'Vanupi\xe9 Officiel')
# Valgeir Sigurðsson
# aartist_mbid b47171a4-1bfc-4d80-a91e-33c368fa6a5a
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Valgeir Sigurðsson
#
# Vakula
# ('NOMBID for', u'Vakula')
# VOICE OF RUIN
# ('NOMBID for', u'VOICE OF RUIN')
# VINCENT GIUMELLI
# ('NOMBID for', u'VINCENT GIUMELLI')
# V.I.A.
# ('NOMBID for', u'V.I.A.')
# Until Rain
# ('NOMBID for', u'Until Rain')
# Unit
# aartist_mbid 410e6545-3952-4402-9281-b4c1308cc296
# Unit
#
# Uncle Acid and the deadbeats
# ('NOMBID for', u'Uncle Acid and the deadbeats')
# Uli Jon Roth
# aartist_mbid cc533920-6a69-4b14-96ff-27a4cac89365
# Uli Jon Roth
#
# UKANDANZ
# ('NOMBID for', u'UKANDANZ')
# Typoboy
# ('NOMBID for', u'Typoboy')
# Twin Atlantic
# aartist_mbid 98a819b7-2634-4987-815b-bc66182dc97f
# Twin Atlantic
#
# Turnsteak
# ('NOMBID for', u'Turnsteak')
# Tub' à l'image
# ('NOMBID for', u"Tub' \xe0 l'image")
# Troubles Fete
# ('NOMBID for', u'Troubles Fete')
# Tristan
# aartist_mbid 8e3fbfcf-e072-47d0-80cb-a01700ea90c9
# NORELEASEDATE2
# Tristan
#
# Trio Nelson Schmidt
# ('NOMBID for', u'Trio Nelson Schmidt')
# Trilok Gurtu
# aartist_mbid 5af7a83c-88ba-493f-8bec-5c9e3b895e3e
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Trilok Gurtu
#
# TraumeR
# ('NOMBID for', u'TraumeR')
# Toxic Holocaust
# aartist_mbid b1c00b61-2673-458f-bba3-7470712a3b94
# pppppppppppppp
# Toxic Holocaust
#
# Toto
# aartist_mbid aab5c954-cabe-432e-899e-1c4f99757327
# Toto
#
# Tony Match
# ('NOMBID for', u'Tony Match')
# Toneshifterz
# ('NOMBID for', u'Toneshifterz')
# Tom Joyce
# ('NOMBID for', u'Tom Joyce')
# Tom Browne
# aartist_mbid 2b2596a1-089b-47ee-9aad-0587da08383a
# pppppppppppppp
# Tom Browne
#
# Tokyo Taboo
# ('NOMBID for', u'Tokyo Taboo')
# Tocotronic
# aartist_mbid 7717539b-33aa-45d5-b88d-9e627172db19
# pppppppppppppp
# Tocotronic
#
# 沖野修也
# aartist_mbid e903ba3c-8d06-4256-9c80-f264ae3431a7
# 沖野修也
#
# Виктория Муллова
# aartist_mbid 02bd2dff-f337-4788-9e75-0eb6beb932ac
# Виктория Муллова
#
# ÿordan
# ('NOMBID for', u'\xffordan')
# youn caro
# ('NOMBID for', u'youn caro')
# waze
# ('NOMBID for', u'waze')
# top 50
# ('NOMBID for', u'top 50')
# the Krooks
# ('NOMBID for', u'the Krooks')
# aoki
# ('NOMBID for', u'aoki')
# Tiëstolive
# ('NOMBID for', u'Ti\xebstolive')
# עידן רייכל
# aartist_mbid 48b69932-5352-4b2e-9847-b15ec8736d1e
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# עידן רייכל
#
# Ólafur Arnalds
# ('NOMBID for', u'\xd3lafur Arnalds')
# the magician
# ('NOMBID for', u'the magician')
# svadba
# ('NOMBID for', u'svadba')
# secret room
# ('NOMBID for', u'secret room')
# pHEN
# ('NOMBID for', u'pHEN')
# of Montreal
# aartist_mbid 8475297d-fb78-4630-8d74-9b87b6bb7cc8
# of Montreal
#
# nFiX & Candice
# ('NOMBID for', u'nFiX & Candice')
# module virus
# ('NOMBID for', u'module virus')
# mathieu salama
# ('NOMBID for', u'mathieu salama')
# manu lanvin
# ('NOMBID for', u'manu lanvin')
# la smala
# ('NOMBID for', u'la smala')
# jun
# aartist_mbid 767c86d6-cdcc-4d08-a104-318a06e05e03
# jun
#
# iAROSS
# ('NOMBID for', u'iAROSS')
# gainsbourg
# ('NOMBID for', u'gainsbourg')
# electrophazz
# ('NOMBID for', u'electrophazz')
# dj mat denum
# ('NOMBID for', u'dj mat denum')
# davoodi
# ('NOMBID for', u'davoodi')
# amine edge
# ('NOMBID for', u'amine edge')
# al mckay
# ('NOMBID for', u'al mckay')
# ___________
# ('NOMBID for', u'___________')
# Zombie-Zombie
# aartist_mbid 6d78ed61-5275-4af4-bcec-b609d2ade96c
# pppppppppppppp
# pppppppppppppp
# Zombie-Zombie
#
# Zenzile
# aartist_mbid 813d273f-a945-4c09-8318-49dba4fd13a4
# pppppppppppppp
# Zenzile
#
# Zebda
# aartist_mbid 8eebc0a9-653e-4b12-bfb6-471a95f8cf73
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Zebda
#
# Zaltan
# ('NOMBID for', u'Zaltan')
# Zach & Cedre
# ('NOMBID for', u'Zach & Cedre')
# ZIMA
# ('NOMBID for', u'ZIMA')
# Yves Torchinsky
# ('NOMBID for', u'Yves Torchinsky')
# Yul
# aartist_mbid a4685130-60aa-443c-ab35-f9f6ffa08a2a
# Yul
#
# Youssou N'Dour
# aartist_mbid af081ea2-7a2c-4fbd-8200-92d62056b5f5
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Youssou N'Dour
#
# Youngstown country band
# ('NOMBID for', u'Youngstown country band')
# Young Blood Brass Band
# ('NOMBID for', u'Young Blood Brass Band')
# Yoni Zelnik
# ('NOMBID for', u'Yoni Zelnik')
# Yngve and his Boogie Legs
# ('NOMBID for', u'Yngve and his Boogie Legs')
# Yelle
# aartist_mbid f43d43c8-eedf-4628-99b0-04120e7124c8
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Yelle
#
# Yasmine KYD
# ('NOMBID for', u'Yasmine KYD')
# Yarol Poupaud
# ('NOMBID for', u'Yarol Poupaud')
# Yannick Noah
# aartist_mbid fe87035a-eef5-4cde-9961-747f0492c5d7
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Yannick Noah
#
# YOUSK
# ('NOMBID for', u'YOUSK')
# YAN WAGNER
# ('NOMBID for', u'YAN WAGNER')
# XOMA SILENT LISTENER
# ('NOMBID for', u'XOMA SILENT LISTENER')
# Wynton Marsalis
# aartist_mbid 0d74dcc7-5684-4695-830f-a9846aad8ba9
# pppppppppppppp
# Wynton Marsalis
#
# Working Class Zero
# ('NOMBID for', u'Working Class Zero')
# Wooden Beaver
# ('NOMBID for', u'Wooden Beaver')
# Wolf Alice
# ('NOMBID for', u'Wolf Alice')
# Winston McAnuff
# aartist_mbid 46685feb-c574-4777-b5ff-3a60c232b955
# pppppppppppppp
# pppppppppppppp
# pppppppppppppp
# Winston McAnuff
#
# Willy Monfret
# ('NOMBID for', u'Willy Monfret')
# William Brunard
# ('NOMBID for', u'William Brunard')
# Whyskins
# ('NOMBID for', u'Whyskins')
# White Hills
# aartist_mbid 524718e3-ff02-489a-a131-753dc2f9cb9d
# pppppppppppppp
# White Hills
#
# What So Not
# ('NOMBID for', u'What So Not')
# Weiland
# ('NOMBID for', u'Weiland')
# We are LUX
# ('NOMBID for', u'We are LUX')
# We Insist !
# ('NOMBID for', u'We Insist !')
# Waysons
# ('NOMBID for', u'Waysons')
# Waxhead
# ('NOMBID for', u'Waxhead')
# Water Babies
# ('NOMBID for', u'Water Babies')
# Wally Stryk
# ('NOMBID for', u'Wally Stryk')
# Wailing Trees
# ('NOMBID for', u'Wailing Trees')
# WDB Management
# ('NOMBID for', u'WDB Management')
# W.A.S.A.B.I.
# ('NOMBID for', u'W.A.S.A.B.I.')
# Voodoo Vegas
# aartist_mbid 075bfeef-296d-4c01-b115-523545a08e11
# Voodoo Vegas
#
# Volutes
# ('NOMBID for', u'Volutes')
# Visualize
# ('NOMBID for', u'Visualize')
# Virage
# ('NOMBID for', u'Virage')
# Vincent Segal
# ('NOMBID for', u'Vincent Segal')
# Vince
# aartist_mbid e28d09d2-3aab-40fa-b604-7b9c1fa2489f
# Vince
#
# Victor
# aartist_mbid 12368b95-69ae-42bd-bf7b-85b54bd28938
# Victor
#
# Vetiver
# aartist_mbid 328068c9-ee60-408e-8c24-b1dc1ae08b94
# pppppppppppppp
# pppppppppppppp
# Vetiver
#
# Vertigo (Official)
# ('NOMBID for', u'Vertigo (Official)')
# Venom
# aartist_mbid 7ac77718-541a-4ca2-98de-004bff2420e8
# Venom
#
# Vaudou Game
# ('NOMBID for', u'Vaudou Game')
# Vanderstar
# ('NOMBID for', u'Vanderstar')
# Valerie Ghent
# ('NOMBID for', u'Valerie Ghent')
# VIVa Music
# ('NOMBID for', u'VIVa Music')
# VINCENT BLACK
# ('NOMBID for', u'VINCENT BLACK')
# Urban Trad
# aartist_mbid 175c2096-38c4-45ee-b034-5a2f51095a26
# pppppppppppppp
# Urban Trad
#
# Uniform Motion
# ('NOMBID for', u'Uniform Motion')
# Uncle Acid & The Deadbeats
# ('NOMBID for', u'Uncle Acid & The Deadbeats')
# Ugonna Okegwo
# ('NOMBID for', u'Ugonna Okegwo')
# UB40
# aartist_mbid 7113aab7-628f-4050-ae49-dbecac110ca8
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-8cce69c954ce> in <module>()
#      72                                             labels_aliases[label["label"]["id"]] = musicbrainzngs.get_label_by_id(label["label"]["id"], includes=["aliases", "annotation", "area-rels", "label-rels", "place-rels"])
#      73                                         #print "labels_aliases",labels_aliases
# ---> 74                                     labels_dict[label["label"]["id"]][str(key)]={}
#      75                                     #print key
#      76                                     labels_dict[label["label"]["id"]][str(key)]["album_id"]=release["id"]
#
# KeyError: 'label'
