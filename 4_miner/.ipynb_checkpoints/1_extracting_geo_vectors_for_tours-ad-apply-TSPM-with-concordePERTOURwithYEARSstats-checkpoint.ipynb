# %%
# %matplotlib inline

##THIS IS FOR ACCESSING THE CONCORDE TSP SOLVER
from subprocess import Popen

import os
class tsp:
    def __init__(self, points=None):
        self.points = points if points else []
    def solve(self, filename='_tmp_'):
        with open('%s.dat' % filename, 'w') as fp:
            fp.write('TYPE : TSP\nDIMENSION : %d\n' % len(self.points))
            fp.write('EDGE_WEIGHT_TYPE : GEO\nNODE_COORD_SECTION\n')
            for i, (x, y) in enumerate(self.points):
                fp.write('%d %g %g\n' % (i, x, y))
            fp.write('EOF\n')
        prc = Popen('./concorde   -m %s.dat' % filename, shell=True)
        prc.wait()
        with open('%s.sol' % filename) as fp:
            ll = (''.join(fp)).split()
        self.result = [int(s) for s in ll[1:]]
        for s in ('%s.dat', '%s.sol'): os.remove(s % filename)

# %%
##THIS I FOR ACCESSING THE CONCORDE TSP SOLVER BZCKUP,SWITCHING TO GEO
#from subprocess import Popen
#import os
#class tsp:
#    def __init__(self, points=None):
#        self.points = points if points else []
#    def solve(self, filename='_tmp_'):
#        with open('%s.dat' % filename, 'w') as fp:
#            fp.write('TYPE : TSP\nDIMENSION : %d\n' % len(self.points))
#            fp.write('EDGE_WEIGHT_TYPE : EUC_2D\nNODE_COORD_SECTION\n')
#            for i, (x, y) in enumerate(self.points):
#                fp.write('%d %g %g\n' % (i, x, y))
#            fp.write('EOF\n')
#        prc = Popen('./concorde -m  %s.dat' % filename, shell=True)
#        prc.wait()
#        with open('%s.sol' % filename) as fp:
#            ll = (''.join(fp)).split()
#        self.result = [int(s) for s in ll[1:]]
#        for s in ('%s.dat', '%s.sol'): os.remove(s % filename)

# %%
import geopy
import pickle
import json
import pymongo
from geopy.distance import vincenty
#import musicbrainzngs
import arrow
from datetime import datetime
from pymongo import MongoClient
from collections import defaultdict
from dateutil import parser
from slugify import slugify
import math
from numbers import Number

# setup mongo
client = MongoClient()
db = client["bandstour"]
bandsintown =  db["bandsintown"]

# date parsing
DATETIME_FORMAT = '%Y-%m-%dT%H:%M:%S'
DATETIME_FORMAT_FOR_MSBNZ ='%Y-%m-%d'

#retrieve trip coords for each artist
dict_coords={}

import numpy as np
from matplotlib import pyplot as plt

# %%
#INITIALIZE

final_embeddings=[]
totalDists=0
totalOptDists=0
totalOptDistsMin=0
#for artist in db.minedArtists.find({ 'name' : 'David Guetta' }) :
#for artist in db.minedArtists.find({ 'name' : 'Vokab Kompany' }) :
#for artist in db.minedArtists.find({ 'name' : 'Ural Kosaken Chor' }) :
#for artist in db.minedArtists.find({ 'name' : 'Leo Kottke' }) :
#for artist in db.minedArtists.find({ 'name' : 'Björk' }) :
#for artist in db.minedArtists.find({ 'name' : 'Deerhoof' }) :
#for artist in db.minedArtists.find({ 'name' : 'Legends' }) :
#for artist in db.minedArtists.find({ 'name' : 'Laidback Luke' }) :
#for artist in db.minedArtists.find({ 'name' : 'Andy Moor' }) :
#for artist in db.minedArtists.find({ 'name' : 'Mia' }) :
#for artist in db.minedArtists.find({ 'name' : 'Dead Kennedys' }) :
#for artist in db.minedArtists.find({ 'name' : 'House of Pain' }) :
for artist in db.minedArtists.find(no_cursor_timeout=True) :
#LOOP THROUGH ALL ARTISTS IN BASE AND CALCULATE OPTIMIZED PARAMETER
 if os.path.exists("./tour_miner/"+slugify(artist["name"]+str(artist["mbid"]))+".obj")==True:
        print "SKIPPED",artist["name"]
        #print slugify(artist["name"])
        with open("./tour_miner/"+slugify(artist["name"]+str(artist["mbid"]))+".obj", 'rb') as handle:
          temp= pickle.load( handle)
        #print temp
        tmppp =0
        
        totalArtistTourDist=0
        totalArtistOptTourDist=0
        totalArtistTourDist=temp["totalArtistTourDist"]
        totalArtistOptTourDist=temp["totalArtistOptTourDist"]
        
        totalDists+=totalArtistTourDist
        totalOptDists+=totalArtistOptTourDist
        if float(totalArtistTourDist) <= float(totalArtistOptTourDist)      :  
            tmppp=float(totalArtistTourDist)
        else:
            tmppp=float(totalArtistOptTourDist)
        totalOptDistsMin+=tmppp
        #print totalArtistTourDist," / ",totalArtistOptTourDist
        #print totalDists," / ",totalOptDists," / ",totalOptDistsMin," / ",tmppp
        
        #pass
 else:
    

    results={}
    tourindice=0
    results["name"]=artist["name"]
    #print artist["name"]
    totalArtistTourDist=0
    totalArtistOptTourDist=0
    for tour in artist["tours"]:
        #print tour["gigs"][0]["datetime"].year
        #print tour["gigs"][-1]["datetime"].year
        #print int(math.ceil(len(tour["gigs"])/2))
        tourCoords= []
        tourdist=0
        tourdistOpt=0
        tourdistOpt2=0
        tourdistOpt3=0
        tourLength=0
        tourYear=0
        tourYearStart=0
        tourYearEnd=0
        tourYearMid=0
        t=0
        #print len(tour["tourCoords"])
        if len(tour["tourCoords"])>2:
            tourLength=int(math.ceil(len(tour["gigs"])))
            tourYearStart=tour["gigs"][0]["datetime"].year
            tourYearEnd=tour["gigs"][-1]["datetime"].year
            if tourYearStart == tourYearEnd :
                tourYear= tourYearStart
            else:
                tourYearMid= tourYearEnd=tour["gigs"][int(math.ceil(len(tour["gigs"])/2))]["datetime"].year
                if tourYearStart == tourYearMid :
                    tourYear= tourYearStart
                else:
                    tourYear= tourYearEnd
            
            tourindice+=1
            tourCoords=[tuple(tourCoord) for tourCoord in tour["tourCoords"]]
            #print tourCoords
            ###RERUN OPT,PICKING BETTER SOLUTION
            t=tsp(tourCoords)
            t.solve()
            #print "here"

            #print t.result
            #print t.points
            #print "long",len (t.result)
            i = 0
            while i < len (t.result)-1:
                res=t.result[i]
                res2=t.result[i+1]
                #print vincenty(t.points[res],t.points[res2]).kilometers
                tourdistOpt= tourdistOpt + vincenty(t.points[res],t.points[res2]).kilometers
                
                
                i+=1
            
            j = 0
            while j < len (tourCoords)-1:
                
                #print vincenty(t.points[res],t.points[res2]).kilometers
                tourdist= tourdist + vincenty(tourCoords[j],tourCoords[j+1]).kilometers
                j+=1
            
            #print "DEFAULT TOUR DIST",tourdist
            #print "TOURDISTOPTIMIZED",tourdistOpt
            totalArtistTourDist+=tourdist
            totalArtistOptTourDist+=tourdistOpt
            results[tourindice]={'tourdist':tourdist,'tourdistOpt':tourdistOpt,'tourLength' : tourLength , 'tourYear': tourYear}
    #print results
    tourInd=0
    resultsYears={}
    for tourInd in results:
        #print tourInd
        if tourInd != 'name':
          """"reduce dataset to its relevant years !!!! 
        1990 / Nb de groupes comptabilisés cette année / 1
1991 / Nb de groupes comptabilisés cette année / 1
1992 / Nb de groupes comptabilisés cette année / 3
1993 / Nb de groupes comptabilisés cette année / 1
1994 / Nb de groupes comptabilisés cette année / 2
1995 / Nb de groupes comptabilisés cette année / 2
1996 / Nb de groupes comptabilisés cette année / 2
1997 / Nb de groupes comptabilisés cette année / 8
1998 / Nb de groupes comptabilisés cette année / 2
1999 / Nb de groupes comptabilisés cette année / 15
2000 / Nb de groupes comptabilisés cette année / 4
2001 / Nb de groupes comptabilisés cette année / 1
2002 / Nb de groupes comptabilisés cette année / 3
2003 / Nb de groupes comptabilisés cette année / 7
2004 / Nb de groupes comptabilisés cette année / 10
2005 / Nb de groupes comptabilisés cette année / 17
2006 / Nb de groupes comptabilisés cette année / 22
2007 / Nb de groupes comptabilisés cette année / 2719
2008 / Nb de groupes comptabilisés cette année / 4101
2009 / Nb de groupes comptabilisés cette année / 5447
2010 / Nb de groupes comptabilisés cette année / 7083
2011 / Nb de groupes comptabilisés cette année / 6965
2012 / Nb de groupes comptabilisés cette année / 11048
2013 / Nb de groupes comptabilisés cette année / 13451
2014 / Nb de groupes comptabilisés cette année / 16331
2015 / Nb de groupes comptabilisés cette année / 20790
2016 / Nb de groupes comptabilisés cette année / 25322
2017 / Nb de groupes comptabilisés cette année / 25302
2018 / Nb de groupes comptabilisés cette année / 475
2019 / Nb de groupes comptabilisés cette année / 1)
          if results[tourInd]['tourYear'] >= 2007 and results[tourInd]['tourYear'] <= 2017:"""
            #print results[tourInd]['tourYear']
        if results[tourInd]['tourYear'] not in resultsYears:
              
                resultsYears[results[tourInd]['tourYear']]={'toursCount':0,'toursDist':0,'toursDistOpt':0,'toursLength':0}
            
        resultsYears[results[tourInd]['tourYear']]['toursCount']+=1
        resultsYears[results[tourInd]['tourYear']]['toursDist']=resultsYears[results[tourInd]['tourYear']]['toursDist']+results[tourInd]['tourdist']
        resultsYears[results[tourInd]['tourYear']]['toursDistOpt']=resultsYears[results[tourInd]['tourYear']]['toursDistOpt']+results[tourInd]['tourdistOpt']
        resultsYears[results[tourInd]['tourYear']]['toursLength']=resultsYears[results[tourInd]['tourYear']]['toursLength']+results[tourInd]['tourLength']
            
    #print resultsYears
    statNbYear=len(resultsYears)
    statMeanYearDist=0
    statMeanDistOpt=0
    statMeanYeartoursLength=0
    statMeanYeartoursCount=0
    #Calculating means
    for Year in resultsYears:
        statMeanYearDist+=resultsYears[Year]['toursDist']
        statMeanDistOpt+=resultsYears[Year]['toursDistOpt']
        statMeanYeartoursLength+=resultsYears[Year]['toursLength']
        statMeanYeartoursCount+=resultsYears[Year]['toursCount']
    #print statMeanYearDist
    #print statNbYear
    if statMeanYearDist > 0:
        statMeanYearDist=statMeanYearDist/statNbYear
        statMeanDistOpt=statMeanDistOpt/statNbYear
        statMeanYeartoursLength=statMeanYeartoursLength/statNbYear
        statMeanYeartoursCount=statMeanYeartoursCount/statNbYear
        resultsYears['statMeanYearDist']=statMeanYearDist
        resultsYears['statMeanYearDistOpt']=statMeanDistOpt
        resultsYears['statMeanYeartoursLength']=statMeanYeartoursLength
        resultsYears['statMeanYeartoursCount']=statMeanYeartoursCount
        resultsYears['statNbYear']=statNbYear
        
        for Year in resultsYears:
            if isinstance(Year, Number):
                #print Year
                resultsYears[Year]['stattoursDist']=float(resultsYears[Year]['toursDist']-resultsYears['statMeanYearDist'])/resultsYears['statMeanYearDist']
                resultsYears[Year]['stattoursDistOpt']=float(resultsYears[Year]['toursDistOpt']-resultsYears['statMeanYearDistOpt'])/resultsYears['statMeanYearDistOpt']
                resultsYears[Year]['stattoursLength']=float(resultsYears[Year]['toursLength']-resultsYears['statMeanYeartoursLength'])/resultsYears['statMeanYeartoursLength']
                resultsYears[Year]['stattoursCount']=float(resultsYears[Year]['toursCount']-resultsYears['statMeanYeartoursCount'])/resultsYears['statMeanYeartoursCount']
    
        
        
    #print "TOTAL DEFAULT ARTIST TOURS DISTS",totalArtistTourDist
    #print "TOTAL OPTIMIZED ARTIST TOURS DISTS",totalArtistOptTourDist 
    if totalArtistTourDist > 0 :
        OptArtistPercent=0
        OptArtistPercent=100 *(totalArtistTourDist-totalArtistOptTourDist) / totalArtistTourDist
        results["OptArtistPercent"]=OptArtistPercent
        #print "OPTIMIZED BY ", OptArtistPercent," %"
    #print"_______________________________"
    totalDists+=totalArtistTourDist
    totalOptDists+=totalArtistOptTourDist
    tmppp=0
    if float(totalArtistTourDist) <= float(totalArtistOptTourDist)      :  
            tmppp=float(totalArtistTourDist)
    else:
            tmppp=float(totalArtistOptTourDist)
    totalOptDistsMin+=tmppp
    
    results["resultsYears"]=resultsYears
    results["totalArtistTourDist"]=totalArtistTourDist
    results["totalArtistOptTourDist"]=totalArtistOptTourDist
    
    with open("./tour_miner/"+slugify(artist["name"]+str(artist["mbid"]))+".obj", 'wb') as handle:
                            pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
    #print results['resultsYears']
    #print totalDists," / ",totalArtistTourDist," / ",totalArtistOptTourDist," / ",totalOptDistsMin," / ",tmppp
print "***************************"
print "TOTAL ARTISTS TOURS DISTS",totalDists
print "TOTAL AUTO OPTIMIZED ARTISTS TOURS DISTS",totalOptDists 
print "TOTAL MANUALLY OPTIMIZED ARTISTS TOURS DISTS",totalOptDistsMin 
print "AUTO-OPTIMIZED BY ", 100 *(totalDists-totalOptDists) / totalDists," %"
print "MANUALLY OPTIMIZED BY ", 100 *(totalDists-totalOptDistsMin) / totalDists," %"
print "***************************"
with open("./RESULTSGLOBAL.obj", 'wb') as handle:
                            pickle.dump({"totalDists":totalDists,"totalOptDists":totalOptDists,"totalOptDistsMin":totalOptDistsMin,"autoOpt":(totalDists-totalOptDists) / totalDists,"manOpt":(totalDists-totalOptDistsMin) / totalDists}, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#CALCULATE GLOBAL  RAW YEAR STATS
import os

#totalDistsPERYEAR={}
#totalOptDistsPERYEAR={}
#totalOptDistsMinPERYEAR={}
resultsGlobalYears={}
resultsGlobalYearsAddedResultsCount={}
for filename in os.listdir('./tour_miner'):
    with open("./tour_miner/"+filename, 'rb') as handle:
#with open("./tour_miner/young-mc693097c4-17ec-4bb8-9b7c-74a5a2a85723"+".obj", 'rb') as handle:    
        temp= pickle.load( handle)
        resultsYears=temp["resultsYears"]
        #print "------------"
        #print resultsYears  
        #print "------------"
        for Year in resultsYears:
            #print Year
            #print resultsYears[Year]
            
            #print "****"
         if isinstance(Year, Number):
            if Year not in resultsGlobalYears:
                resultsGlobalYears[Year]={"stattoursGlobalLength": 0,"toursGlobalLength": 0,"toursGlobalDistOpt": 0,"stattoursGlobalDist": 0,"toursGlobalDist": 0,"stattoursGlobalDistOpt": 0,"toursGlobalCount": 0,"stattoursGlobalCount": 0,"stattoursGlobalLengthMEAN": 0,"toursGlobalLengthMEAN": 0,"toursGlobalDistOptMEAN": 0,"stattoursGlobalDistMEAN": 0,"toursGlobalDistMEAN": 0,"stattoursGlobalDistOptMEAN": 0,"toursGlobalCountMEAN": 0,"stattoursGlobalCountMEAN": 0,"stattoursGlobalLengthMEAN": 0,"toursGlobalLengthMEAN": 0,"toursGlobalDistOptMEAN": 0,"stattoursGlobalDistMEAN": 0,"toursGlobalDistMEAN": 0,"stattoursGlobalDistOptMEAN": 0,"toursGlobalCountMEAN": 0,"stattoursGlobalCountMEAN": 0}
                resultsGlobalYearsAddedResultsCount[Year]=0
            
                #print "statLE",resultsYears[Year]["stattoursLength"]
            try:
                    resultsGlobalYearsAddedResultsCount[Year]+=1
                    resultsGlobalYears[Year]["stattoursGlobalLength"]=float(resultsYears[Year]["stattoursLength"])+float(resultsGlobalYears[Year]["stattoursGlobalLength"])
                    resultsGlobalYears[Year]["toursGlobalLength"]=float(resultsYears[Year]["toursLength"])+float(resultsGlobalYears[Year]["toursGlobalLength"])
                    resultsGlobalYears[Year]["toursGlobalDistOpt"]=float(resultsYears[Year]["toursDistOpt"])+float(resultsGlobalYears[Year]["toursGlobalDistOpt"])
                    resultsGlobalYears[Year]["stattoursGlobalDist"]=float(resultsYears[Year]["stattoursDist"])+float(resultsGlobalYears[Year]["stattoursGlobalDist"])
                    resultsGlobalYears[Year]["toursGlobalDist"]=float(resultsYears[Year]["toursDist"])+float(resultsGlobalYears[Year]["toursGlobalDist"])
                    resultsGlobalYears[Year]["stattoursGlobalDistOpt"]=float(resultsYears[Year]["stattoursDistOpt"])+float(resultsGlobalYears[Year]["stattoursGlobalDistOpt"])
                    resultsGlobalYears[Year]["toursGlobalCount"]=float(resultsYears[Year]["toursCount"])+float(resultsGlobalYears[Year]["toursGlobalCount"])
                    resultsGlobalYears[Year]["stattoursGlobalCount"]=float(resultsYears[Year]["stattoursCount"])+float(resultsGlobalYears[Year]["stattoursGlobalCount"])
            except KeyError :
                    print Year
                    print resultsYears[Year]
                    print KeyError
                    #NOT ENOUGH DATAS FOR YEAR
                    
                    #pass
                    break
        

            
        
    
#WE REALISE THAT TO GET ACCURATE STATS, WE SHOULD FILTER BY YEARS WITH ENOUGH DATAS, AND BANDS WITH ENOUGH SHOWS
# Out:
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 59, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 22, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 14, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 68, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2010
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2008
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2018
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 488, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 31, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 47, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2008
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 15, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2010
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2010
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 72, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 3, 'toursLength': 17, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 36, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 34, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 34, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2008
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 180, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2011
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 36, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 3, 'toursLength': 34, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 17, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 17, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 17, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2008
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 68, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 5, 'toursLength': 18, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2018
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 34, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2007
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2010
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 120, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 36, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 26, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 33, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2008
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 278, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 31, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2008
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 38, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 93, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 134, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 33, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 70, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 70, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 30, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 461, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 180, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 89, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 20, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 93, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 59, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 20, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 34, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 285, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 31, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 11, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 12, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 14, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 15, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 26, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 11, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 36, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 47, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 12, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 11, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 31, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 38, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 21, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 12, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 12, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 31, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 45, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 32, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 17, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2008
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2018
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 598, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 153, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2011
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 14, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 15, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 93, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 4, 'toursLength': 17, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 14, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 11, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2008
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 30, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 11, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 14, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 585, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 36, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 12, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2011
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2018
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2011
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 13, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 70, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 26, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 39, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2007
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 18, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 26, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 14, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2008
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 11, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 15, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 18, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 33, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 25, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 925, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 33, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 181, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 14, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 4, 'toursLength': 21, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2008
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 17, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 20, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 33, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 33, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 3, 'toursLength': 14, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 32, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2008
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 14, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 17, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2010
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 11, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 32, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 97, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2010
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 36, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 31, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 20, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 12, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 3, 'toursLength': 73, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2018
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 12, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 36, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2010
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 34, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 166, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 34, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 120, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 12, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 12, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 73, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 3, 'toursLength': 77, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 32, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 66, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 30, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 21, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2010
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 16, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 225, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 75, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 174, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 39, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 201, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 32, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 3, 'toursLength': 17, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2011
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# ...
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 12, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 13, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 35, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 26, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 15, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 38, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 18, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2018
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 42, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 73, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 13, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 11, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 634, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 30, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 27, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2011
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 15, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 28, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 3, 'toursLength': 38, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 6, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 18, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 14, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 152, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2018
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 12, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 339, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 4, 'toursLength': 17, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 36, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 3, 'toursLength': 38, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 30, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 21, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 61, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 21, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 11, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 11, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 34, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 34, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 29, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2018
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 240, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 165, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 15, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 57, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 19, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 76, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 34, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 5, 'toursLength': 46, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2010
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2013
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 10, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2009
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 60, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2011
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2010
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 8, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 21, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 12, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 31, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 35, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 4, 'toursLength': 22, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 9, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 33, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 13, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 24, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2015
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2012
# {'toursDist': 0.0, 'toursCount': 2, 'toursLength': 7, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 34, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 61, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2010
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2008
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 5, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2014
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 3, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2016
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 4, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>
# 2017
# {'toursDist': 0.0, 'toursCount': 1, 'toursLength': 18, 'toursDistOpt': 0.0}
# <type 'exceptions.KeyError'>

# %%
#print resultsGlobalYears
listP=["","MOY","MAX","MIN","VAR","ECTP"]
for YearG in resultsGlobalYears:
 if YearG >=2007 and YearG <= 2017:
    #CALCULATE MEAN VALUES
    resultsGlobalYears[YearG]["stattoursGlobalLengthMEAN"]=float(resultsGlobalYears[YearG]["stattoursGlobalLength"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["toursGlobalLengthMEAN"]=float(resultsGlobalYears[YearG]["toursGlobalLength"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["toursGlobalDistOptMEAN"]=float(resultsGlobalYears[YearG]["toursGlobalDistOpt"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["stattoursGlobalDistMEAN"]=float(resultsGlobalYears[YearG]["stattoursGlobalDist"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["toursGlobalDistMEAN"]=float(resultsGlobalYears[YearG]["toursGlobalDist"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["stattoursGlobalDistOptMEAN"]=float(resultsGlobalYears[YearG]["stattoursGlobalDistOpt"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["toursGlobalCountMEAN"]=float(resultsGlobalYears[YearG]["toursGlobalCount"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    resultsGlobalYears[YearG]["stattoursGlobalCountMEAN"]=float(resultsGlobalYears[YearG]["stattoursGlobalCount"])/float(resultsGlobalYearsAddedResultsCount[YearG])
    
    #CALCULATE TOT VALUES
    resultsGlobalYears[YearG]["stattoursGlobalLength"]=float(resultsGlobalYears[YearG]["stattoursGlobalLength"])
    resultsGlobalYears[YearG]["toursGlobalLength"]=float(resultsGlobalYears[YearG]["toursGlobalLength"])
    resultsGlobalYears[YearG]["toursGlobalDistOpt"]=float(resultsGlobalYears[YearG]["toursGlobalDistOpt"])
    resultsGlobalYears[YearG]["stattoursGlobalDist"]=float(resultsGlobalYears[YearG]["stattoursGlobalDist"])
    resultsGlobalYears[YearG]["toursGlobalDist"]=float(resultsGlobalYears[YearG]["toursGlobalDist"])
    resultsGlobalYears[YearG]["stattoursGlobalDistOpt"]=float(resultsGlobalYears[YearG]["stattoursGlobalDistOpt"])
    resultsGlobalYears[YearG]["toursGlobalCount"]=float(resultsGlobalYears[YearG]["toursGlobalCount"])
    resultsGlobalYears[YearG]["stattoursGlobalCount"]=float(resultsGlobalYears[YearG]["stattoursGlobalCount"])
    
    

    
    
    print "*----------"
    print YearG,"/ Nb de groupes comptabilisés cette année /",resultsGlobalYearsAddedResultsCount[YearG]
    print "-----------"
    
    
    print "=>stat longueur tournées moy",100*resultsGlobalYears[YearG]["stattoursGlobalLengthMEAN"], "%" 
    print "=>longueur tournées ",resultsGlobalYears[YearG]["toursGlobalLength"]," dates" 
    print "=>longueur tournées moy",resultsGlobalYears[YearG]["toursGlobalLengthMEAN"]," dates" 
    print "=>distances tournées ",resultsGlobalYears[YearG]["toursGlobalDist"]," km" 
    print "=>distances tournées moy",resultsGlobalYears[YearG]["toursGlobalDistMEAN"]," km" 
    print "=>distances tournées optimisés  ",resultsGlobalYears[YearG]["toursGlobalDistOpt"]," km" 
    print "=>distances tournées optimisés moy ",resultsGlobalYears[YearG]["toursGlobalDistOptMEAN"]," km" 
    
    print "=>Stat distances tournées moy",100*resultsGlobalYears[YearG]["stattoursGlobalDistMEAN"]," %" 
    
    print "=>Stat distances tournées optimisés moy",100*resultsGlobalYears[YearG]["stattoursGlobalDistOptMEAN"]," %" 
    print "=>nombre de tournées  ",resultsGlobalYears[YearG]["toursGlobalCount"] 
    print "=>nombre de tournées moy ",resultsGlobalYears[YearG]["toursGlobalCountMEAN"] 
    
    print "=>Stat nombre de tournées moy",100*resultsGlobalYears[YearG]["stattoursGlobalCountMEAN"]," %" 
    
    
    
    
    print "----------*"
# Out:
# *----------
# 2007 / Nb de groupes comptabilisés cette année / 2719
# -----------
# =>stat longueur tournées moy -18.4777530356 %
# =>longueur tournées  60339.0  dates
# =>longueur tournées moy 22.1916145642  dates
# =>distances tournées  40780697.6766  km
# =>distances tournées moy 14998.4176817  km
# =>distances tournées optimisés   35285760.184  km
# =>distances tournées optimisés moy  12977.4770813  km
# =>Stat distances tournées moy -25.978268979  %
# =>Stat distances tournées optimisés moy -24.2540334653  %
# =>nombre de tournées   6647.0
# =>nombre de tournées moy  2.44464876793
# =>Stat nombre de tournées moy 3.95020052891  %
# ----------*
# *----------
# 2008 / Nb de groupes comptabilisés cette année / 4101
# -----------
# =>stat longueur tournées moy 3.61238475356 %
# =>longueur tournées  113378.0  dates
# =>longueur tournées moy 27.6464277006  dates
# =>distances tournées  87710447.0051  km
# =>distances tournées moy 21387.5754706  km
# =>distances tournées optimisés   73997128.0255  km
# =>distances tournées optimisés moy  18043.6791089  km
# =>Stat distances tournées moy 4.3898787751  %
# =>Stat distances tournées optimisés moy 5.65821597229  %
# =>nombre de tournées   11948.0
# =>nombre de tournées moy  2.91343574738
# =>Stat nombre de tournées moy 26.0990447549  %
# ----------*
# *----------
# 2009 / Nb de groupes comptabilisés cette année / 5447
# -----------
# =>stat longueur tournées moy 12.3182833807 %
# =>longueur tournées  161781.0  dates
# =>longueur tournées moy 29.7009362952  dates
# =>distances tournées  135558278.61  km
# =>distances tournées moy 24886.7777878  km
# =>distances tournées optimisés   96940406.8132  km
# =>distances tournées optimisés moy  17797.0271366  km
# =>Stat distances tournées moy 12.9805326968  %
# =>Stat distances tournées optimisés moy 6.42896383279  %
# =>nombre de tournées   13136.0
# =>nombre de tournées moy  2.41160271709
# =>Stat nombre de tournées moy 17.3746652446  %
# ----------*
# *----------
# 2010 / Nb de groupes comptabilisés cette année / 7083
# -----------
# =>stat longueur tournées moy 14.7468988837 %
# =>longueur tournées  203291.0  dates
# =>longueur tournées moy 28.7012565297  dates
# =>distances tournées  156446913.846  km
# =>distances tournées moy 22087.6625506  km
# =>distances tournées optimisés   113068149.07  km
# =>distances tournées optimisés moy  15963.3134364  km
# =>Stat distances tournées moy 11.3312100941  %
# =>Stat distances tournées optimisés moy 6.0332968303  %
# =>nombre de tournées   16658.0
# =>nombre de tournées moy  2.35182832133
# =>Stat nombre de tournées moy 20.9502576032  %
# ----------*
# *----------
# 2011 / Nb de groupes comptabilisés cette année / 6965
# -----------
# =>stat longueur tournées moy -6.98076594967 %
# =>longueur tournées  164769.0  dates
# =>longueur tournées moy 23.6567121321  dates
# =>distances tournées  118464368.279  km
# =>distances tournées moy 17008.5238017  km
# =>distances tournées optimisés   92442182.8758  km
# =>distances tournées optimisés moy  13272.3880654  km
# =>Stat distances tournées moy -13.8296805795  %
# =>Stat distances tournées optimisés moy -14.6048920396  %
# =>nombre de tournées   15301.0
# =>nombre de tournées moy  2.19684134961
# =>Stat nombre de tournées moy 7.71443384724  %
# ----------*
# *----------
# 2012 / Nb de groupes comptabilisés cette année / 11048
# -----------
# =>stat longueur tournées moy -2.95981020878 %
# =>longueur tournées  240709.0  dates
# =>longueur tournées moy 21.7875633599  dates
# =>distances tournées  183202662.681  km
# =>distances tournées moy 16582.4278314  km
# =>distances tournées optimisés   141792116.58  km
# =>distances tournées optimisés moy  12834.1886839  km
# =>Stat distances tournées moy -8.54115507351  %
# =>Stat distances tournées optimisés moy -8.60328711903  %
# =>nombre de tournées   25545.0
# =>nombre de tournées moy  2.31218320058
# =>Stat nombre de tournées moy 15.6602071193  %
# ----------*
# *----------
# 2013 / Nb de groupes comptabilisés cette année / 13451
# -----------
# =>stat longueur tournées moy -0.251283299625 %
# =>longueur tournées  294729.0  dates
# =>longueur tournées moy 21.9113077095  dates
# =>distances tournées  228098509.955  km
# =>distances tournées moy 16957.7362245  km
# =>distances tournées optimisés   177891681.617  km
# =>distances tournées optimisés moy  13225.1640486  km
# =>Stat distances tournées moy -5.08461285676  %
# =>Stat distances tournées optimisés moy -4.51831273963  %
# =>nombre de tournées   33177.0
# =>nombre de tournées moy  2.46650806631
# =>Stat nombre de tournées moy 20.4299320402  %
# ----------*
# *----------
# 2014 / Nb de groupes comptabilisés cette année / 16331
# -----------
# =>stat longueur tournées moy 2.1222117633 %
# =>longueur tournées  359902.0  dates
# =>longueur tournées moy 22.0379646072  dates
# =>distances tournées  255066447.416  km
# =>distances tournées moy 15618.5443277  km
# =>distances tournées optimisés   201910370.204  km
# =>distances tournées optimisés moy  12363.6256325  km
# =>Stat distances tournées moy -3.60140984295  %
# =>Stat distances tournées optimisés moy -2.83591117278  %
# =>nombre de tournées   41129.0
# =>nombre de tournées moy  2.51846182108
# =>Stat nombre de tournées moy 22.7759746122  %
# ----------*
# *----------
# 2015 / Nb de groupes comptabilisés cette année / 20790
# -----------
# =>stat longueur tournées moy 5.83511615084 %
# =>longueur tournées  452948.0  dates
# =>longueur tournées moy 21.7868205868  dates
# =>distances tournées  310006698.759  km
# =>distances tournées moy 14911.3371216  km
# =>distances tournées optimisés   244397012.485  km
# =>distances tournées optimisés moy  11755.508056  km
# =>Stat distances tournées moy 3.05325673377  %
# =>Stat distances tournées optimisés moy 3.89389966518  %
# =>nombre de tournées   52998.0
# =>nombre de tournées moy  2.54920634921
# =>Stat nombre de tournées moy 27.1999041523  %
# ----------*
# *----------
# 2016 / Nb de groupes comptabilisés cette année / 25322
# -----------
# =>stat longueur tournées moy 12.3584675025 %
# =>longueur tournées  563162.0  dates
# =>longueur tournées moy 22.2400284338  dates
# =>distances tournées  353483382.46  km
# =>distances tournées moy 13959.5364687  km
# =>distances tournées optimisés   278403709.523  km
# =>distances tournées optimisés moy  10994.5387222  km
# =>Stat distances tournées moy 11.9075984415  %
# =>Stat distances tournées optimisés moy 12.3934191236  %
# =>nombre de tournées   64317.0
# =>nombre de tournées moy  2.53996524761
# =>Stat nombre de tournées moy 30.7809779773  %
# ----------*
# *----------
# 2017 / Nb de groupes comptabilisés cette année / 25302
# -----------
# =>stat longueur tournées moy -4.60693176175 %
# =>longueur tournées  443755.0  dates
# =>longueur tournées moy 17.5383368904  dates
# =>distances tournées  260209113.761  km
# =>distances tournées moy 10284.1322331  km
# =>distances tournées optimisés   204674748.775  km
# =>distances tournées optimisés moy  8089.27155066  km
# =>Stat distances tournées moy -4.57673586089  %
# =>Stat distances tournées optimisés moy -3.84531157062  %
# =>nombre de tournées   49899.0
# =>nombre de tournées moy  1.97213658999
# =>Stat nombre de tournées moy 9.76553878546  %
# ----------*

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

ax1 = fig.add_subplot(111)

ax1.set_title("Classement groupes par distances parcourues ")    
ax1.set_xlabel('rang')
ax1.set_ylabel('km')
ax1.plot(data['pos'],data['km'],'x' ,color='r', label="data['nom']")
ax1.set_autoscale_on
leg = ax1.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-425c64d9e216> in <module>()
#       8 ax1.set_xlabel('rang')
#       9 ax1.set_ylabel('km')
# ---> 10 ax1.plot(data['pos'],data['km'],'x' ,color='r', label="data['nom']")
#      11 ax1.set_autoscale_on
#      12 leg = ax1.legend()
#
# NameError: name 'data' is not defined

# %%
with open("./tour_miner/"+"young-mc693097c4-17ec-4bb8-9b7c-74a5a2a85723"+".obj", 'rb') as handle:
    temp= pickle.load(handle)
    
print temp
# Out:
# {1: {'tourLength': 3, 'tourdist': 4412.095403569076, 'tourYear': 2013, 'tourdistOpt': 4412.095403569076}, 2: {'tourLength': 3, 'tourdist': 3598.3834783813863, 'tourYear': 2016, 'tourdistOpt': 3598.3834783813863}, 3: {'tourLength': 20, 'tourdist': 27289.99921420611, 'tourYear': 2016, 'tourdistOpt': 9304.647910861806}, 4: {'tourLength': 6, 'tourdist': 4892.130973463658, 'tourYear': 2016, 'tourdistOpt': 4892.130973463658}, 'name': u'Young MC', 6: {'tourLength': 8, 'tourdist': 7787.715648749957, 'tourYear': 2017, 'tourdistOpt': 6323.238414375028}, 7: {'tourLength': 31, 'tourdist': 73680.08716318749, 'tourYear': 2017, 'tourdistOpt': 46773.53267687943}, 8: {'tourLength': 4, 'tourdist': 2438.171813830467, 'tourYear': 2017, 'tourdistOpt': 2438.171813830467}, 9: {'tourLength': 10, 'tourdist': 16354.945789979454, 'tourYear': 2017, 'tourdistOpt': 10940.483749558794}, 10: {'tourLength': 8, 'tourdist': 8978.55589883757, 'tourYear': 2017, 'tourdistOpt': 15295.868189735194}, 'totalArtistOptTourDist': 117104.55491428997, 'OptArtistPercent': 35.167405650966764, 'totalArtistTourDist': 180626.0509703576, 'resultsYears': {2016: {'stattoursLength': 0.38461538461538464, 'toursLength': 54, 'toursDistOpt': 30921.164666341967, 'stattoursDist': 0.11237242179193828, 'toursDist': 66974.4792522036, 'stattoursDistOpt': -0.2078575076185511, 'toursCount': 4, 'stattoursCount': 0.3333333333333333}, 2017: {'stattoursLength': 0.5641025641025641, 'toursLength': 61, 'toursDistOpt': 81771.2948443789, 'stattoursDist': 0.8143475272984647, 'toursDist': 109239.47631458494, 'stattoursDistOpt': 1.0948278631235522, 'toursCount': 5, 'stattoursCount': 0.6666666666666666}, 'statMeanYeartoursLength': 39, 'statMeanYeartoursCount': 3, 'statMeanYearDistOpt': 39034.851638096654, 'statNbYear': 3, 'statMeanYearDist': 60208.68365678588, 2013: {'stattoursLength': -0.9230769230769231, 'toursLength': 3, 'toursDistOpt': 4412.095403569076, 'stattoursDist': -0.9267199490904032, 'toursDist': 4412.095403569076, 'stattoursDistOpt': -0.8869703555050015, 'toursCount': 1, 'stattoursCount': -0.6666666666666666}}, 5: {'tourLength': 25, 'tourdist': 31193.96558615244, 'tourYear': 2016, 'tourdistOpt': 13126.002303635118}}

# %%
with open("./RESULTSGLOBAL.obj", 'rb') as handle:
          temp= pickle.load( handle)
print temp
# Out:
# {'manOpt': 0.23255376595961377, 'autoOpt': 0.21995298276047787, 'totalOptDistsMin': 1639279100.4292355, 'totalOptDists': 1666194602.2991636, 'totalDists': 2136018170.0272305}

# %%
***************************
TOTAL ARTISTS TOURS DISTS 2135250690.17
TOTAL AUTO OPTIMIZED ARTISTS TOURS DISTS 1665625398.71
TOTAL MANUALLY OPTIMIZED ARTISTS TOURS DISTS 1638787824.49
AUTO-OPTIMIZED BY  21.993918261  %
MANUALLY OPTIMIZED BY  23.2507999161  %
***************************

***************************
TOTAL ARTISTS TOURS DISTS 2136018170.03
TOTAL AUTO OPTIMIZED ARTISTS TOURS DISTS 1666994420.69
TOTAL MANUALLY OPTIMIZED ARTISTS TOURS DISTS 1640164490.57
AUTO-OPTIMIZED BY  21.9578539134  %
MANUALLY OPTIMIZED BY  23.2139260994  %
***************************
