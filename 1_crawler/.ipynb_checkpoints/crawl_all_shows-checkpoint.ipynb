# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import json
import urllib
import time
import csv
import math
import os

# dir
places_dir = "data/places/"
artists_dir = "data/artists/"


# API
PLACE_BASE_URL = "https://app.bandsintown.com/events/popular/?location=PLACE&radius=10&per_page=100&authenticate=false&page=PAGE_NUMBER"
DATES_BASE_URL = "http://api.bandsintown.com/artists/ARTIST/events.json?api_version=2.0&app_id=YOUR_APP_ID&date=all"
bands_urls=[]

# %%
def get_filename(place, page_number):
    return places_dir + place.split("%")[0]+ "_" + str(page_number) +".json"

def get_page_url(place, page_number):
    url = PLACE_BASE_URL.replace("PLACE", place) # base url
    return url.replace("PAGE_NUMBER", str(page_number))

def get_page(place, page_number):

    f = get_filename(place, page_number)

    # check if the file already exists
    if not os.path.isfile(f):
        print f, " downloading"
        time.sleep(1)
        url = get_page_url(place, page_number)
        urllib.urlretrieve( url , filename=f)
    else :
        print f, " already exists"

def get_dates_from_place(place):

    # save first page
    page = get_page(place, 1)

    # compute number of pages
    with open( get_filename(place, 1) ) as data_file:
        page = json.load(data_file)
        nb_of_pages =  int( math.ceil( int(page["pages"]["total_results"]) / int(page["pages"]["results_per_page"]) ) ) + 2
        print "  total", place, nb_of_pages

    # crawl api
    for page_number in range(2, nb_of_pages) :
        # print place, str(page_number), "/", str(nb_of_pages)
        get_page(place,  page_number)

# %%
# parse places in FR
places = []
with open('list_villes/sousprefs') as souspref_file:
    places = souspref_file.read().splitlines()

with open('list_villes/prefs') as pref_file:
    places += pref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+France"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place
        
# parse places in Germany
places = []
with open('list_villes/prefsDE') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Germany"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place
# parse places in UK
with open('list_villes/gdesvillesUK') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+England"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place
        
# parse places in Spain
places = []
with open('list_villes/gdciudES') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Spain"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place        
        
        
# parse places in Poland
places = []
with open('list_villes/prefPOL') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Poland"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place
        
        
# parse places in Hungary
places = []
with open('list_villes/gdsvillesHU') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Hungary"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place
        
        
# parse places in greece
places = []
with open('list_villes/prefsGK') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Greece"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place
        
        
# parse places in Austria
places = []
with open('list_villes/gdsvillesAT') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Austria"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place
        
        
        
        
        
# parse places in Belgium
places = []
with open('list_villes/gdesvillesBE') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Belgium"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place        

                
# parse places in Bulgaria
places = []
with open('list_villes/gdesvillesBU') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Bulgaria"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place        
        
        
        
# parse places in Cyprus
places = []
with open('list_villes/gdsvillesCY') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Cyprus"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place        
  
        
        
        
        
        
        
# parse places in Italy
places = []
with open('list_villes/gdsvillesIT') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Italy"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place
        

        
# parse places in Sweden
places = []
with open('list_villes/gdesvillesSW') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Sweden"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place                
        
        
# parse places in Norway
places = []
with open('list_villes/gdesvillesNW') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Norway"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place                
        
        
# parse places in CZ
places = []
with open('list_villes/gdesvillesCZ') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+Czech"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place        
        
        
# parse places in US
places = []
with open('list_villes/gdsvillesUS') as souspref_file:
    places = souspref_file.read().splitlines()

# get data from places
for place in places :
    place.replace(' ',"%20")

    place = place+"%2C+US"
    # print  get_page_url(place, 1)
    try :
        get_dates_from_place(place)
    except :
        print "ERROR :",  place        
        
        
        
# get a unique list of artists
artists = []
for f in os.listdir(places_dir):
    #print "--- ", f
    if f != "_1.json" :
        with open(os.path.join(places_dir,f)) as data_file:
            try :
                data = json.load(data_file)
                for event in data["data"]["events"] :
                    for artist in event["artists"]:
                        if artist["name"] not in artists : artists.append(artist["name"])
                        # print artist["name"]
            except (ValueError,KeyError):
                print os.path.join(places_dir,f)
                print data
                pass
                

print "total : %s artists"%len( set(artists) )

# crawl all artists
for i, artist in enumerate(artists) :
    f = os.path.join(artists_dir, artist.replace(" ", "_").replace("/", "_") + ".json")
    print str(i) + "/" + str(len(artists))
    if not os.path.isfile(f):
        url = DATES_BASE_URL.replace("ARTIST", artist.replace(' ',"%20")).encode('utf8')
        #print "download : ", url
        try :
            urllib.urlretrieve( url , filename=f)
            time.sleep(0.3)
        except:
            print "ERROR", f,"  <<<<>>", sys.exc_info()[0]
            pass
    else :
        print f, "already exists"
# Out:
# data/places/Belley_1.json  already exists
#   total Belley%2C+France 2
# data/places/Gex_1.json  already exists
#   total Gex%2C+France 5
# data/places/Gex_2.json  already exists
# data/places/Gex_3.json  already exists
# data/places/Gex_4.json  already exists
# data/places/Nantua_1.json  already exists
#   total Nantua%2C+France 2
# data/places/Château-Thierry_1.json  already exists
#   total Château-Thierry%2C+France 2
# data/places/Saint-Quentin_1.json  already exists
#   total Saint-Quentin%2C+France 2
# data/places/Soissons_1.json  already exists
#   total Soissons%2C+France 2
# data/places/Vervins_1.json  already exists
#   total Vervins%2C+France 2
# data/places/Montluçon_1.json  already exists
#   total Montluçon%2C+France 2
# data/places/Vichy_1.json  already exists
#   total Vichy%2C+France 2
# data/places/Barcelonnette_1.json  already exists
#   total Barcelonnette%2C+France 2
# data/places/Castellane_1.json  already exists
#   total Castellane%2C+France 2
# data/places/Forcalquier_1.json  already exists
#   total Forcalquier%2C+France 2
# data/places/Briançon_1.json  already exists
#   total Briançon%2C+France 2
# data/places/Grasse_1.json  already exists
#   total Grasse%2C+France 4
# data/places/Grasse_2.json  already exists
# data/places/Grasse_3.json  already exists
# data/places/Largentière_1.json  already exists
#   total Largentière%2C+France 2
# data/places/Tournon-sur-Rhône_1.json  already exists
#   total Tournon-sur-Rhône%2C+France 2
# data/places/Rethel_1.json  already exists
#   total Rethel%2C+France 2
# data/places/Sedan_1.json  already exists
#   total Sedan%2C+France 2
# data/places/Vouziers_1.json  already exists
#   total Vouziers%2C+France 2
# data/places/Pamiers_1.json  already exists
#   total Pamiers%2C+France 2
# data/places/Saint-Girons_1.json  already exists
#   total Saint-Girons%2C+France 2
# data/places/Bar-sur-Aube_1.json  already exists
#   total Bar-sur-Aube%2C+France 2
# data/places/Nogent-sur-Seine_1.json  already exists
#   total Nogent-sur-Seine%2C+France 2
# data/places/Limoux_1.json  already exists
#   total Limoux%2C+France 2
# data/places/Narbonne_1.json  already exists
#   total Narbonne%2C+France 2
# data/places/Millau_1.json  already exists
#   total Millau%2C+France 2
# data/places/Villefranche-de-Rouergue_1.json  already exists
#   total Villefranche-de-Rouergue%2C+France 2
# data/places/Aix-en-Provence_1.json  already exists
#   total Aix-en-Provence%2C+France 3
# data/places/Aix-en-Provence_2.json  already exists
# data/places/Arles_1.json  already exists
#   total Arles%2C+France 2
# data/places/Istres_1.json  already exists
#   total Istres%2C+France 2
# data/places/Bayeux_1.json  already exists
#   total Bayeux%2C+France 2
# data/places/Lisieux_1.json  already exists
#   total Lisieux%2C+France 2
# data/places/Vire_1.json  already exists
#   total Vire%2C+France 2
# data/places/Mauriac_1.json  already exists
#   total Mauriac%2C+France 2
# data/places/Saint-Flour_1.json  already exists
#   total Saint-Flour%2C+France 2
# data/places/Cognac_1.json  already exists
#   total Cognac%2C+France 2
# data/places/Confolens_1.json  already exists
#   total Confolens%2C+France 2
# data/places/Jonzac_1.json  already exists
#   total Jonzac%2C+France 2
# data/places/Rochefort_1.json  already exists
#   total Rochefort%2C+France 2
# data/places/Saintes_1.json  already exists
#   total Saintes%2C+France 2
# data/places/Saint-Jean-d’Angély_1.json  already exists
# ERROR : Saint-Jean-d’Angély%2C+France
# data/places/Saint-Amand-Montrond_1.json  already exists
#   total Saint-Amand-Montrond%2C+France 2
# data/places/Vierzon_1.json  already exists
#   total Vierzon%2C+France 2
# data/places/Brive-la-Gaillarde_1.json  already exists
#   total Brive-la-Gaillarde%2C+France 2
# data/places/Ussel_1.json  already exists
#   total Ussel%2C+France 2
# data/places/Sartène_1.json  already exists
#   total Sartène%2C+France 2
# data/places/Calvi_1.json  already exists
#   total Calvi%2C+France 2
# data/places/Corte_1.json  already exists
#   total Corte%2C+France 2
# data/places/Beaune_1.json  already exists
#   total Beaune%2C+France 2
# data/places/Montbard_1.json  already exists
#   total Montbard%2C+France 2
# data/places/Dinan_1.json  already exists
#   total Dinan%2C+France 2
# data/places/Guingamp_1.json  already exists
#   total Guingamp%2C+France 2
# data/places/Lannion_1.json  already exists
#   total Lannion%2C+France 2
# data/places/Aubusson_1.json  already exists
#   total Aubusson%2C+France 2
# data/places/Bergerac_1.json  already exists
#   total Bergerac%2C+France 2
# data/places/Nontron_1.json  already exists
#   total Nontron%2C+France 2
# data/places/Sarlat-la-Canéda_1.json  already exists
#   total Sarlat-la-Canéda%2C+France 2
# data/places/Montbéliard_1.json  already exists
#   total Montbéliard%2C+France 3
# data/places/Montbéliard_2.json  already exists
# data/places/Pontarlier_1.json  already exists
#   total Pontarlier%2C+France 2
# data/places/Die_1.json  already exists
#   total Die%2C+France 2
# data/places/Nyons_1.json  already exists
#   total Nyons%2C+France 2
# data/places/Les Andelys_1.json  already exists
#   total Les Andelys%2C+France 2
# data/places/Bernay_1.json  already exists
#   total Bernay%2C+France 2
# data/places/Châteaudun_1.json  already exists
#   total Châteaudun%2C+France 2
# data/places/Dreux_1.json  already exists
#   total Dreux%2C+France 2
# data/places/Nogent-le-Rotrou_1.json  already exists
#   total Nogent-le-Rotrou%2C+France 2
# data/places/Brest_1.json  already exists
#   total Brest%2C+France 3
# data/places/Brest_2.json  already exists
# data/places/Châteaulin_1.json  already exists
#   total Châteaulin%2C+France 2
# data/places/Morlaix_1.json  already exists
#   total Morlaix%2C+France 2
# data/places/Alès_1.json  already exists
#   total Alès%2C+France 2
# data/places/Le Vigan_1.json  already exists
#   total Le Vigan%2C+France 2
# data/places/Muret_1.json  already exists
#   total Muret%2C+France 5
# data/places/Muret_2.json  already exists
# data/places/Muret_3.json  already exists
# data/places/Muret_4.json  already exists
# data/places/Saint-Gaudens_1.json  already exists
#   total Saint-Gaudens%2C+France 2
# data/places/Condom_1.json  already exists
#   total Condom%2C+France 2
# data/places/Mirande_1.json  already exists
#   total Mirande%2C+France 2
# data/places/Arcachon_1.json  already exists
#   total Arcachon%2C+France 2
# data/places/Blaye_1.json  already exists
#   total Blaye%2C+France 3
# data/places/Blaye_2.json  already exists
# data/places/Langon_1.json  already exists
#   total Langon%2C+France 2
# data/places/Lesparre-Médoc_1.json  already exists
#   total Lesparre-Médoc%2C+France 2
# data/places/Libourne_1.json  already exists
#   total Libourne%2C+France 2
# data/places/Béziers_1.json  already exists
#   total Béziers%2C+France 2
# data/places/Lodève_1.json  already exists
#   total Lodève%2C+France 2
# data/places/Fougères_1.json  already exists
#   total Fougères%2C+France 2
# data/places/Redon_1.json  already exists
#   total Redon%2C+France 2
# data/places/Saint-Malo_1.json  already exists
#   total Saint-Malo%2C+France 3
# data/places/Saint-Malo_2.json  already exists
# data/places/Le Blanc_1.json  already exists
#   total Le Blanc%2C+France 2
# data/places/La Châtre_1.json  already exists
#   total La Châtre%2C+France 2
# data/places/Issoudun_1.json  already exists
#   total Issoudun%2C+France 2
# data/places/Chinon_1.json  already exists
#   total Chinon%2C+France 2
# data/places/Loches_1.json  already exists
#   total Loches%2C+France 2
# data/places/La Tour-du-Pin_1.json  already exists
#   total La Tour-du-Pin%2C+France 2
# data/places/Vienne_1.json  already exists
#   total Vienne%2C+France 3
# data/places/Vienne_2.json  already exists
# data/places/Dole_1.json  already exists
#   total Dole%2C+France 2
# data/places/Saint-Claude_1.json  already exists
#   total Saint-Claude%2C+France 2
# data/places/Dax_1.json  already exists
#   total Dax%2C+France 2
# data/places/Romorantin-Lanthenay_1.json  already exists
#   total Romorantin-Lanthenay%2C+France 2
# data/places/Vendôme_1.json  already exists
#   total Vendôme%2C+France 2
# data/places/Montbrison_1.json  already exists
#   total Montbrison%2C+France 2
# data/places/Roanne_1.json  already exists
#   total Roanne%2C+France 2
# data/places/Brioude_1.json  already exists
#   total Brioude%2C+France 2
# data/places/Yssingeaux_1.json  already exists
#   total Yssingeaux%2C+France 2
# data/places/Ancenis_1.json  already exists
#   total Ancenis%2C+France 2
# data/places/Châteaubriant_1.json  already exists
#   total Châteaubriant%2C+France 2
# data/places/Saint-Nazaire_1.json  already exists
#   total Saint-Nazaire%2C+France 3
# data/places/Saint-Nazaire_2.json  already exists
# data/places/Montargis_1.json  already exists
#   total Montargis%2C+France 2
# data/places/Pithiviers_1.json  already exists
#   total Pithiviers%2C+France 2
# data/places/Figeac_1.json  already exists
#   total Figeac%2C+France 2
# data/places/Gourdon_1.json  already exists
#   total Gourdon%2C+France 3
# data/places/Gourdon_2.json  already exists
# data/places/Marmande_1.json  already exists
#   total Marmande%2C+France 2
# data/places/Nérac_1.json  already exists
#   total Nérac%2C+France 2
# data/places/Villeneuve-sur-Lot_1.json  already exists
#   total Villeneuve-sur-Lot%2C+France 2
# data/places/Florac_1.json  already exists
#   total Florac%2C+France 2
# data/places/Cholet_1.json  already exists
#   total Cholet%2C+France 2
# data/places/Saumur_1.json  already exists
#   total Saumur%2C+France 2
# data/places/Segré_1.json  already exists
#   total Segré%2C+France 2
# data/places/Avranches_1.json  already exists
#   total Avranches%2C+France 2
# data/places/Cherbourg-Octeville_1.json  already exists
#   total Cherbourg-Octeville%2C+France 2
# data/places/Coutances_1.json  already exists
#   total Coutances%2C+France 2
# data/places/Épernay_1.json  already exists
#   total Épernay%2C+France 2
# data/places/Reims_1.json  already exists
#   total Reims%2C+France 2
# data/places/Sainte-Menehould_1.json  already exists
#   total Sainte-Menehould%2C+France 2
# data/places/Vitry-le-François_1.json  already exists
#   total Vitry-le-François%2C+France 2
# data/places/Langres_1.json  already exists
#   total Langres%2C+France 2
# data/places/Saint-Dizier_1.json  already exists
#   total Saint-Dizier%2C+France 2
# data/places/Château-Gontier_1.json  already exists
#   total Château-Gontier%2C+France 2
# data/places/Mayenne_1.json  already exists
#   total Mayenne%2C+France 2
# data/places/Briey_1.json  already exists
#   total Briey%2C+France 2
# data/places/Lunéville_1.json  already exists
#   total Lunéville%2C+France 2
# data/places/Toul_1.json  already exists
#   total Toul%2C+France 2
# data/places/Commercy_1.json  already exists
#   total Commercy%2C+France 2
# data/places/Verdun_1.json  already exists
#   total Verdun%2C+France 2
# data/places/Lorient_1.json  already exists
#   total Lorient%2C+France 3
# data/places/Lorient_2.json  already exists
# data/places/Pontivy_1.json  already exists
#   total Pontivy%2C+France 2
# data/places/Château-Salins_1.json  already exists
#   total Château-Salins%2C+France 2
# data/places/Forbach_1.json  already exists
#   total Forbach%2C+France 3
# data/places/Forbach_2.json  already exists
# data/places/Sarrebourg_1.json  already exists
#   total Sarrebourg%2C+France 2
# data/places/Sarreguemines_1.json  already exists
#   total Sarreguemines%2C+France 3
# data/places/Sarreguemines_2.json  already exists
# data/places/Thionville_1.json  already exists
#   total Thionville%2C+France 3
# data/places/Thionville_2.json  already exists
# data/places/Château-Chinon (Ville)_1.json  already exists
# ERROR : Château-Chinon (Ville)%2C+France
# data/places/Clamecy_1.json  already exists
#   total Clamecy%2C+France 2
# data/places/Cosne-Cours-sur-Loire_1.json  already exists
#   total Cosne-Cours-sur-Loire%2C+France 2
# data/places/Avesnes-sur-Helpe_1.json  already exists
#   total Avesnes-sur-Helpe%2C+France 2
# data/places/Cambrai_1.json  already exists
#   total Cambrai%2C+France 2
# data/places/Douai_1.json  already exists
#   total Douai%2C+France 2
# data/places/Dunkerque_1.json  already exists
#   total Dunkerque%2C+France 2
# data/places/Valenciennes_1.json  already exists
#   total Valenciennes%2C+France 2
# data/places/Clermont_1.json  already exists
#   total Clermont%2C+France 2
# data/places/Compiègne_1.json  already exists
#   total Compiègne%2C+France 2
# data/places/Senlis_1.json  already exists
#   total Senlis%2C+France 2
# data/places/Argentan_1.json  already exists
#   total Argentan%2C+France 2
# data/places/Mortagne-au-Perche_1.json  already exists
#   total Mortagne-au-Perche%2C+France 2
# data/places/Béthune_1.json  already exists
#   total Béthune%2C+France 2
# data/places/Boulogne-sur-Mer_1.json  already exists
#   total Boulogne-sur-Mer%2C+France 2
# data/places/Calais_1.json  already exists
#   total Calais%2C+France 2
# data/places/Lens_1.json  already exists
#   total Lens%2C+France 3
# data/places/Lens_2.json  already exists
# data/places/Montreuil_1.json  already exists
#   total Montreuil%2C+France 45
# data/places/Montreuil_2.json  already exists
# data/places/Montreuil_3.json  already exists
# data/places/Montreuil_4.json  already exists
# data/places/Montreuil_5.json  already exists
# data/places/Montreuil_6.json  already exists
# data/places/Montreuil_7.json  already exists
# data/places/Montreuil_8.json  already exists
# data/places/Montreuil_9.json  already exists
# data/places/Montreuil_10.json  already exists
# data/places/Montreuil_11.json  already exists
# data/places/Montreuil_12.json  already exists
# data/places/Montreuil_13.json  already exists
# data/places/Montreuil_14.json  already exists
# data/places/Montreuil_15.json  already exists
# data/places/Montreuil_16.json  already exists
# data/places/Montreuil_17.json  already exists
# data/places/Montreuil_18.json  already exists
# data/places/Montreuil_19.json  already exists
# data/places/Montreuil_20.json  already exists
# data/places/Montreuil_21.json  already exists
# data/places/Montreuil_22.json  already exists
# data/places/Montreuil_23.json  already exists
# data/places/Montreuil_24.json  already exists
# data/places/Montreuil_25.json  already exists
# data/places/Montreuil_26.json  already exists
# data/places/Montreuil_27.json  already exists
# data/places/Montreuil_28.json  already exists
# data/places/Montreuil_29.json  already exists
# data/places/Montreuil_30.json  already exists
# data/places/Montreuil_31.json  already exists
# data/places/Montreuil_32.json  already exists
# data/places/Montreuil_33.json  already exists
# data/places/Montreuil_34.json  already exists
# data/places/Montreuil_35.json  already exists
# data/places/Montreuil_36.json  already exists
# data/places/Montreuil_37.json  already exists
# data/places/Montreuil_38.json  already exists
# data/places/Montreuil_39.json  already exists
# data/places/Montreuil_40.json  already exists
# data/places/Montreuil_41.json  already exists
# data/places/Montreuil_42.json  already exists
# data/places/Montreuil_43.json  already exists
# data/places/Montreuil_44.json  already exists
# data/places/Saint-Omer_1.json  already exists
#   total Saint-Omer%2C+France 2
# data/places/Ambert_1.json  already exists
#   total Ambert%2C+France 2
# data/places/Issoire_1.json  already exists
#   total Issoire%2C+France 2
# data/places/Riom_1.json  already exists
#   total Riom%2C+France 3
# data/places/Riom_2.json  already exists
# data/places/Thiers_1.json  already exists
#   total Thiers%2C+France 2
# data/places/Bayonne_1.json  already exists
#   total Bayonne%2C+France 3
# data/places/Bayonne_2.json  already exists
# data/places/Oloron-Sainte-Marie_1.json  already exists
#   total Oloron-Sainte-Marie%2C+France 2
# data/places/Argelès-Gazost_1.json  already exists
#   total Argelès-Gazost%2C+France 2
# data/places/Bagnères-de-Bigorre_1.json  already exists
#   total Bagnères-de-Bigorre%2C+France 2
# data/places/Céret_1.json  already exists
#   total Céret%2C+France 2
# data/places/Prades_1.json  already exists
#   total Prades%2C+France 2
# data/places/Haguenau_1.json  already exists
#   total Haguenau%2C+France 2
# data/places/Molsheim_1.json  already exists
#   total Molsheim%2C+France 3
# data/places/Molsheim_2.json  already exists
# data/places/Saverne_1.json  already exists
#   total Saverne%2C+France 2
# data/places/Sélestat_1.json  already exists
#   total Sélestat%2C+France 3
# data/places/Sélestat_2.json  already exists
# data/places/Altkirch_1.json  already exists
#   total Altkirch%2C+France 3
# data/places/Altkirch_2.json  already exists
# data/places/Mulhouse_1.json  already exists
#   total Mulhouse%2C+France 2
# data/places/Thann_1.json  already exists
#   total Thann%2C+France 2
# data/places/Villefranche-sur-Saône_1.json  already exists
#   total Villefranche-sur-Saône%2C+France 2
# data/places/Lure_1.json  already exists
#   total Lure%2C+France 2
# data/places/Autun_1.json  already exists
#   total Autun%2C+France 2
# data/places/Chalon-sur-Saône_1.json  already exists
#   total Chalon-sur-Saône%2C+France 2
# data/places/Charolles_1.json  already exists
#   total Charolles%2C+France 2
# data/places/Louhans_1.json  already exists
#   total Louhans%2C+France 2
# data/places/La Flèche_1.json  already exists
#   total La Flèche%2C+France 2
# data/places/Mamers_1.json  already exists
#   total Mamers%2C+France 2
# data/places/Albertville_1.json  already exists
#   total Albertville%2C+France 2
# data/places/Saint-Jean-de-Maurienne_1.json  already exists
#   total Saint-Jean-de-Maurienne%2C+France 2
# data/places/Bonneville_1.json  already exists
#   total Bonneville%2C+France 2
# data/places/Saint-Julien-en-Genevois_1.json  already exists
#   total Saint-Julien-en-Genevois%2C+France 5
# data/places/Saint-Julien-en-Genevois_2.json  already exists
# data/places/Saint-Julien-en-Genevois_3.json  already exists
# data/places/Saint-Julien-en-Genevois_4.json  already exists
# data/places/Thonon-les-Bains_1.json  already exists
#   total Thonon-les-Bains%2C+France 4
# data/places/Thonon-les-Bains_2.json  already exists
# data/places/Thonon-les-Bains_3.json  already exists
# data/places/_1.json  already exists
# ERROR : %2C+France
# data/places/Dieppe_1.json  already exists
#   total Dieppe%2C+France 2
# data/places/Le Havre_1.json  already exists
#   total Le Havre%2C+France 2
# data/places/Fontainebleau_1.json  already exists
#   total Fontainebleau%2C+France 2
# data/places/Meaux_1.json  already exists
#   total Meaux%2C+France 2
# data/places/Provins_1.json  already exists
#   total Provins%2C+France 2
# data/places/Torcy_1.json  already exists
#   total Torcy%2C+France 4
# data/places/Torcy_2.json  already exists
# data/places/Torcy_3.json  already exists
# data/places/Mantes-la-Jolie_1.json  already exists
#   total Mantes-la-Jolie%2C+France 2
# data/places/Rambouillet_1.json  already exists
#   total Rambouillet%2C+France 2
# data/places/Saint-Germain-en-Laye_1.json  already exists
#   total Saint-Germain-en-Laye%2C+France 8
# data/places/Saint-Germain-en-Laye_2.json  already exists
# data/places/Saint-Germain-en-Laye_3.json  already exists
# data/places/Saint-Germain-en-Laye_4.json  already exists
# data/places/Saint-Germain-en-Laye_5.json  already exists
# data/places/Saint-Germain-en-Laye_6.json  already exists
# data/places/Saint-Germain-en-Laye_7.json  already exists
# data/places/Bressuire_1.json  already exists
#   total Bressuire%2C+France 2
# data/places/Parthenay_1.json  already exists
#   total Parthenay%2C+France 2
# data/places/Abbeville_1.json  already exists
#   total Abbeville%2C+France 2
# data/places/Montdidier_1.json  already exists
#   total Montdidier%2C+France 2
# data/places/Péronne_1.json  already exists
#   total Péronne%2C+France 2
# data/places/Castres_1.json  already exists
#   total Castres%2C+France 2
# data/places/Castelsarrasin_1.json  already exists
#   total Castelsarrasin%2C+France 2
# data/places/Brignoles_1.json  already exists
#   total Brignoles%2C+France 2
# data/places/Draguignan_1.json  already exists
#   total Draguignan%2C+France 2
# data/places/Apt_1.json  already exists
#   total Apt%2C+France 2
# data/places/Carpentras_1.json  already exists
#   total Carpentras%2C+France 2
# data/places/Fontenay-le-Comte_1.json  already exists
#   total Fontenay-le-Comte%2C+France 2
# data/places/Les Sables-d’Olonne_1.json  already exists
#   total Les Sables-d’Olonne%2C+France 2
# data/places/Châtellerault_1.json  already exists
#   total Châtellerault%2C+France 2
# data/places/Montmorillon_1.json  already exists
#   total Montmorillon%2C+France 2
# data/places/Bellac_1.json  already exists
#   total Bellac%2C+France 2
# data/places/Rochechouart_1.json  already exists
#   total Rochechouart%2C+France 2
# data/places/Neufchâteau_1.json  already exists
#   total Neufchâteau%2C+France 2
# data/places/Saint-Dié-des-Vosges_1.json  already exists
#   total Saint-Dié-des-Vosges%2C+France 2
# data/places/Avallon_1.json  already exists
#   total Avallon%2C+France 2
# data/places/Sens_1.json  already exists
#   total Sens%2C+France 2
# data/places/_1.json  already exists
# ERROR : %2C+France
# data/places/Étampes_1.json  already exists
#   total Étampes%2C+France 2
# data/places/Palaiseau_1.json  already exists
#   total Palaiseau%2C+France 38
# data/places/Palaiseau_2.json  already exists
# data/places/Palaiseau_3.json  already exists
# data/places/Palaiseau_4.json  already exists
# data/places/Palaiseau_5.json  already exists
# data/places/Palaiseau_6.json  already exists
# data/places/Palaiseau_7.json  already exists
# data/places/Palaiseau_8.json  already exists
# data/places/Palaiseau_9.json  already exists
# data/places/Palaiseau_10.json  already exists
# data/places/Palaiseau_11.json  already exists
# data/places/Palaiseau_12.json  already exists
# data/places/Palaiseau_13.json  already exists
# data/places/Palaiseau_14.json  already exists
# data/places/Palaiseau_15.json  already exists
# data/places/Palaiseau_16.json  already exists
# data/places/Palaiseau_17.json  already exists
# data/places/Palaiseau_18.json  already exists
# data/places/Palaiseau_19.json  already exists
# data/places/Palaiseau_20.json  already exists
# data/places/Palaiseau_21.json  already exists
# data/places/Palaiseau_22.json  already exists
# data/places/Palaiseau_23.json  already exists
# data/places/Palaiseau_24.json  already exists
# data/places/Palaiseau_25.json  already exists
# data/places/Palaiseau_26.json  already exists
# data/places/Palaiseau_27.json  already exists
# data/places/Palaiseau_28.json  already exists
# data/places/Palaiseau_29.json  already exists
# data/places/Palaiseau_30.json  already exists
# data/places/Palaiseau_31.json  already exists
# data/places/Palaiseau_32.json  already exists
# data/places/Palaiseau_33.json  already exists
# data/places/Palaiseau_34.json  already exists
# data/places/Palaiseau_35.json  already exists
# data/places/Palaiseau_36.json  already exists
# data/places/Palaiseau_37.json  already exists
# data/places/Antony_1.json  already exists
#   total Antony%2C+France 46
# data/places/Antony_2.json  already exists
# data/places/Antony_3.json  already exists
# data/places/Antony_4.json  already exists
# data/places/Antony_5.json  already exists
# data/places/Antony_6.json  already exists
# data/places/Antony_7.json  already exists
# data/places/Antony_8.json  already exists
# data/places/Antony_9.json  already exists
# data/places/Antony_10.json  already exists
# data/places/Antony_11.json  already exists
# data/places/Antony_12.json  already exists
# data/places/Antony_13.json  already exists
# data/places/Antony_14.json  already exists
# data/places/Antony_15.json  already exists
# data/places/Antony_16.json  already exists
# data/places/Antony_17.json  already exists
# data/places/Antony_18.json  already exists
# data/places/Antony_19.json  already exists
# data/places/Antony_20.json  already exists
# data/places/Antony_21.json  already exists
# data/places/Antony_22.json  already exists
# data/places/Antony_23.json  already exists
# data/places/Antony_24.json  already exists
# data/places/Antony_25.json  already exists
# data/places/Antony_26.json  already exists
# data/places/Antony_27.json  already exists
# data/places/Antony_28.json  already exists
# data/places/Antony_29.json  already exists
# data/places/Antony_30.json  already exists
# data/places/Antony_31.json  already exists
# data/places/Antony_32.json  already exists
# data/places/Antony_33.json  already exists
# data/places/Antony_34.json  already exists
# data/places/Antony_35.json  already exists
# data/places/Antony_36.json  already exists
# data/places/Antony_37.json  already exists
# data/places/Antony_38.json  already exists
# data/places/Antony_39.json  already exists
# data/places/Antony_40.json  already exists
# data/places/Antony_41.json  already exists
# data/places/Antony_42.json  already exists
# data/places/Antony_43.json  already exists
# data/places/Antony_44.json  already exists
# data/places/Antony_45.json  already exists
# data/places/Boulogne-Billancourt_1.json  already exists
#   total Boulogne-Billancourt%2C+France 46
# data/places/Boulogne-Billancourt_2.json  already exists
# data/places/Boulogne-Billancourt_3.json  already exists
# data/places/Boulogne-Billancourt_4.json  already exists
# data/places/Boulogne-Billancourt_5.json  already exists
# data/places/Boulogne-Billancourt_6.json  already exists
# data/places/Boulogne-Billancourt_7.json  already exists
# data/places/Boulogne-Billancourt_8.json  already exists
# data/places/Boulogne-Billancourt_9.json  already exists
# data/places/Boulogne-Billancourt_10.json  already exists
# data/places/Boulogne-Billancourt_11.json  already exists
# data/places/Boulogne-Billancourt_12.json  already exists
# data/places/Boulogne-Billancourt_13.json  already exists
# data/places/Boulogne-Billancourt_14.json  already exists
# data/places/Boulogne-Billancourt_15.json  already exists
# data/places/Boulogne-Billancourt_16.json  already exists
# data/places/Boulogne-Billancourt_17.json  already exists
# data/places/Boulogne-Billancourt_18.json  already exists
# data/places/Boulogne-Billancourt_19.json  already exists
# data/places/Boulogne-Billancourt_20.json  already exists
# data/places/Boulogne-Billancourt_21.json  already exists
# data/places/Boulogne-Billancourt_22.json  already exists
# data/places/Boulogne-Billancourt_23.json  already exists
# data/places/Boulogne-Billancourt_24.json  already exists
# data/places/Boulogne-Billancourt_25.json  already exists
# data/places/Boulogne-Billancourt_26.json  already exists
# data/places/Boulogne-Billancourt_27.json  already exists
# data/places/Boulogne-Billancourt_28.json  already exists
# data/places/Boulogne-Billancourt_29.json  already exists
# data/places/Boulogne-Billancourt_30.json  already exists
# data/places/Boulogne-Billancourt_31.json  already exists
# data/places/Boulogne-Billancourt_32.json  already exists
# data/places/Boulogne-Billancourt_33.json  already exists
# data/places/Boulogne-Billancourt_34.json  already exists
# data/places/Boulogne-Billancourt_35.json  already exists
# data/places/Boulogne-Billancourt_36.json  already exists
# data/places/Boulogne-Billancourt_37.json  already exists
# data/places/Boulogne-Billancourt_38.json  already exists
# data/places/Boulogne-Billancourt_39.json  already exists
# data/places/Boulogne-Billancourt_40.json  already exists
# data/places/Boulogne-Billancourt_41.json  already exists
# data/places/Boulogne-Billancourt_42.json  already exists
# data/places/Boulogne-Billancourt_43.json  already exists
# data/places/Boulogne-Billancourt_44.json  already exists
# data/places/Boulogne-Billancourt_45.json  already exists
# data/places/Le Raincy_1.json  already exists
#   total Le Raincy%2C+France 41
# data/places/Le Raincy_2.json  already exists
# data/places/Le Raincy_3.json  already exists
# data/places/Le Raincy_4.json  already exists
# data/places/Le Raincy_5.json  already exists
# data/places/Le Raincy_6.json  already exists
# data/places/Le Raincy_7.json  already exists
# data/places/Le Raincy_8.json  already exists
# data/places/Le Raincy_9.json  already exists
# data/places/Le Raincy_10.json  already exists
# data/places/Le Raincy_11.json  already exists
# data/places/Le Raincy_12.json  already exists
# data/places/Le Raincy_13.json  already exists
# data/places/Le Raincy_14.json  already exists
# data/places/Le Raincy_15.json  already exists
# data/places/Le Raincy_16.json  already exists
# data/places/Le Raincy_17.json  already exists
# data/places/Le Raincy_18.json  already exists
# data/places/Le Raincy_19.json  already exists
# data/places/Le Raincy_20.json  already exists
# data/places/Le Raincy_21.json  already exists
# data/places/Le Raincy_22.json  already exists
# data/places/Le Raincy_23.json  already exists
# data/places/Le Raincy_24.json  already exists
# data/places/Le Raincy_25.json  already exists
# data/places/Le Raincy_26.json  already exists
# data/places/Le Raincy_27.json  already exists
# data/places/Le Raincy_28.json  already exists
# data/places/Le Raincy_29.json  already exists
# data/places/Le Raincy_30.json  already exists
# data/places/Le Raincy_31.json  already exists
# data/places/Le Raincy_32.json  already exists
# data/places/Le Raincy_33.json  already exists
# data/places/Le Raincy_34.json  already exists
# data/places/Le Raincy_35.json  already exists
# data/places/Le Raincy_36.json  already exists
# data/places/Le Raincy_37.json  already exists
# data/places/Le Raincy_38.json  already exists
# data/places/Le Raincy_39.json  already exists
# data/places/Le Raincy_40.json  already exists
# data/places/Saint-Denis_1.json  already exists
#   total Saint-Denis%2C+France 45
# data/places/Saint-Denis_2.json  already exists
# data/places/Saint-Denis_3.json  already exists
# data/places/Saint-Denis_4.json  already exists
# data/places/Saint-Denis_5.json  already exists
# data/places/Saint-Denis_6.json  already exists
# data/places/Saint-Denis_7.json  already exists
# data/places/Saint-Denis_8.json  already exists
# data/places/Saint-Denis_9.json  already exists
# data/places/Saint-Denis_10.json  already exists
# data/places/Saint-Denis_11.json  already exists
# data/places/Saint-Denis_12.json  already exists
# data/places/Saint-Denis_13.json  already exists
# data/places/Saint-Denis_14.json  already exists
# data/places/Saint-Denis_15.json  already exists
# data/places/Saint-Denis_16.json  already exists
# data/places/Saint-Denis_17.json  already exists
# data/places/Saint-Denis_18.json  already exists
# data/places/Saint-Denis_19.json  already exists
# data/places/Saint-Denis_20.json  already exists
# data/places/Saint-Denis_21.json  already exists
# data/places/Saint-Denis_22.json  already exists
# data/places/Saint-Denis_23.json  already exists
# data/places/Saint-Denis_24.json  already exists
# data/places/Saint-Denis_25.json  already exists
# data/places/Saint-Denis_26.json  already exists
# data/places/Saint-Denis_27.json  already exists
# data/places/Saint-Denis_28.json  already exists
# data/places/Saint-Denis_29.json  already exists
# data/places/Saint-Denis_30.json  already exists
# data/places/Saint-Denis_31.json  already exists
# data/places/Saint-Denis_32.json  already exists
# data/places/Saint-Denis_33.json  already exists
# data/places/Saint-Denis_34.json  already exists
# data/places/Saint-Denis_35.json  already exists
# data/places/Saint-Denis_36.json  already exists
# data/places/Saint-Denis_37.json  already exists
# data/places/Saint-Denis_38.json  already exists
# data/places/Saint-Denis_39.json  already exists
# data/places/Saint-Denis_40.json  already exists
# data/places/Saint-Denis_41.json  already exists
# data/places/Saint-Denis_42.json  already exists
# data/places/Saint-Denis_43.json  already exists
# data/places/Saint-Denis_44.json  already exists
# data/places/L’Haÿ-les-Roses_1.json  already exists
#   total L’Haÿ-les-Roses%2C+France 46
# data/places/L’Haÿ-les-Roses_2.json  already exists
# data/places/L’Haÿ-les-Roses_3.json  already exists
# data/places/L’Haÿ-les-Roses_4.json  already exists
# data/places/L’Haÿ-les-Roses_5.json  already exists
# data/places/L’Haÿ-les-Roses_6.json  already exists
# data/places/L’Haÿ-les-Roses_7.json  already exists
# data/places/L’Haÿ-les-Roses_8.json  already exists
# data/places/L’Haÿ-les-Roses_9.json  already exists
# data/places/L’Haÿ-les-Roses_10.json  already exists
# data/places/L’Haÿ-les-Roses_11.json  already exists
# data/places/L’Haÿ-les-Roses_12.json  already exists
# data/places/L’Haÿ-les-Roses_13.json  already exists
# data/places/L’Haÿ-les-Roses_14.json  already exists
# data/places/L’Haÿ-les-Roses_15.json  already exists
# data/places/L’Haÿ-les-Roses_16.json  already exists
# data/places/L’Haÿ-les-Roses_17.json  already exists
# data/places/L’Haÿ-les-Roses_18.json  already exists
# data/places/L’Haÿ-les-Roses_19.json  already exists
# data/places/L’Haÿ-les-Roses_20.json  already exists
# data/places/L’Haÿ-les-Roses_21.json  already exists
# data/places/L’Haÿ-les-Roses_22.json  already exists
# data/places/L’Haÿ-les-Roses_23.json  already exists
# data/places/L’Haÿ-les-Roses_24.json  already exists
# data/places/L’Haÿ-les-Roses_25.json  already exists
# data/places/L’Haÿ-les-Roses_26.json  already exists
# data/places/L’Haÿ-les-Roses_27.json  already exists
# data/places/L’Haÿ-les-Roses_28.json  already exists
# data/places/L’Haÿ-les-Roses_29.json  already exists
# data/places/L’Haÿ-les-Roses_30.json  already exists
# data/places/L’Haÿ-les-Roses_31.json  already exists
# data/places/L’Haÿ-les-Roses_32.json  already exists
# data/places/L’Haÿ-les-Roses_33.json  already exists
# data/places/L’Haÿ-les-Roses_34.json  already exists
# data/places/L’Haÿ-les-Roses_35.json  already exists
# data/places/L’Haÿ-les-Roses_36.json  already exists
# data/places/L’Haÿ-les-Roses_37.json  already exists
# data/places/L’Haÿ-les-Roses_38.json  already exists
# data/places/L’Haÿ-les-Roses_39.json  already exists
# data/places/L’Haÿ-les-Roses_40.json  already exists
# data/places/L’Haÿ-les-Roses_41.json  already exists
# data/places/L’Haÿ-les-Roses_42.json  already exists
# data/places/L’Haÿ-les-Roses_43.json  already exists
# data/places/L’Haÿ-les-Roses_44.json  already exists
# data/places/L’Haÿ-les-Roses_45.json  already exists
# data/places/Nogent-sur-Marne_1.json  already exists
#   total Nogent-sur-Marne%2C+France 43
# data/places/Nogent-sur-Marne_2.json  already exists
# data/places/Nogent-sur-Marne_3.json  already exists
# data/places/Nogent-sur-Marne_4.json  already exists
# data/places/Nogent-sur-Marne_5.json  already exists
# data/places/Nogent-sur-Marne_6.json  already exists
# data/places/Nogent-sur-Marne_7.json  already exists
# data/places/Nogent-sur-Marne_8.json  already exists
# data/places/Nogent-sur-Marne_9.json  already exists
# data/places/Nogent-sur-Marne_10.json  already exists
# data/places/Nogent-sur-Marne_11.json  already exists
# data/places/Nogent-sur-Marne_12.json  already exists
# data/places/Nogent-sur-Marne_13.json  already exists
# data/places/Nogent-sur-Marne_14.json  already exists
# data/places/Nogent-sur-Marne_15.json  already exists
# data/places/Nogent-sur-Marne_16.json  already exists
# data/places/Nogent-sur-Marne_17.json  already exists
# data/places/Nogent-sur-Marne_18.json  already exists
# data/places/Nogent-sur-Marne_19.json  already exists
# data/places/Nogent-sur-Marne_20.json  already exists
# data/places/Nogent-sur-Marne_21.json  already exists
# data/places/Nogent-sur-Marne_22.json  already exists
# data/places/Nogent-sur-Marne_23.json  already exists
# data/places/Nogent-sur-Marne_24.json  already exists
# data/places/Nogent-sur-Marne_25.json  already exists
# data/places/Nogent-sur-Marne_26.json  already exists
# data/places/Nogent-sur-Marne_27.json  already exists
# data/places/Nogent-sur-Marne_28.json  already exists
# data/places/Nogent-sur-Marne_29.json  already exists
# data/places/Nogent-sur-Marne_30.json  already exists
# data/places/Nogent-sur-Marne_31.json  already exists
# data/places/Nogent-sur-Marne_32.json  already exists
# data/places/Nogent-sur-Marne_33.json  already exists
# data/places/Nogent-sur-Marne_34.json  already exists
# data/places/Nogent-sur-Marne_35.json  already exists
# data/places/Nogent-sur-Marne_36.json  already exists
# data/places/Nogent-sur-Marne_37.json  already exists
# data/places/Nogent-sur-Marne_38.json  already exists
# data/places/Nogent-sur-Marne_39.json  already exists
# data/places/Nogent-sur-Marne_40.json  already exists
# data/places/Nogent-sur-Marne_41.json  already exists
# data/places/Nogent-sur-Marne_42.json  already exists
# data/places/Argenteuil_1.json  already exists
#   total Argenteuil%2C+France 46
# data/places/Argenteuil_2.json  already exists
# data/places/Argenteuil_3.json  already exists
# data/places/Argenteuil_4.json  already exists
# data/places/Argenteuil_5.json  already exists
# data/places/Argenteuil_6.json  already exists
# data/places/Argenteuil_7.json  already exists
# data/places/Argenteuil_8.json  already exists
# data/places/Argenteuil_9.json  already exists
# data/places/Argenteuil_10.json  already exists
# data/places/Argenteuil_11.json  already exists
# data/places/Argenteuil_12.json  already exists
# data/places/Argenteuil_13.json  already exists
# data/places/Argenteuil_14.json  already exists
# data/places/Argenteuil_15.json  already exists
# data/places/Argenteuil_16.json  already exists
# data/places/Argenteuil_17.json  already exists
# data/places/Argenteuil_18.json  already exists
# data/places/Argenteuil_19.json  already exists
# data/places/Argenteuil_20.json  already exists
# data/places/Argenteuil_21.json  already exists
# data/places/Argenteuil_22.json  already exists
# data/places/Argenteuil_23.json  already exists
# data/places/Argenteuil_24.json  already exists
# data/places/Argenteuil_25.json  already exists
# data/places/Argenteuil_26.json  already exists
# data/places/Argenteuil_27.json  already exists
# data/places/Argenteuil_28.json  already exists
# data/places/Argenteuil_29.json  already exists
# data/places/Argenteuil_30.json  already exists
# data/places/Argenteuil_31.json  already exists
# data/places/Argenteuil_32.json  already exists
# data/places/Argenteuil_33.json  already exists
# data/places/Argenteuil_34.json  already exists
# data/places/Argenteuil_35.json  already exists
# data/places/Argenteuil_36.json  already exists
# data/places/Argenteuil_37.json  already exists
# data/places/Argenteuil_38.json  already exists
# data/places/Argenteuil_39.json  already exists
# data/places/Argenteuil_40.json  already exists
# data/places/Argenteuil_41.json  already exists
# data/places/Argenteuil_42.json  already exists
# data/places/Argenteuil_43.json  already exists
# data/places/Argenteuil_44.json  already exists
# data/places/Argenteuil_45.json  already exists
# data/places/Sarcelles_1.json  already exists
#   total Sarcelles%2C+France 43
# data/places/Sarcelles_2.json  already exists
# data/places/Sarcelles_3.json  already exists
# data/places/Sarcelles_4.json  already exists
# data/places/Sarcelles_5.json  already exists
# data/places/Sarcelles_6.json  already exists
# data/places/Sarcelles_7.json  already exists
# data/places/Sarcelles_8.json  already exists
# data/places/Sarcelles_9.json  already exists
# data/places/Sarcelles_10.json  already exists
# data/places/Sarcelles_11.json  already exists
# data/places/Sarcelles_12.json  already exists
# data/places/Sarcelles_13.json  already exists
# data/places/Sarcelles_14.json  already exists
# data/places/Sarcelles_15.json  already exists
# data/places/Sarcelles_16.json  already exists
# data/places/Sarcelles_17.json  already exists
# data/places/Sarcelles_18.json  already exists
# data/places/Sarcelles_19.json  already exists
# data/places/Sarcelles_20.json  already exists
# data/places/Sarcelles_21.json  already exists
# data/places/Sarcelles_22.json  already exists
# data/places/Sarcelles_23.json  already exists
# data/places/Sarcelles_24.json  already exists
# data/places/Sarcelles_25.json  already exists
# data/places/Sarcelles_26.json  already exists
# data/places/Sarcelles_27.json  already exists
# data/places/Sarcelles_28.json  already exists
# data/places/Sarcelles_29.json  already exists
# data/places/Sarcelles_30.json  already exists
# data/places/Sarcelles_31.json  already exists
# data/places/Sarcelles_32.json  already exists
# data/places/Sarcelles_33.json  already exists
# data/places/Sarcelles_34.json  already exists
# data/places/Sarcelles_35.json  already exists
# data/places/Sarcelles_36.json  already exists
# data/places/Sarcelles_37.json  already exists
# data/places/Sarcelles_38.json  already exists
# data/places/Sarcelles_39.json  already exists
# data/places/Sarcelles_40.json  already exists
# data/places/Sarcelles_41.json  already exists
# data/places/Sarcelles_42.json  already exists
# data/places/Pontoise (Chef-lieu)_1.json  already exists
#   total Pontoise (Chef-lieu)%2C+France 3
# data/places/Pontoise (Chef-lieu)_2.json  already exists
# data/places/Pointe-à-Pitre_1.json  already exists
# ERROR : Pointe-à-Pitre%2C+France
# data/places/Le Marin_1.json  already exists
#   total Le Marin%2C+France 2
# data/places/Saint-Pierre_1.json  already exists
#   total Saint-Pierre%2C+France 3
# data/places/Saint-Pierre_2.json  already exists
# data/places/La Trinité_1.json  already exists
#   total La Trinité%2C+France 5
# data/places/La Trinité_2.json  already exists
# data/places/La Trinité_3.json  already exists
# data/places/La Trinité_4.json  already exists
# data/places/Saint-Laurent-du-Maroni_1.json  already exists
#   total Saint-Laurent-du-Maroni%2C+France 2
# data/places/Saint-Benoît_1.json  already exists
#   total Saint-Benoît%2C+France 2
# data/places/Saint-Paul_1.json  already exists
#   total Saint-Paul%2C+France 2
# data/places/Saint-Pierre_1.json  already exists
#   total Saint-Pierre%2C+France 3
# data/places/Saint-Pierre_2.json  already exists
# data/places/Bourg-en-Bresse_1.json  already exists
#   total Bourg-en-Bresse%2C+France 2
# data/places/Laon_1.json  already exists
#   total Laon%2C+France 2
# data/places/Moulins_1.json  already exists
#   total Moulins%2C+France 2
# data/places/Digne-les-Bains_1.json  already exists
#   total Digne-les-Bains%2C+France 2
# data/places/Gap_1.json  already exists
#   total Gap%2C+France 2
# data/places/Nice_1.json  already exists
#   total Nice%2C+France 5
# data/places/Nice_2.json  already exists
# data/places/Nice_3.json  already exists
# data/places/Nice_4.json  already exists
# data/places/Privas_1.json  already exists
#   total Privas%2C+France 2
# data/places/Charleville-Mézières_1.json  already exists
#   total Charleville-Mézières%2C+France 2
# data/places/Foix_1.json  already exists
#   total Foix%2C+France 2
# data/places/Troyes_1.json  already exists
#   total Troyes%2C+France 2
# data/places/Carcassonne_1.json  already exists
#   total Carcassonne%2C+France 2
# data/places/Rodez_1.json  already exists
#   total Rodez%2C+France 2
# data/places/Marseille_1.json  already exists
#   total Marseille%2C+France 6
# data/places/Marseille_2.json  already exists
# data/places/Marseille_3.json  already exists
# data/places/Marseille_4.json  already exists
# data/places/Marseille_5.json  already exists
# data/places/Caen_1.json  already exists
#   total Caen%2C+France 3
# data/places/Caen_2.json  already exists
# data/places/Aurillac_1.json  already exists
#   total Aurillac%2C+France 2
# data/places/Angoulême_1.json  already exists
#   total Angoulême%2C+France 2
# data/places/La Rochelle_1.json  already exists
#   total La Rochelle%2C+France 3
# data/places/La Rochelle_2.json  already exists
# data/places/Bourges_1.json  already exists
#   total Bourges%2C+France 2
# data/places/Tulle_1.json  already exists
#   total Tulle%2C+France 2
# data/places/Ajaccio_1.json  already exists
#   total Ajaccio%2C+France 2
# data/places/Bastia_1.json  already exists
#   total Bastia%2C+France 2
# data/places/Dijon_1.json  already exists
#   total Dijon%2C+France 3
# data/places/Dijon_2.json  already exists
# data/places/Saint-Brieuc_1.json  already exists
#   total Saint-Brieuc%2C+France 2
# data/places/Guéret_1.json  already exists
#   total Guéret%2C+France 2
# data/places/Périgueux_1.json  already exists
#   total Périgueux%2C+France 2
# data/places/Besançon_1.json  already exists
#   total Besançon%2C+France 2
# data/places/Valence_1.json  already exists
#   total Valence%2C+France 2
# data/places/Évreux_1.json  already exists
#   total Évreux%2C+France 2
# data/places/Chartres_1.json  already exists
#   total Chartres%2C+France 2
# data/places/Quimper_1.json  already exists
#   total Quimper%2C+France 2
# data/places/Nîmes_1.json  already exists
#   total Nîmes%2C+France 3
# data/places/Nîmes_2.json  already exists
# data/places/Toulouse_1.json  already exists
#   total Toulouse%2C+France 6
# data/places/Toulouse_2.json  already exists
# data/places/Toulouse_3.json  already exists
# data/places/Toulouse_4.json  already exists
# data/places/Toulouse_5.json  already exists
# data/places/Auch_1.json  already exists
#   total Auch%2C+France 2
# data/places/Bordeaux_1.json  already exists
#   total Bordeaux%2C+France 5
# data/places/Bordeaux_2.json  already exists
# data/places/Bordeaux_3.json  already exists
# data/places/Bordeaux_4.json  already exists
# data/places/Montpellier_1.json  already exists
#   total Montpellier%2C+France 5
# data/places/Montpellier_2.json  already exists
# data/places/Montpellier_3.json  already exists
# data/places/Montpellier_4.json  already exists
# data/places/Rennes_1.json  already exists
#   total Rennes%2C+France 4
# data/places/Rennes_2.json  already exists
# data/places/Rennes_3.json  already exists
# data/places/Châteauroux_1.json  already exists
#   total Châteauroux%2C+France 2
# data/places/Tours_1.json  already exists
#   total Tours%2C+France 3
# data/places/Tours_2.json  already exists
# data/places/Grenoble_1.json  already exists
#   total Grenoble%2C+France 3
# data/places/Grenoble_2.json  already exists
# data/places/Lons-le-Saunier_1.json  already exists
#   total Lons-le-Saunier%2C+France 2
# data/places/Mont-de-Marsan_1.json  already exists
#   total Mont-de-Marsan%2C+France 2
# data/places/Blois_1.json  already exists
#   total Blois%2C+France 2
# data/places/Saint-Étienne_1.json  already exists
#   total Saint-Étienne%2C+France 3
# data/places/Saint-Étienne_2.json  already exists
# data/places/Le Puy-en-Velay_1.json  already exists
#   total Le Puy-en-Velay%2C+France 2
# data/places/Nantes_1.json  already exists
#   total Nantes%2C+France 6
# data/places/Nantes_2.json  already exists
# data/places/Nantes_3.json  already exists
# data/places/Nantes_4.json  already exists
# data/places/Nantes_5.json  already exists
# data/places/Orléans_1.json  already exists
#   total Orléans%2C+France 2
# data/places/Cahors_1.json  already exists
#   total Cahors%2C+France 2
# data/places/Agen_1.json  already exists
#   total Agen%2C+France 2
# data/places/Mende_1.json  already exists
#   total Mende%2C+France 2
# data/places/Angers_1.json  already exists
#   total Angers%2C+France 2
# data/places/Saint-Lô_1.json  already exists
#   total Saint-Lô%2C+France 2
# data/places/Châlons-en-Champagne_1.json  already exists
#   total Châlons-en-Champagne%2C+France 2
# data/places/Chaumont_1.json  already exists
#   total Chaumont%2C+France 2
# data/places/Laval_1.json  already exists
#   total Laval%2C+France 2
# data/places/Nancy_1.json  already exists
#   total Nancy%2C+France 3
# data/places/Nancy_2.json  already exists
# data/places/Bar-le-Duc_1.json  already exists
#   total Bar-le-Duc%2C+France 2
# data/places/Vannes_1.json  already exists
#   total Vannes%2C+France 3
# data/places/Vannes_2.json  already exists
# data/places/Metz_1.json  already exists
#   total Metz%2C+France 3
# data/places/Metz_2.json  already exists
# data/places/Nevers_1.json  already exists
#   total Nevers%2C+France 2
# data/places/Lille_1.json  already exists
#   total Lille%2C+France 6
# data/places/Lille_2.json  already exists
# data/places/Lille_3.json  already exists
# data/places/Lille_4.json  already exists
# data/places/Lille_5.json  already exists
# data/places/Beauvais_1.json  already exists
#   total Beauvais%2C+France 2
# data/places/Alençon_1.json  already exists
#   total Alençon%2C+France 2
# data/places/Arras_1.json  already exists
#   total Arras%2C+France 2
# data/places/Clermont-Ferrand_1.json  already exists
#   total Clermont-Ferrand%2C+France 3
# data/places/Clermont-Ferrand_2.json  already exists
# data/places/Pau_1.json  already exists
#   total Pau%2C+France 2
# data/places/Tarbes_1.json  already exists
#   total Tarbes%2C+France 2
# data/places/Perpignan_1.json  already exists
#   total Perpignan%2C+France 4
# data/places/Perpignan_2.json  already exists
# data/places/Perpignan_3.json  already exists
# data/places/Strasbourg_1.json  already exists
#   total Strasbourg%2C+France 5
# data/places/Strasbourg_2.json  already exists
# data/places/Strasbourg_3.json  already exists
# data/places/Strasbourg_4.json  already exists
# data/places/Colmar_1.json  already exists
#   total Colmar%2C+France 2
# data/places/Lyon_1.json  already exists
#   total Lyon%2C+France 8
# data/places/Lyon_2.json  already exists
# data/places/Lyon_3.json  already exists
# data/places/Lyon_4.json  already exists
# data/places/Lyon_5.json  already exists
# data/places/Lyon_6.json  already exists
# data/places/Lyon_7.json  already exists
# data/places/Vesoul_1.json  already exists
#   total Vesoul%2C+France 2
# data/places/Mâcon_1.json  already exists
#   total Mâcon%2C+France 2
# data/places/Le Mans_1.json  already exists
#   total Le Mans%2C+France 2
# data/places/Chambéry_1.json  already exists
#   total Chambéry%2C+France 3
# data/places/Chambéry_2.json  already exists
# data/places/Annecy_1.json  already exists
# ...
# ---  Siofok_1.json
# ---  Omaha_3.json
# ---  Tempe_23.json
# ---  Norwalk_7.json
# ---  Daly city_34.json
# ---  Westminster_22.json
# ---  Sunrise manor_2.json
# ---  Palmdale_1.json
# ---  Créteil_12.json
# ---  Inglewood_31.json
# ---  Vendôme_1.json
# ---  Houston_3.json
# ---  Seattle_10.json
# ---  Lokeren_2.json
# ---  Arvada_20.json
# ---  Sint-pieters-leeuw_6.json
# ---  Irvine_12.json
# ---  Bernay_1.json
# ---  Seattle_21.json
# ---  Palaiseau_5.json
# ---  Cincinnati_16.json
# ---  Lier_1.json
# ---  Palaiseau_23.json
# ---  Berkeley_9.json
# ---  New york_104.json
# ---  Chula vista_10.json
# ---  Modling_5.json
# ---  Ayioi anaryiroi_1.json
# ---  Spring valley_49.json
# ---  Rochdale_2.json
# ---  Cirpan_1.json
# ---  Schwabach_4.json
# ---  Oakland_76.json
# ---  El paso_2.json
# ---  Newark_144.json
# ---  North las vegas_53.json
# ---  Paris_8.json
# ---  Sutton Coldfield_8.json
# ---  Plano_18.json
# ---  Oberhausen_5.json
# ---  Boston_31.json
# ---  Oakland_20.json
# ---  L’Haÿ-les-Roses_34.json
# ---  Berkeley_57.json
# ---  New york_7.json
# ---  Fort wayne_1.json
# ---  Lyon_5.json
# ---  Phoenix_5.json
# ---  Pittsburgh_8.json
# ---  North las vegas_151.json
# ---  Las vegas_156.json
# ---  San francisco_75.json
# ---  Anaheim_1.json
# ---  Jersey city_40.json
# ---  Lakewood_58.json
# ---  San francisco_40.json
# ---  Bressuire_1.json
# ---  Argenteuil_42.json
# ---  Paris_28.json
# ---  Los angeles_50.json
# ---  Nogent-sur-Marne_11.json
# ---  Luton_4.json
# ---  Newark_121.json
# ---  Newark_23.json
# ---  Saverne_1.json
# ---  Chicago_59.json
# ---  Garland_4.json
# ---  Alexandria_21.json
# ---  New york_146.json
# ---  Birmingham_11.json
# ---  Paradise_176.json
# ---  Arlington_7.json
# ---  Metairie_13.json
# ---  Jersey city_7.json
# ---  Henderson_18.json
# ---  Spring valley_13.json
# ---  Garland_18.json
# ---  Santander_1.json
# ---  West valley city_8.json
# ---  Austin_14.json
# ---  Arlington_8.json
# ---  Miramar_3.json
# ---  North las vegas_4.json
# ---  Worcester_2.json
# ---  Paradise_4.json
# ---  Pesaro_1.json
# ---  Créteil_15.json
# ---  Stamford_1.json
# ---  Braunschweig_2.json
# ---  Jersey city_47.json
# ---  Nashville_21.json
# ---  Saint louis_1.json
# ---  Lille_5.json
# ---  Bludenz_1.json
# ---  Las vegas_84.json
# ---  Chicago_83.json
# ---  Argenteuil_27.json
# ---  Hajduboszormeny_1.json
# ---  Elizabeth_1.json
# ---  Oakland_56.json
# ---  Bobigny_15.json
# ---  Tumba_3.json
# ---  Karlsruhe_2.json
# ---  Mannheim_1.json
# ---  West valley city_13.json
# ---  Boulogne-Billancourt_22.json
# ---  Inglewood_44.json
# ---  Bergen_1.json
# ---  Sunrise manor_24.json
# ---  North las vegas_72.json
# ---  East los angeles_32.json
# ---  Daly city_27.json
# ---  Céret_1.json
# ---  Figeac_1.json
# ---  Mol_3.json
# ---  Norwalk_14.json
# ---  Chicago_49.json
# ---  Plano_20.json
# ---  Portland_25.json
# ---  Dearborn_11.json
# ---  Ornskoldsvik_1.json
# ---  Miramar_6.json
# ---  Bristol_4.json
# ---  San francisco_37.json
# ---  Torrance_3.json
# ---  Lakewood_50.json
# ---  Gorzów Wielkopolski_1.json
# ---  Richardson_40.json
# ---  Austin_15.json
# ---  Sandy springs_13.json
# ---  North las vegas_82.json
# ---  Garland_9.json
# ---  Praha_5.json
# ---  Lier_9.json
# ---  Atlanta_11.json
# ---  Paradise_170.json
# ---  Lakewood_56.json
# ---  Las vegas_153.json
# ---  Frankfurt am Main_8.json
# ---

# %%
        
# get a unique list of artists
artists = []
for f in os.listdir(places_dir):
    print "--- ", f
    if f != "_1.json":
        with (open(os.path.join(places_dir,f))) as data_file:
            try :
                data = json.load(data_file)
                for event in data["data"]["events"] :
                    for artist in event["artists"]:
                        if artist["name"] not in artists : artists.append(artist["name"])
                        # print artist["name"]
            except ValueError :
                pass # json not parsable

print "total : %s artists"%len( set(artists) )

# crawl all artists
for i, artist in enumerate(artists) :
    f = os.path.join(artists_dir, artist.replace(" ", "_").replace("/", "_") + ".json")
    print str(i) + "/" + str(len(artists))
    if not os.path.isfile(f):
        url = DATES_BASE_URL.replace("ARTIST", artist.replace(' ',"%20")).encode('utf8')
        print "download : ", url
        urllib.urlretrieve( url , filename=f)
        time.sleep(1)
    else :
        print f, "already exists"
# Out:
#   File "<ipython-input-12-d05bd54f72f3>", line 7
#     with (open(os.path.join(places_dir,f))) as data_file:
#                                                          ^
# IndentationError: expected an indented block
