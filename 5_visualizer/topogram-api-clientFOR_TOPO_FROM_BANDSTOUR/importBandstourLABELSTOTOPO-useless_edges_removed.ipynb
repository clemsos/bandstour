# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from topogram_client import TopogramAPIClient
from slugify import slugify
from csv import DictReader
import os
import json
import pymongo
#import musicbrainzngs
import arrow
from datetime import datetime
from pymongo import MongoClient
from collections import defaultdict
from dateutil import parser
from datetime import timedelta
import time
import pickle

# %%
import colorsys
def get_N_HexCol(N=20):

    HSV_tuples = [(x*1.0/N, 0.5, 0.5) for x in xrange(N)]
    hex_out = []
    for rgb in HSV_tuples:
        rgb = map(lambda x: int(x*255),colorsys.hsv_to_rgb(*rgb))
        hex_out.append("".join(map(lambda x: chr(x).encode('hex'),rgb)))
    return hex_out

# %%
def create_topogram(title, nodes, edges):

    print "Creating topogram '%s'"%title

    try :
        r = topogram.create_topogram(title)
    except ValueError:
        print '> Topogram already exists'
        r = topogram.get_topogram_by_name(title)
    print r
    #print r["data"][0]
    topogram_ID = r["data"]["_id"]
    print "topogram ID : %s"%topogram_ID

    # get and backup existing nodes and edges
    existing_nodes = topogram.get_nodes(topogram_ID)["data"]
    existing_edges = topogram.get_edges(topogram_ID)["data"]

    # clear existing graph
    if len(existing_nodes):
        topogram.delete_nodes([n["_id"] for n in existing_nodes])
        print "%s nodes deleted"%len(existing_nodes)
    if len(existing_edges):
        topogram.delete_edges([n["_id"] for n in existing_edges])
        print "%s edges deleted"%len(existing_edges)

    r = topogram.create_nodes(topogram_ID, nodes)
    print r
    print "%s nodes created."%len(r["data"])
    r = topogram.create_edges(topogram_ID, edges)
    print "%s edges created."%len(r["data"])

    print "done. Topogram has been updated. Check it at %s/topograms/%s"%(TOPOGRAM_URL, topogram_ID)

# %%
from geopy.exc import GeocoderTimedOut
from geopy.geocoders import GoogleV3
    

my_api_key = os.environ.get('MY_API_KEY', None)
#print my_api_key

def do_geocode(address,G_API_KEY):
    
    
    google_maps = GoogleV3(api_key=G_API_KEY,domain='maps.google.com')
    try:
        return google_maps.geocode(address,"exactly_one=True")
    except GeocoderTimedOut:
        return do_geocode(address)

# %%
# setup mongo
client = MongoClient()
db = client["bandstour"]
bandsintown =  db["minedArtists"]

# credentials
TOPOGRAM_URL = "http://localhost:3000"
#TOPOGRAM_URL = "https://app.topogram.io"
USER = "gregory.bahde@laposte.net"
PASSWORD = "matrix"

# %%
with open('./LABEL_graph.obj', 'rb') as handle:
    LABEL_graph=pickle.load(handle)
print len(LABEL_graph[0])
print len(LABEL_graph[1])
print len(LABEL_graph[2])

title = LABEL_graph[0]
title+=" useless edges removed Alpha"
my_nodes= LABEL_graph[1]
my_edges= LABEL_graph[2]
# Out:
# 15
# 13864
# 14271

# %%
print title
missing_nodes=[]
to_remove_edges=[]
for node in my_nodes:
    try:
        if not node["data"]["lat"]:
            print node
    except KeyError:
        print node
        
#print map(lambda x: x["data"]["id"],my_nodes)
        
for edge in my_edges:
    if edge["data"]["source"] not in map(lambda x: x["data"]["id"],my_nodes):
        #print edge["data"]["source"]
        missing_nodes.append(edge["data"]["source"])
    if edge["data"]["target"] not in map(lambda x: x["data"]["id"],my_nodes):
        #print edge["data"]["target"]
        to_remove_edges.append(edge["data"]["id"])
print len(missing_nodes)    
print missing_nodes
print "_____________________________#####"
print len(to_remove_edges)
print to_remove_edges
print my_nodes[:10]
print my_edges[:10]
# Out:
# M4P 2 the ST4RZ
# 0
# []
# _____________________________#####
# 4974
# ['846b38a4-5295-495d-812d-e3d7f143a3f1=>c51c6914-1820-4d8c-b994-05a8b6b4a6e1', '995428e7-81b6-41dd-bd38-5a7a0ece8ad6=>2b6dcfa9-db2d-4b25-9bb1-9f9a4d5336a3', '995428e7-81b6-41dd-bd38-5a7a0ece8ad6=>53be0cd6-a60b-4236-be5f-467c0453ceb6', '995428e7-81b6-41dd-bd38-5a7a0ece8ad6=>578d18e6-fe1b-4b63-9e26-cf8fa0e26ddb', '995428e7-81b6-41dd-bd38-5a7a0ece8ad6=>5f40c7c4-abde-4504-95d7-193102ef0b78', '995428e7-81b6-41dd-bd38-5a7a0ece8ad6=>7c720ce5-5724-4cf1-93dd-2cd338fae92d', '995428e7-81b6-41dd-bd38-5a7a0ece8ad6=>863f76f2-ada7-432e-8046-bef4e1c11663', '995428e7-81b6-41dd-bd38-5a7a0ece8ad6=>b5d31add-2ca6-45db-b651-282469aa6e57', '995428e7-81b6-41dd-bd38-5a7a0ece8ad6=>c04ecb08-8b95-4901-ba4c-8e247fecb662', '995428e7-81b6-41dd-bd38-5a7a0ece8ad6=>e7a47102-11b8-4008-8541-ed272dbca2fb', '995428e7-81b6-41dd-bd38-5a7a0ece8ad6=>f72ae2f2-0e72-4325-a639-c62079d6045f', '995428e7-81b6-41dd-bd38-5a7a0ece8ad6=>f8a12a01-fe28-44a5-9241-99df2382a46c', 'cb7f0188-11fb-4a2d-9fe7-00672d41fc2f=>b7ef7dda-79c4-4077-9e9d-c9be41a4ffaf', '7c284371-51f2-4fa9-8bde-b4503c61a12d=>14bc4a34-d207-41e0-8490-5cf2158aa874', 'bf0951a3-14e6-4241-b68a-3827969a80a6=>fc14b2cb-5f91-4880-8f1e-b542df908ed9', 'dc940013-b8a8-4362-a465-291026c04b42=>169e9d9f-8f15-448f-9774-3262d22ab61b', 'dc940013-b8a8-4362-a465-291026c04b42=>97db6db7-3cd8-4a78-8dab-af0aed9209be', '0dc73038-3ec1-4634-900d-61bfd223e0bb=>dfea8476-163f-4ee0-801f-e8c1d508722f', 'af2720e3-3631-4a63-b1a9-f8487b3252d8=>18e06bc0-11f1-478f-b4d8-b66432be73d6', 'af2720e3-3631-4a63-b1a9-f8487b3252d8=>20032274-4ee2-4bc1-8b36-9cce0d50f5f5', 'af2720e3-3631-4a63-b1a9-f8487b3252d8=>2d8564bf-bdbd-40ff-8cf6-77f76180d96d', 'fb36a6ef-6015-4020-80d7-a047c497e512=>b5199e7c-58cf-4cd3-8974-8ec367f67a5e', '2b84cc9f-dcc6-42ba-b9ec-fccc11a403bc=>03e7e0ee-ffc0-439b-bc71-ffdc19842211', '2b84cc9f-dcc6-42ba-b9ec-fccc11a403bc=>77987d07-c576-4a9b-8cd5-b965bf8b0a85', 'dee0a0c0-eb07-47e8-aadc-f3b483cfad6c=>ab74775d-a524-49a7-ae25-e92af8b85b52', 'dee0a0c0-eb07-47e8-aadc-f3b483cfad6c=>f7738fb5-22d9-40a0-9b7a-1abb8f0e6b65', '0e1c139e-b622-45cb-bf24-7598ba6e6c11=>05881c1d-54ac-4e4e-8b3d-66f444e4c94a', '0e1c139e-b622-45cb-bf24-7598ba6e6c11=>989a0cb3-69cc-471f-9563-2bc68c93c60b', '7fd6a368-1932-4621-88e1-9a71929ee9b9=>e7035bb9-c732-4324-86af-346355bd1085', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>086aa220-bc04-41bb-b73d-76d742b33c6d', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>132526e1-b41a-4215-b651-dd44309eab94', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>146acff7-cd59-49d4-811f-0f64496a6c3a', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>194ee27c-1240-42ac-9922-98b1d2f50079', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>24661418-b290-4373-8c53-0fcb74c8127d', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>30d9da00-d507-4ce2-81ee-4cce3d57c408', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>5b415f89-8b7d-4f01-839a-333a30417b48', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>6939ab2d-88ca-4339-97c3-b079cf824a48', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>76abc333-5b76-4cae-9b25-0fefd8ae37a7', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>7bf580dd-5fda-4f46-bbce-faf70b6426dd', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>a9646c15-5811-4560-bf3f-91a649ffd7c4', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>b05f7290-1868-4763-8b61-d17175b8ec93', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>b64c86f3-cb78-448c-a97a-536f0a4e97bb', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>b64e0234-2d34-4b89-bcf3-73fcdbd8cbd8', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>cd73fc5d-7959-4fe1-a6b4-8da2c5dfe112', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>cd7ae43b-fe42-454a-bfcd-46a66f91d210', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>ce419252-a114-4806-8b40-2a709070b417', '615fa478-3901-42b8-80bc-bf58b1ff0e03=>fc5265e7-f495-4e78-b1c0-bebed51249a6', '08e6c3c8-81ab-405f-9cff-10f6b8db064c=>0a94e96a-9219-4dd7-a529-18d34e77f50f', 'b28d652f-5102-4712-aed0-93ee1412d98e=>361af197-cc2d-408d-965b-7557a3712dbb', '663466ee-6907-433f-a615-f352cb03f867=>0996a163-8bd6-4373-aabd-2029c1f75859', '663466ee-6907-433f-a615-f352cb03f867=>36c1826f-5a6c-4942-8478-4b5235920262', '0b05d7e9-fd0b-4967-9 ...
# [{'data': {'lat': 41.87194, 'notes': u"id 781c73fd-71d0-4309-b9bb-a3036ffc705c  \nnameThe Spew Records  \ncoords41.87194/12.56738  \ndates d'activit\xe9{'begin': '2000'}  \n", 'id': '781c73fd-71d0-4309-b9bb-a3036ffc705c', 'lng': 12.567379999999957, 'name': 'The Spew Records'}}, {'data': {'lat': 52.132633, 'notes': u"id 7020b318-6b95-49d4-ab5f-7cb1fe9fd3ea  \nnameN.V. Bovema  \ncoords52.132633/5.291266  \ndates d'activit\xe9{'ended': 'true', 'begin': '1946', 'end': '1971'}  \n", 'id': '7020b318-6b95-49d4-ab5f-7cb1fe9fd3ea', 'lng': 5.2912659999999505, 'name': 'N.V. Bovema'}}, {'data': {'lat': 51.165691, 'notes': u'id a7d455f1-93f6-4bb7-a9cf-e4514efd7e02  \nnameUlftone Music  \ncoords51.165691/10.451526  \n', 'id': 'a7d455f1-93f6-4bb7-a9cf-e4514efd7e02', 'lng': 10.451526000000058, 'name': 'Ulftone Music'}}, {'data': {'lat': -25.274398, 'notes': u'id c3da866a-1ed0-4d10-96e0-d6b5b80a50a0  \nnameLabel "X"  \ncoords-25.274398/133.775136  \n', 'id': 'c3da866a-1ed0-4d10-96e0-d6b5b80a50a0', 'lng': 133.77513599999997, 'name': 'Label "X"'}}, {'data': {'lat': 40.6781784, 'notes': u"id aa3400d4-26f8-47eb-8bd7-2d71684b7885  \nnameRising Pulse Records  \ncoords40.6781784/-73.9441579  \ndates d'activit\xe9{'begin': '2008'}  \n", 'id': 'aa3400d4-26f8-47eb-8bd7-2d71684b7885', 'lng': -73.9441579, 'name': 'Rising Pulse Records'}}, {'data': {'lat': 60.128161, 'notes': u'id b53d13de-fda6-462d-aa94-376c2251e7fc  \nnameV2 Music Scandinavia AB  \ncoords60.128161/18.643501  \n', 'id': 'b53d13de-fda6-462d-aa94-376c2251e7fc', 'lng': 18.643501000000015, 'name': 'V2 Music Scandinavia AB'}}, {'data': {'lat': 37.09024, 'notes': u'id e06695b0-ded1-421f-939f-cde2470a0944  \nnameWeb Entertainment  \ncoords37.09024/-95.712891  \n', 'id': 'e06695b0-ded1-421f-939f-cde2470a0944', 'lng': -95.71289100000001, 'name': 'Web Entertainment'}}, {'data': {'lat': 48.4371143, 'notes': u'id c0239ec2-0b3e-4878-9160-059417c6b422  \nnameFirework Edition Records  \ncoords FICTIVES48.4371143/-37.3321004  \n', 'id': 'c0239ec2-0b3e-4878-9160-059417c6b422', 'lng': -37.3321004, 'name': 'Firework Edition Records'}}, {'data': {'lat': 37.09024, 'notes': u'id 90cf3cdb-68ca-493f-8df6-df98ba1681d2  \nnameBamaJam Records  \ncoords37.09024/-95.712891  \n', 'id': '90cf3cdb-68ca-493f-8df6-df98ba1681d2', 'lng': -95.71289100000001, 'name': 'BamaJam Records'}}, {'data': {'lat': 36.204824, 'notes': u'id 846b38a4-5295-495d-812d-e3d7f143a3f1  \nnameSohbi Corporation  \ncoords36.204824/138.252924  \n', 'id': '846b38a4-5295-495d-812d-e3d7f143a3f1', 'lng': 138.252924, 'name': 'Sohbi Corporation'}}]
# [{'data': {'source': '7020b318-6b95-49d4-ab5f-7cb1fe9fd3ea', 'target': '7e1a1cff-ffca-440a-9999-3bc7dd0a03fa', 'id': '7020b318-6b95-49d4-ab5f-7cb1fe9fd3ea=>7e1a1cff-ffca-440a-9999-3bc7dd0a03fa'}}, {'data': {'source': 'b53d13de-fda6-462d-aa94-376c2251e7fc', 'target': 'bbf062b0-b3b2-4b58-8bfa-06d2bfa80a62', 'id': 'b53d13de-fda6-462d-aa94-376c2251e7fc=>bbf062b0-b3b2-4b58-8bfa-06d2bfa80a62'}}, {'data': {'source': 'b53d13de-fda6-462d-aa94-376c2251e7fc', 'target': 'dc2f5993-7a3d-4c59-bba0-0a77bf9d7416', 'id': 'b53d13de-fda6-462d-aa94-376c2251e7fc=>dc2f5993-7a3d-4c59-bba0-0a77bf9d7416'}}, {'data': {'source': 'ea2555da-5ba4-4eb5-ae32-16e40da24703', 'target': 'b53d13de-fda6-462d-aa94-376c2251e7fc', 'id': 'ea2555da-5ba4-4eb5-ae32-16e40da24703=>b53d13de-fda6-462d-aa94-376c2251e7fc'}}, {'data': {'source': '846b38a4-5295-495d-812d-e3d7f143a3f1', 'target': '168f48c8-057e-4974-9600-aa9956d21e1a', 'id': '846b38a4-5295-495d-812d-e3d7f143a3f1=>168f48c8-057e-4974-9600-aa9956d21e1a'}}, {'data': {'source': '846b38a4-5295-495d-812d-e3d7f143a3f1', 'target': 'c51c6914-1820-4d8c-b994-05a8b6b4a6e1', 'id': '846b38a4-5295-495d-812d-e3d7f143a3f1=>c51c6914-1820-4d8c-b994-05a8b6b4a6e1'}}, {'data': {'source': '19d052fa-570a-4b17-9a3d-8f2f029b7b57', 'target': '995428e7-81b6-41dd-bd38-5a7a0ece8ad6', 'id': '19d052fa-570a-4b17-9a3d-8f2f029b7b57=>995428e7-81b6-41dd-bd38-5a7a0ece8ad6'}}, {'data': {'source': '995428e7-81b6-41dd-bd38-5a7a0ece8ad6', 'target': '1b3b52a5-ef89-4f8b-8d5f-e15a7a58863b', 'id': '995428e7-81b6-41dd-bd38-5a7a0ece8ad6=>1b3b52a5-ef89-4f8b-8d5f-e15a7a58863b'}}, {'data': {'source': '1fc9f71a-8d08-4c02-ab13-fa752750ae44', 'target': '995428e7-81b6-41dd-bd38-5a7a0ece8ad6', 'id': '1fc9f71a-8d08-4c02-ab13-fa752750ae44=>995428e7-81b6-41dd-bd38-5a7a0ece8ad6'}}, {'data': {'source': '2556d09c-93ae-4ca9-9b01-e275fdec5bec', 'target': '995428e7-81b6-41dd-bd38-5a7a0ece8ad6', 'id': '2556d09c-93ae-4ca9-9b01-e275fdec5bec=>995428e7-81b6-41dd-bd38-5a7a0ece8ad6'}}]

# %%
i=0
k=0
my_edges_filtered=[]
for edge in my_edges:
    i+=1
    if edge["data"]["id"] in to_remove_edges:
        print my_edges[i]
        k+=1
        
    else: 
        my_edges_filtered.append(edge)
        #my_edges.pop(i)
        #i-=1
print k
print len(my_edges_filtered)
my_edges=my_edges_filtered
# Out:
# 0
# 9297

# %%
# credentials
TOPOGRAM_URL = "http://localhost:3000"
USER = "gregory.bahde@laposte.net"
PASSWORD = "matrix"

# %%
# connect to the topogram instance (pass debug=True params for more info )
topogram = TopogramAPIClient(TOPOGRAM_URL) #, debug=True)

# create a new user
try :
    topogram.create_user(USER, PASSWORD)
except ValueError:
    print "> User has already been created."

# login a new user if needed
resp_user_login = topogram.user_login(USER, PASSWORD)
print resp_user_login

assert(resp_user_login["status"] == "success")
assert(resp_user_login["status_code"] == 200)
# Out:
# ERROR:topogram-client:403 Unauthorized request
# > User has already been created.
# {u'status': u'success', 'status_code': 200, u'data': {u'authToken': u'6Z-X1Apq9XmQCO1Z_iLA2M9CFG-10HEAK00DtSTyIuF', u'userId': u'BxRn4kp4WFL92jW8g'}}

# %%
create_topogram(title, my_nodes, my_edges)
# Out:
# ERROR:topogram-client:500 - Error : A topogram with the same name already exists
# Creating topogram 'M4P 2 the ST4RZ connected Alpha'
# > Topogram already exists
# {u'status': u'success', 'status_code': 200, u'data': {u'sharedPublic': False, u'title': u'M4P 2 the ST4RZ connected Alpha', u'userId': u'BxRn4kp4WFL92jW8g', u'_id': u'C4vFh5ZPNMs5mj9Wp', u'slug': u'm4p-2-the-st4rz-connected-alpha', u'createdAt': u'2018-05-09T09:02:23.362Z'}, u'statusCode': 200}
# topogram ID : C4vFh5ZPNMs5mj9Wp
# {u'status': u'success', 'status_code': 200, u'data': [u'uG7F3792gMgnYQ7Ra', u'Q4KPM6iEb9Zc8x8FG', u'xbMYoMJ2Fmnjcoogz', u'7rKrCP6wxfjNTYML3', u'xBBGNaM9zxSkWwqwG', u'E22i2uXb6jX4TEdH4', u'mguKewzcvr9dZNJyn', u'9GNjTHtaQMpX8xfft', u'ymyzb7GQH9P9wcHPh', u'5eSTGgWCQmwDEzpB4', u'Ej9TkQt8XsbRpxB9T', u'ak7RMEeTFMoRoFRTJ', u'48pWrgEzBjMqSiBxq', u'E7TkvxkMg3uRz38Sm', u'dSGbomJ5BHvvQzbYG', u'KYFnJTY6yMHxvgf4h', u'i8wCKA9RX74gLTKvo', u'KrKnF22YPyGaznto7', u'E48PPiBSbGDvpxdiq', u'twSgNwbzydgbhW6X5', u'jZHzuSx9upJp7T2aC', u'7xMkjFE7p9TjWN2hi', u'ztqa8Th7HT8wMSd5e', u'x2JXDQA3WTSoiJEY7', u'X29tgRRjJnAGD5J9j', u'av5FehycMiKHGckuf', u'LAcmZeozaT3CAbAvP', u'adBWmnksGRygEbnMJ', u'R6s5w2StE5hLaAzfn', u'eQrgxscg2jquFDj9f', u'XKczmrrJTZffPq7va', u'4YkkQD4cpDxL4XAx2', u'fX7ZZ2tJQGcx2CEfH', u'rNQKLR5yHvv48eXsk', u'83EDfBbJZjJCdi2iu', u'6L2MuR9XNpPaxMkMX', u'wCQJTyzQ8pquKdGyM', u'BvYB6oSc6FjSdNBn3', u'hpa7dRAg8YMTY5Rcc', u'4m4y38ecceWzxGqop', u'AxJDeEk3ekTxsfGtS', u'TcT6c9WJrCAoxiX5g', u'h3vEPd9eonKKbARQg', u'fdBMcPD3mamHxb5PQ', u'g8EKqGs7NDA6E2ttG', u'TYBC3JFEQ6xADQENo', u'DT6HnD35N6jQpEDe2', u'txomQNxwLkpSAxM5n', u'gufyBepbae9QRradj', u'oSvtarC6cLHEJxqR2', u'7knzceGa7ojxrvKPJ', u'NWpPJkz8sDinN2Yfx', u'j6cvKtmKdA3dvJ9AJ', u'YMLv4YJpE5dy3nB4T', u'dz94DuamFXw6KgxfJ', u'jCXhoAiiiuQz5i6Zx', u'Rm5DBSzA8sMPJ2KQk', u'irNuFyt48Jsj2L43A', u'24FH2kCSACTRFDeGb', u'amqFLwHtDaoHP8ou9', u'hCePJ8TkiG95yfPB3', u'wzk9QYGgoQfvHmTmt', u'x6G8yFh5gurT7ihcJ', u'oiso2GZTD3Xts37fu', u'FWJTiEALgBcpcmnrh', u'kDhrpYr98Yv3Jgiew', u'wsSEZQifSA7BD7r3F', u'YqxbAxqPw9pYLDxSQ', u'xBhMPK6iQvLr2M95a', u'fgpEhTAfPwYomQeYi', u'F8hmYNs2N6cCz9gL9', u'f7y5nSoqB2zpLDYSz', u'9nqB9dHxoHXpY8Rz5', u'weXtqyMctheSMDMeM', u'a58YaWneFYdZb7Zm4', u'imXEqgAEx4Ybqiocw', u'dMwsHqn6rFKpZzNpp', u'WS4Tj2MoRRhzLYy6T', u'6jFBYcgdXK5hvQ88C', u'oApqKxbT3RZzZBfQW', u'dRwZkvxCRvGSr5Jbc', u'i5QjEveQvt3A9hGKa', u'vSB2LrsHGtpsaMSMt', u'dG5Kv9TPWESdgikjk', u'2tiuDsbFaCaMTRDwA', u'WwDEyqfpJLxs8TuJw', u'e4aoAFG8vdcog495q', u'XztxjYCYhzRyP23dH', u'xjy8wJZ54AW8R9dCx', u'DB64GzNjLrnMkgydc', u'9P8TucnuScKWoLaJn', u'biRJqb9LF6xxwzxsZ', u'3FdQzNzcPFDZbHTfw', u'TZHZ9ao3v4cq5Atub', u'TaFQw7tEumAMeGdQr', u'k36pApbZrcwsmD9fS', u'3fHmpJmWmvScxJdLn', u'WpAaieBLSztj67sJ3', u'r5ktCTwCv6azXytsb', u'P6MLWzqj6DLtbrMXA', u'RxgsKfiQB5zq6zcFL', u'HmdtTRXnTxZHqzoqA', u'k8hFveTFJxuth6bcq', u'Pojp4KdDDsySNWiRw', u'zTwGJFGiwid7N6xZo', u'SXT4mhbNnQvPfR46b', u'x3YWtgzH8v8ZozzNv', u'Jzk5fEECeHtRih5RA', u'RDrkgYEeZFYaP8mGT', u'TLRC8xLNci3B9JmkC', u'mKBXuPcJyrRJ2B4Df', u'bGXr2JiDDAJ5tNLCY', u'gHuTpCrkgsnr77h6x', u'ihcwXmoLGEBupjBJ3', u'pJjmEe8yrrwBiBQNF', u'8kcHgA3HhTWDmWWQp', u'JGhaLvxLMGjvEp7oW', u'w7DESRFQZ6MGxtsck', u'4dornsFHm3ZyhizbB', u'EuYkMFSprn7DgyPcF', u'bqTN8pFJEvyKMDtas', u'iGmCKMz6SQPLWZ7Xj', u'Ki87uQNw6TkQMQ3Wn', u'hqiRY36Br8Kk98Eks', u'9G4kFghD6my2qbgpq', u'ayvDXrT8g4iLdR8Qr', u'7xJea55zv49pmMJZY', u'N5qsgqmKwrxwi4o2S', u'2yArQLKtiw9gbA7M2', u'YBiMvNFvkAriLN7Na', u'hkYacFtoiXtMora3R', u'C9csQmD45dr8KxCFK', u'w94D7E6skMTiNqyr7', u'B7xSycok8QeG3ZdkD', u'ajz4F7TzEnKzwPToP', u'nyEyN4cWSbxskYkPE', u'JzqCzGHPfymsbwYcn', u'NE79WddFfsFEDub3n', u'p2kc9vLNfYha8ufXK', u'owHvGPoKa6csB8X5g', u'Q8Tr8tjPXCvk7Mkhz', u'MCuygfR8MGxEMt7go', u'LR22XwGBrckA69S9i', u'do5EHkeFvAtbozWZA', u'DwNsxYRffZEjGryhH', u'xMqi8cFZ3KC6oQSZ7', u'ARuLALBDuJx2kQKy6', u'BrJeGDTsuwXGqQ7kk', u'FFhNrb8ZBNrN7sP8e', u'SYiu32nRRraT6S4ME', u'chF4zun2cAYs67Hi8', u'ZWNrxP5MF9w8qgrGn', u'Jd4LxRHEzA5CL8tXX', u'JAEy5hCEZnMpTPZQc', u'6MvyJQo53KY6MAZtD', u'F3at46HRywZivY2BH', u'XBEgcxhiYiQPSMgZk', u'jxkb9KdyK2XBt7ngb', u'M43qzBJw3rPKRZN6T', u'BJXu4TTNJzwrKmzuT', u'j66t6hrLKASLKadWJ', u'idnxiJaWyjxXtEz3y', u'wijKovYoxas4duoQu', u'2XGK33HbqX956SqJ8', u'8gFvdzTKPuKssuBn8', u'yqWPKfQ6iBXStThkH', u'dfx3ksbCy7DRFTr2z', u'xoqozSBgCLhHAQBBn', u'XbJthqKrDuSSgEPyi', u'mK5Khdns4EwXfvssu', u'vf4g9mZFjcX9QJaGX', u'y8FyyXgaHx7DzGNuw', u'qBG3YiPZu8HFaiWXc', u'RHM5xo3cbrJfeguDx', u'LP7a43v2AEx8aTEyJ', u'eBDECHmtW23hKg2Bz', u'SahcHPTrH3Zaesyia', u'9SGvGdKCof63t7vQw', u'Tt5ezALm8dgNxuA6z', u'sDG5ur ...
# 13864 nodes created.
# 9297 edges created.
# done. Topogram has been updated. Check it at http://localhost:3000/topograms/C4vFh5ZPNMs5mj9Wp
