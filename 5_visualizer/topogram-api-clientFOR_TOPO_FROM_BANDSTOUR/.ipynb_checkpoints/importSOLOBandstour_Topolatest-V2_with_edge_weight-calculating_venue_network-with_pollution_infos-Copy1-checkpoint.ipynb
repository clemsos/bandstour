# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from topogram_client import TopogramAPIClient

from csv import DictReader
import os
import json
import pymongo
#import musicbrainzngs
import arrow
from datetime import datetime
from pymongo import MongoClient
from collections import defaultdict
from dateutil import parser
from datetime import timedelta
import pickle
import time
from slugify import slugify
from fuzzywuzzy import fuzz
import urllib
import math

##SET PATH TO SAVE FILES:
savpath="./bands_dicts/"

# %%
#a function to have a range of colors for nodes/edges 
import colorsys
def get_N_HexCol(N=20):

    HSV_tuples = [(x*1.0/N, 0.5, 0.5) for x in xrange(N)]
    hex_out = []
    for rgb in HSV_tuples:
        rgb = map(lambda x: int(x*255),colorsys.hsv_to_rgb(*rgb))
        hex_out.append("".join(map(lambda x: chr(x).encode('hex'),rgb)))
    return hex_out

# %%
def create_topogram(title, nodes, edges):

    print "Creating topogram '%s'"%title

    try :
        r = topogram.create_topogram(title)
    except ValueError:
        print '> Topogram already exists'
        r = topogram.get_topogram_by_name(title)
    print r
    topogram_ID = r["data"]["_id"]
    print "topogram ID : %s"%topogram_ID

    # get and backup existing nodes and edges
    existing_nodes = topogram.get_nodes(topogram_ID)["data"]
    existing_edges = topogram.get_edges(topogram_ID)["data"]

    # clear existing graph
    if len(existing_nodes):
        topogram.delete_nodes([n["_id"] for n in existing_nodes])
        print "%s nodes deleted"%len(existing_nodes)
    if len(existing_edges):
        topogram.delete_edges([n["_id"] for n in existing_edges])
        print "%s edges deleted"%len(existing_edges)

    r = topogram.create_nodes(topogram_ID, nodes)
    #print r
    print "%s nodes created."%len(r["data"])
    r = topogram.create_edges(topogram_ID, edges)
    print "%s edges created."%len(r["data"])

    print "done. Topogram has been updated. Check it at %s/topograms/%s"%(TOPOGRAM_URL, topogram_ID)

# %%
artist={}
artist["name"]="steve-aoki"
artist["mbid"]="a39acc4a-985e-4173-a9ed-f325f2d3bc1c"

with open("../../4_miner/tour_miner/"+slugify(artist["name"]+artist["mbid"])+".obj", 'rb') as handle:
          tempL= pickle.load( handle)
print tempL

# %%
###HERE WE BUILD A LABEL OWNERSHIP CRUSHER FACTORIZED
with open("../../4_miner/labels_aliases_TOTAL.obj", 'rb') as handle:
          tempRelAll= pickle.load( handle)
def find_owning_label(label):
    
    labrels=[]
    if "label-relation-list" in tempRelAll[label]["label"] :

        for relat in tempRelAll[label]["label"]["label-relation-list"]:
            if "direction" in relat and relat["direction"] == "backward":
                print tempRelAll[label]["label"]["name"],"OWNED BY",relat["target"]," ",tempRelAll[relat["target"]]["label"]["name"]
                labrels.append(relat["target"])
                rum_and_whisky=""
                while rum_and_whisky != "SELF": 
                    rum_and_whisky=find_owning_label(relat["target"])
                print "ENDED LOOP"
                labrels.remove(relat["target"])
                print "LABRELS",labrels
                #if labrels[0]==relat["target"]:
                 #   break
                
            else:
                pass
            
        
        if not labrels :
            print "TOP OF THE TREE FOR ",tempRelAll[label]["label"]["name"]
            return "SELF"
        else:
            return labrels
                


artist={}
artist["name"]="Steve Aoki"
artist["mbid"]="a39acc4a-985e-4173-a9ed-f325f2d3bc1c"

with open("../../4_miner/release_mbnz/"+artist["name"]+artist["mbid"]+".obj", 'rb') as handle:
          tempRelz= pickle.load( handle)
#print tempRel["release-list"][0]['label-info-list'][0]['label']['id']
#print tempRel["release-list"][0]['release-event-list'][0]["date"]




for release in tempRelz["release-list"]:
    print"---------------------------"
    print release['label-info-list'][0]['label']['id']
    print release['label-info-list'][0]['label']['name']
    print release['release-event-list'][0]["date"]
    
    #print tempRelAll[release['label-info-list'][0]['label']['id']]["label"]
    try:
        result_lab=find_owning_label(release['label-info-list'][0]['label']['id'])
        print "REZLAB",result_lab 
        print"XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
    except KeyError as e:
        #print e
        pass

# %%
# setup mongo
client = MongoClient()
db = client["bandstour"]
bandsintown =  db["minedArtists"]

# credentials
TOPOGRAM_URL = "https://app.topogram.io"
USER = "gregory.bahde@laposte.net"
PASSWORD = "matrix"

# data
#title = "Foo Fighters bandstour 0.1"
my_nodesdict = {}
my_nodes= []
my_edges = []
my_edgesdict = {}
my_nodesdictGLOBAL={}

#LIVENATION CATALOGUE
liste_salles_LN = json.load(open('./JSON_LIVENATION_VENUE.json'))

liste_salle_parsee_LN={}
for salle in liste_salles_LN:
    if liste_salles_LN[salle]["type"]=="venue":
 
            liste_salle_parsee_LN[slugify(liste_salles_LN[salle]["title"])]={"lat":liste_salles_LN[salle]["position"]["lat"],"lng":liste_salles_LN[salle]["position"]["lng"]}
#print liste_salle_parsee_LN


# date parsing
DATETIME_FORMAT = '%Y-%m-%dT%H:%M:%S'
DATETIME_FORMAT_FOR_MSBNZ ='%Y-%m-%d'

#retrieve trip coords for each artist
dict_coords={}
colors_for_nodes_and_edges = get_N_HexCol()

#for artist in db.minedArtists.find({"totalKm": {"$gte": 250000}}) :
for artist in db.minedArtists.find({"name" : "Bad Brains"}) :
 title = artist["name"]   
 if os.path.exists(savpath+slugify(artist["name"]+str(artist["mbid"]))+".obj")==True:
        my_nodesdict = {}
        my_nodesdictList=[]
        print "SKIPPED PROCESSING BUT TAKING INTO ACCOUNT ",artist["name"]
        with open(savpath+slugify(artist["name"]+str(artist["mbid"]))+".obj", 'rb') as handle:
          tempL= pickle.load( handle)
    #print 
        tit=tempL[0].encode("utf-8")
        #edgestop=temp[2]
        my_nodesdictList=tempL[1]
        for node in my_nodesdictList:
            my_nodesdict[node["data"]["id"]]=node

        #print my_nodes
        #pass
 else:
    my_nodesdict = {}
    my_nodes= []
    my_edges = []
    my_nodesdictList=[]
    my_edgesdict = {}
    #colors_for_nodes_and_edges = get_N_HexCol()
    
    print artist["name"]
    #print artist
    dates_coords = []
    dates = artist.get("gigs")
    tours = artist.get("tours")    
    singlegigs = artist.get("singleGigs")
    dateini=0
    touring=0
    tour_indice=0
    tour_counter_for_CO2=1
    tour_counter_for_CO2_lock=0
    tmpOLDgig ={}
    with open("../../4_miner/tour_miner/"+slugify(artist["name"]+str(artist["mbid"]))+".obj", 'rb') as handle:
                    tempCO2= pickle.load( handle)
    #print tempCO2
    #print tours
    for tour in tours:
        
        ##WE NEED TO MATCH TOUR INDICES OF CO2 SPECS FILES...
     if tour_counter_for_CO2_lock == 1:
        tour_counter_for_CO2+=1
     tour_counter_for_CO2_lock=0
     tour_color = "#"+colors_for_nodes_and_edges[tour_indice % 20]
     #print tour_color
     #print tour
     gig_indice =0
     dates = tour.get("gigs")
     for date in dates:
        #print date.get("datetime")
        venue = date.get("venue")
        latitude = venue.get("latitude")
        longitude = venue.get("longitude")
        #print venue
        ###concat key
        idd= slugify(venue["name"])+str(int(venue["latitude"]))+str(int(venue["longitude"]))
        
        if idd not in my_nodesdict:
            
            node = {
                    "id" : idd,
                    "name" : slugify(venue["name"]),
                    "lat" : float(venue["latitude"]),
                    "lng" : float(venue["longitude"]),
                    "weight" : float(1),
                    "start" : date.get("datetime").isoformat(),
                    "end" : (date.get("datetime")+timedelta(days=1)).isoformat(),
                    "color" : tour_color,
                    "notes" : "name : "+slugify(venue["name"])+"  \nlat : "+str(float(venue["latitude"]))+"  \nlng :"+str(float(venue["longitude"]))+"  \n weight :"+str((float(my_nodesdict[idd]["data"].get("weight")))**2)+"  \nstart : "+str(my_nodesdict[idd]["data"].get("start"))+"  \nend : "+(date.get("datetime")+timedelta(days=1)).isoformat()+"  \ncolor :"+tour_color+"  \n  <a href=\"https://google.com/search?q="+slugify(venue["name"])+"\" target=\"_blank\"> "+slugify(venue["name"])+" </a>"
                #+"  \n[search venue named "+slugify(venue["name"])+" on google](https://google.com/search?q="+slugify(venue["name"])+")"
                    }
        else:
                
                node = {
                    "id" : idd,
                    "name" : slugify(venue["name"]),
                    "lat" : float(venue["latitude"]),
                    "lng" : float(venue["longitude"]),
                    "weight" : math.sqrt(float(int(round(float(my_nodesdict[idd]["data"].get("weight"))**2))+1)) ,
                    "start" : my_nodesdict[idd]["data"].get("start"),
                    "end" : (date.get("datetime")+timedelta(days=1)).isoformat(),
                    "color" : tour_color,
                    "notes" : "name : "+slugify(venue["name"])+"  \nlat : "+str(float(venue["latitude"]))+"  \nlng :"+str(float(venue["longitude"]))+"  \n weight :"+str((float(my_nodesdict[idd]["data"].get("weight")))**2+1)+"  \nstart : "+str(my_nodesdict[idd]["data"].get("start"))+"  \nend : "+(date.get("datetime")+timedelta(days=1)).isoformat()+"  \ncolor :"+tour_color+"  \n  <a href=\"https://google.com/search?q="+slugify(venue["name"])+"\" target=\"_blank\"> "+slugify(venue["name"])+" </a>"
                    #+"  \n[search venue named "+slugify(venue["name"])+" on google](https://google.com/search?q="+slugify(venue["name"])+")"
                    
                    }
        if dateini == 0:
                dateini =1
        else:
                #print my_nodes[-1]["data"]["id"]
                #print dates[gig_indice-1]["distanceToNextGig"]
                
                
                
                notesE=""
                notesE+="distance : "
                try: 
                    notesE+=str(dates[gig_indice]["distanceToNextGig"])
                except KeyError:
                    notesE+="dates[gig_indice][distanceToNextGig] NOT AVAILABLE"
                notesE+=" km  \n"
                notesE+="source : "
                notesE+=str(my_nodes[-1]["data"]["id"])
                notesE+="  target : "
                notesE+=str(node["id"])
                notesE+="  \ndatesource : "
                notesE+=dates[gig_indice -1]["datetime"].isoformat()
                notesE+="  \ndatetarget : "
                notesE+=dates[gig_indice]["datetime"].isoformat()
                notesE+="  \ngroup: "
                notesE+=str(int(tour_indice)+1)
                #notesE+=
                
                
                #print gig_indice
                edge = {
                    "source" : my_nodes[-1]["data"]["id"],
                    "target" : node["id"],
                    "color" :  tour_color,
                    "notes" : notesE,
                    #"weight" : float(e["weight"]),
                    "start" : dates[gig_indice -1]["datetime"].isoformat(),
                    "end" : dates[gig_indice]["datetime"].isoformat(),
                    "group" : str(tour_counter_for_CO2)
                    
                }
                #print edge
                #ADDING EDGES GROUPS/CO2 HERE
                
                if tour["nbGigs"] > 2:
                    try:
                        if tempCO2[tour_counter_for_CO2]['tourdist'] > 1.25*tempCO2[tour_counter_for_CO2]['tourdistOpt']:
                            
                            edge["group"]+=" DASHED2"
                            edge["notes"]+="  \n tournée grandement optimisable  \nDistance parcourue pendant le tour: "+str(tempCO2[tour_counter_for_CO2]['tourdist'])+" km  \n"
                            edge["notes"]+="Distance recalculée: "+str(tempCO2[tour_counter_for_CO2]['tourdistOpt'])+" km  \n"
                            try:
                                edge["notes"]+="Taux d'optimisation "+str((tempCO2[tour_counter_for_CO2]['tourdist']-tempCO2[tour_counter_for_CO2]['tourdistOpt'])/tempCO2[tour_counter_for_CO2]['tourdist'])+" %"
                            except:
                                print "OUPS 2"
                        elif (tempCO2[tour_counter_for_CO2]['tourdist'] < 1.25*tempCO2[tour_counter_for_CO2]['tourdistOpt']) and (tempCO2[tour_counter_for_CO2]['tourdist'] > 1.1*tempCO2[tour_counter_for_CO2]['tourdistOpt']):
                            
                            edge["group"]+=" DASHED1"
                            edge["notes"]+="  \n  tournée optimisable  \nDistance parcourue pendant le tour: "+str(tempCO2[tour_counter_for_CO2]['tourdist'])+" km  \n"
                            edge["notes"]+="Distance recalculée: "+str(tempCO2[tour_counter_for_CO2]['tourdistOpt'])+" km  \n"
                            try:
                                edge["notes"]+="Taux d'optimisation "+str((tempCO2[tour_counter_for_CO2]['tourdist']-tempCO2[tour_counter_for_CO2]['tourdistOpt'])/tempCO2[tour_counter_for_CO2]['tourdist'])+" %"
                            except:
                                print "OUPS 1"
                        elif tempCO2[tour_counter_for_CO2]['tourdistOpt'] > 1.25*tempCO2[tour_counter_for_CO2]['tourdist']:
                            
                            edge["group"]+=" DASHED-2"
                            edge["notes"]+="  \n tournée déjà grandement optimisée  \nDistance parcourue pendant le tour: "+str(tempCO2[tour_counter_for_CO2]['tourdist'])+" km  \n"
                            edge["notes"]+="Distance recalculée: "+str(tempCO2[tour_counter_for_CO2]['tourdistOpt'])+" km  \n"
                            try:
                                edge["notes"]+="Taux d'optimisation "+str((tempCO2[tour_counter_for_CO2]['tourdist']-tempCO2[tour_counter_for_CO2]['tourdistOpt'])/tempCO2[tour_counter_for_CO2]['tourdist'])+" %"
                            except:
                                print "OUPS -2"
                        elif tempCO2[tour_counter_for_CO2]['tourdistOpt'] < 1.25*tempCO2[tour_counter_for_CO2]['tourdist'] and tempCO2[tour_counter_for_CO2]['tourdistOpt'] > 1.1*tempCO2[tour_counter_for_CO2]['tourdist']:
                            
                            edge["group"]+=" DASHED-1"
                            edge["notes"]+="  \n  tournée déjà optimisée  \nDistance parcourue pendant le tour: "+str(tempCO2[tour_counter_for_CO2]['tourdist'])+" km  \n"
                            edge["notes"]+="Distance recalculée: "+str(tempCO2[tour_counter_for_CO2]['tourdistOpt'])+" km  \n"
                            try:
                                edge["notes"]+="Taux d'optimisation "+str((tempCO2[tour_counter_for_CO2]['tourdist']-tempCO2[tour_counter_for_CO2]['tourdistOpt'])/tempCO2[tour_counter_for_CO2]['tourdist'])+" %"
                            except:
                                print "OUPS -1"
                        
                        else:

                            edge["notes"]+="  \nDistance parcourue pendant le tour: "+str(tempCO2[tour_counter_for_CO2]['tourdist'])+" km  \n"
                        tour_counter_for_CO2_lock=1
                    except KeyError as e:
                        print e
                else:
                    #print "TOUR NON COMPTE ", tour_indice, "//",tour_counter_for_CO2
                    continue
                    
                    
                    
                my_edges.append({ "data" : edge })
        my_nodes.append({ "data" : node })   
        my_nodesdict[node["id"]]= { "data" : node }
        gig_indice+=1
    #print my_nodes
    #print "<=============================================>"
    #print my_nodesdict
    #print "<=============================================>"
    #print my_edges
     tour_indice +=1
        #print "coords",latitude,"/",longitude
    for key, value in my_nodesdict.iteritems():
            my_nodesdictList.append(value)
    
    #ADDING LIVENATION DETECTOR

    for node in my_nodesdictList:
        for salle in liste_salle_parsee_LN:
            if fuzz.partial_ratio( node['data']['name'], salle)>=80:
                #print "ONE HEERE"
                if round(node['data']['lat'],2)==round(liste_salle_parsee_LN[salle]["lat"],2) and round(node['data']['lng'],2)==round(liste_salle_parsee_LN[salle]["lng"],2) :
                    #print "CONFIRMED LIVENATION!"
                    node['data']['color']="#ff0000"
                    node['data']["notes"]+="  \nLivenation venue"
        #if liste_salle_parsee_LN
        
        
    #ADDING EDGES WEIGHT
    terp= map(lambda x : str(sorted([x["data"]["source"],x["data"]["target"]])),my_edges)
    
    #print terp
    from collections import Counter
    c= Counter()
    for ter in terp:
        c[ter]+=1
    #print c
    for edge in my_edges:
        if str(sorted([edge["data"]["source"],edge["data"]["target"]])) not in terp:
            print "BUG!!!!"
        else:
            if edge["data"]["source"] == edge["data"]["target"]:
                #print c[str(sorted([edge["data"]["source"],edge["data"]["target"]]))]
                edge["data"]["notes"]+="  \ncounted "+str(c[str(sorted([edge["data"]["source"],edge["data"]["target"]]))])+"  times"
                edge["data"]["weight"]= float(1)
                #print "a"
            else:
                edge["data"]["notes"]+="  \ncounted "+str(c[str(sorted([edge["data"]["source"],edge["data"]["target"]]))])+"  times"
                edge["data"]["weight"]= float(c[str(sorted([edge["data"]["source"],edge["data"]["target"]]))])
                #print "b"
    #print my_edges

    
    
    
    

    titredugraphe =artist["name"]+"/BETA_0.4"+"  \nDistance totale parcourue par l'artiste: "+str(tempCO2["totalArtistTourDist"])+" km"
    titredugraphe += "  \nDistance calculee par Concorde: "+str(tempCO2["totalArtistOptTourDist"])+" km"
    if  "OptArtistPercent" in tempCO2 :
         rateOpt=0
         rateOpt=float(tempCO2["OptArtistPercent"])
         titredugraphe+="  \nPourcentage d'optimisation global calcule:"+str(rateOpt)+" %"
         if rateOpt > 10: 
             titredugraphe+="  \nMARGE D'OPTIMISATION IMPORTANTE"
         elif rateOpt < -10:
              titredugraphe+="  \nTOURNEE DEJA OPTIMISEE"
         else: 
             titredugraphe+="  \nGLOBALEMENT IDENTIQUE"
         
         
    with open(savpath+slugify(artist["name"]+str(artist["mbid"]))+".obj", 'wb') as handle:
                            pickle.dump([titredugraphe,my_nodesdictList,my_edges], handle, protocol=pickle.HIGHEST_PROTOCOL)    
            
    ###CREATE NODE GLOBAL DICT
# Out:
# SKIPPED PROCESSING BUT TAKING INTO ACCOUNT  Bad Brains

# %%
     with open("./my_nodesdictGLOBAL.obj", 'rb') as handle:
          my_nodesdictGLOBAL= pickle.load( handle)

# %%
from itertools import islice

def take(n, iterable):
    "Return first n items of the iterable as a list"
    return list(islice(iterable, n))

print take(5,my_nodesdictGLOBAL.iteritems())
# Out:
# [('pete-s-place32-117', {'data': {'count': 1, 'end': '2017-04-01T19:00:00', 'name': 'pete-s-place', 'weight': 1.0, 'color': '#7f523f', 'notes': '  \n List of the bands that played in this venue:  \nblack-joe-lewis  \n TOTAL: 1 Bands', 'start': '2017-03-31T19:00:00', 'lat': 32.7677778, 'lng': -117.0222222, 'id': 'pete-s-place32-117'}}), ('tucson-music-hall32-110', {'data': {'count': 35, 'end': '2018-01-15T14:00:00', 'name': 'tucson-music-hall', 'weight': 7.158396516477644, 'color': '#3f7f6c', 'notes': '  \n List of the bands that played in this venue:  \ncherish-the-ladies  \nitzhak-perlman  \nbill-maher  \ncurtis-stigers  \njonathan-richman  \nthe-lettermen  \npiotr-ilich-chaikovskii  \nthe-midtown-men  \njoseph-haydn  \ngeorge-lopez  \nsuper-diamond  \njane-s-addiction  \nlindsey-stirling  \narturo-sandoval  \nlewis-black  \ndon-giovanni  \njerry-seinfeld  \nkt-tunstall  \nvideo-games-live  \nthe-ten-tenors  \nbellamy-brothers-band  \nbrian-regan  \nmichael-feinstein  \nrain  \njackson-browne  \nwilco  \nthe-1975  \njohn-pizzarelli  \njohn-legend  \njames-taylor  \ncarmina-burana  \nceltic-woman  \njudy-collins  \npink-martini  \njoe-bonamassa  \n TOTAL: 35 Bands', 'start': '2007-12-17T00:00:00', 'lat': 32.2216667, 'lng': -110.9258333, 'id': 'tucson-music-hall32-110'}}), ('bluegrass-festival37-107', {'data': {'count': 1, 'end': '2008-04-14T19:00:00', 'name': 'bluegrass-festival', 'weight': 1.5537739740300374, 'color': '#3f7f46', 'notes': '  \n List of the bands that played in this venue:  \nthe-infamous-stringdusters  \n TOTAL: 1 Bands', 'start': '2008-04-11T19:00:00', 'lat': 37.2752778, 'lng': -107.8794444, 'id': 'bluegrass-festival37-107'}}), ('salle-des-dominicains440', {'data': {'count': 2, 'end': '2013-07-22T18:00:00', 'name': 'salle-des-dominicains', 'weight': 2.19736822693562, 'color': '#3f7f46', 'notes': '  \n List of the bands that played in this venue:  \nchic  \nchick-corea  \n TOTAL: 2 Bands', 'start': '2013-07-18T18:00:00', 'lat': 44.895123, 'lng': -0.155287, 'id': 'salle-des-dominicains440'}}), ('gem-brunch42-71', {'data': {'count': 1, 'end': '2015-05-04T16:00:00', 'name': 'gem-brunch', 'weight': 1.4142135623730951, 'color': '#727f3f', 'notes': '  \n List of the bands that played in this venue:  \nchachi  \n TOTAL: 1 Bands', 'start': '2015-03-29T17:00:00', 'lat': 42.3569387, 'lng': -71.0599056, 'id': 'gem-brunch42-71'}})]

# %%
# credentials
TOPOGRAM_URL = "http://localhost:3000"
USER = "gregory.bahde@laposte.net"
PASSWORD = "matrix"

# %%
print len(my_nodesdictGLOBAL)

# %%
# connect to the topogram instance (pass debug=True params for more info )
topogram = TopogramAPIClient(TOPOGRAM_URL) #, debug=True)

# create a new user
try :
    topogram.create_user(USER, PASSWORD)
except ValueError:
    print "> User has already been created."

# login a new user if needed
resp_user_login = topogram.user_login(USER, PASSWORD)
print resp_user_login

assert(resp_user_login["status"] == "success")
assert(resp_user_login["status_code"] == 200)
# Out:
# ERROR:topogram-client:403 Unauthorized request
# > User has already been created.
# {u'status': u'success', 'status_code': 200, u'data': {u'authToken': u'mym8r5tXEMa2ZCCY83e_0lo5gYtuTuN-Q3lGdEbEMOU', u'userId': u'Bf5svhLniEkkcvts2'}}

# %%
###IMPORT ALL THE BANDS GRAPHS

nodestop=[]
edgestop=[]
tit=[]
import glob, os

print os.getcwd()

#file= "./bands_dicts/dead-kennedys37c78aeb-d196-42b5-b991-6afb4fc9bc2e.obj"
file="./bands_dicts/the-real-mckenzies01612542-01ec-4fc4-a9ad-b6a6e33f11d7.obj"
with open(file, 'rb') as handle:
          temp= pickle.load( handle)
    #print 
tit=temp[0].encode("utf-8")
edgestop=temp[2]
nodestop=temp[1]
    #print edgestop
    #for edge in edgestop:
    #    assert edge["data
while True:
        try:
            #print
            create_topogram(tit, nodestop, edgestop)
        except TypeError:
            continue
        break
print 'DONE'
# Out:
# ERROR:topogram-client:500 - Error : A topogram with the same name already exists
# /home/goonieb/gitrep/bandstour/5_visualizer/topogram-api-clientFOR_TOPO_FROM_BANDSTOUR
# Creating topogram 'The Real McKenzies/BETA_0.8
# Distance totale parcourue par l'artiste: 180691.650535 km
# Distance calculee par Concorde: 156448.795249 km
# Pourcentage d'optimisation global calculee:13.4166992303 %
# MARGE D'OPTIMISATION IMPORTANTE'
# > Topogram already exists
# {u'status': u'success', 'status_code': 200, u'data': {u'sharedPublic': False, u'title': u"The Real McKenzies/BETA_0.8  \nDistance totale parcourue par l'artiste: 180691.650535 km  \nDistance calculee par Concorde: 156448.795249 km  \nPourcentage d'optimisation global calculee:13.4166992303 %  \nMARGE D'OPTIMISATION IMPORTANTE", u'userId': u'Bf5svhLniEkkcvts2', u'_id': u'Newbq9eHeCDWZH9EC', u'slug': u'the-real-mckenziesbeta_08-distance-totale-parcourue-par-lartiste-180691650535-km-distance-calculee-par-concorde-156448795249-km-pourcentage-doptimisation-global-calculee134166992303-marge-doptimisation-importante', u'createdAt': u'2019-09-23T20:22:27.710Z'}, u'statusCode': 200}
# topogram ID : Newbq9eHeCDWZH9EC
# 273 nodes deleted
# 323 edges deleted
# 273 nodes created.
# 323 edges created.
# done. Topogram has been updated. Check it at http://localhost:3000/topograms/Newbq9eHeCDWZH9EC
# DONE

# %%
###IMPORT THE GLOBAL VENUE  GRAPH
my_nodesdictList=[]
nodestopo=[]
edgestopo=[]
with open("./my_nodesdictGLOBAL.obj", 'rb') as handle:
          my_nodesdictGLOBAL= pickle.load( handle)
        
for key, value in my_nodesdictGLOBAL.iteritems():
            my_nodesdictGLOBAL[key]["data"].pop('count')
        
for key, value in my_nodesdictGLOBAL.iteritems():
            my_nodesdictList.append(value)
        
nodestopo=sorted(my_nodesdictList, key= lambda (v) : v['data']['weight'], reverse=True)[:3000]
print len(nodestopo)



title="global venue graph /BETA 0.8"

while True:
        try:
            print nodestopo
            create_topogram(title, nodestopo, edgestopo)
        
        except TypeError:
            continue
        break
# Out:
# ERROR:topogram-client:500 - Error : A topogram with the same name already exists
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# {u'status': u'success', 'status_code': 200, u'data': {u'sharedPublic': False, u'title': u'global venue graph /BETA 0.8', u'userId': u'Bf5svhLniEkkcvts2', u'_id': u'E3ZrufFMWjZa2gFFi', u'slug': u'global-venue-graph-beta-08', u'createdAt': u'2019-09-24T07:02:52.932Z'}, u'statusCode': 200}
# topogram ID : E3ZrufFMWjZa2gFFi
# 6057 nodes deleted
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-e339b751a75a> in <module>()
#      22         try:
#      23             print nodestopo
# ---> 24             create_topogram(title, nodestopo, edgestopo)
#      25
#      26         except TypeError:
#
# <ipython-input-3-09bf76edf12d> in create_topogram(title, nodes, edges)
#      24         print "%s edges deleted"%len(existing_edges)
#      25
# ---> 26     r = topogram.create_nodes(topogram_ID, nodes)
#      27     #print r
#      28     print "%s nodes created."%len(r["data"])
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/topogram_api_client-1.0.1-py2.7.egg/topogram_client/__init__.pyc in create_nodes(self, topogramId, nodes)
#     146         """POST Create a bunch of nodes. Returns the created nodes"""
#     147         assert type(nodes) is list
# --> 148         return self.make_request("POST", "nodes", { "topogramId" : topogramId, "nodes" : nodes})
#     149
#     150     def get_node(self, _id):
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/topogram_api_client-1.0.1-py2.7.egg/topogram_client/__init__.pyc in make_request(self, method, path, data)
#      55
#      56         if r.status_code >= 500 : # handle 403 error
# ---> 57             err = "%s - Error : %s"%(r.status_code, r.json()["message"])
#      58             log.error(err)
#      59             raise ValueError(err)
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/requests/models.pyc in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /home/goonieb/anaconda2/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# /home/goonieb/anaconda2/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     365         end = _w(s, end).end()
#     366         if end != len(s):
#
# /home/goonieb/anaconda2/lib/python2.7/json/decoder.pyc in raw_decode(self, s, idx)
#     380             obj, end = self.scan_once(s, idx)
#     381         except StopIteration:
# --> 382             raise ValueError("No JSON object could be decoded")
#     383         return obj, end
#
# ValueError: No JSON object could be decoded

# %%
###IMPORT THE GLOBAL VENUE  GRAPH
my_nodesdictList=[]
nodestopo=[]
edgestopo=[]
with open("./my_nodesdictGLOBAL.obj", 'rb') as handle:
          my_nodesdictGLOBAL= pickle.load( handle)
        
for key, value in my_nodesdictGLOBAL.iteritems():
            my_nodesdictGLOBAL[key]["data"].pop('count')
        
for key, value in my_nodesdictGLOBAL.iteritems():
            my_nodesdictList.append(value)
        
nodestopo=sorted(my_nodesdictList, key= lambda (v) : v['data']['weight'], reverse=True)[:5000]
print len(nodestopo)
# Out:
# 5000

# %%
for node in nodestopo:
    #print node["data"]["weight"]
    node["data"]["weight"]=(node["data"]["weight"]/10)
    #print len(node["data"]["notes"])
    print node["data"]["name"],"//", node["data"]["notes"][-16:]
    node["data"]["notes"]=node["data"]["notes"][-16:]
    #print node["data"]["weight"]
# Out:
# 9-30-club // TOTAL: 978 Bands
# masquerade // TOTAL: 798 Bands
# webster-hall // TOTAL: 873 Bands
# house-of-blues-dallas // TOTAL: 809 Bands
# the-fillmore // TOTAL: 750 Bands
# the-observatory // TOTAL: 755 Bands
# the-norva // TOTAL: 735 Bands
# paradise-rock-club // TOTAL: 735 Bands
# ogden-theatre // TOTAL: 724 Bands
# the-pageant // TOTAL: 713 Bands
# higher-ground // TOTAL: 666 Bands
# the-national // TOTAL: 693 Bands
# cain-s-ballroom // TOTAL: 662 Bands
# red-rocks-amphitheatre // TOTAL: 634 Bands
# first-avenue // TOTAL: 648 Bands
# house-of-blues-boston // TOTAL: 679 Bands
# the-orange-peel // TOTAL: 660 Bands
# the-social // TOTAL: 618 Bands
# melkweg // TOTAL: 705 Bands
# troubadour // TOTAL: 620 Bands
# theatre-of-living-arts // TOTAL: 651 Bands
# paradiso // TOTAL: 696 Bands
# shoreline-amphitheatre // TOTAL: 594 Bands
# roseland-theater // TOTAL: 649 Bands
# the-intersection // TOTAL: 587 Bands
# bowery-ballroom // TOTAL: 593 Bands
# marquee-theatre // TOTAL: 593 Bands
# hawthorne-theatre // TOTAL: 531 Bands
# commodore-ballroom // TOTAL: 604 Bands
# terminal-5 // TOTAL: 576 Bands
# el-corazon // TOTAL: 505 Bands
# merriweather-post-pavilion // TOTAL: 610 Bands
# the-independent // TOTAL: 558 Bands
# blueburd-theater // TOTAL: 571 Bands
# electric-factory // TOTAL: 584 Bands
# house-of-blues // TOTAL: 612 Bands
# the-catalyst // TOTAL: 587 Bands
# starland-ballroom // TOTAL: 498 Bands
# world-cafe-live // TOTAL: 518 Bands
# newport-music-hall // TOTAL: 552 Bands
# highline-ballroom // TOTAL: 587 Bands
# house-of-blues-sunset-strip // TOTAL: 528 Bands
# house-of-blues // TOTAL: 576 Bands
# house-of-blues-houston // TOTAL: 584 Bands
# music-hall-of-williamsburg // TOTAL: 553 Bands
# belly-up // TOTAL: 508 Bands
# cat-s-cradle // TOTAL: 522 Bands
# neumos // TOTAL: 551 Bands
# slim-s // TOTAL: 523 Bands
# rams-head-live // TOTAL: 552 Bands
# u-street-music-hall // TOTAL: 522 Bands
# trees // TOTAL: 533 Bands
# warehouse-live // TOTAL: 541 Bands
# mohegan-sun-arena // TOTAL: 459 Bands
# the-blue-note // TOTAL: 531 Bands
# the-rave-eagles-club // TOTAL: 499 Bands
# ext-in // TOTAL: 535 Bands
# house-of-blues-chicago // TOTAL: 540 Bands
# wonder-ballroom // TOTAL: 539 Bands
# middle-east // TOTAL: 549 Bands
# irving-plaza // TOTAL: 518 Bands
# ryman-auditorium // TOTAL: 470 Bands
# o2-academy-brixton // TOTAL: 501 Bands
# grog-shop // TOTAL: 499 Bands
# house-of-blues-new-orleans // TOTAL: 530 Bands
# birchmere // TOTAL: 387 Bands
# fox-theatre // TOTAL: 492 Bands
# bogart-s // TOTAL: 505 Bands
# the-tabernacle // TOTAL: 512 Bands
# house-of-blues-cleveland // TOTAL: 531 Bands
# cullture-room // TOTAL: 476 Bands
# rams-head-on-stage // TOTAL: 406 Bands
# union-transfer // TOTAL: 503 Bands
# lincoln-theatre // TOTAL: 478 Bands
# brooklyn-bowl // TOTAL: 432 Bands
# gothic-theatre // TOTAL: 533 Bands
# fabric // TOTAL: 393 Bands
# belly-up-tavern // TOTAL: 455 Bands
# house-of-blues-san-diego // TOTAL: 536 Bands
# granada-theater // TOTAL: 494 Bands
# pnc-bank-arts-center // TOTAL: 485 Bands
# ace-of-spades // TOTAL: 465 Bands
# rock-city // TOTAL: 462 Bands
# dte-energy-music-theatre // TOTAL: 470 Bands
# knitting-factory-concert-house // TOTAL: 497 Bands
# metropolis // TOTAL: 491 Bands
# chameleon-club // TOTAL: 432 Bands
# rialto-theater // TOTAL: 505 Bands
# great-american-music-hall // TOTAL: 453 Bands
# the-masquerade // TOTAL: 418 Bands
# baltimore-soundstage // TOTAL: 498 Bands
# marquis-theater // TOTAL: 408 Bands
# riverbend-music-center // TOTAL: 442 Bands
# variety-playhouse // TOTAL: 447 Bands
# output // TOTAL: 408 Bands
# metro // TOTAL: 477 Bands
# doug-fir-lounge // TOTAL: 429 Bands
# amnesia // TOTAL: 352 Bands
# stage-ae // TOTAL: 449 Bands
# el-rey-theatre // TOTAL: 505 Bands
# bottom-lounge // TOTAL: 482 Bands
# showbox-sodo // TOTAL: 471 Bands
# o2-academy-birmingham // TOTAL: 454 Bands
# in-the-venue // TOTAL: 426 Bands
# brighton-music-hall // TOTAL: 477 Bands
# house-of-blues-myrtle-beach // TOTAL: 421 Bands
# coachella // TOTAL: 336 Bands
# susquehanna-bank-center // TOTAL: 444 Bands
# hollywood-bowl // TOTAL: 412 Bands
# black-sheep // TOTAL: 407 Bands
# beachland-ballroom // TOTAL: 425 Bands
# manchester-academy // TOTAL: 453 Bands
# the-regency-ballroom // TOTAL: 460 Bands
# b-b-king-blues-club-and-grill // TOTAL: 375 Bands
# house-of-blues-orlando // TOTAL: 447 Bands
# mercury-lounge // TOTAL: 421 Bands
# headliners-music-hall // TOTAL: 442 Bands
# tractor-tavern // TOTAL: 371 Bands
# the-sinclair // TOTAL: 431 Bands
# crescent-ballroom // TOTAL: 432 Bands
# showbox-at-the-market // TOTAL: 445 Bands
# fox-theater // TOTAL: 427 Bands
# house-of-blues // TOTAL: 440 Bands
# amos-southend // TOTAL: 414 Bands
# vinyl-music-hall // TOTAL: 414 Bands
# sunshine-theater // TOTAL: 397 Bands
# revolution-live // TOTAL: 448 Bands
# ministry-of-sound // TOTAL: 350 Bands
# aladdin-theater // TOTAL: 372 Bands
# house-of-blues // TOTAL: 416 Bands
# koko // TOTAL: 457 Bands
# magic-stick // TOTAL: 415 Bands
# fillmore-auditorium // TOTAL: 411 Bands
# mr-smalls-theatre // TOTAL: 431 Bands
# launchpad // TOTAL: 372 Bands
# gorge-amphitheatre // TOTAL: 410 Bands
# the-complex // TOTAL: 412 Bands
# playstation-theater // TOTAL: 404 Bands
# gramercy-theatre // TOTAL: 404 Bands
# space // TOTAL: 338 Bands
# o2-academy-bristol // TOTAL: 416 Bands
# granada // TOTAL: 409 Bands
# house-of-blues // TOTAL: 414 Bands
# the-paramount // TOTAL: 385 Bands
# wooly-s // TOTAL: 394 Bands
# sellersville-theater-1894 // TOTAL: 320 Bands
# the-ark // TOTAL: 302 Bands
# o2-academy-oxford // TOTAL: 388 Bands
# black-cat // TOTAL: 342 Bands
# the-wiltern // TOTAL: 409 Bands
# house-of-blues // TOTAL: 387 Bands
# rex-theater // TOTAL: 401 Bands
# house-of-blues // TOTAL: 374 Bands
# knitting-factory-concert-house // TOTAL: 401 Bands
# the-palladium // TOTAL: 316 Bands
# the-warfield // TOTAL: 408 Bands
# mercy-lounge // TOTAL: 380 Bands
# o2-academy-newcastle // TOTAL: 368 Bands
# terminal-west // TOTAL: 380 Bands
# the-chance // TOTAL: 349 Bands
# comcast-center // TOTAL: 381 Bands
# greek-theatre // TOTAL: 369 Bands
# lincoln-hall // TOTAL: 387 Bands
# boulder-theater // TOTAL: 378 Bands
# the-fillmore-charlotte // TOTAL: 402 Bands
# casbah // TOTAL: 340 Bands
# upstate-concert-hall // TOTAL: 373 Bands
# eagles-club-the-rave-eagles-ballroom // TOTAL: 355 Bands
# state-theatre // TOTAL: 377 Bands
# concorde-2 // TOTAL: 363 Bands
# royal-oak-music-theatre // TOTAL: 406 Bands
# o2-academy-islington // TOTAL: 371 Bands
# soma // TOTAL: 313 Bands
# wow-hall // TOTAL: 366 Bands
# o2-shepherds-bush-empire // TOTAL: 370 Bands
# at-t-center // TOTAL: 355 Bands
# beacon-theatre // TOTAL: 311 Bands
# emos-austin // TOTAL: 347 Bands
# ruby-skye // TOTAL: 280 Bands
# keswick-theatre // TOTAL: 313 Bands
# anciennebelgique // TOTAL: 388 Bands
# northwell-health-jones-beach-theater // TOTAL: 367 Bands
# city-winery // TOTAL: 288 Bands
# house-of-blues-anaheim // TOTAL: 361 Bands
# aggie-theatre // TOTAL: 342 Bands
# mezzanine // TOTAL: 361 Bands
# the-studio-at-webster-hall // TOTAL: 386 Bands
# gexa-energy-pavilion // TOTAL: 369 Bands
# iron-horse-music-hall // TOTAL: 314 Bands
# port-city-music-hall // TOTAL: 357 Bands
# blossom-music-center // TOTAL: 337 Bands
# high-noon-saloon // TOTAL: 350 Bands
# the-fillmore-detroit // TOTAL: 370 Bands
# space // TOTAL: 269 Bands
# o2-academy-leeds // TOTAL: 347 Bands
# club-cafe // TOTAL: 305 Bands
# zydeco // TOTAL: 326 Bands
# the-mid // TOTAL: 312 Bands
# town-ballroom // TOTAL: 364 Bands
# back-porch-stage-at-house-of-blues-chicago // TOTAL: 332 Bands
# fubar // TOTAL: 282 Bands
# varsity-theater // TOTAL: 370 Bands
# northern-lights // TOTAL: 319 Bands
# triple-rock-social-club // TOTAL: 333 Bands
# double-door // TOTAL: 346 Bands
# the-glass-house // TOTAL: 356 Bands
# pjohnny-brenda-s // TOTAL: 317 Bands
# ottobar // TOTAL: 322 Bands
# the-white-rabbit // TOTAL: 277 Bands
# first-midwest-bank-amphitheatre // TOTAL: 327 Bands
# lupo-s-heartbreak-hotel // TOTAL: 336 Bands
# club-congress // TOTAL: 327 Bands
# club-nokia // TOTAL: 359 Bands
# the-crocodile // TOTAL: 355 Bands
# o2-academy-glasgow // TOTAL: 337 Bands
# ridgefield-playhouse // TOTAL: 289 Bands
# brudenell-social-club // TOTAL: 313 Bands
# roundhouse // TOTAL: 342 Bands
# lee-s-palace // TOTAL: 324 Bands
# trocadero // TOTAL: 329 Bands
# jammin-java // TOTAL: 266 Bands
# metro-theatre // TOTAL: 348 Bands
# 3rd-lindsley // TOTAL: 290 Bands
# watergate // TOTAL: 229 Bands
# the-firebird // TOTAL: 316 Bands
# house-of-blues // TOTAL: 336 Bands
# rockwood-music-hall // TOTAL: 320 Bands
# mountain-winery // TOTAL: 271 Bands
# scout-bar // TOTAL: 265 Bands
# house-of-blues // TOTAL: 341 Bands
# hampton-beach-casino-ballroom // TOTAL: 280 Bands
# studio-seven // TOTAL: 261 Bands
# key-club // TOTAL: 320 Bands
# the-workplay-theatre // TOTAL: 298 Bands
# pops // TOTAL: 276 Bands
# belly-up // TOTAL: 306 Bands
# diamond-ballroom // TOTAL: 296 Bands
# saint-andrews-hall // TOTAL: 345 Bands
# pacha // TOTAL: 240 Bands
# the-palace-of-auburn-hills // TOTAL: 323 Bands
# the-fillmore-silver-spring // TOTAL: 320 Bands
# vega // TOTAL: 350 Bands
# the-chicago-theatre // TOTAL: 297 Bands
# klipsch-music-center // TOTAL: 303 Bands
# echoplex // TOTAL: 318 Bands
# the-fillmore-new-york-at-irving-plaza // TOTAL: 307 Bands
# subterranean // TOTAL: 323 Bands
# bridgestone-arena // TOTAL: 288 Bands
# house-of-blues // TOTAL: 302 Bands
# concord-music-hall // TOTAL: 331 Bands
# cruzan-amphitheatre // TOTAL: 302 Bands
# backbooth // TOTAL: 291 Bands
# bourbon-theatre // TOTAL: 316 Bands
# the-earl // TOTAL: 283 Bands
# off-broadway // TOTAL: 262 Bands
# mississippi-studios // TOTAL: 295 Bands
# the-rock // TOTAL: 264 Bands
# slowdown // TOTAL: 330 Bands
# uptown-theater // TOTAL: 336 Bands
# knuckleheads-saloon // TOTAL: 237 Bands
# jiffy-lube-live // TOTAL: 286 Bands
# knitting-factory-concert-house // TOTAL: 325 Bands
# freebird-live // TOTAL: 279 Bands
# the-basement // TOTAL: 304 Bands
# 013 // TOTAL: 326 Bands
# the-depot // TOTAL: 315 Bands
# turner-hall-ballroom // TOTAL: 315 Bands
# enmore-theatre // TOTAL: 298 Bands
# madison-square-garden // TOTAL: 269 Bands
# the-riot-room // TOTAL: 314 Bands
# chain-reaction // TOTAL: 227 Bands
# neighborhood-theatre // TOTAL: 296 Bands
# yoshi-s-oakland // TOTAL: 208 Bands
# sound-acadmey // TOTAL: 320 Bands
# air-canada-centre // TOTAL: 261 Bands
# manchester-academy-3 // TOTAL: 320 Bands
# the-summit-muic-hall // TOTAL: 278 Bands
# first-niagara-pavilion // TOTAL: 290 Bands
# echostage // TOTAL: 271 Bands
# bergen-performing-arts-center // TOTAL: 263 Bands
# exchange-la // TOTAL: 251 Bands
# beta // TOTAL: 248 Bands
# cedar-cultural-center // TOTAL: 267 Bands
# infinity-hall // TOTAL: 236 Bands
# the-starlite-room // TOTAL: 308 Bands
# station-4 // TOTAL: 246 Bands
# trucky-falls // TOTAL: 297 Bands
# humphreys-concerts-by-the-bay // TOTAL: 262 Bands
# xoyo // TOTAL: 271 Bands
# state-theatre // TOTAL: 296 Bands
# water-street-music-hall // TOTAL: 292 Bands
# hollywood-palladium // TOTAL: 296 Bands
# the-coach-house // TOTAL: 260 Bands
# la-maroquinerie // TOTAL: 325 Bands
# varsity-theatre // TOTAL: 266 Bands
# mcmenamins-crystal-ballroom // TOTAL: 279 Bands
# cambridge-room-at-house-of-blues-cleveland // TOTAL: 296 Bands
# bottom-of-the-hill // TOTAL: 263 Bands
# mcdonald-theatre // TOTAL: 298 Bands
# tipitinas // TOTAL: 266 Bands
# antone-s // TOTAL: 264 Bands
# the-grey-eagle // TOTAL: 257 Bands
# local-506 // TOTAL: 281 Bands
# house-of-blues-las-vegas // TOTAL: 289 Bands
# palladium // TOTAL: 261 Bands
# fitzgerald-s // TOTAL: 297 Bands
# paradiso-grote-zaal // TOTAL: 296 Bands
# avalon-hollywood // TOTAL: 253 Bands
# cervantes-masterpiece-ballroom // TOTAL: 250 Bands
# altar-bar // TOTAL: 267 Bands
# sprint-center // TOTAL: 265 Bands
# public-works // TOTAL: 259 Bands
# afas-live // TOTAL: 270 Bands
# new-city-gas // TOTAL: 234 Bands
# the-opera-house // TOTAL: 286 Bands
# ruth-eckerd-hall // TOTAL: 254 Bands
# alamo-city-music-hall // TOTAL: 259 Bands
# vinoy-park // TOTAL: 277 Bands
# stereo-live // TOTAL: 241 Bands
# xfinity-center // TOTAL: 293 Bands
# phoenix-concert-theatre // TOTAL: 297 Bands
# mill-city-nights // TOTAL: 290 Bands
# electric-ballroom // TOTAL: 305 Bands
# the-hamilton // TOTAL: 245 Bands
# the-orpheum // TOTAL: 252 Bands
# saratoga-performing-arts-center // TOTAL: 276 Bands
# city-winery // TOTAL: 237 Bands
# shank-hall // TOTAL: 246 Bands
# one-eyed-jacks // TOTAL: 264 Bands
# massey-hall // TOTAL: 240 Bands
# ventura-theater // TOTAL: 282 Bands
# matathon-music-works // TOTAL: 309 Bands
# webster-theater // TOTAL: 259 Bands
# live-music-hall // TOTAL: 283 Bands
# count-basie-theatre // TOTAL: 239 Bands
# howard-theatre // TOTAL: 265 Bands
# jack-rabbits // TOTAL: 274 Bands
# the-arches // TOTAL: 285 Bands
# great-scott // TOTAL: 266 Bands
# arena // TOTAL: 257 Bands
# aaron-s-amphitheatre-at-lakewood // TOTAL: 277 Bands
# the-o2 // TOTAL: 213 Bands
# trix // TOTAL: 297 Bands
# minglewood-hall // TOTAL: 294 Bands
# cannery-ballroom // TOTAL: 288 Bands
# the-altar-bar // TOTAL: 289 Bands
# le-bikini // TOTAL: 278 Bands
# rockefeller // TOTAL: 287 Bands
# the-urban-lounge // TOTAL: 260 Bands
# crocodile-rock // TOTAL: 242 Bands
# the-warehouse-project // TOTAL: 234 Bands
# jefferson-theater // TOTAL: 264 Bands
# the-music-farm // TOTAL: 259 Bands
# razzmatazz // TOTAL: 277 Bands
# rexall-place // TOTAL: 243 Bands
# the-castle-theatre // TOTAL: 267 Bands
# summit-music-hall // TOTAL: 254 Bands
# yoshi-s // TOTAL: 202 Bands
# mts-centre // TOTAL: 257 Bands
# santa-barbara-bowl // TOTAL: 271 Bands
# the-mint // TOTAL: 235 Bands
# rickshaw-stop // TOTAL: 273 Bands
# club-red // TOTAL: 248 Bands
# belly-up-aspen // TOTAL: 258 Bands
# knitting-factory // TOTAL: 274 Bands
# larimer-lounge // TOTAL: 263 Bands
# london-music-hall // TOTAL: 272 Bands
# new-daisy-theatre // TOTAL: 256 Bands
# jannus-live // TOTAL: 253 Bands
# wolf-trap // TOTAL: 246 Bands
# verizon-theatre-at-grand-prairie // TOTAL: 274 Bands
# kilby-court // TOTAL: 248 Bands
# foundation-nightclub // TOTAL: 223 Bands
# thekla // TOTAL: 284 Bands
# first-unitarian-church // TOTAL: 252 Bands
# beaumont-club // TOTAL: 261 Bands
# empire-polo-club // TOTAL: 259 Bands
# space-ibiza // TOTAL: 199 Bands
# summerfest // TOTAL: 257 Bands
# le-poisson-rouge // TOTAL: 267 Bands
# crystal-ballroom // TOTAL: 262 Bands
# jazz-alley // TOTAL: 140 Bands
# urban-lounge // TOTAL: 263 Bands
# beat-kitchen // TOTAL: 243 Bands
# tremont-music-hall // TOTAL: 247 Bands
# rex-club // TOTAL: 210 Bands
# st-andrews-hall // TOTAL: 261 Bands
# flash // TOTAL: 228 Bands
# tomorrowland // TOTAL: 201 Bands
# narrows-center-for-the-arts // TOTAL: 201 Bands
# house-of-rock // TOTAL: 211 Bands
# charleston-pour-house // TOTAL: 208 Bands
# mystic-theatre // TOTAL: 232 Bands
# eddie-s-attic // TOTAL: 192 Bands
# avalon // TOTAL: 254 Bands
# l-olympia // TOTAL: 242 Bands
# bok-center // TOTAL: 241 Bands
# schubas-tavern // TOTAL: 233 Bands
# alcatraz // TOTAL: 248 Bands
# batschkapp // TOTAL: 251 Bands
# o2-abc // TOTAL: 262 Bands
# the-academy // TOTAL: 250 Bands
# berghain // TOTAL: 213 Bands
# venue-578 // TOTAL: 275 Bands
# sentrum-scene // TOTAL: 246 Bands
# markthalle // TOTAL: 227 Bands
# ramshead-live // TOTAL: 261 Bands
# the-stone-pony // TOTAL: 250 Bands
# the-state-room // TOTAL: 221 Bands
# underground // TOTAL: 234 Bands
# colston-hall // TOTAL: 238 Bands
# the-barns-at-wolf-trap // TOTAL: 219 Bands
# cricket-wireless-amphitheatre // TOTAL: 252 Bands
# sokol-auditorium // TOTAL: 246 Bands
# the-roxy-theatre // TOTAL: 265 Bands
# the-showbox // TOTAL: 273 Bands
# verizon-wireless-theater // TOTAL: 252 Bands
# canopy-club // TOTAL: 249 Bands
# club-solda // TOTAL: 244 Bands
# revention-music-center // TOTAL: 271 Bands
# essigfabrik // TOTAL: 226 Bands
# opera-house // TOTAL: 250 Bands
# whelans // TOTAL: 246 Bands
# rocketown // TOTAL: 189 Bands
# world-cafe-live-philadelphia // TOTAL: 242 Bands
# american-airlines-center // TOTAL: 218 Bands
# the-palladium-ballroom // TOTAL: 260 Bands
# doornroosje // TOTAL: 269 Bands
# 7th-street-entry // TOTAL: 248 Bands
# vaudeville-mews // TOTAL: 238 Bands
# georgia-theatre // TOTAL: 245 Bands
# aragon-ballroom // TOTAL: 253 Bands
# laiterie // TOTAL: 253 Bands
# o2-academy-liverpool // TOTAL: 237 Bands
# village-underground // TOTAL: 254 Bands
# visulite-theatre // TOTAL: 224 Bands
# vic-theatre // TOTAL: 233 Bands
# stereo // TOTAL: 182 Bands
# saint-rocke // TOTAL: 201 Bands
# beachland-tavern // TOTAL: 223 Bands
# yost-theater // TOTAL: 233 Bands
# the-parish // TOTAL: 242 Bands
# rhythm-room // TOTAL: 219 Bands
# mojoes // TOTAL: 203 Bands
# ushuaia // TOTAL: 175 Bands
# pabst-theater // TOTAL: 234 Bands
# roxy-theatre // TOTAL: 247 Bands
# stageone // TOTAL: 206 Bands
# ram-s-head // TOTAL: 222 Bands
# jazz-cafe // TOTAL: 205 Bands
# the-empty-bottle // TOTAL: 227 Bands
# sound-control // TOTAL: 261 Bands
# mohawak // TOTAL: 238 Bands
# red-7 // TOTAL: 235 Bands
# le-bataclan // TOTAL: 256 Bands
# toyota-center // TOTAL: 213 Bands
# borderline // TOTAL: 237 Bands
# mr-smalls // TOTAL: 241 Bands
# waterfront // TOTAL: 229 Bands
# casino-rama // TOTAL: 190 Bands
# lizard-lounge // TOTAL: 194 Bands
# olympia-theatre // TOTAL: 212 Bands
# riviera-theatre // TOTAL: 242 Bands
# express-live // TOTAL: 257 Bands
# congress-theater // TOTAL: 238 Bands
# o2-apollo-manchester // TOTAL: 228 Bands
# verizon-wireless-amphitheater-st-louis // TOTAL: 228 Bands
# southgate-house // TOTAL: 222 Bands
# nectar-lounge // TOTAL: 198 Bands
# dante-s // TOTAL: 221 Bands
# berghain-panorama-bar // TOTAL: 174 Bands
# music-farm // TOTAL: 250 Bands
# o2-academy-sheffield // TOTAL: 232 Bands
# peabody-s // TOTAL: 205 Bands
# reggie-s-rock-club // TOTAL: 217 Bands
# constellation-room // TOTAL: 243 Bands
# smart-bar // TOTAL: 210 Bands
# paramount-theatre // TOTAL: 237 Bands
# roseland-ballroom // TOTAL: 235 Bands
# majestic-theatre-madison // TOTAL: 232 Bands
# backstage // TOTAL: 228 Bands
# senator-theatre // TOTAL: 228 Bands
# madison-theater // TOTAL: 244 Bands
# nycb-theatre-at-westbury // TOTAL: 203 Bands
# triple-door // TOTAL: 200 Bands
# peabody-s-downunder // TOTAL: 197 Bands
# the-canyon // TOTAL: 204 Bands
# toad-s-place-of-new-haven // TOTAL: 221 Bands
# knitting-factor // TOTAL: 240 Bands
# emo-s // TOTAL: 263 Bands
# kool-haus // TOTAL: 244 Bands
# bank-of-america-pavilion // TOTAL: 225 Bands
# bethel-woods-center-for-the-arts // TOTAL: 222 Bands
# the-hoxton // TOTAL: 212 Bands
# lido // TOTAL: 253 Bands
# the-waiting-room // TOTAL: 244 Bands
# maxwell-s // TOTAL: 220 Bands
# beachland-ballroom-tavern // TOTAL: 228 Bands
# old-rock-house // TOTAL: 233 Bands
# sands-bethlehem-event-center // TOTAL: 230 Bands
# knitting-factory // TOTAL: 244 Bands
# grand-central // TOTAL: 214 Bands
# verizon-center // TOTAL: 200 Bands
# the-ritz-ybor // TOTAL: 257 Bands
# luxor // TOTAL: 228 Bands
# showcase // TOTAL: 222 Bands
# moe-s-alley // TOTAL: 182 Bands
# the-echo // TOTAL: 219 Bands
# boardwalk // TOTAL: 200 Bands
# bell-centre // TOTAL: 219 Bands
# botanique // TOTAL: 226 Bands
# soul-kitchen // TOTAL: 224 Bands
# mjestic-theatre // TOTAL: 238 Bands
# smiths-olde-bar // TOTAL: 184 Bands
# tarrytown-music-hall // TOTAL: 192 Bands
# vogue-theatre // TOTAL: 237 Bands
# darien-lake-performing-arts-center // TOTAL: 219 Bands
# club-dada // TOTAL: 228 Bands
# royal-albert-hall // TOTAL: 188 Bands
# penn-s-peak // TOTAL: 192 Bands
# sound-nightclub // TOTAL: 190 Bands
# toad-s-place // TOTAL: 225 Bands
# oracle-arena // TOTAL: 217 Bands
# xcel-energy-center // TOTAL: 198 Bands
# soda-bar // TOTAL: 218 Bands
# st-augustine-amphitheatre // TOTAL: 226 Bands
# rickshaw-theatre // TOTAL: 220 Bands
# ultra-music-festival // TOTAL: 205 Bands
# the-clubhouse // TOTAL: 223 Bands
# dna-lounge // TOTAL: 209 Bands
# wilbur-theatre // TOTAL: 212 Bands
# tupelo-music-hall // TOTAL: 175 Bands
# 1015-folsom // TOTAL: 212 Bands
# staples-center // TOTAL: 180 Bands
# orpheum-theatre // TOTAL: 220 Bands
# meridian // TOTAL: 223 Bands
# dc10 // TOTAL: 148 Bands
# barclays-center // TOTAL: 205 Bands
# recher-theatre // TOTAL: 206 Bands
# house-of-blues // TOTAL: 234 Bands
# track-29 // TOTAL: 225 Bands
# velvet-jones // TOTAL: 216 Bands
# corner-hotel // TOTAL: 221 Bands
# uebel-gefahrlich // TOTAL: 234 Bands
# gruene-hall // TOTAL: 148 Bands
# van-andel-arena // TOTAL: 216 Bands
# pumpehuset // TOTAL: 234 Bands
# sherman-theater // TOTAL: 213 Bands
# hard-rock-live // TOTAL: 180 Bands
# vogue-theatre // TOTAL: 217 Bands
# iron-city // TOTAL: 232 Bands
# pnc-music-pavilion // TOTAL: 218 Bands
# empire // TOTAL: 188 Bands
# lifestyle-communities-pavilion // TOTAL: 216 Bands
# corporation // TOTAL: 207 Bands
# city-winery // TOTAL: 204 Bands
# verboten // TOTAL: 199 Bands
# park-west // TOTAL: 213 Bands
# royale-boston // TOTAL: 227 Bands
# billy-bob-s // TOTAL: 142 Bands
# peppermill-concert-hall // TOTAL: 151 Bands
# reading-festival // TOTAL: 211 Bands
# target-center // TOTAL: 212 Bands
# the-crofoot-ballroom // TOTAL: 232 Bands
# coach-house // TOTAL: 178 Bands
# revolution // TOTAL: 223 Bands
# strummer-s // TOTAL: 212 Bands
# neurolux-lounge // TOTAL: 206 Bands
# taft-theatre // TOTAL: 212 Bands
# lollapalooza // TOTAL: 227 Bands
# parc-jean-drapeau // TOTAL: 245 Bands
# blue-moose-tap-house // TOTAL: 211 Bands
# tower-theatre // TOTAL: 216 Bands
# blind-pig // TOTAL: 203 Bands
# peoria-civic-center // TOTAL: 208 Bands
# bluebird-nightclub // TOTAL: 194 Bands
# amager-bio // TOTAL: 217 Bands
# george-s-majestic-lounge // TOTAL: 188 Bands
# the-tivoli // TOTAL: 211 Bands
# le-trabendo // TOTAL: 233 Bands
# freight-salvage-coffeehouse // TOTAL: 162 Bands
# the-new-parish // TOTAL: 200 Bands
# la-cigale // TOTAL: 226 Bands
# the-georgia-theatre // TOTAL: 190 Bands
# grove-of-anaheim // TOTAL: 205 Bands
# knust // TOTAL: 217 Bands
# the-phoenix-concert-theatre // TOTAL: 232 Bands
# gorilla // TOTAL: 225 Bands
# hollywood-casino-amphitheatre // TOTAL: 225 Bands
# sam-s-burger-joint // TOTAL: 167 Bands
# cafe-du-nord // TOTAL: 207 Bands
# brooklyn-bowl-las-vegas // TOTAL: 203 Bands
# the-music-box // TOTAL: 212 Bands
# mansion // TOTAL: 167 Bands
# victoria-park // TOTAL: 195 Bands
# the-lost-horizon // TOTAL: 200 Bands
# slo-brew // TOTAL: 209 Bands
# nokia-theatre-times-square // TOTAL: 202 Bands
# oran-mor // TOTAL: 206 Bands
# gas-monkey-bar-n-grill // TOTAL: 216 Bands
# bottleneck // TOTAL: 204 Bands
# mercury-ballroom // TOTAL: 228 Bands
# oxford-art-factory // TOTAL: 224 Bands
# celebrity-theatre // TOTAL: 194 Bands
# tennessee-theatre // TOTAL: 186 Bands
# the-fleece // TOTAL: 208 Bands
# the-crocodile-rock-cafe // TOTAL: 194 Bands
# house-of-blues // TOTAL: 205 Bands
# the-cabooze // TOTAL: 211 Bands
# cabooze // TOTAL: 203 Bands
# the-danforth-music-hall // TOTAL: 218 Bands
# space // TOTAL: 181 Bands
# eygptian-room-at-old-national-centre // TOTAL: 221 Bands
# hafenklang // TOTAL: 183 Bands
# vicar-street // TOTAL: 179 Bands
# cape-cod-melody-tent // TOTAL: 172 Bands
# bowery-ballroom // TOTAL: 195 Bands
# philips-arena // TOTAL: 186 Bands
# myth // TOTAL: 207 Bands
# showcase-live // TOTAL: 185 Bands
# td-garden // TOTAL: 177 Bands
# the-note // TOTAL: 207 Bands
# o2-academy-bournemouth // TOTAL: 202 Bands
# wamu-theater // TOTAL: 227 Bands
# flames-central // TOTAL: 195 Bands
# mexicali-live // TOTAL: 172 Bands
# rockhal // TOTAL: 220 Bands
# d-club // TOTAL: 188 Bands
# reggies-rock-club // TOTAL: 192 Bands
# hmv-hammersmith-apollo // TOTAL: 188 Bands
# rock-and-roll-hotel // TOTAL: 207 Bands
# the-casbah // TOTAL: 200 Bands
# florida-theatre-jacksonville // TOTAL: 192 Bands
# manchester-arena // TOTAL: 184 Bands
# royale // TOTAL: 209 Bands
# orbit-room // TOTAL: 191 Bands
# ziggy-s // TOTAL: 200 Bands
# new-morning // TOTAL: 173 Bands
# comcast-theatre // TOTAL: 202 Bands
# the-met // TOTAL: 210 Bands
# comerica-theatre // TOTAL: 215 Bands
# burton-cummings-theatre // TOTAL: 201 Bands
# underground-arts // TOTAL: 204 Bands
# the-fillmore-miami-beach-at-jackie-gleason-theater // TOTAL: 198 Bands
# electric-brixton // TOTAL: 214 Bands
# orpheum-theater-flagstaff // TOTAL: 197 Bands
# howlin-wolf // TOTAL: 193 Bands
# one-world-theatre // TOTAL: 156 Bands
# jaxx-nightclub // TOTAL: 151 Bands
# chastain-park-amphitheatre // TOTAL: 181 Bands
# sunshine-theatre // TOTAL: 202 Bands
# majestic-theatre // TOTAL: 213 Bands
# the-beacham // TOTAL: 218 Bands
# egg-london // TOTAL: 171 Bands
# harlow-s // TOTAL: 193 Bands
# patronaat // TOTAL: 209 Bands
# the-rialto-theatre // TOTAL: 220 Bands
# the-kent-stage // TOTAL: 188 Bands
# los-globos // TOTAL: 205 Bands
# the-capitol-theatre // TOTAL: 189 Bands
# the-bottleneck // TOTAL: 186 Bands
# tivolivredenburg // TOTAL: 229 Bands
# womb // TOTAL: 180 Bands
# the-fillmore // TOTAL: 204 Bands
# independent // TOTAL: 185 Bands
# superpages-com-center // TOTAL: 203 Bands
# emerson-theater // TOTAL: 150 Bands
# the-forum // TOTAL: 198 Bands
# the-westcot-theater // TOTAL: 182 Bands
# bill-graham-civic-auditorium // TOTAL: 192 Bands
# carolina-theatre // TOTAL: 187 Bands
# prudential-center // TOTAL: 185 Bands
# biltmore-cabaret // TOTAL: 199 Bands
# mavericks // TOTAL: 172 Bands
# garage // TOTAL: 183 Bands
# le-trianon // TOTAL: 205 Bands
# monarch // TOTAL: 180 Bands
# austin-city-limits-live-at-the-moody-theater // TOTAL: 197 Bands
# bowery-poetry-club // TOTAL: 184 Bands
# clwb-ifor-bach // TOTAL: 202 Bands
# conne-island // TOTAL: 177 Bands
# the-chapel // TOTAL: 190 Bands
# lka-longhorn // TOTAL: 190 Bands
# cielo // TOTAL: 179 Bands
# venue // TOTAL: 209 Bands
# union-chapel // TOTAL: 181 Bands
# project-irl // TOTAL: 150 Bands
# pier-six-pavilion // TOTAL: 207 Bands
# blue-hills-bank-pavilion // TOTAL: 192 Bands
# val-air-ballroom // TOTAL: 186 Bands
# la-zona-rosa // TOTAL: 216 Bands
# hard-rock-live // TOTAL: 209 Bands
# king-tuts-wah-wah-hut // TOTAL: 195 Bands
# rogers-arena // TOTAL: 184 Bands
# canterbury-park // TOTAL: 177 Bands
# arena-wien // TOTAL: 203 Bands
# harlow-s-restaurant-and-nightclub // TOTAL: 184 Bands
# budweiser-stage // TOTAL: 186 Bands
# new-jersey-performing-arts-center // TOTAL: 176 Bands
# the-door // TOTAL: 156 Bands
# agora-ballroom // TOTAL: 193 Bands
# o2-abc-glasgow // TOTAL: 205 Bands
# the-republik // TOTAL: 187 Bands
# rescue-rooms // TOTAL: 198 Bands
# brick-by-brick // TOTAL: 178 Bands
# the-fonda-theatre // TOTAL: 205 Bands
# fine-line-music-cafe // TOTAL: 194 Bands
# sankeys // TOTAL: 142 Bands
# the-waiting-room // TOTAL: 206 Bands
# les-docks // TOTAL: 202 Bands
# 40-watt-club // TOTAL: 194 Bands
# fuse // TOTAL: 174 Bands
# underworld-camden // TOTAL: 171 Bands
# south-side-ballroom // TOTAL: 204 Bands
# fiddler-s-green-amphitheatre // TOTAL: 200 Bands
# crowbar // TOTAL: 192 Bands
# 8x10 // TOTAL: 149 Bands
# santos-party-house // TOTAL: 201 Bands
# american-music-theatre // TOTAL: 155 Bands
# cervantes-other-side // TOTAL: 165 Bands
# trocadero-theatre // TOTAL: 215 Bands
# tivoli // TOTAL: 202 Bands
# nikki-beach // TOTAL: 162 Bands
# the-marquee // TOTAL: 187 Bands
# john-dee // TOTAL: 208 Bands
# wedgewood-rooms // TOTAL: 179 Bands
# calvin-theatre // TOTAL: 164 Bands
# sweetwater-music-hall // TOTAL: 164 Bands
# the-venue // TOTAL: 152 Bands
# state-theatre // TOTAL: 156 Bands
# thalia-hall // TOTAL: 189 Bands
# leeds-festival // TOTAL: 188 Bands
# save-mart-center // TOTAL: 192 Bands
# usana-amphitheatre // TOTAL: 184 Bands
# scottrade-center // TOTAL: 181 Bands
# xfinity-theatre // TOTAL: 184 Bands
# stubb-s // TOTAL: 196 Bands
# dodge-theatre // TOTAL: 188 Bands
# revolution-music-room // TOTAL: 160 Bands
# the-ready-room // TOTAL: 199 Bands
# united-center // TOTAL: 156 Bands
# metro-city // TOTAL: 184 Bands
# brady-theater // TOTAL: 177 Bands
# frankies // TOTAL: 163 Bands
# waiting-room // TOTAL: 183 Bands
# the-old-rock-house // TOTAL: 183 Bands
# hammerstein-ballroom // TOTAL: 182 Bands
# union-hall // TOTAL: 196 Bands
# mcgonigel-s-mucky-duck // TOTAL: 125 Bands
# bootshaus // TOTAL: 158 Bands
# dpac // TOTAL: 155 Bands
# the-vogue // TOTAL: 183 Bands
# the-cotillion-ballroom // TOTAL: 174 Bands
# dosey-doe // TOTAL: 150 Bands
# grizzly-rose // TOTAL: 129 Bands
# musica // TOTAL: 158 Bands
# neptune-theatre // TOTAL: 202 Bands
# elysee-montmartre // TOTAL: 194 Bands
# tinker-field // TOTAL: 178 Bands
# state-theatre // TOTAL: 180 Bands
# barrymore-theatre // TOTAL: 189 Bands
# the-state-theatre // TOTAL: 187 Bands
# the-midland-by-amc // TOTAL: 185 Bands
# louisville-palace // TOTAL: 181 Bands
# park-city-live // TOTAL: 171 Bands
# spark-arena // TOTAL: 166 Bands
# piere-s // TOTAL: 145 Bands
# shaw-confernece-centre // TOTAL: 180 Bands
# verizon-arena // TOTAL: 168 Bands
# den-atelier // TOTAL: 186 Bands
# privilege // TOTAL: 148 Bands
# keyarena // TOTAL: 179 Bands
# zanzabar // TOTAL: 169 Bands
# orange-peel // TOTAL: 192 Bands
# zilker-park // TOTAL: 176 Bands
# the-aquarium // TOTAL: 178 Bands
# wilma-theatre // TOTAL: 179 Bands
# chop-suey // TOTAL: 190 Bands
# macewan-hall // TOTAL: 177 Bands
# fonda-theatre // TOTAL: 179 Bands
# bb-t-pavilion // TOTAL: 196 Bands
# center-stage-theatre // TOTAL: 175 Bands
# mohawk-place // TOTAL: 171 Bands
# schlachthof // TOTAL: 174 Bands
# dc9 // TOTAL: 179 Bands
# glasslands-gallery // TOTAL: 167 Bands
# whisky-a-go-go // TOTAL: 158 Bands
# rumba-cafe // TOTAL: 149 Bands
# hyde-park // TOTAL: 182 Bands
# cynthia-woods-mitchell-pavilion // TOTAL: 186 Bands
# the-ritz // TOTAL: 184 Bands
# beta-nightclub // TOTAL: 161 Bands
# higher-ground-ballroom // TOTAL: 186 Bands
# grant-park // TOTAL: 168 Bands
# tralf // TOTAL: 167 Bands
# bassmnt // TOTAL: 142 Bands
# the-fillmore // TOTAL: 186 Bands
# the-forum // TOTAL: 174 Bands
# g-boro-coliseum-complex // TOTAL: 175 Bands
# new-brookland-tavern // TOTAL: 162 Bands
# san-manuel-amphitheater // TOTAL: 173 Bands
# kingdom-nightclub // TOTAL: 169 Bands
# wells-fargo-center // TOTAL: 154 Bands
# bonnaroo-music-festival // TOTAL: 183 Bands
# social-club // TOTAL: 166 Bands
# 20th-century-theater // TOTAL: 165 Bands
# honda-center // TOTAL: 160 Bands
# logo // TOTAL: 160 Bands
# skyway-theatre // TOTAL: 170 Bands
# estragon // TOTAL: 167 Bands
# dos-amigos // TOTAL: 146 Bands
# cricket-wireless-pavilion // TOTAL: 166 Bands
# mayo-performing-arts-center // TOTAL: 158 Bands
# state-theatre // TOTAL: 165 Bands
# the-dakota-jazz-club-restaurant // TOTAL: 122 Bands
# jacksonville-veterans-memorial-arena // TOTAL: 165 Bands
# sam-houston-race-park // TOTAL: 172 Bands
# paramount-theatre // TOTAL: 178 Bands
# gas-monkey-live // TOTAL: 180 Bands
# expo-five // TOTAL: 156 Bands
# the-korova // TOTAL: 162 Bands
# outland-ballroom // TOTAL: 154 Bands
# orpheum // TOTAL: 165 Bands
# nottingham-rescue-rooms // TOTAL: 183 Bands
# hard-rock-live // TOTAL: 149 Bands
# substage // TOTAL: 156 Bands
# center-stage // TOTAL: 185 Bands
# o2-academy-3-birmingham // TOTAL: 171 Bands
# the-pyramid-scheme // TOTAL: 176 Bands
# sub-89 // TOTAL: 176 Bands
# ponte-vedra-concert-hall // TOTAL: 156 Bands
# wulfrun-hall // TOTAL: 168 Bands
# corsica-studios // TOTAL: 151 Bands
# festival-pier // TOTAL: 169 Bands
# hmv-institute-birmingham // TOTAL: 175 Bands
# huxleys-neue-welt // TOTAL: 178 Bands
# grand-ole-opry // TOTAL: 122 Bands
# hodi-s-half-note // TOTAL: 148 Bands
# the-haunt // TOTAL: 165 Bands
# verizon-wireless-amphitheatre-charlotte // TOTAL: 162 Bands
# the-haunt // TOTAL: 183 Bands
# all-state-arena // TOTAL: 148 Bands
# house-of-blues // TOTAL: 164 Bands
# hirsch // TOTAL: 160 Bands
# sutra // TOTAL: 134 Bands
# turf-club // TOTAL: 161 Bands
# arlene-schnitzer-concert-hall // TOTAL: 163 Bands
# theatre-of-the-living-arts // TOTAL: 177 Bands
# bijou-theatre // TOTAL: 169 Bands
# sokol-underground // TOTAL: 145 Bands
# pearl-street // TOTAL: 161 Bands
# irving-plaza-powered-by-klipsch // TOTAL: 174 Bands
# treehouse // TOTAL: 132 Bands
# tivoli-de-helling // TOTAL: 179 Bands
# c-club // TOTAL: 169 Bands
# nordstern // TOTAL: 137 Bands
# star-theater // TOTAL: 175 Bands
# scala // TOTAL: 189 Bands
# town-hall // TOTAL: 148 Bands
# westcott-theater // TOTAL: 162 Bands
# verizon-wireless-amphitheatre-at-encore-park // TOTAL: 165 Bands
# melkweg-the-max // TOTAL: 180 Bands
# gasometer // TOTAL: 175 Bands
# chastain-park-amphitheatre-parking-lots // TOTAL: 151 Bands
# edmonton-event-centre // TOTAL: 172 Bands
# ziggy-s-by-the-sea // TOTAL: 174 Bands
# trouw // TOTAL: 130 Bands
# marcus-amphitheater // TOTAL: 174 Bands
# soho-restaurant-and-music-club // TOTAL: 161 Bands
# o2-academy-2-liverpool // TOTAL: 179 Bands
# dar-constitution-hall // TOTAL: 144 Bands
# arvest-bank-theatre-at-the-midland // TOTAL: 169 Bands
# credit-union-centre // TOTAL: 170 Bands
# schermerhorn-symphony-center // TOTAL: 130 Bands
# the-colosseum-at-caesars-windsor // TOTAL: 148 Bands
# the-cotillion // TOTAL: 157 Bands
# danforth-music-hall // TOTAL: 176 Bands
# time-warner-cable-music-pavilion-at-walnut-creek // TOTAL: 141 Bands
# o2-shepherd-s-bush-empire // TOTAL: 175 Bands
# isleta-amphitheater // TOTAL: 166 Bands
# magic-bag // TOTAL: 149 Bands
# the-conservatory // TOTAL: 148 Bands
# the-frequency // TOTAL: 165 Bands
# canal-club // TOTAL: 166 Bands
# the-canal-club // TOTAL: 164 Bands
# daryl-s-house // TOTAL: 156 Bands
# wiltern-theatre // TOTAL: 177 Bands
# the-anthology // TOTAL: 136 Bands
# reverb // TOTAL: 153 Bands
# city-national-grove-of-anaheim // TOTAL: 150 Bands
# hi-dive // TOTAL: 138 Bands
# story-miami // TOTAL: 131 Bands
# de-oosterpoort // TOTAL: 166 Bands
# greek-theatre // TOTAL: 157 Bands
# bush-hall // TOTAL: 163 Bands
# the-prophat-bar // TOTAL: 170 Bands
# ravinia // TOTAL: 144 Bands
# marquis-theatre // TOTAL: 149 Bands
# carl-s-cradle // TOTAL: 184 Bands
# chinese-laundry // TOTAL: 155 Bands
# the-basement // TOTAL: 143 Bands
# the-mountain-winery // TOTAL: 153 Bands
# z7-konzertfabrik // TOTAL: 141 Bands
# mighty // TOTAL: 143 Bands
# the-twisted-pepper // TOTAL: 139 Bands
# wembley-arena // TOTAL: 148 Bands
# grosse-freiheit-36 // TOTAL: 166 Bands
# the-broadberry // TOTAL: 159 Bands
# the-end // TOTAL: 142 Bands
# uptown-theatre-napa // TOTAL: 145 Bands
# spanish-moon // TOTAL: 146 Bands
# underworld // TOTAL: 157 Bands
# eddies-attic // TOTAL: 123 Bands
# debaser-meids // TOTAL: 171 Bands
# kfc-yum-center // TOTAL: 156 Bands
# spybar // TOTAL: 141 Bands
# the-blockley // TOTAL: 140 Bands
# handlebar // TOTAL: 148 Bands
# concrete-street-amphitheater // TOTAL: 147 Bands
# verizon-wireless-music-center // TOTAL: 172 Bands
# ak-chin-pavilion // TOTAL: 151 Bands
# z7 // TOTAL: 131 Bands
# matter // TOTAL: 128 Bands
# voyeur // TOTAL: 139 Bands
# granada-theater // TOTAL: 167 Bands
# the-kessler // TOTAL: 142 Bands
# brisbane-entertainment-centre // TOTAL: 128 Bands
# celebrities // TOTAL: 144 Bands
# the-machine-shop // TOTAL: 115 Bands
# la-machine-du-moulin-rouge // TOTAL: 168 Bands
# hotel-cafe // TOTAL: 131 Bands
# tt-the-bear-s // TOTAL: 156 Bands
# the-pavilion-at-montage-mountain // TOTAL: 161 Bands
# saint-vitus // TOTAL: 129 Bands
# the-garage // TOTAL: 165 Bands
# rio-theatre // TOTAL: 144 Bands
# lakewood-amphitheatre // TOTAL: 176 Bands
# joiners // TOTAL: 149 Bands
# gretchen // TOTAL: 144 Bands
# liv // TOTAL: 112 Bands
# theatre-at-westbury // TOTAL: 142 Bands
# metro-radio-arena // TOTAL: 130 Bands
# motion // TOTAL: 149 Bands
# nosturi // TOTAL: 155 Bands
# the-fraze-pavilion // TOTAL: 153 Bands
# creamfields // TOTAL: 127 Bands
# austin-music-hall // TOTAL: 171 Bands
# liberty-hall // TOTAL: 159 Bands
# three-links // TOTAL: 144 Bands
# colos-saal // TOTAL: 134 Bands
# thebarton-theatre // TOTAL: 164 Bands
# chalet // TOTAL: 129 Bands
# concrete // TOTAL: 123 Bands
# nassau-coliseum // TOTAL: 152 Bands
# ziggo-dome // TOTAL: 132 Bands
# harpers-ferry // TOTAL: 149 Bands
# firebird // TOTAL: 156 Bands
# l-aeronef // TOTAL: 166 Bands
# the-roxy // TOTAL: 171 Bands
# will-s-pub // TOTAL: 127 Bands
# salon-zur-wilden-renate // TOTAL: 120 Bands
# pepsi-center // TOTAL: 150 Bands
# house-of-blues-atlantic-city // TOTAL: 158 Bands
# the-southern // TOTAL: 145 Bands
# pearl-concert-theater-at-palms-casino-resort // TOTAL: 144 Bands
# hallenstadion // TOTAL: 133 Bands
# the-cynthia-woods-mitchell-pavilion-presented-by-huntsman // TOTAL: 167 Bands
# elektricity // TOTAL: 136 Bands
# plaza-live // TOTAL: 162 Bands
# hard-rock-live-orlando // TOTAL: 154 Bands
# the-loft // TOTAL: 149 Bands
# robert-johnson // TOTAL: 114 Bands
# create // TOTAL: 123 Bands
# north-star-bar // TOTAL: 150 Bands
# canyon-club // TOTAL: 155 Bands
# the-high-watt // TOTAL: 150 Bands
# fire // TOTAL: 153 Bands
# the-town-ballroom // TOTAL: 153 Bands
# the-exchange // TOTAL: 140 Bands
# harvester-performance-center // TOTAL: 145 Bands
# abbey-pub // TOTAL: 158 Bands
# glazart // TOTAL: 153 Bands
# stone-mountain-arts-center // TOTAL: 106 Bands
# surrender-nightclub //  TOTAL: 91 Bands
# the-button-factory // TOTAL: 159 Bands
# coda // TOTAL: 141 Bands
# thunder-valley-casino-resort // TOTAL: 141 Bands
# humboldt-brews // TOTAL: 134 Bands
# indigo2 // TOTAL: 141 Bands
# nokia-theatre-at-grand-prairie // TOTAL: 161 Bands
# columbiahalle // TOTAL: 161 Bands
# bonnaroo // TOTAL: 151 Bands
# the-black-sheep // TOTAL: 146 Bands
# the-melting-point // TOTAL: 142 Bands
# bramham-park // TOTAL: 151 Bands
# flex // TOTAL: 160 Bands
# rock-roll-hotel // TOTAL: 154 Bands
# gypsy-sally-s // TOTAL: 124 Bands
# hi-tone-cafe // TOTAL: 143 Bands
# brewster-street-ice-house // TOTAL: 112 Bands
# starlight-theatre // TOTAL: 146 Bands
# cathouse // TOTAL: 141 Bands
# electric-forest // TOTAL: 133 Bands
# albert-hall // TOTAL: 158 Bands
# cactus-cafe // TOTAL: 122 Bands
# fitzgerald-s // TOTAL: 106 Bands
# martini-ranch // TOTAL: 146 Bands
# the-international // TOTAL: 155 Bands
# high-dive // TOTAL: 140 Bands
# mojo-s // TOTAL: 152 Bands
# electric-zoo // TOTAL: 141 Bands
# dour-festival // TOTAL: 156 Bands
# bang-bang // TOTAL: 135 Bands
# matrix // TOTAL: 139 Bands
# proud-larry-s // TOTAL: 141 Bands
# melkweg-oude-zaal // TOTAL: 161 Bands
# the-evening-muse // TOTAL: 118 Bands
# club-101 // TOTAL: 152 Bands
# the-ritz // TOTAL: 165 Bands
# deluxe-at-old-national-centre // TOTAL: 162 Bands
# billy-bob-s-texas // TOTAL: 106 Bands
# culture-box // TOTAL: 123 Bands
# woodlands-pavilion // TOTAL: 146 Bands
# martyrs // TOTAL: 122 Bands
# farm-bureau-live-at-virginia-beach // TOTAL: 133 Bands
# gillioz-theatre // TOTAL: 148 Bands
# warner-theatre // TOTAL: 127 Bands
# paradiso-kleine-zaal // TOTAL: 158 Bands
# murat-theatre-at-old-national-centre // TOTAL: 146 Bands
# pacha // TOTAL: 126 Bands
# iowa-state-fair // TOTAL: 140 Bands
# duling-hall // TOTAL: 132 Bands
# the-horseshoe-tavern // TOTAL: 140 Bands
# the-great-saltair // TOTAL: 153 Bands
# symphony-hall // TOTAL: 125 Bands
# el-rey // TOTAL: 160 Bands
# hmv-forum // TOTAL: 147 Bands
# gallagher-park //  TOTAL: 93 Bands
# donington-park // TOTAL: 130 Bands
# middle-east-restaurant-nightclub // TOTAL: 147 Bands
# crystal-bay-casino // TOTAL: 123 Bands
# headliners // TOTAL: 136 Bands
# the-saint // TOTAL: 132 Bands
# f-m-kirby-center // TOTAL: 151 Bands
# pustervik // TOTAL: 151 Bands
# durer-kert // TOTAL: 142 Bands
# grand-ole-opry-house // TOTAL: 106 Bands
# moore-theatre // TOTAL: 147 Bands
# riot-room // TOTAL: 143 Bands
# main-street-armory // TOTAL: 148 Bands
# fortune-sound-club // TOTAL: 153 Bands
# sydney-opera-house // TOTAL: 113 Bands
# georges-majestic-lounge // TOTAL: 126 Bands
# backstage-werk // TOTAL: 149 Bands
# king-tuts // TOTAL: 147 Bands
# sub-club // TOTAL: 129 Bands
# stubbs-restaurant // TOTAL: 149 Bands
# sonar // TOTAL: 143 Bands
# wolverhampton-civic-hall // TOTAL: 141 Bands
# ford-amphitheatre // TOTAL: 145 Bands
# woodlands-tavern // TOTAL: 116 Bands
# the-wellmont-theatre // TOTAL: 146 Bands
# tacoma-dome // TOTAL: 151 Bands
# tabernacle // TOTAL: 153 Bands
# walt-disney-concert-hall // TOTAL: 113 Bands
# magazzini-generali // TOTAL: 156 Bands
# i-boat // TOTAL: 148 Bands
# gramarcy-theatre // TOTAL: 146 Bands
# brooklyn-bowl // TOTAL: 153 Bands
# berklee-performance-center // TOTAL: 133 Bands
# hopmonk-tavern // TOTAL: 121 Bands
# union-park // TOTAL: 139 Bands
# the-bell-house // TOTAL: 136 Bands
# beau-rivage-theater // TOTAL: 111 Bands
# liquid-room // TOTAL: 145 Bands
# liverpool-echo-arena // TOTAL: 124 Bands
# grand-opera-house // TOTAL: 144 Bands
# machine-shop // TOTAL: 109 Bands
# electric-pickle // TOTAL: 124 Bands
# ritter-butzke // TOTAL: 116 Bands
# ip-casino-resort-and-spa // TOTAL: 125 Bands
# del-mar-fairgrounds // TOTAL: 139 Bands
# the-rhythm-room // TOTAL: 134 Bands
# brighton-concorde-2 // TOTAL: 152 Bands
# sankey-s // TOTAL: 130 Bands
# stanhop-house // TOTAL: 126 Bands
# thee-parkside // TOTAL: 125 Bands
# the-bronze-peacock-at-house-of-blues-houston // TOTAL: 150 Bands
# kb // TOTAL: 138 Bands
# austin-city-limits // TOTAL: 115 Bands
# pub-rock // TOTAL: 140 Bands
# north-charleston-performing-arts-center // TOTAL: 139 Bands
# scotiabank-saddledome // TOTAL: 134 Bands
# gabe-s // TOTAL: 143 Bands
# vooruit // TOTAL: 153 Bands
# la-rivier // TOTAL: 147 Bands
# carling-academy // TOTAL: 146 Bands
# park-street-saloon // TOTAL: 145 Bands
# lucerna-music-bar // TOTAL: 148 Bands
# bryce-jordan-center // TOTAL: 142 Bands
# voxhall // TOTAL: 148 Bands
# soapbox-laundro-lounge // TOTAL: 145 Bands
# high-sierra-music-festival //  TOTAL: 94 Bands
# crossroadskc // TOTAL: 144 Bands
# the-barbary // TOTAL: 142 Bands
# top-hat-lounge // TOTAL: 137 Bands
# turning-stone-resort-casino-event-center // TOTAL: 126 Bands
# golden-gate-park-outside-lands-festival // TOTAL: 109 Bands
# empire-polo-field // TOTAL: 105 Bands
# amway-center // TOTAL: 132 Bands
# toyota-pavilion // TOTAL: 142 Bands
# the-miramar-theatre // TOTAL: 123 Bands
# kaufleuten // TOTAL: 146 Bands
# schubas // TOTAL: 143 Bands
# carnegie-hall // TOTAL: 131 Bands
# the-catalyst-club // TOTAL: 130 Bands
# zouk // TOTAL: 118 Bands
# parc-del-forum // TOTAL: 144 Bands
# old-town-school-of-folk-music // TOTAL: 118 Bands
# sound-bar // TOTAL: 127 Bands
# joe-s-on-weed-street // TOTAL: 103 Bands
# genesee-theatre // TOTAL: 141 Bands
# point-ephemere // TOTAL: 154 Bands
# bluebird-theater // TOTAL: 145 Bands
# molotow // TOTAL: 141 Bands
# effenaar // TOTAL: 149 Bands
# hollywood-casino-amphitheatre // TOTAL: 157 Bands
# emo-s-east // TOTAL: 161 Bands
# hordern-pavilion // TOTAL: 136 Bands
# the-o2 // TOTAL: 123 Bands
# intust-bank-arena // TOTAL: 128 Bands
# gruenspan // TOTAL: 148 Bands
# oval-space // TOTAL: 148 Bands
# the-record-bar // TOTAL: 138 Bands
# republic-new-orleans // TOTAL: 140 Bands
# tavastia // TOTAL: 139 Bands
# the-satellite // TOTAL: 125 Bands
# gibson-amphitheatre // TOTAL: 133 Bands
# dynamo // TOTAL: 144 Bands
# the-bluebird // TOTAL: 126 Bands
# le-transbordeur // TOTAL: 154 Bands
# knitting-factory // TOTAL: 148 Bands
# greene-street // TOTAL: 126 Bands
# valley-view-casino-center // TOTAL: 138 Bands
# the-mod-club // TOTAL: 150 Bands
# fox-theatre-detroit // TOTAL: 126 Bands
# adelaide-entertainment-centre // TOTAL: 128 Bands
# verizon-wireless-nc // TOTAL: 135 Bands
# nationwide-arena // TOTAL: 133 Bands
# the-boardwalk // TOTAL: 133 Bands
# trade // TOTAL: 117 Bands
# wildhorse-saloon // TOTAL: 121 Bands
# blue-note //  TOTAL: 71 Bands
# band-on-the-wall // TOTAL: 129 Bands
# three20south // TOTAL: 111 Bands
# sticky-fingers // TOTAL: 135 Bands
# aftershock // TOTAL: 121 Bands
# paard-van-troje // TOTAL: 144 Bands
# bitterzoest // TOTAL: 151 Bands
# rupp-arena // TOTAL: 127 Bands
# prince-charles // TOTAL: 135 Bands
# smiling-moose // TOTAL: 131 Bands
# cafe-nine // TOTAL: 111 Bands
# white-rabbit // TOTAL: 128 Bands
# branx // TOTAL: 135 Bands
# marquee // TOTAL: 109 Bands
# la-cooperative-de-mai // TOTAL: 143 Bands
# wells-fargo-arena // TOTAL: 144 Bands
# fox-theatre-atlanta // TOTAL: 117 Bands
# backstage // TOTAL: 128 Bands
# sugar-nightclub // TOTAL: 138 Bands
# greene-street-club // TOTAL: 125 Bands
# soundgarden-hall // TOTAL: 119 Bands
# arco-arena // TOTAL: 135 Bands
# southland-ballroom // TOTAL: 124 Bands
# pnc-pavilion // TOTAL: 144 Bands
# forum-melbourne // TOTAL: 122 Bands
# nouveau-casino // TOTAL: 152 Bands
# the-garrick-centre // TOTAL: 129 Bands
# backstage-halle // TOTAL: 139 Bands
# the-vanguard // TOTAL: 141 Bands
# worthy-farm // TOTAL: 137 Bands
# royale-nightclub // TOTAL: 127 Bands
# the-alberta-rose-theatre // TOTAL: 114 Bands
# szene // TOTAL: 127 Bands
# the-zoo // TOTAL: 144 Bands
# the-shelter // TOTAL: 142 Bands
# motion-skate-park // TOTAL: 120 Bands
# the-pour-house // TOTAL: 105 Bands
# sullivan-hall // TOTAL: 103 Bands
# winstar-casino // TOTAL: 128 Bands
# charleston-music-hall // TOTAL: 129 Bands
# asbury-lanes // TOTAL: 116 Bands
# cuthbert-amphitheater // TOTAL: 126 Bands
# hp-pavilion-at-san-jose // TOTAL: 119 Bands
# verizon-wireless-in // TOTAL: 132 Bands
# soundcheck // TOTAL: 137 Bands
# red-butte-garden // TOTAL: 122 Bands
# pacha-ibiza //  TOTAL: 95 Bands
# snoqualmie-casino-ballroom // TOTAL: 125 Bands
# academy-2 // TOTAL: 137 Bands
# schottenstein-center // TOTAL: 137 Bands
# radio-radio // TOTAL: 116 Bands
# majestic-theatre-san-antonio // TOTAL: 105 Bands
# cobb-energy-performing-arts-centre // TOTAL: 127 Bands
# 170-russell // TOTAL: 125 Bands
# toyota-pavilion-at-montage-mountain // TOTAL: 135 Bands
# henham-park // TOTAL: 108 Bands
# leadmill // TOTAL: 129 Bands
# potawatomi-casino-northern-lights-theater // TOTAL: 114 Bands
# the-cockpit // TOTAL: 131 Bands
# alexandra-palace // TOTAL: 122 Bands
# grelle-forelle // TOTAL: 130 Bands
# pomona-fairplex // TOTAL: 112 Bands
# kravis-center // TOTAL: 107 Bands
# flemington-racecourse // TOTAL: 138 Bands
# scala // TOTAL: 133 Bands
# audio // TOTAL: 139 Bands
# the-globe // TOTAL: 133 Bands
# transbordeur // TOTAL: 145 Bands
# wild-bills // TOTAL: 108 Bands
# waiting-room // TOTAL: 134 Bands
# fowlers-live // TOTAL: 135 Bands
# catalina-bar-grill //  TOTAL: 74 Bands
# detroit-bar // TOTAL: 117 Bands
# the-circus // TOTAL: 131 Bands
# fulton-55 // TOTAL: 125 Bands
# uno-lakefront-arena // TOTAL: 129 Bands
# cosmic-charlie-s // TOTAL: 118 Bands
# common-grounds // TOTAL: 122 Bands
# holocene // TOTAL: 129 Bands
# the-loft // TOTAL: 124 Bands
# the-powerstation // TOTAL: 125 Bands
# chateau-ste-michelle-winery // TOTAL: 110 Bands
# saturn // TOTAL: 135 Bands
# quicken-loans-arena // TOTAL: 125 Bands
# divan-du-monde // TOTAL: 134 Bands
# kuumbwa-jazz-center // TOTAL: 106 Bands
# tresor // TOTAL: 105 Bands
# the-loft // TOTAL: 134 Bands
# sonar-main-stage // TOTAL: 139 Bands
# wrongbar // TOTAL: 130 Bands
# bass-performance-hall // TOTAL: 108 Bands
# crazy-donkey-bar-and-grill // TOTAL: 127 Bands
# ground-zero // TOTAL: 112 Bands
# buster-s-billiards-backroom // TOTAL: 131 Bands
# knitting-factory-bklyn // TOTAL: 125 Bands
# dynamo // TOTAL: 124 Bands
# yoshi-s-san-francisco //  TOTAL: 95 Bands
# 8-seconds-saloon // TOTAL: 100 Bands
# mississippi-coast-coliseum // TOTAL: 122 Bands
# the-valarium // TOTAL: 130 Bands
# berbati-s-pan // TOTAL: 136 Bands
# the-double-door-inn // TOTAL: 103 Bands
# iridium //  TOTAL: 93 Bands
# apollo // TOTAL: 125 Bands
# revolution-bar-music-hall // TOTAL: 129 Bands
# marquee // TOTAL: 130 Bands
# silver-legacy-casino // TOTAL: 115 Bands
# mccallum-theatre // TOTAL: 101 Bands
# monarch-theatre // TOTAL: 131 Bands
# montage-music-hall // TOTAL: 127 Bands
# joe-s-pub // TOTAL: 114 Bands
# liv-nightclub //  TOTAL: 94 Bands
# bournemouth-international-centre // TOTAL: 104 Bands
# germain-arena // TOTAL: 115 Bands
# gebaude-9 // TOTAL: 128 Bands
# college-street-music-hall // TOTAL: 139 Bands
# teragram-ballroom // TOTAL: 119 Bands
# sankeys-ibiza //  TOTAL: 96 Bands
# the-cluny // TOTAL: 133 Bands
# coda // TOTAL: 118 Bands
# club-passim //  TOTAL: 92 Bands
# virginia-beach-amphitheater // TOTAL: 137 Bands
# verizon-wireless-arena // TOTAL: 119 Bands
# lg-arena-birmingham // TOTAL: 115 Bands
# corona-theatre // TOTAL: 143 Bands
# ovens-auditorium // TOTAL: 116 Bands
# agora-theatre // TOTAL: 133 Bands
# warung-beach-club // TOTAL: 105 Bands
# the-camel // TOTAL: 106 Bands
# pukkelpop // TOTAL: 136 Bands
# the-space // TOTAL: 122 Bands
# nokia-theatre-l-a-live // TOTAL: 122 Bands
# knuckleheads // TOTAL: 111 Bands
# the-district // TOTAL: 131 Bands
# charter-one-pavilion-at-northerly-island // TOTAL: 115 Bands
# britt-pavilion // TOTAL: 125 Bands
# cardiff-international-arena // TOTAL: 117 Bands
# mandela-hall // TOTAL: 126 Bands
# 4th-and-b // TOTAL: 129 Bands
# brown-alley // TOTAL: 128 Bands
# empire-control-room // TOTAL: 123 Bands
# walters // TOTAL: 112 Bands
# rod-laver-arena-at-melbourne-park //  TOTAL: 92 Bands
# the-media-club // TOTAL: 128 Bands
# the-glasgow-royal-concert-hall // TOTAL: 110 Bands
# mac-s-bar // TOTAL: 111 Bands
# southern-alberta-jubilee-auditorium // TOTAL: 103 Bands
# studio-80 // TOTAL: 109 Bands
# the-stephen-talkhouse //  TOTAL: 98 Bands
# times-union-center // TOTAL: 126 Bands
# tomorrowworld // TOTAL: 127 Bands
# floydfest //  TOTAL: 98 Bands
# arcada-theatre // TOTAL: 115 Bands
# docks // TOTAL: 123 Bands
# the-fillmore // TOTAL: 137 Bands
# baby-s-all-right // TOTAL: 118 Bands
# royal-festival-hall // TOTAL: 114 Bands
# big-sandy-superstore-arena // TOTAL: 112 Bands
# sziget-festival // TOTAL: 133 Bands
# jacobs-pavilion-at-nautica // TOTAL: 136 Bands
# time-warner-cable-arena // TOTAL: 134 Bands
# utah-state-fiarpark // TOTAL: 123 Bands
# pikes-peak-center // TOTAL: 124 Bands
# cambridge-corn-exchange // TOTAL: 115 Bands
# chene-park // TOTAL: 103 Bands
# la-tulipe // TOTAL: 116 Bands
# beauty-bar // TOTAL: 128 Bands
# northern-alberta-jubilee-auditorium // TOTAL: 103 Bands
# le-nouveau-casino // TOTAL: 137 Bands
# the-sound-academy // TOTAL: 133 Bands
# amsterdamse-bos // TOTAL: 101 Bands
# the-basement // TOTAL: 110 Bands
# stiefel-theatre // TOTAL: 129 Bands
# the-loft // TOTAL: 132 Bands
# opera // TOTAL: 104 Bands
# grand-sierra-resort-and-casino // TOTAL: 131 Bands
# motorpoint-arena-cardiff // TOTAL: 107 Bands
# meadowbrook-u-s-cellular-pavilion // TOTAL: 122 Bands
# white-riveramphitheatre // TOTAL: 119 Bands
# sleep-train-amphitheatre // TOTAL: 134 Bands
# patriot-center // TOTAL: 115 Bands
# jazz-standard //  TOTAL: 62 Bands
# fort-punta-christo //  TOTAL: 96 Bands
# islington-assembly-hall // TOTAL: 124 Bands
# ...
# independence-events-center //  TOTAL: 47 Bands
# kansas-county-fair //  TOTAL: 40 Bands
# mahalia-jackson-theater-for-the-performing-arts //  TOTAL: 47 Bands
# kampnagel //  TOTAL: 44 Bands
# barfly //  TOTAL: 44 Bands
# highfield-festival //  TOTAL: 44 Bands
# forum-karlin //  TOTAL: 48 Bands
# the-speedway-in-fontana //  TOTAL: 28 Bands
# club-202 //  TOTAL: 38 Bands
# dazzle-jazz //  TOTAL: 27 Bands
# lestat-s //  TOTAL: 32 Bands
# the-country-club //  TOTAL: 39 Bands
# largo //  TOTAL: 40 Bands
# revolution-room //  TOTAL: 40 Bands
# el-lokal //  TOTAL: 40 Bands
# the-workmans-club //  TOTAL: 41 Bands
# mezz //  TOTAL: 43 Bands
# tokyo-international-forum //  TOTAL: 32 Bands
# heritage-hall //  TOTAL: 35 Bands
# ohm-nightclub //  TOTAL: 34 Bands
# wakarusa-festival //  TOTAL: 38 Bands
# hyde-beach //  TOTAL: 40 Bands
# accorhotels-arena //  TOTAL: 42 Bands
# nighttown //  TOTAL: 35 Bands
# heinz-hall //  TOTAL: 31 Bands
# complex //  TOTAL: 49 Bands
# fox-theatre //  TOTAL: 43 Bands
# the-waiting-room-lounge //  TOTAL: 48 Bands
# mohegan-sun-arena-at-casey-plaza //  TOTAL: 44 Bands
# nurburgring //  TOTAL: 47 Bands
# evanston-space //  TOTAL: 44 Bands
# washington-county-fairgrounds //  TOTAL: 47 Bands
# heymann-performing-arts-center //  TOTAL: 46 Bands
# smirnoff-music-centre //  TOTAL: 50 Bands
# oprheum //  TOTAL: 46 Bands
# susquehanna-bank-center //  TOTAL: 47 Bands
# musikzentrum //  TOTAL: 43 Bands
# bardot //  TOTAL: 48 Bands
# the-knitting-factory //  TOTAL: 47 Bands
# the-grove //  TOTAL: 46 Bands
# karlstorbahnhof //  TOTAL: 46 Bands
# casino-rama-resort //  TOTAL: 38 Bands
# the-rivoli //  TOTAL: 47 Bands
# le-showcase //  TOTAL: 47 Bands
# way-out-west //  TOTAL: 49 Bands
# flow-festival //  TOTAL: 49 Bands
# von-braun-center //  TOTAL: 46 Bands
# big-four-building //  TOTAL: 46 Bands
# global-event-center-at-winstar-world-resorts //  TOTAL: 46 Bands
# elektricity-nightclub //  TOTAL: 47 Bands
# festival-place //  TOTAL: 44 Bands
# o2-guildhall-southampton //  TOTAL: 47 Bands
# festhalle-frankfurt //  TOTAL: 35 Bands
# zitadelle-spandau //  TOTAL: 45 Bands
# seven-steps-up //  TOTAL: 32 Bands
# palace-theater //  TOTAL: 42 Bands
# club-teatria //  TOTAL: 43 Bands
# hi-ho-lounge //  TOTAL: 42 Bands
# ulster-hall-belfast //  TOTAL: 44 Bands
# south-by-so-what //  TOTAL: 38 Bands
# frankfurter-hof //  TOTAL: 39 Bands
# savannah-music-festival //  TOTAL: 38 Bands
# rhythm-and-brews //  TOTAL: 38 Bands
# mur-mur //  TOTAL: 29 Bands
# blackpool-opera-house //  TOTAL: 30 Bands
# shaky-knees-festival //  TOTAL: 41 Bands
# the-peachtree-tavern //  TOTAL: 31 Bands
# john-f-kennedy-center-for-the-performing-arts //  TOTAL: 41 Bands
# bethesda-blues-jazz-supper-club //  TOTAL: 37 Bands
# zenith-de-lille //  TOTAL: 42 Bands
# lyric-theatre //  TOTAL: 41 Bands
# les-trinitaires //  TOTAL: 46 Bands
# discovery-ventura //  TOTAL: 41 Bands
# emerald-lounge //  TOTAL: 36 Bands
# curtis-m-phillips-center-for-performing-arts //  TOTAL: 40 Bands
# sluggos //  TOTAL: 41 Bands
# thirsty-hippo //  TOTAL: 33 Bands
# ushuaia-ibiza-beach-hotel //  TOTAL: 33 Bands
# new-parish //  TOTAL: 38 Bands
# michael-fowler-centre //  TOTAL: 38 Bands
# mokai //  TOTAL: 36 Bands
# the-bug-jar //  TOTAL: 39 Bands
# lambert-s //  TOTAL: 47 Bands
# club-regent-casino //  TOTAL: 39 Bands
# batschkapp-frankfurt //  TOTAL: 40 Bands
# metro-smart-bar //  TOTAL: 44 Bands
# st-augustin-amphitheatre //  TOTAL: 47 Bands
# holy-mountain //  TOTAL: 43 Bands
# raleigh-hotel //  TOTAL: 42 Bands
# the-belasco //  TOTAL: 46 Bands
# gaswerk //  TOTAL: 43 Bands
# zenith //  TOTAL: 46 Bands
# borgata-casino-event-center //  TOTAL: 42 Bands
# leeds-university-union //  TOTAL: 45 Bands
# red-fox-tavern //  TOTAL: 37 Bands
# club-rodeo //  TOTAL: 40 Bands
# voodoo-lounge //  TOTAL: 45 Bands
# the-pint //  TOTAL: 43 Bands
# pacha //  TOTAL: 33 Bands
# carnival-cruise-line-s-inspiration //  TOTAL: 19 Bands
# boettcher-concert-hall //  TOTAL: 34 Bands
# callahan-s //  TOTAL: 29 Bands
# fuel //  TOTAL: 39 Bands
# bull-run //  TOTAL: 38 Bands
# downsview-park-allen-road //  TOTAL: 31 Bands
# lunario-del-auditorio-nacional //  TOTAL: 36 Bands
# california-roots-festival //  TOTAL: 31 Bands
# the-brook //  TOTAL: 38 Bands
# stuart-s-opera-house //  TOTAL: 40 Bands
# manchester-ruby-lounge //  TOTAL: 42 Bands
# kresge-suditorium //  TOTAL: 42 Bands
# skylight //  TOTAL: 44 Bands
# alltel-arena //  TOTAL: 46 Bands
# moncton-coliseum //  TOTAL: 43 Bands
# avalon-theatre //  TOTAL: 41 Bands
# subculture-la //  TOTAL: 47 Bands
# rolling-stone //  TOTAL: 44 Bands
# univ-of-central-florida //  TOTAL: 44 Bands
# the-black-box //  TOTAL: 42 Bands
# imperial-du-quebec //  TOTAL: 47 Bands
# muziekgebouw-eindhoven //  TOTAL: 42 Bands
# closure //  TOTAL: 47 Bands
# fedex-forum //  TOTAL: 47 Bands
# bmo-centre //  TOTAL: 45 Bands
# artpark-mainstage //  TOTAL: 46 Bands
# tuxedo-junction //  TOTAL: 45 Bands
# lisner-auditorium //  TOTAL: 44 Bands
# the-paper-box //  TOTAL: 46 Bands
# crobar //  TOTAL: 45 Bands
# decadance //  TOTAL: 47 Bands
# la-machine //  TOTAL: 46 Bands
# the-surf-lodge //  TOTAL: 41 Bands
# lakota //  TOTAL: 43 Bands
# mandalay-bay-beach //  TOTAL: 43 Bands
# plea-for-peace-center //  TOTAL: 39 Bands
# goethebunker //  TOTAL: 41 Bands
# lifest //  TOTAL: 29 Bands
# dingbatz //  TOTAL: 37 Bands
# the-5-spot //  TOTAL: 33 Bands
# the-orpheum //  TOTAL: 42 Bands
# high-dive //  TOTAL: 43 Bands
# tba //  TOTAL: 42 Bands
# dixie-roadhouse //  TOTAL: 39 Bands
# down-home //  TOTAL: 31 Bands
# the-mousetrap //  TOTAL: 31 Bands
# wolf-creek-amphitheater //  TOTAL: 34 Bands
# citi-wang-theatre //  TOTAL: 40 Bands
# east-village //  TOTAL: 39 Bands
# the-blue-moose-tap-house //  TOTAL: 45 Bands
# altria-theater //  TOTAL: 40 Bands
# mahaffey-theater //  TOTAL: 45 Bands
# the-venue //  TOTAL: 42 Bands
# weetamix //  TOTAL: 35 Bands
# hardly-strictly-bluegrass //  TOTAL: 39 Bands
# sacramento-memorial-auditorium //  TOTAL: 41 Bands
# southampton-talking-heads //  TOTAL: 45 Bands
# wild-west //  TOTAL: 29 Bands
# blaines-pub //  TOTAL: 25 Bands
# rummelsburg //  TOTAL: 41 Bands
# ampere //  TOTAL: 46 Bands
# sporthalle-hamburg //  TOTAL: 45 Bands
# cable-london //  TOTAL: 41 Bands
# civic-underground //  TOTAL: 43 Bands
# luna-park //  TOTAL: 39 Bands
# coliseum //  TOTAL: 44 Bands
# baum //  TOTAL: 41 Bands
# faust //  TOTAL: 43 Bands
# osheaga //  TOTAL: 44 Bands
# jackpot-saloon //  TOTAL: 40 Bands
# ftc-stage-one //  TOTAL: 41 Bands
# brook //  TOTAL: 37 Bands
# intrigue-nightclub //  TOTAL: 22 Bands
# rockstar-pro-arena //  TOTAL: 40 Bands
# groove-cruise //  TOTAL: 37 Bands
# tip-top-deluxe-bar-grill //  TOTAL: 37 Bands
# rocks-off-concert-cruise-series //  TOTAL: 42 Bands
# paramount-theatre //  TOTAL: 38 Bands
# dosey-doe-music-cafe //  TOTAL: 38 Bands
# cross-club //  TOTAL: 39 Bands
# oc-fair-event-center //  TOTAL: 42 Bands
# the-rutledge //  TOTAL: 40 Bands
# de-pul //  TOTAL: 37 Bands
# escapade-music-festival //  TOTAL: 41 Bands
# tavastia-klubi //  TOTAL: 44 Bands
# theatre-lino-ventura //  TOTAL: 40 Bands
# van-wezel-performing-arts-hall //  TOTAL: 43 Bands
# hooligans-jacksonville //  TOTAL: 42 Bands
# heirloom-arts-theatre //  TOTAL: 41 Bands
# the-amphitheater-at-clark-county //  TOTAL: 46 Bands
# dickens-pub //  TOTAL: 43 Bands
# the-hog-wallow-pub //  TOTAL: 41 Bands
# soaring-eagle-casino-resort //  TOTAL: 47 Bands
# thalia-mara-hall //  TOTAL: 42 Bands
# oakland-metro-operahouse //  TOTAL: 45 Bands
# hardly-strictly-bluegrass-festival //  TOTAL: 45 Bands
# the-e-center-of-west-valley-city //  TOTAL: 43 Bands
# numbers //  TOTAL: 47 Bands
# fox-theatre-cafe //  TOTAL: 44 Bands
# black-oak-ranch //  TOTAL: 42 Bands
# kesselhaus //  TOTAL: 46 Bands
# perron //  TOTAL: 44 Bands
# cine-el-rey //  TOTAL: 47 Bands
# the-hi-fi //  TOTAL: 46 Bands
# geisha //  TOTAL: 44 Bands
# zenith-munich //  TOTAL: 47 Bands
# ocean-club //  TOTAL: 44 Bands
# fivesixty //  TOTAL: 45 Bands
# lifestyles-communities //  TOTAL: 47 Bands
# madison-theatre //  TOTAL: 45 Bands
# allegany-county-fairgrounds //  TOTAL: 32 Bands
# marvins-mountaintop //  TOTAL: 37 Bands
# tucson-music-hall //  TOTAL: 35 Bands
# lavo-new-york //  TOTAL: 34 Bands
# pour-house-the //  TOTAL: 40 Bands
# orpheum-theater //  TOTAL: 40 Bands
# scandinavium //  TOTAL: 40 Bands
# philharmonie-de-paris //  TOTAL: 40 Bands
# abbotsford-entertainment-and-sports-centre //  TOTAL: 40 Bands
# atwood-s-tavern //  TOTAL: 34 Bands
# cheese-and-grain //  TOTAL: 37 Bands
# the-music-factory //  TOTAL: 36 Bands
# treefort-music-fest //  TOTAL: 34 Bands
# daylight-beach-club //  TOTAL: 31 Bands
# drais-rooftop-beachclub //  TOTAL: 29 Bands
# olympiahalle-munchen //  TOTAL: 36 Bands
# outlook-festival //  TOTAL: 34 Bands
# concord-pavilion //  TOTAL: 41 Bands
# sangamon-auditorium //  TOTAL: 42 Bands
# mcaninch-arts-center-theatre-2 //  TOTAL: 35 Bands
# treasure-island-resort-casino //  TOTAL: 45 Bands
# stockton-arena //  TOTAL: 42 Bands
# uc-davis //  TOTAL: 41 Bands
# rosenhof //  TOTAL: 39 Bands
# omnia-nightclub //  TOTAL: 23 Bands
# gelredome //  TOTAL: 31 Bands
# grey-fox-bluegrass-festival //  TOTAL: 27 Bands
# isis-restaurant-music-hall //  TOTAL: 38 Bands
# garfield-artworks //  TOTAL: 40 Bands
# epicentre //  TOTAL: 43 Bands
# volt-festival //  TOTAL: 44 Bands
# digital //  TOTAL: 44 Bands
# guaba-beach-bar //  TOTAL: 35 Bands
# cn-centre //  TOTAL: 43 Bands
# sunset-station //  TOTAL: 43 Bands
# whiskey-a-go-go //  TOTAL: 43 Bands
# san-francisco-bath-house //  TOTAL: 43 Bands
# colosseum //  TOTAL: 42 Bands
# island-resort-casino //  TOTAL: 24 Bands
# spreckels-theatre //  TOTAL: 37 Bands
# electric-love-festival //  TOTAL: 39 Bands
# the-overture-center //  TOTAL: 43 Bands
# the-stanley //  TOTAL: 44 Bands
# hailey-s //  TOTAL: 41 Bands
# the-dame //  TOTAL: 39 Bands
# schroeder-hall //  TOTAL: 29 Bands
# whiskey-river //  TOTAL: 35 Bands
# paramount-theatre-washington //  TOTAL: 35 Bands
# teatro-metropolitan //  TOTAL: 28 Bands
# gatecrasher-birmingham //  TOTAL: 34 Bands
# egyptian-theatre //  TOTAL: 21 Bands
# cambridge-folk-festival //  TOTAL: 36 Bands
# tour-taxis-brussels //  TOTAL: 37 Bands
# the-champ //  TOTAL: 35 Bands
# uncle-slayton-s //  TOTAL: 35 Bands
# klubi //  TOTAL: 35 Bands
# neuraum //  TOTAL: 40 Bands
# ashkenaz //  TOTAL: 32 Bands
# des-moines-civic-center //  TOTAL: 30 Bands
# hill-s-cafe //  TOTAL: 28 Bands
# memorial-auditorium //  TOTAL: 36 Bands
# jupiter-bar-grill //  TOTAL: 35 Bands
# the-lizard-lounge //  TOTAL: 34 Bands
# wakarusa-festival //  TOTAL: 40 Bands
# southampton-joiners //  TOTAL: 40 Bands
# gatlinburg-convention-center //  TOTAL: 24 Bands
# wharf-amphitheatre //  TOTAL: 41 Bands
# 3s-artspace //  TOTAL: 43 Bands
# arena-riga //  TOTAL: 41 Bands
# so-36 //  TOTAL: 46 Bands
# whittier-narrows-recreation-area //  TOTAL: 35 Bands
# center-for-the-arts //  TOTAL: 41 Bands
# headwaters-park //  TOTAL: 43 Bands
# fyf-fest //  TOTAL: 43 Bands
# casino-regina-show-lounge //  TOTAL: 41 Bands
# kulturhaus-karlstorbahnhof //  TOTAL: 44 Bands
# pier-30-32 //  TOTAL: 43 Bands
# yaam //  TOTAL: 42 Bands
# burgerhaus-stollwerck //  TOTAL: 44 Bands
# southgate-house-revival //  TOTAL: 40 Bands
# district-square //  TOTAL: 44 Bands
# the-key-club //  TOTAL: 46 Bands
# amnesia-rockfest //  TOTAL: 39 Bands
# rock-cafe //  TOTAL: 45 Bands
# vinyl //  TOTAL: 46 Bands
# city-hall //  TOTAL: 45 Bands
# xponential-music-festival //  TOTAL: 39 Bands
# the-venue-at-the-hub //  TOTAL: 45 Bands
# crawdaddy //  TOTAL: 41 Bands
# social-hall-sf //  TOTAL: 45 Bands
# fiddler-s-green-amphitheater //  TOTAL: 43 Bands
# le-marche-gare //  TOTAL: 43 Bands
# o2-institute //  TOTAL: 45 Bands
# cal-coast-credit-union-open-air-theatre-at-sdsu //  TOTAL: 43 Bands
# becool //  TOTAL: 40 Bands
# yotaspace //  TOTAL: 42 Bands
# slakthuset //  TOTAL: 45 Bands
# loppen-christiania //  TOTAL: 43 Bands
# vetter-stone-amphitheater //  TOTAL: 43 Bands
# parkteatret //  TOTAL: 43 Bands
# la-grande-halle-de-la-villette //  TOTAL: 46 Bands
# tvornica-kulture //  TOTAL: 44 Bands
# teatro-cariola //  TOTAL: 46 Bands
# brotfabrik //  TOTAL: 43 Bands
# parq //  TOTAL: 33 Bands
# the-fat-cat-music-house-and-lounge //  TOTAL: 36 Bands
# crocus-city-hall //  TOTAL: 37 Bands
# le-poste-a-galene //  TOTAL: 38 Bands
# rev-room //  TOTAL: 40 Bands
# boone-saloon //  TOTAL: 30 Bands
# cinema-hall //  TOTAL: 33 Bands
# the-rockpile //  TOTAL: 34 Bands
# club-midi //  TOTAL: 31 Bands
# bootleg //  TOTAL: 38 Bands
# centennial-terrace //  TOTAL: 42 Bands
# key-west-theater //  TOTAL: 40 Bands
# factory-theatre //  TOTAL: 41 Bands
# enmax-centrium //  TOTAL: 39 Bands
# winstock-country-music-festival //  TOTAL: 41 Bands
# club-bahnhof-ehrenfeld //  TOTAL: 42 Bands
# the-woods-amphitheater-at-fontanel //  TOTAL: 43 Bands
# long-beach-arena //  TOTAL: 39 Bands
# forest-hills-stadium //  TOTAL: 38 Bands
# q-z-expo-center //  TOTAL: 36 Bands
# another-hole-in-the-wall //  TOTAL: 33 Bands
# le-dome //  TOTAL: 37 Bands
# the-stone-fox //  TOTAL: 36 Bands
# red-square //  TOTAL: 30 Bands
# cork-opera-house //  TOTAL: 38 Bands
# uptown-amphitheatre-at-nc-music-factory //  TOTAL: 44 Bands
# luna-park //  TOTAL: 39 Bands
# strathmore-music-center //  TOTAL: 42 Bands
# the-spot-underground //  TOTAL: 29 Bands
# green-frog-cafe-acoustic-tavern //  TOTAL: 34 Bands
# tachi-palace //  TOTAL: 43 Bands
# guvernment //  TOTAL: 41 Bands
# strand-theatre //  TOTAL: 41 Bands
# eatons-hill-hotel //  TOTAL: 43 Bands
# mcphillips-station-casino //  TOTAL: 33 Bands
# punk-rock-holiday //  TOTAL: 31 Bands
# blue-chip-casino //  TOTAL: 36 Bands
# the-studio-at-hamilton-place //  TOTAL: 38 Bands
# york-barbican-centre //  TOTAL: 41 Bands
# south-moe-s //  TOTAL: 34 Bands
# fat-cat //  TOTAL: 43 Bands
# the-summit //  TOTAL: 40 Bands
# pennysaver-amphitheater //  TOTAL: 40 Bands
# simon-s-677 //  TOTAL: 42 Bands
# rockstore //  TOTAL: 43 Bands
# the-jefferson-theater //  TOTAL: 38 Bands
# northern-quest-resort-casino //  TOTAL: 44 Bands
# levitt-shell //  TOTAL: 39 Bands
# zero-gravity //  TOTAL: 40 Bands
# suma-beach //  TOTAL: 37 Bands
# ikarus-festival //  TOTAL: 26 Bands
# a-club //  TOTAL: 41 Bands
# the-graduate //  TOTAL: 42 Bands
# earl-w-brydges-artpark //  TOTAL: 41 Bands
# tsongas-arena //  TOTAL: 41 Bands
# never-say-never-festival //  TOTAL: 37 Bands
# kulttuuritalo //  TOTAL: 42 Bands
# littlejohn-coliseum //  TOTAL: 41 Bands
# handelsbeurs //  TOTAL: 41 Bands
# viejas-arena //  TOTAL: 41 Bands
# appalachian-brewing-company //  TOTAL: 35 Bands
# kimo-theatre //  TOTAL: 35 Bands
# papp-laszlo-budapest-sportarena //  TOTAL: 34 Bands
# epic-studios //  TOTAL: 37 Bands
# atwood-concert-hall //  TOTAL: 35 Bands
# burdekin-hotel //  TOTAL: 41 Bands
# rockin-rodeo //  TOTAL: 22 Bands
# ymca-hq //  TOTAL: 32 Bands
# la-sucriere //  TOTAL: 31 Bands
# the-high-ground //  TOTAL: 33 Bands
# cafe-611 //  TOTAL: 35 Bands
# wonder-bar //  TOTAL: 36 Bands
# musicfest //  TOTAL: 22 Bands
# zenith-de-dijon //  TOTAL: 34 Bands
# rocksound //  TOTAL: 39 Bands
# ocean-city-music-pier //  TOTAL: 36 Bands
# wally-s-pub //  TOTAL: 36 Bands
# peace-center //  TOTAL: 38 Bands
# gilley-s-dallas //  TOTAL: 30 Bands
# namba-hatch //  TOTAL: 40 Bands
# the-abbey-bar //  TOTAL: 37 Bands
# the-garage //  TOTAL: 31 Bands
# mayo-park //  TOTAL: 41 Bands
# invesco-field-at-mile-high //  TOTAL: 44 Bands
# lake-superior-big-top-chautauqua //  TOTAL: 38 Bands
# sebright-arms //  TOTAL: 44 Bands
# best-buy-theatre //  TOTAL: 43 Bands
# the-pool-at-talking-stick-resort //  TOTAL: 43 Bands
# maimarkthalle //  TOTAL: 44 Bands
# club-infinity //  TOTAL: 43 Bands
# pfingstweide //  TOTAL: 41 Bands
# garde-arts-center //  TOTAL: 41 Bands
# the-metal-grill //  TOTAL: 37 Bands
# merleyn //  TOTAL: 43 Bands
# ulster-performing-arts-center //  TOTAL: 43 Bands
# electric-forest-2015 //  TOTAL: 44 Bands
# fort-lewis-college //  TOTAL: 41 Bands
# pinkpop-festival //  TOTAL: 42 Bands
# bierkeller //  TOTAL: 43 Bands
# the-eagle-theater //  TOTAL: 42 Bands
# emos-sxsw-artery-foundation-showcase //  TOTAL: 46 Bands
# feierwerk-hansa-39 //  TOTAL: 42 Bands
# kaserne //  TOTAL: 44 Bands
# lebreton-fls-park //  TOTAL: 42 Bands
# o2-academy-2 //  TOTAL: 43 Bands
# tupelo-music-hall-vermont //  TOTAL: 36 Bands
# the-showgrounds-at-sam-houston-race-park //  TOTAL: 39 Bands
# sky-slc //  TOTAL: 44 Bands
# melna-piektdiena //  TOTAL: 39 Bands
# constellation-brands-performing-arts-center //  TOTAL: 43 Bands
# rock-en-seine //  TOTAL: 43 Bands
# rebel //  TOTAL: 43 Bands
# champlain-valley-exposition //  TOTAL: 45 Bands
# piedmont-park //  TOTAL: 38 Bands
# mahaiwe-performing-arts-center //  TOTAL: 40 Bands
# tequila-jungle //  TOTAL: 39 Bands
# motion-bristol //  TOTAL: 46 Bands

# %%
title="global venue graph /BETA 0.85"

while True:
        try:
            #print nodestopo
            create_topogram(title, nodestopo, edgestopo)
        
        except TypeError:
            continue
        break
# Out:
# ERROR:topogram-client:500 - Error : A topogram with the same name already exists
# Creating topogram 'global venue graph /BETA 0.85'
# {u'status': u'success', 'status_code': 200, u'data': u'xCuk6sQi3hLjkQc4m', u'statusCode': 201}
# Creating topogram 'global venue graph /BETA 0.85'
# > Topogram already exists
# {u'status': u'success', 'status_code': 200, u'data': {u'sharedPublic': False, u'title': u'global venue graph /BETA 0.85', u'userId': u'Bf5svhLniEkkcvts2', u'_id': u'xCuk6sQi3hLjkQc4m', u'slug': u'global-venue-graph-beta-085', u'createdAt': u'2019-09-24T09:12:11.199Z'}, u'statusCode': 200}
# topogram ID : xCuk6sQi3hLjkQc4m
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-78-1877ab598127> in <module>()
#       5         try:
#       6             #print nodestopo
# ----> 7             create_topogram(title, nodestopo, edgestopo)
#       8
#       9         except TypeError:
#
# <ipython-input-3-09bf76edf12d> in create_topogram(title, nodes, edges)
#      24         print "%s edges deleted"%len(existing_edges)
#      25
# ---> 26     r = topogram.create_nodes(topogram_ID, nodes)
#      27     #print r
#      28     print "%s nodes created."%len(r["data"])
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/topogram_api_client-1.0.1-py2.7.egg/topogram_client/__init__.pyc in create_nodes(self, topogramId, nodes)
#     146         """POST Create a bunch of nodes. Returns the created nodes"""
#     147         assert type(nodes) is list
# --> 148         return self.make_request("POST", "nodes", { "topogramId" : topogramId, "nodes" : nodes})
#     149
#     150     def get_node(self, _id):
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/topogram_api_client-1.0.1-py2.7.egg/topogram_client/__init__.pyc in make_request(self, method, path, data)
#      42
#      43         if method == "POST":
# ---> 44             r = self.session.post(req_url, json=data)
#      45         elif method == "DELETE":
#      46             r = self.session.delete(req_url, json=data)
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/requests/sessions.pyc in post(self, url, data, json, **kwargs)
#     579         """
#     580
# --> 581         return self.request('POST', url, data=data, json=json, **kwargs)
#     582
#     583     def put(self, url, data=None, **kwargs):
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /home/goonieb/gitrep/bandstour/venv/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', BadStatusLine('No status line received - the server has closed the connection',))
