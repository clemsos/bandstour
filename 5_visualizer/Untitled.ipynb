# %%
# coding: utf8
Liste_GZ=[]
import re
file = open("TITLES.TXT",'r')
text=file.readlines()
for a in text :
    ligne= a.strip("\nnn").strip('\"')
    print ligne
    c= re.findall(r'(?<=:).*',ligne)#,re.MULTILINE| re.DOTALL | re.LOCALE )
    print c
    #print len(c)
    if len(c)>0:
        print len(c[0]) 
        if len(c[0]) >= 3 :
            d= re.split("\+|/|,|avec", c[0])
            #print d
            for lem in d:
                if "@" in lem:
                    lem2=lem.split("@")[0]
                else:
                    lem2=lem
                #print lem2
                Liste_GZ.append(lem2)
print Liste_GZ
# Out:
# Joomla! License Guidelines
# []
# Jeudi 22 février 2007 : DUB addict
# [' DUB addict ']
# 12
# Marnie Stern
# []
# Vendredi 23 fev : BRK PARTY avec Donna Summer
# [' BRK PARTY avec Donna Summer']
# 28
# François Virot Superstar
# []
# PARTICIPE !
# []
# C'est vraiment n'importe quoi
# []
# Animal Collective - Video Malta Festival + Infos diverses
# []
# Samedi 17 février à partir de 19 H : Lancement de Mercure Liquide 5
# [' Lancement de Mercure Liquide 5']
# 31
# Alors ce blog interne?
# []
# Alors ce blog interne?...re:
# ['']
# 0
# Site Grnd Zero
# []
# 16 mars, DIARRHING 'NFECT PARTY 2@GZ Vaise,7?:Patrick Catani+Rotator +Aktiv25+Guest
# ['Patrick Catani+Rotator +Aktiv25+Guest']
# 37
# L'OCELLE MARE + BREEZY DAY BAND + Projections...   Dimanche 4 Mars / GRRRND GERLAND
# []
# SYNTHAX ERROR's BOOTYCORE PARTY:Otto Von Schirach Jeudi 5 Avril@GZ Vaise
# ['Otto Von Schirach Jeudi 5 Avril@GZ Vaise']
# 40
# ...
